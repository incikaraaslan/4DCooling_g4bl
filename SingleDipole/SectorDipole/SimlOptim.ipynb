# %% [markdown]
# This notebook demonstrates the full optimization process for the first wedge and the dispersion suppressor.
#
# Updated: 1/10/2026

# %% [markdown]
# # Setup

# %%
from scan import *
from g4beam import *
import math
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import cm
import numpy as np
import pandas as pd
from tqdm import *
import pickle
import itertools
from tabulate import tabulate
from scipy.optimize import differential_evolution
import re

# %%
# Make Sure g4bl is here
import os
os.environ["PATH"] += os.pathsep + "/home/incik/G4beamline-3.08/bin"
import shutil
print(shutil.which("g4bl"))
# Out:
# /home/incik/G4beamline-3.08/bin/g4bl

# %%
import scan, sys
print("scan imported from:", scan.__file__)
print("cwd:", os.getcwd())
print("sys.path[0]:", sys.path[0])
# Out:
# scan imported from: /home/incik/Cooling_4D/SingleDipole/SectorDipole/scan.py
# cwd: /home/incik/Cooling_4D/SingleDipole/SectorDipole
# sys.path[0]: /home/incik/miniconda3/lib/python312.zip

# %% [markdown]
# # Initial distribution
#
# The parameters of the initial beam are treated as constants, but some things are known about their effects:
# - **Transverse emittance**: Should be as low as possible. For this test we use an "optimistic" value of 110 microns.
# - **Momentum**: Decreasing this appears to slightly decreases x-emittance.
# - **Beta**: Decreasing this decreases the y-emittance growth. There may also be an optimal value for x-emittance.
# - **Alpha**: Increasing this decreases the y-emittance growth, but past a certain point increases the x-emittance. I believe 0.7 focuses the beam onto the wedge center with a VD distance of 24 mm.
# - **Longitudinal emittance**: Effects not yet tested.
# - **Standard deviation of momentum**: Decreasing this decreases the x-emittance.
# - **Virtual detector distance**: Almost irrelevant. Should be more than 3x the length of the wedge to ensure accurate measurements.

# %%
t_emit = 0.145  # mm
momentum = 100  # MeV/c
beta = 0.03    # m
alpha = 0.7     # dimensionless
l_emit = 1      # mm
pz_std = 1    # MeV/c
vd_dist = 24    # mm

pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=20000)
pre_w1["PDGid"] = -13
print_all_params(pre_w1)
# Out:
# -----------------------------
# Twiss parameters for X
# emit  = 0.1437818076096742 mm
# beta  = 0.030466185499465576 m
# gamma = 49.42428416892225 1/m
# alpha = 0.7111746688885124
# D     = 0.0011592366415986452 m
# D'    = 0.004371312588090461
#
# Twiss parameters for Y
# emit  = 0.14640352256936354 mm
# beta  = 0.029696597817312737 m
# gamma = 49.90216389720526 1/m
# alpha = 0.6942078157647955
# D     = -0.0012705723953541235 m
# D'    = 0.10161517461138649
#
# Z-emittance:  1.2683550856598909 mm
# Z std: 155.17737989612047 mm
# p std: 0.9995868998024885 MeV/c
# Mean momentum: 99.9970964137528 MeV/c
# -----------------------------

# %%
write_trackfile(pre_w1, "particles_before.txt")

# %% [markdown]
# # First wedge
#
# Determines the optimal length and angle for the first wedge

# %%
# Function to optimize
def func(x):
    length, angle = x
    return emittances(cut_outliers(run_distribution(pre_w1, length, angle, vd_dist, axis=0)))[0]

start = time.time()
# Run optimization
optim_result = minimize(func, [7.5, 45], method="Nelder-Mead", bounds=((1, 10), (30, 70)), options=dict(fatol=1e-6))

# Get results
w1_length, w1_angle = optim_result.x
print(f"Length = {w1_length:.2f} mm\nAngle = {w1_angle:.1f} deg")
print("Time spent:", time.time()-start)

# Runs a single case with the optimal parameters
post_w1 = run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0)
print_all_params(post_w1)
print_all_params(cut_outliers(post_w1))
# Out:
# iter value
#   38 4.15142e-02
# Length = 7.08 mm
# Angle = 46.6 deg
# Time spent: 1527.3936853408813
# -----------------------------
# Twiss parameters for X
# emit  = 0.047207960936941754 mm
# beta  = 0.03424562320506673 m
# gamma = 182.22719296265785 1/m
# alpha = -2.2892102978791984
# D     = 0.020259671582158148 m
# D'    = -0.054812242262435806
#
# Twiss parameters for Y
# emit  = 0.15226941811314 mm
# beta  = 0.025709103419800244 m
# gamma = 58.027407376953114 1/m
# alpha = -0.7013077908001359
# D     = 1.2376937410517047e-05 m
# D'    = 9.904373978701053e-05
#
# Z-emittance:  6.375086983123856 mm
# Z std: 144.1011663648315 mm
# p std: 7.084454514904594 MeV/c
# Mean momentum: 87.96295688431366 MeV/c
# -----------------------------
# -----------------------------
# Twiss parameters for X
# emit  = 0.041514197043219354 mm
# beta  = 0.03596166713431226 m
# gamma = 198.75865863489165 1/m
# alpha = -2.479454117722361
# D     = 0.02036564646604793 m
# D'    = -0.07356663607034661
#
# Twiss parameters for Y
# emit  = 0.14946134916796483 mm
# beta  = 0.025559255071961485 m
# gamma = 57.41689941668722 1/m
# alpha = -0.6837639780160002
# D     = 5.198580365907328e-06 m
# D'    = 0.0017565780461129997
#
# Z-emittance:  6.177383099655468 mm
# Z std: 144.17241700477535 mm
# p std: 6.935578506607218 MeV/c
# Mean momentum: 88.0327985602007 MeV/c
# -----------------------------

# %%
post_w1 = run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0)
print_all_params(post_w1)
print_all_params(cut_outliers(post_w1))
# Out:
# -----------------------------
# Twiss parameters for X
# emit  = 0.047207960936941754 mm
# beta  = 0.03424562320506673 m
# gamma = 182.22719296265785 1/m
# alpha = -2.2892102978791984
# D     = 0.020259671582158148 m
# D'    = -0.054812242262435806
#
# Twiss parameters for Y
# emit  = 0.15226941811314 mm
# beta  = 0.025709103419800244 m
# gamma = 58.027407376953114 1/m
# alpha = -0.7013077908001359
# D     = 1.2376937410517047e-05 m
# D'    = 9.904373978701053e-05
#
# Z-emittance:  6.375086983123856 mm
# Z std: 144.1011663648315 mm
# p std: 7.084454514904594 MeV/c
# Mean momentum: 87.96295688431366 MeV/c
# -----------------------------
# -----------------------------
# Twiss parameters for X
# emit  = 0.041514197043219354 mm
# beta  = 0.03596166713431226 m
# gamma = 198.75865863489165 1/m
# alpha = -2.479454117722361
# D     = 0.02036564646604793 m
# D'    = -0.07356663607034661
#
# Twiss parameters for Y
# emit  = 0.14946134916796483 mm
# beta  = 0.025559255071961485 m
# gamma = 57.41689941668722 1/m
# alpha = -0.6837639780160002
# D     = 5.198580365907328e-06 m
# D'    = 0.0017565780461129997
#
# Z-emittance:  6.177383099655468 mm
# Z std: 144.17241700477535 mm
# p std: 6.935578506607218 MeV/c
# Mean momentum: 88.0327985602007 MeV/c
# -----------------------------

# %%
# Optimized G4_FinalCooling_auto.g4bl parameters
offset = w1_length / (math.tan(w1_angle * math.pi / 180) * 2)
base_length = 2*offset
abswidth = 100
parameters = dict(
        abshalfangle3=str(w1_angle),
        absoffset3=str(offset),
        abshgt=str(offset * base_length / w1_length + 0.1),
        absLEN3=str(base_length)
    )
L_centerline = float(parameters['absLEN3']) + 1
print("Where to put the next element: " + str(L_centerline) + "mm")
# Out:
# Where to put the next element: 7.690390679091528mm

# %%
L_centerline_orig = (abswidth/2)/np.abs(math.tan(w1_angle)) + base_length
print("Where to not put the next element: " + str(L_centerline_orig) + "mm")
# Out:
# Where to not put the next element: 100.47293749992126mm

# %%
# Write the wedge output into a file
write_trackfile(post_w1, "particles_after.txt")

# %%
# If particles_after isn't updated with Z = 0.
def convertZ(input_file, output_file, set_to=0):
    event_id_counter = 1
    with open(input_file, "r") as infile, open(output_file, "w") as outfile:
        for line in infile:
            # Skip header lines (those starting with #)
            if line.strip().startswith("#"):
                outfile.write(line)
                continue

            # Split the line into columns
            parts = line.strip().split()
            if len(parts) >= 12:
                parts[2] = str(set_to)  # Set the 3rd column (z) to 0
                # Replace event ID (assuming it's the 9th column, zero-based index 8)
                # Adjust if your event ID is in a different column
                parts[8] = str(event_id_counter)
                event_id_counter += 1
                new_line = " ".join(parts)
                outfile.write(new_line + "\n")
            else:
                # Handle lines that don't match expected format
                outfile.write(line)
    print(f"Updated file saved as '{output_file}'")
    os.remove(input_file)
    return None

# %%
convertZ("particles_after.txt", "particles_afterupt.txt", set_to=0.0)
# Out:
# Updated file saved as 'particles_afterupt.txt'

# %% [markdown]
# # Dispersion correction optimization
#
# The main goal is to have $D_x \approx 0$ up to 1e-5 m while keeping $\beta_x$ relatively periodic and about at the same value.

# %%
# Write values to the prepared G4BL template
def write_input_from_template(template_path, replacements, out_path):
    with open(template_path, 'r') as f:
        txt = f.read()
    try:
        txt = txt.format(**replacements)
    except KeyError as e:
        raise RuntimeError(f"Template substitution failed; missing placeholder: {e}")
    with open(out_path, 'w') as f:
        f.write(txt)

# %%
x0_params, y0_params, _ = calc_all_params(post_w1)
beta_x_ref= x0_params[1]; beta_y_ref= y0_params[1]
print(r"$\beta_x$: " + str(beta_x_ref), r"$\beta_y$: " + str(beta_y_ref))
print("D_x: " + str(x0_params[4]), "D_y: " + str(y0_params[4]))
# Out:
# $\beta_x$: 0.03424562320506673 $\beta_y$: 0.025709103419800244
# D_x: 0.020259671582158148 D_y: 1.2376937410517047e-05

# %%
def check_dipole_clearance(df, B_val, B_radius, B_angle, B_thickness):
    """
    Check which particles clear the dipole aperture based on their Larmor radius
    and deflection geometry.

    Parameters:
      df : pandas.DataFrame with columns ['Px','Py','Pz'] in MeV/c
      B_val : magnetic field (Tesla)
      dipole_length_mm : dipole magnet effective length (mm)
      dipole_halfwidth_mm : half-width of dipole aperture (mm)

    Returns:
      surviving_mask : boolean array, True if particle clears aperture
      r_L_mm : array of Larmor radii (mm)
      delta_r_mm : array of deflections (mm)
    """
    dipole_length_mm = 2 * B_radius * math.sin(B_angle * math.pi/360)
    dipole_halfwidth_mm = B_thickness
    # constants
    e = 1.602176634e-19  # C
    c = 2.99792458e8     # m/s

    # convert MeV/c to SI (kg·m/s)
    mom_perp = np.sqrt(df["Px"]**2 + df["Pz"]**2) * 1e6 * e / c  # B assumed along y

    # Larmor radius [m]
    r_L = mom_perp / (e * np.abs(B_val))

    # convert to mm
    r_L_mm = r_L * 1e3
    s_mm = dipole_length_mm

    # deflection Δr = r * (1 - cos(φ)), φ = s / r
    phi = s_mm / r_L_mm
    delta_r_mm = r_L_mm * (1 - np.cos(phi))

    # check if deflection < half-width
    surviving_mask = delta_r_mm < dipole_halfwidth_mm
    

    return surviving_mask, r_L_mm, delta_r_mm

# %%
def run_dipole(df, B_field, B_angle, B_radius, B_z=0, B_thickness=50, B_height=100):
    if os.path.exists("field_cellB.dat"):
        os.remove("field_cellB.dat")
    """Run dipole simulation with given parameters."""
    params = {
        "B1_field": B_field,
        "B1_angle": B_angle,
        "B1_radius": B_radius,
        "B1_z": B_z,
        "B1_z_end": B_z + 2 * (B_radius * B_angle * math.pi/360)+0.1,
        "B1_x_end": B_z - B_thickness * math.sin(B_angle * math.pi/360),
        "B1_thickness": B_thickness,
        "B1_height": B_height,
    }
    
    write_input_from_template("G4_FinalCooling_dispsup_B.g4bl", params, "G4_FinalCooling_dispsup_B_run.g4bl")
    # Run G4Beamline
    df_out = run_g4beam(df, "G4_FinalCooling_dispsup_B_run.g4bl")

    return df_out

# %%
def optimize_dipole(x, df_in, beta_x_ref, beta_y_ref, 
                    w_disp=1000.0, w_beta=10.0, w_clear=100.0, 
                    D_tol=1e-3, survival_threshold=0.95):
    """
    Optimize dipole parameters using G4Beamline simulations.

    Parameters
    ----------
    x : array-like
        Dipole parameters: [B_field, B_angle_deg, B_radius]
    df_in : pandas.DataFrame
        Input particle distribution
    beta_x_ref, beta_y_ref : float
        Target beta functions
    w_disp, w_beta : float
        Weights for cost function
    survival_threshold : float
        Minimum fraction of particles that must survive

    Returns
    -------
    float
        Objective function value (smaller is better)
    """
    # Unpack parameters
    B_field, B_angle, B_radius = x
    B_thickness = 50.0
    B_height = 100.0

    # Run dipole simulation
    result = run_dipole(df_in, B_field, B_angle, B_radius)
    if result is None or len(result) == 0:
        # no particles survived, penalize heavily
        return 1e6

    mask, r_L_mm, delta_r_mm = check_dipole_clearance(df_in, B_field, B_radius, B_angle, B_thickness)
    mask = mask[:len(result)]  # truncate if needed
    if len(result) == 0:
        survival_frac = 0.0
    else:
        if isinstance(result, np.ndarray):
            df_survived = result[mask]
        else:
            df_survived = result[mask.values]
        survival_frac = len(df_survived) / 2000 #len(df_in)

    if survival_frac < survival_threshold:
        return 1e6 + 1e3*(survival_threshold - survival_frac)


    # Compute dispersion & beta from survived particles
    df_survived = result[mask] if isinstance(result, np.ndarray) else result[mask.values]
    x_params_d, y_params_d, _ = calc_all_params(df_survived)
    Dx, beta_x = x_params_d[4], x_params_d[1]
    Dy, beta_y = y_params_d[4], y_params_d[1]

    # Penalties
    disp_penalty = ((Dx - 0)/D_tol)**2  # target dispersion = 0 at end
    beta_penalty = ((beta_x - beta_x_ref)/beta_x_ref)**2 + ((beta_y - beta_y_ref)/beta_y_ref)**2

    # Total objective function
    val = w_disp * disp_penalty + w_beta * beta_penalty

    print(f"Objective = {val:.3f}, Survival = {survival_frac:.3f}, Dx = {Dx:.3f}, beta_x = {beta_x:.3f}, beta_y = {beta_y:.3f}")
    return val

# %%
start = time.time()
# Run optimization
optim_result = minimize(optimize_dipole, [1.5, 2.0, 1000.0], args=(post_w1, beta_x_ref, beta_y_ref), method="Nelder-Mead", bounds=((0.1, 3.0), (1.0, 10.0), (100.0, 2000.0)), options=dict(fatol=1e-6))

# Get results
B_field, B_angle, B_radius = optim_result.x
print(f"Field = {B_field:.2f} T \nAngle = {B_angle:.2f} deg\nRadius = {B_radius:.1f} mm")
print("Time spent:", time.time()-start)
# Out:
# iter value
# Objective = 515740.847, Survival = 1.000, Dx = 0.023, beta_x = 0.437, beta_y = 0.147
# Objective = 525842.278, Survival = 1.000, Dx = 0.023, beta_x = 0.437, beta_y = 0.147
# Objective = 532281.880, Survival = 1.000, Dx = 0.023, beta_x = 0.468, beta_y = 0.157
# Objective = 531535.330, Survival = 1.000, Dx = 0.023, beta_x = 0.468, beta_y = 0.157
# Objective = 516005.416, Survival = 1.000, Dx = 0.023, beta_x = 0.426, beta_y = 0.144
# Objective = 507675.296, Survival = 1.000, Dx = 0.023, beta_x = 0.402, beta_y = 0.136
# Objective = 496725.349, Survival = 1.000, Dx = 0.022, beta_x = 0.371, beta_y = 0.126
# Objective = 494921.524, Survival = 1.000, Dx = 0.022, beta_x = 0.386, beta_y = 0.130
# Objective = 481970.174, Survival = 1.000, Dx = 0.022, beta_x = 0.361, beta_y = 0.123
# Objective = 481205.825, Survival = 1.000, Dx = 0.022, beta_x = 0.353, beta_y = 0.120
# Objective = 466743.395, Survival = 1.000, Dx = 0.022, beta_x = 0.319, beta_y = 0.109
# Objective = 455534.142, Survival = 1.000, Dx = 0.021, beta_x = 0.277, beta_y = 0.097
# Objective = 436662.450, Survival = 1.000, Dx = 0.021, beta_x = 0.217, beta_y = 0.079
# Objective = 435282.219, Survival = 1.000, Dx = 0.021, beta_x = 0.231, beta_y = 0.083
# Objective = 420008.099, Survival = 1.000, Dx = 0.020, beta_x = 0.180, beta_y = 0.068
# Objective = 414837.511, Survival = 1.000, Dx = 0.020, beta_x = 0.142, beta_y = 0.057
# Objective = 407600.424, Survival = 1.000, Dx = 0.020, beta_x = 0.082, beta_y = 0.039
# Objective = 407240.229, Survival = 1.000, Dx = 0.020, beta_x = 0.070, beta_y = 0.036
# Objective = 410403.554, Survival = 1.000, Dx = 0.020, beta_x = 0.044, beta_y = 0.028
# Objective = 409937.561, Survival = 1.000, Dx = 0.020, beta_x = 0.046, beta_y = 0.029
# Objective = 410415.286, Survival = 1.000, Dx = 0.020, beta_x = 0.044, beta_y = 0.028
# Objective = 410325.454, Survival = 1.000, Dx = 0.020, beta_x = 0.045, beta_y = 0.028
# Objective = 407360.478, Survival = 1.000, Dx = 0.020, beta_x = 0.094, beta_y = 0.042
# Objective = 416753.949, Survival = 1.000, Dx = 0.020, beta_x = 0.143, beta_y = 0.057
# Objective = 407684.380, Survival = 1.000, Dx = 0.020, beta_x = 0.061, beta_y = 0.033
# Objective = 409793.625, Survival = 1.000, Dx = 0.020, beta_x = 0.108, beta_y = 0.047
# Objective = 407175.596, Survival = 1.000, Dx = 0.020, beta_x = 0.071, beta_y = 0.036
# Objective = 406742.632, Survival = 1.000, Dx = 0.020, beta_x = 0.072, beta_y = 0.036
# Objective = 406534.919, Survival = 1.000, Dx = 0.020, beta_x = 0.072, beta_y = 0.036
# Objective = 407846.870, Survival = 1.000, Dx = 0.020, beta_x = 0.059, beta_y = 0.032
# Objective = 406915.623, Survival = 1.000, Dx = 0.020, beta_x = 0.081, beta_y = 0.039
# Objective = 406336.764, Survival = 1.000, Dx = 0.020, beta_x = 0.080, beta_y = 0.038
# Objective = 405777.492, Survival = 1.000, Dx = 0.020, beta_x = 0.086, beta_y = 0.040
# Objective = 405576.760, Survival = 1.000, Dx = 0.020, beta_x = 0.088, beta_y = 0.041
# Objective = 404637.151, Survival = 1.000, Dx = 0.020, beta_x = 0.095, beta_y = 0.043
# Objective = 404296.691, Survival = 1.000, Dx = 0.020, beta_x = 0.087, beta_y = 0.041
# Objective = 402572.479, Survival = 1.000, Dx = 0.020, beta_x = 0.096, beta_y = 0.043
# Objective = 400860.630, Survival = 1.000, Dx = 0.020, beta_x = 0.121, beta_y = 0.050
# Objective = 394261.868, Survival = 1.000, Dx = 0.020, beta_x = 0.157, beta_y = 0.061
# Objective = 394047.307, Survival = 1.000, Dx = 0.020, beta_x = 0.139, beta_y = 0.055
# Objective = 381672.463, Survival = 1.000, Dx = 0.020, beta_x = 0.180, beta_y = 0.067
# Objective = 378203.949, Survival = 1.000, Dx = 0.019, beta_x = 0.208, beta_y = 0.075
# Objective = 369078.471, Survival = 1.000, Dx = 0.019, beta_x = 0.293, beta_y = 0.100
# Objective = 360016.502, Survival = 1.000, Dx = 0.019, beta_x = 0.405, beta_y = 0.134
# Objective = 344369.438, Survival = 1.000, Dx = 0.018, beta_x = 0.723, beta_y = 0.230
# Objective = 349269.770, Survival = 1.000, Dx = 0.019, beta_x = 0.587, beta_y = 0.189
# Objective = 339172.048, Survival = 1.000, Dx = 0.018, beta_x = 0.930, beta_y = 0.295
# Objective = 336647.887, Survival = 1.000, Dx = 0.018, beta_x = 1.230, beta_y = 0.391
# Objective = 336785.941, Survival = 1.000, Dx = 0.018, beta_x = 1.166, beta_y = 0.370
# Objective = 310760.665, Survival = 1.000, Dx = 0.017, beta_x = 1.516, beta_y = 0.486
# Objective = 310281.698, Survival = 0.999, Dx = 0.016, beta_x = 2.106, beta_y = 0.668
# Objective = 321594.570, Survival = 0.999, Dx = 0.016, beta_x = 2.502, beta_y = 0.807
# Objective = 333797.720, Survival = 0.998, Dx = 0.016, beta_x = 2.735, beta_y = 0.894
# Objective = 279472.822, Survival = 0.990, Dx = 0.012, beta_x = 3.631, beta_y = 1.249
# Objective = 248792.336, Survival = 0.966, Dx = 0.005, beta_x = 4.657, beta_y = 1.728
# Objective = 272279.300, Survival = 0.990, Dx = 0.012, beta_x = 3.550, beta_y = 1.215
# Objective = 224137.638, Survival = 0.977, Dx = 0.007, beta_x = 4.102, beta_y = 1.473
# Objective = 220438.831, Survival = 0.965, Dx = 0.005, beta_x = 4.304, beta_y = 1.643
# Objective = 281835.559, Survival = 0.993, Dx = 0.013, beta_x = 3.280, beta_y = 1.108
# Objective = 244969.790, Survival = 0.985, Dx = 0.010, beta_x = 3.825, beta_y = 1.348
# Objective = 229227.843, Survival = 0.981, Dx = 0.008, beta_x = 4.024, beta_y = 1.424
# Objective = 235541.575, Survival = 0.986, Dx = 0.010, beta_x = 3.619, beta_y = 1.291
# Objective = 221636.366, Survival = 0.973, Dx = 0.007, beta_x = 4.089, beta_y = 1.526
# Objective = 215946.301, Survival = 0.979, Dx = 0.008, beta_x = 3.939, beta_y = 1.421
# Objective = 196760.354, Survival = 0.975, Dx = 0.007, beta_x = 3.682, beta_y = 1.412
# Objective = 201296.076, Survival = 0.987, Dx = 0.011, beta_x = 2.783, beta_y = 1.077
# Objective = 204899.398, Survival = 0.972, Dx = 0.006, beta_x = 4.044, beta_y = 1.525
# Objective = 198451.749, Survival = 0.982, Dx = 0.008, beta_x = 3.590, beta_y = 1.335
# Objective = 178572.041, Survival = 0.982, Dx = 0.009, beta_x = 3.173, beta_y = 1.223
# Objective = 263680.103, Survival = 0.995, Dx = 0.015, beta_x = 2.224, beta_y = 0.853
# Objective = 203298.443, Survival = 0.988, Dx = 0.011, beta_x = 2.807, beta_y = 1.073
# Objective = 191839.437, Survival = 0.983, Dx = 0.009, beta_x = 3.197, beta_y = 1.216
# Objective = 193192.010, Survival = 0.984, Dx = 0.010, beta_x = 2.881, beta_y = 1.121
# Objective = 254812.039, Survival = 0.994, Dx = 0.014, beta_x = 2.356, beta_y = 0.900
# Objective = 186180.314, Survival = 0.979, Dx = 0.008, beta_x = 3.416, beta_y = 1.322
# Objective = 192911.056, Survival = 0.982, Dx = 0.008, beta_x = 3.462, beta_y = 1.298
# Objective = 188268.268, Survival = 0.981, Dx = 0.008, beta_x = 3.390, beta_y = 1.288
# Objective = 182750.907, Survival = 0.978, Dx = 0.007, beta_x = 3.472, beta_y = 1.350
# Objective = 174635.102, Survival = 0.979, Dx = 0.008, beta_x = 3.274, beta_y = 1.291
# Objective = 169291.308, Survival = 0.979, Dx = 0.008, beta_x = 3.155, beta_y = 1.262
# Objective = 169528.403, Survival = 0.980, Dx = 0.008, beta_x = 3.122, beta_y = 1.233
# Objective = 189218.665, Survival = 0.984, Dx = 0.010, beta_x = 2.744, beta_y = 1.079
# Objective = 177175.604, Survival = 0.979, Dx = 0.008, beta_x = 3.328, beta_y = 1.305
# Objective = 172223.286, Survival = 0.976, Dx = 0.008, beta_x = 3.221, beta_y = 1.305
# Objective = 163776.678, Survival = 0.980, Dx = 0.008, beta_x = 2.933, beta_y = 1.190
# Objective = 228902.279, Survival = 0.992, Dx = 0.013, beta_x = 2.430, beta_y = 0.968
# Objective = 167727.954, Survival = 0.982, Dx = 0.009, beta_x = 2.939, beta_y = 1.164
# Objective = 158934.260, Survival = 0.980, Dx = 0.008, beta_x = 2.887, beta_y = 1.168
# Objective = 194321.195, Survival = 0.986, Dx = 0.011, beta_x = 2.603, beta_y = 1.044
# Objective = 196305.425, Survival = 0.988, Dx = 0.011, beta_x = 2.533, beta_y = 1.017
# Objective = 169824.955, Survival = 0.979, Dx = 0.008, beta_x = 3.048, beta_y = 1.221
# Objective = 159579.657, Survival = 0.980, Dx = 0.008, beta_x = 2.908, beta_y = 1.179
# Objective = 166744.583, Survival = 0.981, Dx = 0.009, beta_x = 2.921, beta_y = 1.169
# Objective = 169184.326, Survival = 0.979, Dx = 0.008, beta_x = 3.033, beta_y = 1.219
# Objective = 162285.242, Survival = 0.983, Dx = 0.009, beta_x = 2.727, beta_y = 1.096
# Objective = 189117.743, Survival = 0.984, Dx = 0.011, beta_x = 2.680, beta_y = 1.069
# Objective = 165526.626, Survival = 0.981, Dx = 0.009, beta_x = 2.885, beta_y = 1.160
# Objective = 162967.155, Survival = 0.983, Dx = 0.009, beta_x = 2.757, beta_y = 1.114
# Objective = 163333.543, Survival = 0.982, Dx = 0.009, beta_x = 2.811, beta_y = 1.137
# Objective = 159247.713, Survival = 0.980, Dx = 0.008, beta_x = 2.897, beta_y = 1.174
# Objective = 163257.853, Survival = 0.982, Dx = 0.009, beta_x = 2.806, beta_y = 1.131
# Objective = 162121.472, Survival = 0.981, Dx = 0.009, beta_x = 2.888, beta_y = 1.164
# Objective = 166621.035, Survival = 0.979, Dx = 0.009, beta_x = 2.965, beta_y = 1.201
# Objective = 164463.974, Survival = 0.981, Dx = 0.009, beta_x = 2.853, beta_y = 1.151
# Objective = 159089.640, Survival = 0.980, Dx = 0.008, beta_x = 2.892, beta_y = 1.171
# Objective = 158989.539, Survival = 0.980, Dx = 0.008, beta_x = 2.887, beta_y = 1.166
# Objective = 164388.656, Survival = 0.981, Dx = 0.009, beta_x = 2.851, beta_y = 1.151
# Objective = 160113.557, Survival = 0.980, Dx = 0.008, beta_x = 2.924, beta_y = 1.187
# Objective = 159559.534, Survival = 0.980, Dx = 0.008, beta_x = 2.907, beta_y = 1.178
# Objective = 161575.847, Survival = 0.981, Dx = 0.009, beta_x = 2.872, beta_y = 1.159
# Objective = 159275.520, Survival = 0.980, Dx = 0.008, beta_x = 2.898, beta_y = 1.173
# Objective = 158729.416, Survival = 0.980, Dx = 0.008, beta_x = 2.880, beta_y = 1.164
# Objective = 161575.847, Survival = 0.981, Dx = 0.009, beta_x = 2.872, beta_y = 1.159
# Objective = 161783.817, Survival = 0.981, Dx = 0.009, beta_x = 2.878, beta_y = 1.161
# Objective = 158987.726, Survival = 0.980, Dx = 0.008, beta_x = 2.888, beta_y = 1.169
# Objective = 158793.765, Survival = 0.980, Dx = 0.008, beta_x = 2.883, beta_y = 1.168
# Objective = 158644.592, Survival = 0.980, Dx = 0.008, beta_x = 2.878, beta_y = 1.165
# Objective = 158475.955, Survival = 0.980, Dx = 0.008, beta_x = 2.873, beta_y = 1.163
# Objective = 158390.840, Survival = 0.980, Dx = 0.008, beta_x = 2.870, beta_y = 1.161
# Objective = 161249.960, Survival = 0.981, Dx = 0.009, beta_x = 2.863, beta_y = 1.158
# Objective = 161405.151, Survival = 0.981, Dx = 0.009, beta_x = 2.867, beta_y = 1.158
# Objective = 158659.616, Survival = 0.980, Dx = 0.008, beta_x = 2.878, beta_y = 1.165
# Objective = 158292.058, Survival = 0.980, Dx = 0.008, beta_x = 2.868, beta_y = 1.162
# Objective = 161008.444, Survival = 0.981, Dx = 0.009, beta_x = 2.855, beta_y = 1.155
# Objective = 158136.715, Survival = 0.980, Dx = 0.008, beta_x = 2.862, beta_y = 1.159
# Objective = 160861.152, Survival = 0.981, Dx = 0.009, beta_x = 2.850, beta_y = 1.152
# Objective = 158053.277, Survival = 0.980, Dx = 0.008, beta_x = 2.860, beta_y = 1.158
# Objective = 160806.841, Survival = 0.981, Dx = 0.009, beta_x = 2.847, beta_y = 1.151
# Objective = 160840.123, Survival = 0.981, Dx = 0.009, beta_x = 2.849, beta_y = 1.151
# Objective = 158275.463, Survival = 0.980, Dx = 0.008, beta_x = 2.866, beta_y = 1.161
# Objective = 161111.711, Survival = 0.981, Dx = 0.009, beta_x = 2.858, beta_y = 1.156
# Objective = 158220.363, Survival = 0.980, Dx = 0.008, beta_x = 2.865, beta_y = 1.161
# Objective = 161012.946, Survival = 0.981, Dx = 0.009, beta_x = 2.855, beta_y = 1.155
# Objective = 158208.421, Survival = 0.980, Dx = 0.008, beta_x = 2.864, beta_y = 1.160
# Objective = 158021.739, Survival = 0.980, Dx = 0.008, beta_x = 2.858, beta_y = 1.158
# Objective = 161041.816, Survival = 0.981, Dx = 0.009, beta_x = 2.856, beta_y = 1.156
# Objective = 160994.947, Survival = 0.981, Dx = 0.009, beta_x = 2.855, beta_y = 1.155
# Objective = 158159.032, Survival = 0.980, Dx = 0.008, beta_x = 2.863, beta_y = 1.159
# Objective = 157989.184, Survival = 0.980, Dx = 0.008, beta_x = 2.857, beta_y = 1.157
# Objective = 160994.947, Survival = 0.981, Dx = 0.009, beta_x = 2.855, beta_y = 1.155
# Objective = 160994.096, Survival = 0.981, Dx = 0.009, beta_x = 2.855, beta_y = 1.155
# Objective = 158074.572, Survival = 0.980, Dx = 0.008, beta_x = 2.860, beta_y = 1.158
# Objective = 161072.141, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 158046.382, Survival = 0.980, Dx = 0.008, beta_x = 2.859, beta_y = 1.158
# Objective = 161104.965, Survival = 0.981, Dx = 0.009, beta_x = 2.858, beta_y = 1.157
# Objective = 158034.225, Survival = 0.980, Dx = 0.008, beta_x = 2.859, beta_y = 1.158
# Objective = 157987.194, Survival = 0.980, Dx = 0.008, beta_x = 2.857, beta_y = 1.157
# Objective = 161068.419, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.156
# Objective = 161080.938, Survival = 0.981, Dx = 0.009, beta_x = 2.858, beta_y = 1.157
# Objective = 158011.534, Survival = 0.980, Dx = 0.008, beta_x = 2.858, beta_y = 1.158
# Objective = 161067.787, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.156
# Objective = 158010.310, Survival = 0.980, Dx = 0.008, beta_x = 2.858, beta_y = 1.157
# Objective = 157969.872, Survival = 0.980, Dx = 0.008, beta_x = 2.857, beta_y = 1.157
# Objective = 161068.334, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.156
# Objective = 161066.305, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.156
# Objective = 157997.685, Survival = 0.980, Dx = 0.008, beta_x = 2.858, beta_y = 1.157
# Objective = 157962.443, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 161066.305, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.156
# Objective = 161074.381, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157981.400, Survival = 0.980, Dx = 0.008, beta_x = 2.857, beta_y = 1.157
# Objective = 161072.787, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157979.946, Survival = 0.980, Dx = 0.008, beta_x = 2.857, beta_y = 1.157
# Objective = 161077.235, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157977.692, Survival = 0.980, Dx = 0.008, beta_x = 2.857, beta_y = 1.157
# Objective = 157960.643, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 161071.592, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 161073.850, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157967.836, Survival = 0.980, Dx = 0.008, beta_x = 2.857, beta_y = 1.157
# Objective = 161070.881, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157968.473, Survival = 0.980, Dx = 0.008, beta_x = 2.857, beta_y = 1.157
# Objective = 161071.961, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157965.866, Survival = 0.980, Dx = 0.008, beta_x = 2.857, beta_y = 1.157
# Objective = 161069.992, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157968.177, Survival = 0.980, Dx = 0.008, beta_x = 2.857, beta_y = 1.157
# Objective = 157962.536, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157964.155, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157965.253, Survival = 0.980, Dx = 0.008, beta_x = 2.857, beta_y = 1.157
# Objective = 161071.787, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157963.973, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157960.307, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 161071.154, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 161071.578, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157963.932, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 161071.992, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157963.075, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157961.007, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 161071.832, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157961.045, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 161073.030, Survival = 0.981, Dx = 0.009, beta_x = 2.857, beta_y = 1.157
# Objective = 157960.461, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157961.817, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157960.802, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157960.924, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.700, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157960.090, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.240, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157960.453, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.168, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157960.545, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157961.179, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.367, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157960.361, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157960.226, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.096, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.359, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157960.209, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157960.568, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.732, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.805, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.446, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.339, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157960.242, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.338, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.391, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.228, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.905, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.489, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.034, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.316, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.157, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.403, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.336, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.128, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.133, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.357, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.208, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.068, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.912, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.035, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.157, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.063, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.087, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.017, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.973, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.027, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.990, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.988, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.972, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.002, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.975, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157959.013, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.990, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.935, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.972, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.962, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.898, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.947, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.922, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.923, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.925, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.917, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.930, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.930, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.943, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.913, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.933, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.908, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.899, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.918, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.913, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.899, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.904, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.898, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.908, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.893, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.913, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.898, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.913, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.898, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.899, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.898, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.898, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.899, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.908, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.898, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.898, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.897, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.897, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.898, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.897, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.898, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.897, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.897, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.893, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.893, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.893, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.893, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
# Objective = 157958.887, Survival = 0.980, Dx = 0.008, beta_x = 2.856, beta_y = 1.157
#  144 1.57959e+05
# Field = 0.10 T
# Angle = 10.00 deg
# Radius = 730.1 mm
# Time spent: 868.9261128902435

# %%
# Run a single case of optimal values
opt_params = {
        "B1_field": optim_result.x[0],
        "B1_angle": optim_result.x[1],
        "B1_radius": optim_result.x[2],
        "B1_z": 0.0,
        "B1_z_end": 0.0 + 2 * (optim_result.x[2] * optim_result.x[1] * math.pi/360)+0.1,
        "B1_x_end": 0.0 - 50 * math.sin(optim_result.x[1] * math.pi/360),
        "B1_thickness": 50,
        "B1_height": 100,
    }
if os.path.exists("field_cellB.dat"):
    os.remove("field_cellB.dat")
write_input_from_template("G4_FinalCooling_dispsup_B.g4bl", opt_params, "G4_FinalCooling_dispsup_B_opt.g4bl")
result = subprocess.run(["g4bl", "G4_FinalCooling_dispsup_B_opt.g4bl"], capture_output=True, text=True, check=True)
df_dip = read_trackfile("particles_after_b.txt")
x_params_dip, y_params_dip, z_emit_dip = calc_all_params(df_dip)
D_dict_dip = {"D_x": x_params_dip[4], "D'_x": x_params_dip[5], "D_y": y_params_dip[4], "D'_y": y_params_dip[5]}
b_dict_dip = {"Beta_x": x_params_dip[1], "Beta_y": y_params_dip[1]}
print(D_dict_dip, r"Epsilon_z: "+str(z_emit_dip), b_dict_dip)
# Out:
# {'D_x': np.float64(0.008407837306234527), "D'_x": np.float64(-0.06794783142108525), 'D_y': np.float64(-0.004269714437024493), "D'_y": np.float64(-0.02773698205472457)} Epsilon_z: 5.970826791921001 {'Beta_x': np.float64(2.8564511269718644), 'Beta_y': np.float64(1.1567855802330196)}

# %%
def fieldEvolution():
    """ 
    Evolution of the magnetic field across elements, plotted. 
    
    """
    # Load file, skipping comment lines
    with open("field_cellB.dat") as f:
        lines = f.readlines()[4:]
    
    data = np.array([[float(x) for x in line.split()] for line in lines])
    print(data)
    
    # If the file has columns: x y z Bx By Bz
    # then we can extract:
    z = data[:, 2]
    by = data[:, 4]
    
    
    # Draw shaded regions for magnets
    # Read your g4bl file
    with open("G4_FinalCooling_dispsup_B_opt.g4bl") as f:
        text = f.read()

    # Extract magnets (dipoles, quads, drifts, etc.)
    pattern = r"\s*([A-Za-z0-9_]+):\s*([-\d\.]+)"
    entries = dict(re.findall(pattern, text))
    
    # Convert numeric values
    params = {k: float(v) for k, v in entries.items()}
    print(params)
    magnet_colors = {
            "B":     "#FFAA33",   # warm orange
        }

    regions = []
    length = 2 * (optim_result.x[2] * optim_result.x[1] * math.pi/360)
    z1 = 0.0
    z2 = length
    regions.append((z1, z2, "#FFAA33", "B"))

    plt.figure(figsize=(8, 4))
    for z1, z2, color, label in regions:
        if z1 is not None and z2 is not None:
            plt.axvspan(z1, z2, color=color, alpha=0.3, label=label)
    
    plt.plot(z, by, '-o', color="#541352FF", markersize=2)
    plt.xlim(0.0, (730.1 * 10 *math.pi/360) *3)
    plt.xlabel("Z (mm)")
    plt.ylabel("By (Tesla)")
    plt.title("On Axis (X0=0) Magnetic Field (By vs Z)")
    plt.grid(True)
    plt.tight_layout()
    plt.legend()
    plt.savefig("Bfields.png")

fieldEvolution()
# Out:
# [[0.000e+00 0.000e+00 0.000e+00 0.000e+00 1.000e-01 0.000e+00]
#  [0.000e+00 0.000e+00 5.000e-01 0.000e+00 1.000e-01 0.000e+00]
#  [0.000e+00 0.000e+00 1.000e+00 0.000e+00 1.000e-01 0.000e+00]
#  ...
#  [0.000e+00 0.000e+00 4.985e+02 0.000e+00 0.000e+00 0.000e+00]
#  [0.000e+00 0.000e+00 4.990e+02 0.000e+00 0.000e+00 0.000e+00]
#  [0.000e+00 0.000e+00 4.995e+02 0.000e+00 0.000e+00 0.000e+00]]
# {'COLORS': 100.0}

# %%
def parse_g4bl_file(filename):
    with open(filename) as f:
        text = f.read()

    pattern = r"\s*([A-Za-z0-9_]+):\s*([-\d\.]+)"
    entries = dict(re.findall(pattern, text))

    return {k: float(v) for k, v in entries.items()}

def build_magnet_regions():
    regions = []
    length = 2 * (optim_result.x[2] * optim_result.x[1] * math.pi/360) # optim_result.x[1]
    z1 = 0.0
    z2 = length
    regions.append((z1, z2, "#FFAA33", "B"))

    return regions

# %%
def twissPlot(z_positions, emit_x, emit_y, emit_z, beta_x, beta_y, alpha_x, alpha_y, D_x, Dp_x, D_y, Dp_y, output_folder="./dispsup_plots"):
    
    # -------------------------------------------------------------------
    # CONVERT TO ARRAYS FOR PLOTTING
    # -------------------------------------------------------------------
    z_positions = np.array(z_positions)
    order = np.argsort(z_positions)

    z_positions = z_positions[order]
    emit_x = np.array(emit_x)[order]
    emit_y = np.array(emit_y)[order]
    beta_x = np.array(beta_x)[order]
    beta_y = np.array(beta_y)[order]
    alpha_x = np.array(alpha_x)[order]
    alpha_y = np.array(alpha_y)[order]
    D_x = np.array(D_x)[order]
    Dp_x = np.array(Dp_x)[order]
    D_y = np.array(D_y)[order]
    Dp_y = np.array(Dp_y)[order]
    emit_z = np.array(emit_z)[order]

    # -------------------------------------------------------------------
    # PLOTTING
    # -------------------------------------------------------------------
    def make_plot(yvals, ylabel, title, filename, labels=("x", "y")):
        plt.figure(figsize=(7,5))

        # ---- draw magnet shading (already parsed) ----
        for z1, z2, color, label in regions:
            plt.axvspan(z1, z2, color=color, alpha=0.3, label=label)

        # ---- twiss curves ----
        plt.plot(z_positions, yvals[0], 'o-', color="#541352FF", label=f"{labels[0]}-plane")
        plt.plot(z_positions, yvals[1], 's--', color="#3A5E8CFF", label=f"{labels[1]}-plane")

        plt.xlabel("z [mm]")
        plt.ylabel(ylabel)
        plt.title(title)
        plt.grid(True)

        # ---- remove duplicate legend entries ----
        handles, labels = plt.gca().get_legend_handles_labels()
        by_label = dict(zip(labels, handles))
        plt.legend(by_label.values(), by_label.keys())

        plt.tight_layout()
        plt.savefig(os.path.join(output_folder, filename))
        plt.close()


    make_plot((emit_x, emit_y), "Emittance [mm·mrad]",
            "Emittance Evolution", "emittance_evolution.png")

    make_plot((beta_x, beta_y), "β-function [m]",
            "Beta Function Evolution", "beta_evolution.png")

    make_plot((alpha_x, alpha_y), "α-function [–]",
            "Alpha Function Evolution", "alpha_evolution.png")

    make_plot((D_x, D_y), "Dispersion D [m]",
            "Dispersion Function", "dispersion_D.png")

    make_plot((Dp_x, Dp_y), "Dispersion Derivative D' [-]",
            "Dispersion Derivative", "dispersion_Dprime.png")

    print(f"All plots saved in '{output_folder}'")


files = ["particles_afterupt.txt", "particles_after_b.txt"]
z_positions = []
emit_x = []
emit_y = []
emit_z = []
beta_x = []
beta_y= []
alpha_x=[]
alpha_y=[]
D_x=[]
Dp_x=[]
D_y=[]
Dp_y=[]

for i in files:
        df1 = read_trackfile(i)
        z_positions.append(np.mean(df1["z"]))
        x_params1, y_params1, z_emit1 = calc_all_params(df1)
        ex, bx, gx, ax, Dx, Dxp = x_params1
        ey, by, gy, ay, Dy, Dyp = y_params1
        emit_x.append(ex)
        emit_y.append(ey)
        beta_x.append(bx)
        beta_y.append(by)
        alpha_x.append(ax)
        alpha_y.append(ay)
        D_x.append(Dx), Dp_x.append(Dxp), D_y.append(Dy), Dp_y.append(Dyp)
        emit_z.append(z_emit1)

g4bl_files = ["G4_FinalCooling_dispsup_B_run.g4bl"]

params = {}
for f in g4bl_files:
    params.update(parse_g4bl_file(f))

regions = build_magnet_regions()


twissPlot(z_positions, emit_x, emit_y, emit_z, beta_x, beta_y, alpha_x, alpha_y, D_x, Dp_x, D_y, Dp_y)
# Out:
# All plots saved in './dispsup_plots'

# %%
with open("particles_after_b.txt") as f:
    N_out = sum(1 for line in f if not line.startswith("#") and line.strip())
    print(N_out)
N_PARTICLES = 2000
# Compute transmission (%)
trans_percent = 100.0 * N_out / int(N_PARTICLES)
print(trans_percent)
# Out:
# 1960
# 98.0

# %% [markdown]
# ## Scrap

# %% [markdown]
# # Phase rotation
#
# The following are taken as constants, as they are primarily constrained by technical limitations. The optimal RF gradient is heavily dependent on both of these.
# - **Drift length**: Longer drift length will give better results
# - **RF frequency**: Lower frequency will usually give better results. There's an optimal point, but I believe it's lower than practical
#
# We then optimize the RF phase, cavity length, and gradient

# %%
drift_length = 16000
rf_freq = 0.025

# Function to optimize
def func(x):
    rf_phase, rf_length, rf_grad = x
    drift_to_start = drift_length-rf_length/2
    post_drift = recenter_t(z_prop(no_transverse, drift_to_start))
    post_cavity = run_g4beam(post_drift, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad, nparticles=len(no_transverse))
    pre_w2 = recombine_transverse(post_cavity, reverse_transverse)
    return np.std(p_total(cut_pz(pre_w2)))

# Run optimization
optim_result = minimize(func, [0, 4700, 7], method="Nelder-Mead", bounds=((-90, 90), (2000, 6000), (1, 10)), options=dict(fatol=1e-6))

# Get results
rf_phase, rf_length, rf_grad = optim_result.x
print(f"Phase = {rf_phase:.2f} deg\nLength = {rf_length:.0f} mm\nGradient = {rf_grad:.2f} MV/m\nFrequency = {rf_freq*1000:.1f} MHz")

# Runs a single case with the optimal parameters and add the transverse back in
drift_to_start = drift_length-rf_length/2
post_drift = recenter_t(z_prop(no_transverse, drift_to_start))
post_cavity = cut_pz(recenter_t(run_g4beam(post_drift, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad)))
pre_w2 = recombine_transverse(post_cavity, reverse_transverse)
print_all_params(pre_w2)

# %% [markdown]
# # Second wedge
#
# Optimize the second wedge in the same way as the first

# %%
# Function to optimize
def func(x):
    length, angle = x
    return emittances(cut_outliers(run_distribution(pre_w2, length, angle, vd_dist, axis=1)))[1]

# Run optimization
optim_result = minimize(func, [5.5, 45], method="Nelder-Mead", bounds=((1, 10), (30, 70)), options=dict(fatol=1e-6))

# Get results
w2_length, w2_angle = optim_result.x
print(f"Length = {w2_length:.2f} mm\nAngle = {w2_angle:.1f} deg")

# Runs a single case with the optimal parameters
post_w2 = run_distribution(pre_w2, w2_length, w2_angle, vd_dist, axis=1)
print_all_params(post_w2)

# Do cuts at this point
post_w2_cut = cut_outliers(post_w2)
print_all_params(post_w2_cut)

# %% [markdown]
# # Save/load result

# %%
# Parameter list
PARAMS = [
    "t_emit",
    "momentum",
    "beta",
    "alpha",
    "l_emit",
    "pz_std",
    "vd_dist",
    "w1_length",
    "w1_angle",
    "w2_length",
    "w2_angle",
    "drift_length",
    "rf_freq",
    "rf_phase",
    "rf_length",
    "rf_grad"
]

# %%
# Show parameters
{k:globals()[k] for k in PARAMS}

# %%
# Input parameters
parameters = {'t_emit': 0.145,
 'momentum': 100,
 'beta': 0.03,
 'alpha': 1,
 'l_emit': 1,
 'pz_std': 1,
 'vd_dist': 24,
 'w1_length': 9.20751061747799,
 'w1_angle': 49.78231333988419,
 'w2_length': 6.724887901827298,
 'w2_angle': 42.245718529695516,
 'drift_length': 16000,
 'rf_freq': 0.025,
 'rf_phase': 0.001987066319906211,
 'rf_length': 5153.756925848655,
 'rf_grad': 4.046563465382562}
globals().update(parameters)

# %%
# Save parameter set
parameters = {k:globals()[k] for k in PARAMS}
filename = "results/parameters/"+input("Enter run name to save: ")+".pkl"
with open(filename, "wb+") as file:
    pickle.dump(parameters, file)
    print("Saved to", filename)

# %%
# Load parameter set
filename = "results/parameters/"+input("Enter run name to load: ")+".pkl"
with open(filename, "rb+") as file:
    parameters = pickle.load(file)
    globals().update(parameters)
    print("Loaded from", filename)

# %%
# View parameter set
filename = "results/parameters/"+input("Enter run name to view: ")+".pkl"
with open(filename, "rb+") as file:
    parameters = pickle.load(file)
    print("Viewing", filename)
    print(parameters)

# %%
vd_dist=36

# %% [markdown]
# # Analyze single case

# %%
# Tweak parameters
rf_phase += 180
rf_phase

# %%
# Run best case
pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=100000)
pre_w1["PDGid"] = -13
print("Running first wedge")
post_w1 = run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0)
post_correct = remove_dispersion(post_w1)
reverse_transverse = post_correct.copy(deep=True)
reverse_transverse["Px"] *= -1
reverse_transverse["Py"] *= -1
drift_to_start = drift_length-rf_length/2
post_drift = recenter_t(z_prop(post_correct, drift_to_start))
no_transverse = remove_transverse(post_drift)
print("Running RF cavity")
post_cavity = cut_pz(recenter_t(run_g4beam(no_transverse, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad, nparticles=len(no_transverse))), tails=0.15)
pre_w2 = recombine_transverse(post_cavity, reverse_transverse)
print("Running second wedge")
post_w2 = run_distribution(pre_w2, w2_length, w2_angle, vd_dist, axis=1)
post_w2_cut = recenter_t(cut_outliers(post_w2))
print_all_params(post_w2_cut)
beep()

# %%
# Make some phase space plots
PLOT_TARGETS = [pre_w1, post_correct, post_drift, pre_w2, remove_dispersion(post_w2_cut)]
PLOT_TITLES = ["Initial distribution", "After first wedge", "After drift", "After RF cavity and refocusing", "After second wedge"]
PLOT_AXES = [("x", "Px"), ("y", "Py"), ("t", "Pz")]
PLOT_LABELS = [("x (mm)", "Px (MeV/c)"), ("y (mm)", "Py (MeV/c)"), ("t (ns)", "Pz (MeV/c)")]
T_RANGES = [[-7.5, 7.5], [-30, 30]]
L_RANGES = [[-10, 10], [40, 110]]

fig, axes = plt.subplots(nrows = len(PLOT_AXES), ncols = len(PLOT_TARGETS), layout="constrained")
fig.set_size_inches(16, 8)
for i, df in enumerate(PLOT_TARGETS):
    axes[0][i].set_title(PLOT_TITLES[i])
    for j, ((xaxis, yaxis), (xlabel, ylabel)) in enumerate(zip(PLOT_AXES, PLOT_LABELS)):
        ax = axes[j][i]
        ax.hist2d(df[xaxis], df[yaxis], bins=50, range=L_RANGES if j == 2 else T_RANGES)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(ylabel)
# fig.suptitle(f"temit={t_emit*1000:.0f} μm, σP={pz_std:.2f} MeV/c")

# %%
SAMPLE_DISTS = [pre_w1, post_correct, pre_w2, remove_dispersion(post_w2_cut)]
SAMPLE_TITLES = ["Initial distribution", "After first wedge", "After RF cavity + 10% cut", "After second wedge + 4 sigma cut"]
VARIABLE_NAMES = ["x emit (μm)", "y emit (μm)", "z-emit (mm)", "sigma-p (MeV/c)", "sigma-t (ns)", "Beam remaining"]
VARIABLE_FUNCS = [
    lambda df: emittances(df)[0]*1000,
    lambda df: emittances(df)[1]*1000,
    lambda df: emittances(df)[2],
    lambda df: np.std(p_total(df)),
    lambda df: np.std(df["t"]),
    lambda df: len(df) / len(pre_w1)
]
table = [[n] + [y(x) for y in VARIABLE_FUNCS] for n, x in zip(SAMPLE_TITLES, SAMPLE_DISTS)]
print(tabulate(
    table,
    headers=["Stage"] + VARIABLE_NAMES,
    # tablefmt="latex_raw",
    floatfmt=(None, ".1f", ".1f", ".3f", ".3f", ".3f", ".1%")
))

# %% [markdown]
# ## Anomaly investigation
#
# This is going insane

# %%
momentum = 100
pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
pre_w1["PDGid"] = -13
run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0, debug=True)

# %%
momentums = list(range(50, 101, 10))
results = list() #  Yeah we're back to the old days now
for momentum in tqdm(momentums):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
    pre_w1["PDGid"] = -13
    results.append(run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0))
beep()

# %%
fig, axs = plt.subplots(nrows = 3, ncols = 2)
axs = axs.flatten()
fig.set_size_inches(10, 12)
for momentum, x, ax in zip(momentums, results, axs):
    ax.hist(p_total(x), bins=200, range=(40, 110))
    ax.axvline(momentum, color="red", linestyle="--")
pass

# %%
results[0]["PDGid"]

# %%
angles = [30, 40, 50, 60]
momentum = 70
results1 = list() #  Yeah we're back to the old days now
for angle in tqdm(angles):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
    results1.append(run_distribution(pre_w1, w1_length, angle, vd_dist, axis=0))
beep()

# %%
fig, axs = plt.subplots(nrows = 2, ncols = 2)
axs = axs.flatten()
fig.set_size_inches(10, 8)
for angle, x, ax in zip(angles, results1, axs):
    ax.hist(p_total(x), bins=200, range=(40, 110))
    ax.axvline(momentum, color="red", linestyle="--")
    ax.set_title(f"{angle} deg")
pass

# %%
lengths = [3, 6, 9, 12]
momentum = 70
results2 = list() #  Yeah we're back to the old days now
for length in tqdm(lengths):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
    results2.append(run_distribution(pre_w1, length, w1_angle, 40, axis=0))
beep()

# %%
fig, axs = plt.subplots(nrows = 2, ncols = 2)
axs = axs.flatten()
fig.set_size_inches(10, 8)
for length, x, ax in zip(lengths, results2, axs):
    ax.hist(p_total(x), bins=200, range=(40, 110))
    ax.axvline(momentum, color="red", linestyle="--")
    ax.set_title(f"{length} mm")
pass

# %%
fig, ax = plt.subplots()
ax.hist(p_total(post_w2_cut), bins=200)
select_bottom, select_top = 60.5, 62.5
ax.axvline(select_bottom, color="r", linestyle="--")
ax.axvline(select_top, color="r", linestyle="--")
anomaly = post_w2_cut[(p_total(post_w2_cut) < select_top) & (p_total(post_w2_cut) > select_bottom)]
pre_anomaly = pre_w2.loc[anomaly["EventID"]]
post_anomaly = run_distribution(pre_anomaly, w2_length, w2_angle, vd_dist, axis=1)

# %%
# Show the anomaly
PLOT_TARGETS = [pre_w2, pre_anomaly, post_w2_cut, post_anomaly]
PLOT_TITLES = ["Before (full)", "Before (anomalous)", "After (full)", "After (anomalous)"]
PLOT_AXES = [("x", "Px"), ("y", "Py"), ("t", "Pz")]
PLOT_LABELS = [("x (mm)", "Px (MeV/c)"), ("y (mm)", "Py (MeV/c)"), ("t (ns)", "Pz (MeV/c)")]
T_RANGES = [[-7.5, 7.5], [-30, 30]]
L_RANGES = [[-10, 10], [40, 110]]

fig, axes = plt.subplots(nrows = len(PLOT_AXES), ncols = len(PLOT_TARGETS), layout="constrained")
fig.set_size_inches(10, 8)
for i, df in enumerate(PLOT_TARGETS):
    axes[0][i].set_title(PLOT_TITLES[i])
    for j, ((xaxis, yaxis), (xlabel, ylabel)) in enumerate(zip(PLOT_AXES, PLOT_LABELS)):
        ax = axes[j][i]
        ax.hist2d(df[xaxis], df[yaxis], bins=50, range=L_RANGES if j == 2 else T_RANGES)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(ylabel)
# fig.suptitle(f"temit={t_emit*1000:.0f} μm, σP={pz_std:.2f} MeV/c")

# %%
run_distribution(pre_w1, w2_length, w2_angle, vd_dist, axis=1, debug=True)

# %%
fig, ax = plt.subplots()
ax.hist(post_w2_cut["y"], bins=200)
pass

# %%
p_ranges = [(58.5+2*i, 60.5+2*i) for i in range(7)]

fig, axes = plt.subplots(ncols = 2, nrows = len(p_ranges), layout="constrained")
fig.set_size_inches(6, 3*len(p_ranges))
for i, r in enumerate(p_ranges):
    ax = axes[i][0]
    ax.hist(p_total(post_w2_cut), bins=200, range=(55, 90))
    select_bottom, select_top = r
    ax.axvline(select_bottom, color="r", linestyle="--")
    ax.axvline(select_top, color="r", linestyle="--")

    selected = post_w2_cut[(p_total(post_w2_cut) < select_top) & (p_total(post_w2_cut) > select_bottom)]
    pre_selected = pre_w2.loc[selected["EventID"]]

    ax = axes[i][1]
    ax.hist2d(pre_selected["y"], pre_selected["Py"], bins=50, range=T_RANGES)
    ax.set_xlabel("y")
    ax.set_ylabel("Py")

# %% [markdown]
# ## Two optimal wedges (regenerated)

# %%
# Range to scan
angles = np.linspace(30, 60, 20)
lengths = np.linspace(5, 11, 20)

# %%
def fun(length, angle):
    return run_distribution(pre_w2, length, angle, 24, axis=1)

results = run_scan(fun, (lengths, angles), filename="results/second_wedge_length_angle.pkl")
beep()

# %%
def fun(length, angle):
    return run_distribution(pre_w1, length, angle, 24, axis=0)

results = run_scan(fun, (lengths, angles), filename="results/first_wedge_length_angle.pkl")
beep()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, layout="constrained")
fig.set_size_inches(10, 4)

# First wedge

with open("results/first_wedge_length_angle.pkl", "rb") as file:
    results = pickle.load(file)

mesh = np.meshgrid(lengths, angles)
meshz = qmap_to_meshgrid(mesh, calc_quantity(lambda df: emittances(cut_outliers(df))[0], results))
meshx, meshy = mesh

cax = ax1.contourf(meshx, meshy, meshz, levels=50)
ax1.set_xlabel("First wedge length (mm)")
ax1.set_ylabel("First wedge half-angle (deg)")
ax1.set_title("First wedge")
plt.colorbar(cax, ax=ax1).set_label("x-emittance (mm)")

ax1.plot(w1_length, w1_angle, 'rx')
ax1.annotate(f"{w1_length:.2f} mm, {w1_angle:.2f} deg", (w1_length, w1_angle), c="red", xytext = (-30, 10), textcoords="offset points")

# Second wedge

with open("results/second_wedge_length_angle.pkl", "rb") as file:
    results = pickle.load(file)

mesh = np.meshgrid(lengths, angles)
meshz = qmap_to_meshgrid(mesh, calc_quantity(lambda df: emittances(cut_outliers(df))[1], results))
meshx, meshy = mesh

cax = ax2.contourf(meshx, meshy, meshz, levels=50)
ax2.set_xlabel("Second wedge length (mm)")
ax2.set_ylabel("Second wedge half-angle (deg)")
ax2.set_title("Second wedge")
plt.colorbar(cax, ax=ax2).set_label("y-emittance (mm)")

ax2.plot(w2_length, w2_angle, 'rx')
ax2.annotate(f"{w2_length:.2f} mm, {w2_angle:.2f} deg", (w2_length, w2_angle), c="red", xytext = (-30, 10), textcoords="offset points")

# %% [markdown]
# ## Frequency and gradient (regenerated)

# %%
rf_freqs = np.linspace(0.01, 0.06, 20)
rf_grads = np.linspace(1,10,20)

# %%
# get no_transverse from above

def fun(rf_grad, rf_freq):
    return recenter_t(run_g4beam(no_transverse, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad))

results = run_scan(fun, (rf_grads, rf_freqs), "results/rf_grad_freq_16m.pkl")

# %%
with open("results/rf_grad_freq_16m.pkl", "rb") as file:
    results = pickle.load(file)
mesh = np.meshgrid(rf_grads, rf_freqs)
meshz = qmap_to_meshgrid(mesh, calc_quantity(lambda df: np.std(cut_pz(df)["Pz"]), results))
meshx, meshy = mesh

meshy = 1000 * meshy # Scale to MHz

fig, ax = plt.subplots()
cax = ax.contourf(meshx, meshy, meshz, levels=50)
ax.set_xlabel("RF gradient (MV/m)")
ax.set_ylabel("RF frequency (MHz)")
plt.colorbar(cax).set_label("sigma-Pz (MeV/c)")

minpoint = np.unravel_index(np.argmin(meshz), meshz.shape)
ax.plot(rf_grad, rf_freq*1000, 'rx')
ax.annotate(f"{rf_grad:.2f} MV/m, {rf_freq*1000:.1f} MHz", (rf_grad, rf_freq*1000), c="red", xytext = (-30, 10), textcoords="offset points")

# %% [markdown]
# # Scan of optimal over pz_std

# %%
t_emit = 0.110  # mm
momentum = 100  # MeV/c
beta = 0.03    # m
alpha = 1     # dimensionless
l_emit = 1      # mm
pz_stds = np.linspace(0.8, 1.1, 6)
vd_dist = 24    # mm

# %%
# Meta-function (containing optimization)
def metafun(pz_std):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit)
    
    def func(x):
        length, angle = x
        return emittances(cut_outliers(run_distribution(pre_w1, length, angle, vd_dist, axis=0)))[0]

    return scipy.optimize.minimize(func, [7.5, 45], method="Nelder-Mead", bounds=((1, 10), (30, 70)), options=dict(fatol=2e-4))

run_scan(metafun, (pz_stds,), filename="results/optimal_scan.pkl", trials=5)

# %%
with open("results/optimal_scan.pkl", "rb") as file:
    results = pickle.load(file)

def optim_fun(optim_result):
    return optim_result.fun

def optim_x1(optim_result):
    return optim_result.x[0]

def optim_x2(optim_result):
    return optim_result.x[1]


fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, layout="constrained")
fig.set_size_inches(10, 4)
ax1.errorbar(*qmap_to_arrays(pz_stds, calc_quantity(optim_fun, results)), capsize=2)
ax1.set_xlabel(r"$\sigma p$ (MeV/c)")
ax1.set_ylabel("minimum x emit (mm)")

ax2.errorbar(*qmap_to_arrays(pz_stds, calc_quantity(optim_x1, results)), capsize=2)
ax2.set_xlabel(r"$\sigma p$ (MeV/c)")
ax2.set_ylabel("optimal length (mm)")

ax3.errorbar(*qmap_to_arrays(pz_stds, calc_quantity(optim_x2, results)), capsize=2)
ax3.set_xlabel(r"$\sigma p$ (MeV/c)")
ax3.set_ylabel("optimal half-angle (deg)")

# %%
calc_quantity(optim_fun, results)

# %%
1e-5

# %%
calc_quantity(optim_fun, results)[(0.8,)][1] / 1e-4
