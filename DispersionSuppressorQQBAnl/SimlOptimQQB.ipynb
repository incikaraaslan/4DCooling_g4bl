# %% [markdown]
# This notebook demonstrates the full optimization process for the first wedge and the dispersion suppressor.
#
# Updated: 1/10/2026

# %% [markdown]
# # Setup

# %%
from scan import *
from g4beam import *
import math
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import cm
import numpy as np
import pandas as pd
from tqdm import *
import pickle
import itertools
from tabulate import tabulate
from scipy.optimize import differential_evolution
import re
import uuid

# %%
# Make Sure g4bl is here
import os
os.environ["PATH"] += os.pathsep + "/home/incik/G4beamline-3.08/bin"
import shutil
print(shutil.which("g4bl"))
# Out:
# /home/incik/G4beamline-3.08/bin/g4bl

# %%
import scan, sys
print("scan imported from:", scan.__file__)
print("cwd:", os.getcwd())
print("sys.path[0]:", sys.path[0])
# Out:
# scan imported from: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/scan.py
# cwd: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl
# sys.path[0]: /home/incik/miniconda3/lib/python312.zip

# %% [markdown]
# # Initial distribution
#
# The parameters of the initial beam are treated as constants, but some things are known about their effects:
# - **Transverse emittance**: Should be as low as possible. For this test we use an "optimistic" value of 110 microns.
# - **Momentum**: Decreasing this appears to slightly decreases x-emittance.
# - **Beta**: Decreasing this decreases the y-emittance growth. There may also be an optimal value for x-emittance.
# - **Alpha**: Increasing this decreases the y-emittance growth, but past a certain point increases the x-emittance. I believe 0.7 focuses the beam onto the wedge center with a VD distance of 24 mm.
# - **Longitudinal emittance**: Effects not yet tested.
# - **Standard deviation of momentum**: Decreasing this decreases the x-emittance.
# - **Virtual detector distance**: Almost irrelevant. Should be more than 3x the length of the wedge to ensure accurate measurements.

# %%
t_emit = 0.145  # mm
momentum = 100  # MeV/c
beta = 0.03    # m
alpha = 0.7     # dimensionless
l_emit = 1      # mm
pz_std = 1    # MeV/c
vd_dist = 24    # mm

pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=20000)
pre_w1["PDGid"] = -13
print_all_params(pre_w1)
# Out:
# -----------------------------
# Twiss parameters for X
# emit  = 0.14652137353180544 mm
# beta  = 0.02976340643176925 m
# gamma = 49.60487300695458 1/m
# alpha = 0.6902245984477
# D     = -0.0014764132821804615 m
# D'    = 0.06494126437235362
#
# Twiss parameters for Y
# emit  = 0.1445921214133504 mm
# beta  = 0.029956681701927088 m
# gamma = 50.03939404662737 1/m
# alpha = 0.7064093714073459
# D     = -0.001397019940754504 m
# D'    = -0.04720493961037511
#
# Z-emittance:  1.2592026976853512 mm
# Z std: 153.36051593516797 mm
# p std: 1.00434958099274 MeV/c
# Mean momentum: 99.99365529962014 MeV/c
# -----------------------------

# %%
write_trackfile(pre_w1, "particles_before.txt")

# %% [markdown]
# # First wedge
#
# Determines the optimal length and angle for the first wedge

# %%
# Function to optimize
def func(x):
    length, angle = x
    return emittances(cut_outliers(run_distribution(pre_w1, length, angle, vd_dist, axis=0)))[0]

start = time.time()
# Run optimization
optim_result = minimize(func, [7.5, 45], method="Nelder-Mead", bounds=((1, 10), (30, 70)), options=dict(fatol=1e-6))

# Get results
w1_length, w1_angle = optim_result.x
print(f"Length = {w1_length:.2f} mm\nAngle = {w1_angle:.1f} deg")
print("Time spent:", time.time()-start)

# Runs a single case with the optimal parameters
post_w1 = run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0)
print_all_params(post_w1)
print_all_params(cut_outliers(post_w1))
# Out:
# iter value
#   35 4.25204e-02
# Length = 7.24 mm
# Angle = 46.4 deg
# Time spent: 607.1109662055969
# -----------------------------
# Twiss parameters for X
# emit  = 0.04460659599073637 mm
# beta  = 0.03521183953554977 m
# gamma = 195.78809475476103 1/m
# alpha = -2.427768311737275
# D     = 0.02071915092354973 m
# D'    = -0.035338401844349124
#
# Twiss parameters for Y
# emit  = 0.15297958712016554 mm
# beta  = 0.02535368423610284 m
# gamma = 58.76907622485101 1/m
# alpha = -0.7000090009795099
# D     = -3.38349063172289e-05 m
# D'    = 0.0034314037702956914
#
# Z-emittance:  6.266552883452206 mm
# Z std: 142.28226929256658 mm
# p std: 7.061341611484322 MeV/c
# Mean momentum: 87.82280475568454 MeV/c
# -----------------------------
# -----------------------------
# Twiss parameters for X
# emit  = 0.042520360172995215 mm
# beta  = 0.03588954350276228 m
# gamma = 200.1664659132795 1/m
# alpha = -2.4867414594583064
# D     = 0.02076235867073278 m
# D'    = -0.05097441813085443
#
# Twiss parameters for Y
# emit  = 0.14918840532374858 mm
# beta  = 0.02509615683967357 m
# gamma = 58.18766302654211 1/m
# alpha = -0.6784443362930933
# D     = 9.237528705222341e-06 m
# D'    = 0.00434545056256114
#
# Z-emittance:  6.122554466060365 mm
# Z std: 142.35921539391907 mm
# p std: 6.954390002198831 MeV/c
# Mean momentum: 87.87993035997401 MeV/c
# -----------------------------

# %%
post_w1 = run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0)
print_all_params(post_w1)
print_all_params(cut_outliers(post_w1))
# Out:
# -----------------------------
# Twiss parameters for X
# emit  = 0.04460659599073637 mm
# beta  = 0.03521183953554977 m
# gamma = 195.78809475476103 1/m
# alpha = -2.427768311737275
# D     = 0.02071915092354973 m
# D'    = -0.035338401844349124
#
# Twiss parameters for Y
# emit  = 0.15297958712016554 mm
# beta  = 0.02535368423610284 m
# gamma = 58.76907622485101 1/m
# alpha = -0.7000090009795099
# D     = -3.38349063172289e-05 m
# D'    = 0.0034314037702956914
#
# Z-emittance:  6.266552883452206 mm
# Z std: 142.28226929256658 mm
# p std: 7.061341611484322 MeV/c
# Mean momentum: 87.82280475568454 MeV/c
# -----------------------------
# -----------------------------
# Twiss parameters for X
# emit  = 0.042520360172995215 mm
# beta  = 0.03588954350276228 m
# gamma = 200.1664659132795 1/m
# alpha = -2.4867414594583064
# D     = 0.02076235867073278 m
# D'    = -0.05097441813085443
#
# Twiss parameters for Y
# emit  = 0.14918840532374858 mm
# beta  = 0.02509615683967357 m
# gamma = 58.18766302654211 1/m
# alpha = -0.6784443362930933
# D     = 9.237528705222341e-06 m
# D'    = 0.00434545056256114
#
# Z-emittance:  6.122554466060365 mm
# Z std: 142.35921539391907 mm
# p std: 6.954390002198831 MeV/c
# Mean momentum: 87.87993035997401 MeV/c
# -----------------------------

# %%
# Optimized G4_FinalCooling_auto.g4bl parameters
offset = w1_length / (math.tan(w1_angle * math.pi / 180) * 2)
base_length = 2*offset
abswidth = 100
parameters = dict(
        abshalfangle3=str(w1_angle),
        absoffset3=str(offset),
        abshgt=str(offset * base_length / w1_length + 0.1),
        absLEN3=str(base_length)
    )
L_centerline = float(parameters['absLEN3']) + 1
print("Where to put the next element: " + str(L_centerline) + "mm")
# Out:
# Where to put the next element: 7.89454545313677mm

# %%
L_centerline_orig = (abswidth/2)/np.abs(math.tan(w1_angle)) + base_length
print("Where to not put the next element: " + str(L_centerline_orig) + "mm")
# Out:
# Where to not put the next element: 64.58016964374013mm

# %%
# Write the wedge output into a file
write_trackfile(post_w1, "particles_after.txt")

# %%
# If particles_after isn't updated with Z = 0.
def convertZ(input_file, output_file, set_to=0):
    event_id_counter = 1
    with open(input_file, "r") as infile, open(output_file, "w") as outfile:
        for line in infile:
            # Skip header lines (those starting with #)
            if line.strip().startswith("#"):
                outfile.write(line)
                continue

            # Split the line into columns
            parts = line.strip().split()
            if len(parts) >= 12:
                parts[2] = str(set_to)  # Set the 3rd column (z) to 0
                # Replace event ID (assuming it's the 9th column, zero-based index 8)
                # Adjust if your event ID is in a different column
                parts[8] = str(event_id_counter)
                event_id_counter += 1
                new_line = " ".join(parts)
                outfile.write(new_line + "\n")
            else:
                # Handle lines that don't match expected format
                outfile.write(line)
    print(f"Updated file saved as '{output_file}'")
    os.remove(input_file)
    return None

# %%
convertZ("particles_after.txt", "particles_afterupt.txt", set_to=0.0)
# Out:
# Updated file saved as 'particles_afterupt0.txt'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 convertZ("particles_afterupt.txt", "particles_afterupt0.txt", set_to=0.0)
#
# Cell In[2], line 25, in convertZ(input_file, output_file, set_to)
#      23             outfile.write(line)
#      24 print(f"Updated file saved as '{output_file}'")
# ---> 25 os.remove(input_file)
#      26 return None
#
# NameError: name 'os' is not defined

# %% [markdown]
# # Dispersion correction optimization
#
# The main goal is to have $D_x \approx 0$ up to 1e-5 m while keeping $\beta_x$ relatively periodic and about at the same value.

# %%
# Write values to the prepared G4BL template
def write_input_from_template(template_path, replacements, out_path):
    with open(template_path, 'r') as f:
        txt = f.read()
    try:
        txt = txt.format(**replacements)
    except KeyError as e:
        raise RuntimeError(f"Template substitution failed; missing placeholder: {e}")
    with open(out_path, 'w') as f:
        f.write(txt)

# %%
def clean_field_files():
    for f in ["field_cellQ1.dat", "field_cellQ2.dat"]:
        if os.path.exists(f):
            os.remove(f)

# %%
x0_params, y0_params, _ = calc_all_params(post_w1)
beta_x_ref= x0_params[1]; beta_y_ref= y0_params[1]
print(r"$\beta_x$: " + str(beta_x_ref), r"$\beta_y$: " + str(beta_y_ref))
print("D_x: " + str(x0_params[4]), "D_y: " + str(y0_params[4]))
# Out:
# $\beta_x$: 0.03521183953554977 $\beta_y$: 0.02535368423610284
# D_x: 0.02071915092354973 D_y: -3.38349063172289e-05

# %%
def run_two_quadrupoles(df, Q1_length, Q1_gradient, Q2_length, Q2_gradient, Q_radius, Drift1_length, Q1_z=L_centerline, thickness=5):
    """
    Runs G4BL with two sequential quadrupoles.
    """
    Drift1_width=2*Q_radius
    Drift1_height=2*Q_radius
    # Q1_z : f"{L_centerline + (Q1_length / 2):.12f}",
    params = {
    "Q1_z": f"{Q1_z + (Q1_length / 2):.12f}",
    "Q1_length": f"{Q1_length:.12f}",
    "Q1_gradient": f"{Q1_gradient:.12f}",
    "radius_q": f"{Q_radius:.12f}",
    "thickness": f"{thickness:.12f}",
    "Q1_end": f"{Q1_z + Q1_length:.12f}",
    "Q2_length":f"{Q2_length:.12f}",
    "Q2_gradient": f"{Q2_gradient:.12f}",
    "Drift1_length": f"{Drift1_length:.12f}",
    "Drift1_z": f"{Q1_z + Q1_length + (Drift1_length / 2):.12f}",
    "Drift1_width": f"{Drift1_width:.12f}", 
    "Drift1_height":f"{Drift1_height:.12f}", 
    "D1_end": f"{Q1_z + Q1_length + Drift1_length:.12f}",
    "Q2_z": f"{Q1_z + Q1_length + Drift1_length + Q2_length/2:.12f}",
    "Q2_end": f"{Q1_z + Q1_length + Drift1_length + Q2_length:.12f}"
    }

    print("PARAMS PASSED TO TEMPLATE:")
    for k, v in params.items():
        print(k, "=", v)
    write_input_from_template("G4_FinalCooling_dispsup_Q2.g4bl", params, "G4_FinalCooling_dispsup_Q2_run.g4bl")
    
    # Print first few lines to confirm
    outfile = "G4_FinalCooling_dispsup_Q2_run.g4bl"
    print("=== DEBUG FILE CHECK ===")
    print("Absolute path:", os.path.abspath(outfile))
    print("Last modified:", time.ctime(os.path.getmtime(outfile)))
    print("========================")

    # Print Q1 block robustly (NOT by line number)
    print("---- Q1 BLOCK ----")
    with open(outfile, "r") as f:
        printing = False
        for line in f:
            if line.startswith("genericquad Q1"):
                printing = True
            if printing:
                print(line.rstrip())
            if printing and line.strip() == "":
                break
    print("-------------------")
    
    # Run this file
    clean_field_files()
    res = run_g4beam(df, "G4_FinalCooling_dispsup_Q2_run.g4bl")

    if res is None or len(res) < 10:
        print("G4BL run failed or empty. Check template and parameters.")
        return None
    return res

# %%
history = []
def optimize_qq_drift_safe(x, df, beta_x_ref, beta_y_ref,
                           w_disp=1.0, w_beta=10.0, w_surv=100.0):
    """
    Optimizer wrapper with:
    - Survival-aware penalty
    - Full diagnostics
    """
    # Physical bounds
    bounds = np.array([
        [50, 2000],   # Q1_length
        [1, 30],      # Q1_gradient
        [50, 2000],   # Q2_length
        [-30, -1],    # Q2_gradient
        [10, 500],    # Q_radius
        [20, 1000]    # Drift1_length
    ])

    """# Clip x to bounds (Nelder-Mead ignores bounds)
    x_clipped = np.clip(x, bounds[:, 0], bounds[:, 1])
    if not np.allclose(x, x_clipped):
        print("Clipping input:", x, "→", x_clipped)
    x = x_clipped"""

    q1_length, q1_gradient, q2_length, q2_gradient, q_radius, d_length = x
    print("\nTRYING x =", x)

    try:
        result = run_two_quadrupoles(
            df,
            Q1_length=q1_length,
            Q1_gradient=q1_gradient,
            Q2_length=q2_length,
            Q2_gradient=q2_gradient,
            Q_radius=q_radius,
            Drift1_length=d_length
        )
    except Exception as e:
        print("EXCEPTION in run_two_quadrupoles:", e)
        return 1e6

    if result is None or len(result) == 0:
        print("No particles survived")
        return 1e6

    # Compute survival fraction
    N0 = len(df)
    Ns = len(result)
    survival = Ns / N0
    survival_penalty = w_surv * (1.0 - survival)**2
    print(f"Particles survived: {Ns}/{N0} → penalty {survival_penalty:.3f}")

    # Compute optics parameters
    try:
        x_params, y_params, _ = calc_all_params(result)
    except Exception as e:
        print("EXCEPTION in calc_all_params:", e)
        return 1e5

    Dx = x_params[4]
    Dy = y_params[4]
    beta_x = x_params[1]
    beta_y = y_params[1]

    beta_penalty = ((beta_x - beta_x_ref)/beta_x_ref)**2 + ((beta_y - beta_y_ref)/beta_y_ref)**2
    eps = 1e-4

    # Log-scaled optics loss
    optics_loss = np.log(Dx**2 + eps) + np.log(beta_penalty**2 + eps)

    # Total objective
    val = optics_loss + survival_penalty

    print(f"OBJECTIVE = {val:.6f}, Dx={Dx:.6f}, beta_penalty={beta_penalty:.6f}")
    history.append({
    "Q1_L": q1_length,
    "Q1_G": q1_gradient,
    "Q2_L": q2_length,
    "Q2_G": q2_gradient,
    "Q_radius": q_radius,
    "Drift1_L": d_length,
    "Dx": Dx,
    "beta_x": beta_x,
    "beta_y": beta_y,
    "survival": survival,
    "objective": val})

    return val

# %%
x0 = [121.21526189, 1, 139.77335625, -17.64495411, 10, 20]
res = scipy.optimize.minimize(
    optimize_qq_drift_safe, x0,
    args=(post_w1, beta_x_ref, beta_y_ref),
    method="Nelder-Mead",
    options={"xatol":1e-4, "fatol":1e-6, "maxiter":500}
)
print("Optimal parameters:", res.x)
# Out:
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.502176398137
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.109807343137
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.109807343137
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.109807343137
# Q2_z = 218.996485468137
# Q2_end = 288.883163593137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:47 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 26/20000 → penalty 99.740
# OBJECTIVE = 108.483142, Dx=-0.001459, beta_penalty=7833.224197
#
# TRYING x = [127.27602498   1.         139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 71.532557945387
# Q1_length = 127.276024984500
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 135.170570437637
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 145.170570437637
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 155.170570437637
# Q2_z = 225.057248562637
# Q2_end = 294.943926687637
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:48 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=127.276024984500 \
#     ironLength=127.276024984500 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.358412, Dx=-0.001556, beta_penalty=7239.833562
#
# TRYING x = [121.21526189   1.05       139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.502176398137
# Q1_length = 121.215261890000
# Q1_gradient = 1.050000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.109807343137
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.109807343137
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.109807343137
# Q2_z = 218.996485468137
# Q2_end = 288.883163593137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:49 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.050000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 25/20000 → penalty 99.750
# OBJECTIVE = 108.537875, Dx=-0.001634, beta_penalty=7989.329562
#
# TRYING x = [121.21526189   1.         146.76202406 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.502176398137
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.109807343137
# Q2_length = 146.762024062500
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.109807343137
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.109807343137
# Q2_z = 222.490819374387
# Q2_end = 295.871831405637
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:50 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 24/20000 → penalty 99.760
# OBJECTIVE = 108.326106, Dx=-0.001054, beta_penalty=7205.726482
#
# TRYING x = [121.21526189   1.         139.77335625 -18.52720182  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.502176398137
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.109807343137
# Q2_length = 139.773356250000
# Q2_gradient = -18.527201815500
# Drift1_length = 20.000000000000
# Drift1_z = 139.109807343137
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.109807343137
# Q2_z = 218.996485468137
# Q2_end = 288.883163593137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:51 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 25/20000 → penalty 99.750
# OBJECTIVE = 108.275186, Dx=-0.000676, beta_penalty=7082.669572
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.5
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.502176398137
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.500000000000
# thickness = 5.000000000000
# Q1_end = 129.109807343137
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.109807343137
# Drift1_width = 21.000000000000
# Drift1_height = 21.000000000000
# D1_end = 149.109807343137
# Q2_z = 218.996485468137
# Q2_end = 288.883163593137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:52 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.500000000000+5.000000000000 \
#     apertureRadius=10.500000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 29/20000 → penalty 99.710
# OBJECTIVE = 108.901991, Dx=-0.006665, beta_penalty=8244.331486
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   21.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.502176398137
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.109807343137
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 21.000000000000
# Drift1_z = 139.609807343137
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 150.109807343137
# Q2_z = 219.996485468137
# Q2_end = 289.883163593137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:53 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 25/20000 → penalty 99.750
# OBJECTIVE = 108.548351, Dx=-0.001676, beta_penalty=8025.826549
#
# TRYING x = [123.23551625   1.01666667 142.10291219 -17.93903668   9.5
#   20.33333333]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.512303580553
# Q1_length = 123.235516254833
# Q1_gradient = 1.016666666667
# radius_q = 9.500000000000
# thickness = 5.000000000000
# Q1_end = 131.130061707970
# Q2_length = 142.102912187500
# Q2_gradient = -17.939036678500
# Drift1_length = 20.333333333333
# Drift1_z = 141.296728374637
# Drift1_width = 19.000000000000
# Drift1_height = 19.000000000000
# D1_end = 151.463395041303
# Q2_z = 222.514851135053
# Q2_end = 293.566307228803
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:54 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.016666666667 \
#     fieldLength=123.235516254833 \
#     ironLength=123.235516254833 \
#     ironRadius=9.500000000000+5.000000000000 \
#     apertureRadius=9.500000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 22/20000 → penalty 99.780
# OBJECTIVE = 108.580568, Dx=0.003426, beta_penalty=7707.220050
#
# TRYING x = [122.73045266   1.0125     141.5205232  -17.86551604   9.75
#   20.25      ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.259771784949
# Q1_length = 122.730452663625
# Q1_gradient = 1.012500000000
# radius_q = 9.750000000000
# thickness = 5.000000000000
# Q1_end = 130.624998116762
# Q2_length = 141.520523203125
# Q2_gradient = -17.865516036375
# Drift1_length = 20.250000000000
# Drift1_z = 140.749998116762
# Drift1_width = 19.500000000000
# Drift1_height = 19.500000000000
# D1_end = 150.874998116762
# Q2_z = 221.635259718324
# Q2_end = 292.395521319887
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:55 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.012500000000 \
#     fieldLength=122.730452663625 \
#     ironLength=122.730452663625 \
#     ironRadius=9.750000000000+5.000000000000 \
#     apertureRadius=9.750000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.322172, Dx=-0.001023, beta_penalty=7157.998742
#
# TRYING x = [123.74057985   1.02083333 142.68530117 -18.01255732   9.91666667
#   19.08333333]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.764835376158
# Q1_length = 123.740579846042
# Q1_gradient = 1.020833333333
# radius_q = 9.916666666667
# thickness = 5.000000000000
# Q1_end = 131.635125299178
# Q2_length = 142.685301171875
# Q2_gradient = -18.012557320625
# Drift1_length = 19.083333333333
# Drift1_z = 141.176791965845
# Drift1_width = 19.833333333333
# Drift1_height = 19.833333333333
# D1_end = 150.718458632512
# Q2_z = 222.061109218449
# Q2_end = 293.403759804387
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:56 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.020833333333 \
#     fieldLength=123.740579846042 \
#     ironLength=123.740579846042 \
#     ironRadius=9.916666666667+5.000000000000 \
#     apertureRadius=9.916666666667 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.320121, Dx=-0.001071, beta_penalty=7147.076111
#
# TRYING x = [124.5823525    0.96111111 143.65594948 -18.13509172   9.88888889
#   19.77777778]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 70.185721702165
# Q1_length = 124.582352498056
# Q1_gradient = 0.961111111111
# radius_q = 9.888888888889
# thickness = 5.000000000000
# Q1_end = 132.476897951192
# Q2_length = 143.655949479167
# Q2_gradient = -18.135091724167
# Drift1_length = 19.777777777778
# Drift1_z = 142.365786840081
# Drift1_width = 19.777777777778
# Drift1_height = 19.777777777778
# D1_end = 152.254675728970
# Q2_z = 224.082650468553
# Q2_end = 295.910625208137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:57 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.961111111111 \
#     fieldLength=124.582352498056 \
#     ironLength=124.582352498056 \
#     ironRadius=9.888888888889+5.000000000000 \
#     apertureRadius=9.888888888889 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.330087, Dx=-0.001209, beta_penalty=7171.636677
#
# TRYING x = [125.70471603   0.99814815 144.95014722 -18.29847093   9.85185185
#   19.7037037 ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 70.746903470174
# Q1_length = 125.704716034074
# Q1_gradient = 0.998148148148
# radius_q = 9.851851851852
# thickness = 5.000000000000
# Q1_end = 133.599261487211
# Q2_length = 144.950147222222
# Q2_gradient = -18.298470928889
# Drift1_length = 19.703703703704
# Drift1_z = 143.451113339063
# Drift1_width = 19.703703703704
# Drift1_height = 19.703703703704
# D1_end = 153.302965190915
# Q2_z = 225.778038802026
# Q2_end = 298.253112413137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:58 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.998148148148 \
#     fieldLength=125.704716034074 \
#     ironLength=125.704716034074 \
#     ironRadius=9.851851851852+5.000000000000 \
#     apertureRadius=9.851851851852 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.336323, Dx=-0.001507, beta_penalty=7165.485514
#
# TRYING x = [119.12018329   0.99753086 146.67574421 -18.51630987   9.80246914
#   19.60493827]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.454637097853
# Q1_length = 119.120183289432
# Q1_gradient = 0.997530864198
# radius_q = 9.802469135802
# thickness = 5.000000000000
# Q1_end = 127.014728742569
# Q2_length = 146.675744212963
# Q2_gradient = -18.516309868519
# Drift1_length = 19.604938271605
# Drift1_z = 136.817197878371
# Drift1_width = 19.604938271605
# Drift1_height = 19.604938271605
# D1_end = 146.619667014174
# Q2_z = 219.957539120655
# Q2_end = 293.295411227137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:58 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.997530864198 \
#     fieldLength=119.120183289432 \
#     ironLength=119.120183289432 \
#     ironRadius=9.802469135802+5.000000000000 \
#     apertureRadius=9.802469135802 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.290572, Dx=-0.000532, beta_penalty=7072.543522
#
# TRYING x = [118.49664799   0.99917695 142.07415224 -17.93540603   9.93415638
#   19.86831276]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.142869448959
# Q1_length = 118.496647991644
# Q1_gradient = 0.999176954733
# radius_q = 9.934156378601
# thickness = 5.000000000000
# Q1_end = 126.391193444781
# Q2_length = 142.074152237654
# Q2_gradient = -17.935406029506
# Drift1_length = 19.868312757202
# Drift1_z = 136.325349823382
# Drift1_width = 19.868312757202
# Drift1_height = 19.868312757202
# D1_end = 146.259506201982
# Q2_z = 217.296582320810
# Q2_end = 288.333658439637
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:06:59 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.999176954733 \
#     fieldLength=118.496647991644 \
#     ironLength=118.496647991644 \
#     ironRadius=9.934156378601+5.000000000000 \
#     apertureRadius=9.934156378601 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 25/20000 → penalty 99.750
# OBJECTIVE = 108.322280, Dx=-0.000475, beta_penalty=7259.772459
#
# TRYING x = [117.59044336   1.04890261 142.84108423 -18.03222334   9.9122085
#   19.82441701]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 66.689767132566
# Q1_length = 117.590443358859
# Q1_gradient = 1.048902606310
# radius_q = 9.912208504801
# thickness = 5.000000000000
# Q1_end = 125.484988811995
# Q2_length = 142.841084233539
# Q2_gradient = -18.032223336008
# Drift1_length = 19.824417009602
# Drift1_z = 135.397197316797
# Drift1_width = 19.824417009602
# Drift1_height = 19.824417009602
# D1_end = 145.309405821598
# Q2_z = 216.729947938367
# Q2_end = 288.150490055137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:00 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.048902606310 \
#     fieldLength=117.590443358859 \
#     ironLength=117.590443358859 \
#     ironRadius=9.912208504801+5.000000000000 \
#     apertureRadius=9.912208504801 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 25/20000 → penalty 99.750
# OBJECTIVE = 108.316629, Dx=-0.000458, beta_penalty=7239.874489
#
# TRYING x = [119.74926112   1.02631459 138.42802971 -18.65145069   9.77183356
#   19.54366712]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.769176014737
# Q1_length = 119.749261123201
# Q1_gradient = 1.026314586191
# radius_q = 9.771833561957
# thickness = 5.000000000000
# Q1_end = 127.643806576337
# Q2_length = 138.428029707219
# Q2_gradient = -18.651450692178
# Drift1_length = 19.543667123914
# Drift1_z = 137.415640138294
# Drift1_width = 19.543667123914
# Drift1_height = 19.543667123914
# D1_end = 147.187473700251
# Q2_z = 216.401488553861
# Q2_end = 285.615503407470
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:01 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.026314586191 \
#     fieldLength=119.749261123201 \
#     ironLength=119.749261123201 \
#     ironRadius=9.771833561957+5.000000000000 \
#     apertureRadius=9.771833561957 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.207499, Dx=-0.000210, beta_penalty=6792.903822
#
# TRYING x = [119.01626074   1.03947188 134.26103253 -19.15469898   9.65775034
#   19.31550069]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.402675823037
# Q1_length = 119.016260739801
# Q1_gradient = 1.039471879287
# radius_q = 9.657750342936
# thickness = 5.000000000000
# Q1_end = 126.910806192938
# Q2_length = 134.261032529578
# Q2_gradient = -19.154698983266
# Drift1_length = 19.315500685871
# Drift1_z = 136.568556535873
# Drift1_width = 19.315500685871
# Drift1_height = 19.315500685871
# D1_end = 146.226306878809
# Q2_z = 213.356823143598
# Q2_end = 280.487339408387
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:02 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.039471879287 \
#     fieldLength=119.016260739801 \
#     ironLength=119.016260739801 \
#     ironRadius=9.657750342936+5.000000000000 \
#     apertureRadius=9.657750342936 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 24/20000 → penalty 99.760
# OBJECTIVE = 108.255638, Dx=-0.000476, beta_penalty=6986.868682
#
# TRYING x = [122.88541273   1.03618351 141.90052736 -18.59968033   9.78356958
#   19.56713916]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.337251819174
# Q1_length = 122.885412732075
# Q1_gradient = 1.036183508611
# radius_q = 9.783569577808
# thickness = 5.000000000000
# Q1_end = 130.779958185212
# Q2_length = 141.900527355253
# Q2_gradient = -18.599680326895
# Drift1_length = 19.567139155617
# Drift1_z = 140.563527763020
# Drift1_width = 19.567139155617
# Drift1_height = 19.567139155617
# D1_end = 150.347097340829
# Q2_z = 221.297361018455
# Q2_end = 292.247624696081
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:03 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.036183508611 \
#     fieldLength=122.885412732075 \
#     ironLength=122.885412732075 \
#     ironRadius=9.783569577808+5.000000000000 \
#     apertureRadius=9.783569577808 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.259134, Dx=-0.000908, beta_penalty=6943.531172
#
# TRYING x = [118.70326142   1.03075497 142.58082444 -18.91429175   9.97891582
#   18.95783163]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.246176161259
# Q1_length = 118.703261416244
# Q1_gradient = 1.030754966214
# radius_q = 9.978915815679
# thickness = 5.000000000000
# Q1_end = 126.597806869381
# Q2_length = 142.580824440491
# Q2_gradient = -18.914291750200
# Drift1_length = 18.957831631357
# Drift1_z = 136.076722685060
# Drift1_width = 19.957831631357
# Drift1_height = 19.957831631357
# D1_end = 145.555638500738
# Q2_z = 216.846050720984
# Q2_end = 288.136462941229
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:04 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.030754966214 \
#     fieldLength=118.703261416244 \
#     ironLength=118.703261416244 \
#     ironRadius=9.978915815679+5.000000000000 \
#     apertureRadius=9.978915815679 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 26/20000 → penalty 99.740
# OBJECTIVE = 108.310336, Dx=-0.002928, beta_penalty=6968.220604
#
# TRYING x = [116.01402809   1.02572884 141.38122089 -19.06782861   9.83299887
#   20.0826644 ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 65.901559498418
# Q1_length = 116.014028090562
# Q1_gradient = 1.025728843842
# radius_q = 9.832998865349
# thickness = 5.000000000000
# Q1_end = 123.908573543699
# Q2_length = 141.381220894613
# Q2_gradient = -19.067828609142
# Drift1_length = 20.082664397365
# Drift1_z = 133.949905742381
# Drift1_width = 19.665997730698
# Drift1_height = 19.665997730698
# D1_end = 143.991237941064
# Q2_z = 214.681848388370
# Q2_end = 285.372458835677
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:05 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.025728843842 \
#     fieldLength=116.014028090562 \
#     ironLength=116.014028090562 \
#     ironRadius=9.832998865349+5.000000000000 \
#     apertureRadius=9.832998865349 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 26/20000 → penalty 99.740
# OBJECTIVE = 108.258229, Dx=-0.002534, beta_penalty=6857.386221
#
# TRYING x = [121.63869282   0.98993498 140.73881672 -19.39336435   9.81105381
#   19.42766318]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.713891863960
# Q1_length = 121.638692821646
# Q1_gradient = 0.989934983375
# radius_q = 9.811053814064
# thickness = 5.000000000000
# Q1_end = 129.533238274783
# Q2_length = 140.738816719974
# Q2_gradient = -19.393364351469
# Drift1_length = 19.427663183684
# Drift1_z = 139.247069866625
# Drift1_width = 19.622107628128
# Drift1_height = 19.622107628128
# D1_end = 148.960901458466
# Q2_z = 219.330309818453
# Q2_end = 289.699718178440
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:06 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.989934983375 \
#     fieldLength=121.638692821646 \
#     ironLength=121.638692821646 \
#     ironRadius=9.811053814064+5.000000000000 \
#     apertureRadius=9.811053814064 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.180958, Dx=-0.000399, beta_penalty=6699.508250
#
# TRYING x = [123.66281755   0.96045117 139.68768296 -20.07393486   9.76047647
#   19.22928627]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.725954229657
# Q1_length = 123.662817553040
# Q1_gradient = 0.960451171908
# radius_q = 9.760476468695
# thickness = 5.000000000000
# Q1_end = 131.557363006176
# Q2_length = 139.687682963191
# Q2_gradient = -20.073934859200
# Drift1_length = 19.229286270724
# Drift1_z = 141.172006141539
# Drift1_width = 19.520952937391
# Drift1_height = 19.520952937391
# D1_end = 150.786649276901
# Q2_z = 220.630490758496
# Q2_end = 290.474332240092
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:07 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.960451171908 \
#     fieldLength=123.662817553040 \
#     ironLength=123.662817553040 \
#     ironRadius=9.760476468695+5.000000000000 \
#     apertureRadius=9.760476468695 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.127223, Dx=-0.000453, beta_penalty=6520.399570
#
# TRYING x = [122.17906014   0.98464803 140.03469602 -18.89784364   9.67153339
#   20.38473344]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.984075524733
# Q1_length = 122.179060143192
# Q1_gradient = 0.984648025369
# radius_q = 9.671533387526
# thickness = 5.000000000000
# Q1_end = 130.073605596329
# Q2_length = 140.034696020588
# Q2_gradient = -18.897843640278
# Drift1_length = 20.384733441718
# Drift1_z = 140.265972317188
# Drift1_width = 19.343066775051
# Drift1_height = 19.343066775051
# D1_end = 150.458339038047
# Q2_z = 220.475687048341
# Q2_end = 290.493035058635
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:08 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.984648025369 \
#     fieldLength=122.179060143192 \
#     ironLength=122.179060143192 \
#     ironRadius=9.671533387526+5.000000000000 \
#     apertureRadius=9.671533387526 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.221552, Dx=-0.000651, beta_penalty=6827.854151
#
# TRYING x = [122.78176389   1.01357785 133.72609352 -19.42300345   9.80433482
#   19.99755852]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.285427397099
# Q1_length = 122.781763887924
# Q1_gradient = 1.013577847776
# radius_q = 9.804334817976
# thickness = 5.000000000000
# Q1_end = 130.676309341061
# Q2_length = 133.726093517325
# Q2_gradient = -19.423003445879
# Drift1_length = 19.997558524841
# Drift1_z = 140.675088603482
# Drift1_width = 19.608669635952
# Drift1_height = 19.608669635952
# D1_end = 150.673867865902
# Q2_z = 217.536914624565
# Q2_end = 284.399961383227
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:09 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.013577847776 \
#     fieldLength=122.781763887924 \
#     ironLength=122.781763887924 \
#     ironRadius=9.804334817976+5.000000000000 \
#     apertureRadius=9.804334817976 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 25/20000 → penalty 99.750
# OBJECTIVE = 108.342267, Dx=-0.001167, beta_penalty=7291.471843
#
# TRYING x = [120.03557844   1.00154261 143.43833154 -18.74298326   9.80293556
#   19.70309333]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.912334672664
# Q1_length = 120.035578439055
# Q1_gradient = 1.001542610092
# radius_q = 9.802935556346
# thickness = 5.000000000000
# Q1_end = 127.930123892192
# Q2_length = 143.438331539054
# Q2_gradient = -18.742983262859
# Drift1_length = 19.703093334914
# Drift1_z = 137.781670559649
# Drift1_width = 19.605871112692
# Drift1_height = 19.605871112692
# D1_end = 147.633217227106
# Q2_z = 219.352382996633
# Q2_end = 291.071548766159
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:10 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.001542610092 \
#     fieldLength=120.035578439055 \
#     ironLength=120.035578439055 \
#     ironRadius=9.802935556346+5.000000000000 \
#     apertureRadius=9.802935556346 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.252514, Dx=-0.000477, beta_penalty=6941.153301
#
# TRYING x = [120.29345747   1.01162292 141.85013991 -19.48403865   9.54111581
#   19.50352791]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.041274188324
# Q1_length = 120.293457470375
# Q1_gradient = 1.011622915338
# radius_q = 9.541115805894
# thickness = 5.000000000000
# Q1_end = 128.188002923512
# Q2_length = 141.850139909973
# Q2_gradient = -19.484038648017
# Drift1_length = 19.503527908084
# Drift1_z = 137.939766877554
# Drift1_width = 19.082231611788
# Drift1_height = 19.082231611788
# D1_end = 147.691530831596
# Q2_z = 218.616600786582
# Q2_end = 289.541670741568
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:10 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.011622915338 \
#     fieldLength=120.293457470375 \
#     ironLength=120.293457470375 \
#     ironRadius=9.541115805894+5.000000000000 \
#     apertureRadius=9.541115805894 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.177169, Dx=-0.000294, beta_penalty=6689.240388
#
# TRYING x = [117.75932154   0.96725254 139.70617299 -19.70634624   9.6767283
#   19.915185  ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 66.774206223670
# Q1_length = 117.759321541066
# Q1_gradient = 0.967252542302
# radius_q = 9.676728304114
# thickness = 5.000000000000
# Q1_end = 125.653866994203
# Q2_length = 139.706172989627
# Q2_gradient = -19.706346243662
# Drift1_length = 19.915185003290
# Drift1_z = 135.611459495848
# Drift1_width = 19.353456608228
# Drift1_height = 19.353456608228
# D1_end = 145.569051997493
# Q2_z = 215.422138492306
# Q2_end = 285.275224987119
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:11 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.967252542302 \
#     fieldLength=117.759321541066 \
#     ironLength=117.759321541066 \
#     ironRadius=9.676728304114+5.000000000000 \
#     apertureRadius=9.676728304114 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 24/20000 → penalty 99.760
# OBJECTIVE = 108.221576, Dx=0.000085, beta_penalty=6876.400280
#
# TRYING x = [125.21247067   0.95821511 139.66713015 -19.45103717   9.57520883
#   19.3438333 ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 70.500780786177
# Q1_length = 125.212470666081
# Q1_gradient = 0.958215106558
# radius_q = 9.575208829495
# thickness = 5.000000000000
# Q1_end = 133.107016119218
# Q2_length = 139.667130148604
# Q2_gradient = -19.451037172923
# Drift1_length = 19.343833296850
# Drift1_z = 142.778932767643
# Drift1_width = 19.150417658990
# Drift1_height = 19.150417658990
# D1_end = 152.450849416067
# Q2_z = 222.284414490369
# Q2_end = 292.117979564671
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:12 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.958215106558 \
#     fieldLength=125.212470666081 \
#     ironLength=125.212470666081 \
#     ironRadius=9.575208829495+5.000000000000 \
#     apertureRadius=9.575208829495 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 22/20000 → penalty 99.780
# OBJECTIVE = 108.464822, Dx=0.003836, beta_penalty=7178.791665
#
# TRYING x = [118.31363873   1.00885041 140.95269821 -19.16363075   9.76855136
#   19.89795662]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.051364820358
# Q1_length = 118.313638734442
# Q1_gradient = 1.008850409521
# radius_q = 9.768551356386
# thickness = 5.000000000000
# Q1_end = 126.208184187578
# Q2_length = 140.952698208111
# Q2_gradient = -19.163630750087
# Drift1_length = 19.897956622236
# Drift1_z = 136.157162498697
# Drift1_width = 19.537102712771
# Drift1_height = 19.537102712771
# D1_end = 146.106140809815
# Q2_z = 216.582489913870
# Q2_end = 287.058839017925
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:13 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.008850409521 \
#     fieldLength=118.313638734442 \
#     ironLength=118.313638734442 \
#     ironRadius=9.768551356386+5.000000000000 \
#     apertureRadius=9.768551356386 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 25/20000 → penalty 99.750
# OBJECTIVE = 108.221075, Dx=-0.000194, beta_penalty=6908.046261
#
# TRYING x = [120.61694042   0.98483727 136.78147506 -19.91609835   9.59381074
#   19.78835879]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.203015661162
# Q1_length = 120.616940416050
# Q1_gradient = 0.984837273451
# radius_q = 9.593810738511
# thickness = 5.000000000000
# Q1_end = 128.511485869187
# Q2_length = 136.781475060516
# Q2_gradient = -19.916098348282
# Drift1_length = 19.788358788408
# Drift1_z = 138.405665263391
# Drift1_width = 19.187621477023
# Drift1_height = 19.187621477023
# D1_end = 148.299844657595
# Q2_z = 216.690582187853
# Q2_end = 285.081319718111
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:14 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.984837273451 \
#     fieldLength=120.616940416050 \
#     ironLength=120.616940416050 \
#     ironRadius=9.593810738511+5.000000000000 \
#     apertureRadius=9.593810738511 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.104661, Dx=0.000005, beta_penalty=6453.864210
#
# TRYING x = [120.9076214    0.97648461 133.45304682 -20.50265589   9.48924833
#   19.83099152]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.348356155410
# Q1_length = 120.907621404547
# Q1_gradient = 0.976484605130
# radius_q = 9.489248329594
# thickness = 5.000000000000
# Q1_end = 128.802166857684
# Q2_length = 133.453046821247
# Q2_gradient = -20.502655890993
# Drift1_length = 19.830991515155
# Drift1_z = 138.717662615262
# Drift1_width = 18.978496659188
# Drift1_height = 18.978496659188
# D1_end = 148.633158372839
# Q2_z = 215.359681783463
# Q2_end = 282.086205194086
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:15 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.976484605130 \
#     fieldLength=120.907621404547 \
#     ironLength=120.907621404547 \
#     ironRadius=9.489248329594+5.000000000000 \
#     apertureRadius=9.489248329594 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.036574, Dx=0.000236, beta_penalty=6236.112474
#
# TRYING x = [123.9426306    1.0222047  138.42925822 -19.21817192   9.65752467
#   19.54820262]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.865860754070
# Q1_length = 123.942630601866
# Q1_gradient = 1.022204695517
# radius_q = 9.657524665903
# thickness = 5.000000000000
# Q1_end = 131.837176055003
# Q2_length = 138.429258220483
# Q2_gradient = -19.218171916589
# Drift1_length = 19.548202623987
# Drift1_z = 141.611277366996
# Drift1_width = 19.315049331806
# Drift1_height = 19.315049331806
# D1_end = 151.385378678990
# Q2_z = 220.600007789231
# Q2_end = 289.814636899473
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:16 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.022204695517 \
#     fieldLength=123.942630601866 \
#     ironLength=123.942630601866 \
#     ironRadius=9.657524665903+5.000000000000 \
#     apertureRadius=9.657524665903 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.187442, Dx=-0.000736, beta_penalty=6708.436448
#
# TRYING x = [120.11074882   1.0173281  137.56558926 -20.13345061   9.65805001
#   18.79981058]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.949919862786
# Q1_length = 120.110748819298
# Q1_gradient = 1.017328102499
# radius_q = 9.658050008617
# thickness = 5.000000000000
# Q1_end = 128.005294272435
# Q2_length = 137.565589256153
# Q2_gradient = -20.133450612077
# Drift1_length = 18.799810579649
# Drift1_z = 137.405199562259
# Drift1_width = 19.316100017235
# Drift1_height = 19.316100017235
# D1_end = 146.805104852084
# Q2_z = 215.587899480160
# Q2_end = 284.370694108236
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:17 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.017328102499 \
#     fieldLength=120.110748819298 \
#     ironLength=120.110748819298 \
#     ironRadius=9.658050008617+5.000000000000 \
#     apertureRadius=9.658050008617 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 24/20000 → penalty 99.760
# OBJECTIVE = 108.171266, Dx=-0.000035, beta_penalty=6705.780329
#
# TRYING x = [124.57520692   0.99595162 135.51855075 -20.19093679   9.52419826
#   18.92053872]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 70.182148914637
# Q1_length = 124.575206923000
# Q1_gradient = 0.995951616007
# radius_q = 9.524198257168
# thickness = 5.000000000000
# Q1_end = 132.469752376137
# Q2_length = 135.518550751311
# Q2_gradient = -20.190936789598
# Drift1_length = 18.920538718268
# Drift1_z = 141.930021735271
# Drift1_width = 19.048396514336
# Drift1_height = 19.048396514336
# D1_end = 151.390291094406
# Q2_z = 219.149566470061
# Q2_end = 286.908841845716
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:18 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.995951616007 \
#     fieldLength=124.575206923000 \
#     ironLength=124.575206923000 \
#     ironRadius=9.524198257168+5.000000000000 \
#     apertureRadius=9.524198257168 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.084257, Dx=-0.000380, beta_penalty=6383.743344
#
# TRYING x = [124.74823313   0.96836645 137.07339293 -21.21627888   9.43837095
#   19.06711875]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 70.268662020224
# Q1_length = 124.748233134175
# Q1_gradient = 0.968366449275
# radius_q = 9.438370950000
# thickness = 5.000000000000
# Q1_end = 132.642778587312
# Q2_length = 137.073392933567
# Q2_gradient = -21.216278879980
# Drift1_length = 19.067118748042
# Drift1_z = 142.176337961333
# Drift1_width = 18.876741900001
# Drift1_height = 18.876741900001
# D1_end = 151.709897335354
# Q2_z = 220.246593802137
# Q2_end = 288.783290268921
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:18 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.968366449275 \
#     fieldLength=124.748233134175 \
#     ironLength=124.748233134175 \
#     ironRadius=9.438370950000+5.000000000000 \
#     apertureRadius=9.438370950000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 22/20000 → penalty 99.780
# OBJECTIVE = 108.336211, Dx=0.004380, beta_penalty=6604.141434
#
# TRYING x = [120.99900413   1.01182755 138.08937051 -19.29265774   9.68846791
#   19.42453003]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.394047516109
# Q1_length = 120.999004125944
# Q1_gradient = 1.011827551962
# radius_q = 9.688467908968
# thickness = 5.000000000000
# Q1_end = 128.893549579081
# Q2_length = 138.089370513806
# Q2_gradient = -19.292657739128
# Drift1_length = 19.424530029946
# Drift1_z = 138.605814594054
# Drift1_width = 19.376935817936
# Drift1_height = 19.376935817936
# D1_end = 148.318079609027
# Q2_z = 217.362764865930
# Q2_end = 286.407450122833
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:19 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.011827551962 \
#     fieldLength=120.999004125944 \
#     ironLength=120.999004125944 \
#     ironRadius=9.688467908968+5.000000000000 \
#     apertureRadius=9.688467908968 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.160229, Dx=-0.000222, beta_penalty=6634.065361
#
# TRYING x = [119.57365483   0.96901729 136.95886852 -20.67438626   9.56299426
#   19.02135905]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.681372868238
# Q1_length = 119.573654830202
# Q1_gradient = 0.969017292098
# radius_q = 9.562994260409
# thickness = 5.000000000000
# Q1_end = 127.468200283339
# Q2_length = 136.958868518077
# Q2_gradient = -20.674386263082
# Drift1_length = 19.021359049955
# Drift1_z = 136.978879808316
# Drift1_width = 19.125988520818
# Drift1_height = 19.125988520818
# D1_end = 146.489559333294
# Q2_z = 214.968993592332
# Q2_end = 283.448427851371
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:20 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.969017292098 \
#     fieldLength=119.573654830202 \
#     ironLength=119.573654830202 \
#     ironRadius=9.562994260409+5.000000000000 \
#     apertureRadius=9.562994260409 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.048831, Dx=0.000429, beta_penalty=6270.422019
#
# TRYING x = [122.98289375   0.9653972  131.90756303 -20.80530207   9.68669594
#   18.90531081]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.385992327288
# Q1_length = 122.982893748302
# Q1_gradient = 0.965397197864
# radius_q = 9.686695938590
# thickness = 5.000000000000
# Q1_end = 130.877439201439
# Q2_length = 131.907563031289
# Q2_gradient = -20.805302070009
# Drift1_length = 18.905310813149
# Drift1_z = 140.330094608013
# Drift1_width = 19.373391877180
# Drift1_height = 19.373391877180
# D1_end = 149.782750014588
# Q2_z = 215.736531530232
# Q2_end = 281.690313045877
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:21 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.965397197864 \
#     fieldLength=122.982893748302 \
#     ironLength=122.982893748302 \
#     ironRadius=9.686695938590+5.000000000000 \
#     apertureRadius=9.686695938590 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 24/20000 → penalty 99.760
# OBJECTIVE = 108.086927, Dx=0.000021, beta_penalty=6428.904033
#
# TRYING x = [124.12298404   0.94238171 134.30610494 -20.37984059   9.57931038
#   19.64419489]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.956037474327
# Q1_length = 124.122984042381
# Q1_gradient = 0.942381709157
# radius_q = 9.579310379191
# thickness = 5.000000000000
# Q1_end = 132.017529495517
# Q2_length = 134.306104943488
# Q2_gradient = -20.379840591927
# Drift1_length = 19.644194886084
# Drift1_z = 141.839626938559
# Drift1_width = 19.158620758382
# Drift1_height = 19.158620758382
# D1_end = 151.661724381601
# Q2_z = 218.814776853345
# Q2_end = 285.967829325089
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:22 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.942381709157 \
#     fieldLength=124.122984042381 \
#     ironLength=124.122984042381 \
#     ironRadius=9.579310379191+5.000000000000 \
#     apertureRadius=9.579310379191 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 108.065307, Dx=-0.000207, beta_penalty=6326.758132
#
# TRYING x = [124.27605537   0.92473365 132.52123516 -21.58302775   9.51250664
#   19.09269705]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 70.032573140410
# Q1_length = 124.276055374547
# Q1_gradient = 0.924733645425
# radius_q = 9.512506635581
# thickness = 5.000000000000
# Q1_end = 132.170600827684
# Q2_length = 132.521235162395
# Q2_gradient = -21.583027749142
# Drift1_length = 19.092697054499
# Drift1_z = 141.716949354933
# Drift1_width = 19.025013271163
# Drift1_height = 19.025013271163
# D1_end = 151.263297882183
# Q2_z = 217.523915463380
# Q2_end = 283.784533044578
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:07:23 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.924733645425 \
#     fieldLength=124.276055374547 \
#     ironLength=124.276055374547 \
#     ironRadius=9.512506635581+5.000000000000 \
#     apertureRadius=9.512506635581 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 23/20000 → penalty 99.770
# OBJECTIVE = 107.961801, Dx=0.000159, beta_penalty=6008.191262
#
# TRYING x = [125.914581     0.88118669 129.73716749 -22.72821275   9.424526
#   18.92678057]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 70.851835952561
# Q1_length = 125.914580998848
# Q1_gradient = 0.881186692157
# radius_q = 9.424525998888
# thickness = 5.000000000000
# Q1_end = 133.809126451985
# Q2_length = 129.737167486690
# Q2_gradient = -22.728212754148
# ...
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105136, Dx=0.006341, beta_penalty=1975.741819
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125490
# Q1_length = 135.189633344707
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624128
# thickness = 5.000000000000
# Q1_end = 143.084178797843
# Q2_length = 46.958400867502
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131701
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465558
# Q2_z = 181.717803899309
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:25 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344707 \
#     ironLength=135.189633344707 \
#     ironRadius=6.771330624128+5.000000000000 \
#     apertureRadius=6.771330624128 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105193, Dx=0.006344, beta_penalty=1975.557179
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125490
# Q1_length = 135.189633344706
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624127
# thickness = 5.000000000000
# Q1_end = 143.084178797843
# Q2_length = 46.958400867502
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131700
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465558
# Q2_z = 181.717803899309
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:26 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344706 \
#     ironLength=135.189633344706 \
#     ironRadius=6.771330624127+5.000000000000 \
#     apertureRadius=6.771330624127 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105136, Dx=0.006341, beta_penalty=1975.741819
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125489
# Q1_length = 135.189633344704
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624127
# thickness = 5.000000000000
# Q1_end = 143.084178797841
# Q2_length = 46.958400867503
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131699
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465556
# Q2_z = 181.717803899308
# Q2_end = 205.197004333059
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:27 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344704 \
#     ironLength=135.189633344704 \
#     ironRadius=6.771330624127+5.000000000000 \
#     apertureRadius=6.771330624127 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105128, Dx=0.006341, beta_penalty=1975.731978
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125488
# Q1_length = 135.189633344703
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624127
# thickness = 5.000000000000
# Q1_end = 143.084178797840
# Q2_length = 46.958400867504
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667716
# Drift1_z = 150.661391131698
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465556
# Q2_z = 181.717803899308
# Q2_end = 205.197004333059
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:28 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344703 \
#     ironLength=135.189633344703 \
#     ironRadius=6.771330624127+5.000000000000 \
#     apertureRadius=6.771330624127 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105266, Dx=0.006344, beta_penalty=1975.626681
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125489
# Q1_length = 135.189633344705
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624127
# thickness = 5.000000000000
# Q1_end = 143.084178797842
# Q2_length = 46.958400867503
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131700
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465557
# Q2_z = 181.717803899308
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:29 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344705 \
#     ironLength=135.189633344705 \
#     ironRadius=6.771330624127+5.000000000000 \
#     apertureRadius=6.771330624127 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105266, Dx=0.006344, beta_penalty=1975.626681
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125489
# Q1_length = 135.189633344705
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624128
# thickness = 5.000000000000
# Q1_end = 143.084178797842
# Q2_length = 46.958400867503
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131699
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465557
# Q2_z = 181.717803899308
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:30 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344705 \
#     ironLength=135.189633344705 \
#     ironRadius=6.771330624128+5.000000000000 \
#     apertureRadius=6.771330624128 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105085, Dx=0.006341, beta_penalty=1975.688528
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125489
# Q1_length = 135.189633344705
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624128
# thickness = 5.000000000000
# Q1_end = 143.084178797842
# Q2_length = 46.958400867503
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131699
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465557
# Q2_z = 181.717803899308
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:31 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344705 \
#     ironLength=135.189633344705 \
#     ironRadius=6.771330624128+5.000000000000 \
#     apertureRadius=6.771330624128 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105085, Dx=0.006341, beta_penalty=1975.688528
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125489
# Q1_length = 135.189633344705
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624128
# thickness = 5.000000000000
# Q1_end = 143.084178797842
# Q2_length = 46.958400867503
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131699
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465557
# Q2_z = 181.717803899308
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:32 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344705 \
#     ironLength=135.189633344705 \
#     ironRadius=6.771330624128+5.000000000000 \
#     apertureRadius=6.771330624128 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105085, Dx=0.006341, beta_penalty=1975.688528
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125489
# Q1_length = 135.189633344705
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624127
# thickness = 5.000000000000
# Q1_end = 143.084178797841
# Q2_length = 46.958400867503
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131699
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465557
# Q2_z = 181.717803899308
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:33 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344705 \
#     ironLength=135.189633344705 \
#     ironRadius=6.771330624127+5.000000000000 \
#     apertureRadius=6.771330624127 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105085, Dx=0.006341, beta_penalty=1975.688528
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125489
# Q1_length = 135.189633344704
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624127
# thickness = 5.000000000000
# Q1_end = 143.084178797841
# Q2_length = 46.958400867503
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131699
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465557
# Q2_z = 181.717803899308
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:34 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344704 \
#     ironLength=135.189633344704 \
#     ironRadius=6.771330624127+5.000000000000 \
#     apertureRadius=6.771330624127 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105128, Dx=0.006341, beta_penalty=1975.731978
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125489
# Q1_length = 135.189633344705
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624128
# thickness = 5.000000000000
# Q1_end = 143.084178797842
# Q2_length = 46.958400867503
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131700
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465557
# Q2_z = 181.717803899309
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:35 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344705 \
#     ironLength=135.189633344705 \
#     ironRadius=6.771330624128+5.000000000000 \
#     apertureRadius=6.771330624128 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105085, Dx=0.006341, beta_penalty=1975.688528
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125489
# Q1_length = 135.189633344705
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624128
# thickness = 5.000000000000
# Q1_end = 143.084178797842
# Q2_length = 46.958400867503
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131700
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465557
# Q2_z = 181.717803899309
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:36 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344705 \
#     ironLength=135.189633344705 \
#     ironRadius=6.771330624128+5.000000000000 \
#     apertureRadius=6.771330624128 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105085, Dx=0.006341, beta_penalty=1975.688528
#
# TRYING x = [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125489
# Q1_length = 135.189633344705
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624128
# thickness = 5.000000000000
# Q1_end = 143.084178797842
# Q2_length = 46.958400867503
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131699
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465557
# Q2_z = 181.717803899308
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:16:37 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344705 \
#     ironLength=135.189633344705 \
#     ironRadius=6.771330624128+5.000000000000 \
#     apertureRadius=6.771330624128 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Particles survived: 20/20000 → penalty 99.800
# OBJECTIVE = 106.105085, Dx=0.006341, beta_penalty=1975.688528
# Optimal parameters: [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]

# %%
df_hist = pd.DataFrame(history)
plt.figure(figsize=(6,5))

sc = plt.scatter(
    df_hist["Q1_G"],
    df_hist["Q2_G"],
    c=df_hist["objective"].values,
    cmap="viridis",
    s=40
)

best = df_hist.loc[df_hist["objective"].idxmin()]
plt.scatter(
    best["Q1_G"],
    best["Q2_G"],
    color="red",
    s=120,
    label="Best"
)

plt.colorbar(sc, label="Objective")
plt.xlabel("Q1 gradient")
plt.ylabel("Q2 gradient")
plt.title("Quad optimization search space")
plt.legend()
plt.show()

plt.scatter(
    df_hist["Q1_G"],
    df_hist["Q2_G"],
    c=df_hist["survival"],
    cmap="plasma",
    s=40
)
plt.colorbar(label="Survival fraction")
plt.xlabel("Q1 gradient (T/m)")
plt.ylabel("Q2 gradient (T/m)")
plt.title("Survival across quad parameter space")
plt.show()
plt.figure()
sc= plt.scatter(df_hist["Dx"], df_hist["objective"], c=df_hist["beta_x"].values, cmap="plasma", alpha=0.6)
plt.colorbar(sc, label="beta_x")
plt.xlabel("Dx (m)")
plt.ylabel("Objective")
plt.title("Dispersion vs objective")
plt.show()

plt.figure(figsize=(6,5))
sc = plt.scatter(
    df_hist["Q1_G"],
    df_hist["Q2_G"],
    c=df_hist["Dx"].values,
    cmap="viridis",
    s=40
)

best = df_hist.loc[df_hist["Dx"].idxmin()]
plt.scatter(
    best["Q1_G"],
    best["Q2_G"],
    color="red",
    s=120,
    label="Best"
)

plt.colorbar(sc, label="Dx")
plt.xlabel("Q1 gradient (T/m)")
plt.ylabel("Q2 gradient (T/m)")
plt.title("Quad optimization search space")
plt.legend()
plt.show()

plt.figure(figsize=(6,5))
sc = plt.scatter(
    df_hist["Q1_G"],
    df_hist["Q2_G"],
    c=df_hist["beta_x"].values,
    cmap="viridis",
    s=40
)

best = df_hist.loc[df_hist["beta_x"].idxmin()]
plt.scatter(
    best["Q1_G"],
    best["Q2_G"],
    color="red",
    s=120,
    label="Best"
)

plt.colorbar(sc, label="beta_x")
plt.xlabel("Q1 gradient (T/m)")
plt.ylabel("Q2 gradient (T/m)")
plt.title("Quad optimization search space")
plt.legend()
plt.show()

# %%
# [165.44850696   1.         117.80564137 -16.64715284  10. 20.        ]
# [203.10586964   1.         242.37880814  -7.24549651  10. 20.        ]
print(res.x)
# Out:
# [ 1.35189633e+02  5.93115665e-02  4.69584009e+01 -5.02770897e+01
#   6.77133062e+00  1.51544247e+01]

# %%
if os.path.exists("field_cellQ2.dat"):
    os.remove("field_cellQ2.dat")
df_opt = run_two_quadrupoles(post_w1, Q1_length=res.x[0], Q1_gradient=res.x[1],
                             Q2_length=res.x[2], Q2_gradient=res.x[3],
                             Q_radius=res.x[4], Drift1_length=res.x[5])
print(df_opt)
x_params, y_params, z_emit = calc_all_params(df_opt)
print("Dx, Dy =", x_params[4], y_params[4])
# Out:
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 75.489362125489
# Q1_length = 135.189633344705
# Q1_gradient = 0.059311566517
# radius_q = 6.771330624128
# thickness = 5.000000000000
# Q1_end = 143.084178797842
# Q2_length = 46.958400867503
# Q2_gradient = -50.277089739229
# Drift1_length = 15.154424667715
# Drift1_z = 150.661391131699
# Drift1_width = 13.542661248255
# Drift1_height = 13.542661248255
# D1_end = 158.238603465557
# Q2_z = 181.717803899308
# Q2_end = 205.197004333060
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 09:07:00 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=0.059311566517 \
#     fieldLength=135.189633344705 \
#     ironLength=135.189633344705 \
#     ironRadius=6.771330624128+5.000000000000 \
#     apertureRadius=6.771330624128 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
#            x         y        z        Px        Py       Pz         t  PDGid  \
# 0  -4.264390  5.232060  205.197 -4.337240 -0.786093  93.3461  1.957380    -13
# 1   0.824282  3.972690  205.197  0.293119 -1.005270  92.2722  2.505360    -13
# 2   2.181640  0.806005  205.197  2.024360 -1.192840  89.0847  0.383239    -13
# 3   1.958130  1.953760  205.197  1.133100 -0.648537  93.2017  1.766070    -13
# 4   5.518730  2.108690  205.197  5.324610 -1.595570  84.8370  2.546220    -13
# 5  -2.962510 -3.234840  205.197 -3.189450  0.500815  91.7802  1.820430    -13
# 6  -1.436190 -2.425850  205.197 -0.958848  0.555935  82.9382 -0.326337    -13
# 7   5.208550  3.478560  205.197  4.282300 -0.902508  96.1181  0.794256    -13
# 8   4.549010 -4.793080  205.197  4.481000 -0.274315  80.9138  0.064169    -13
# 9   0.633067  4.740830  205.197  1.381760 -2.040860  73.9373  1.983310    -13
# 10 -4.095120 -3.263180  205.197 -2.866430  0.394987  79.5135 -1.016910    -13
# 11 -1.883680 -3.375520  205.197 -1.296190  1.263620  80.8044  2.595040    -13
# 12  1.713720  2.220910  205.197  2.483040  0.520080  71.3381  0.615694    -13
# 13  3.583390 -4.381060  205.197  2.910170 -0.414844  91.9461 -0.045593    -13
# 14  0.238564  5.514960  205.197  0.818770 -1.229190  81.4324  0.871866    -13
# 15  2.208280  1.411690  205.197  2.838840 -1.422360  75.7925  1.972860    -13
# 16  1.921130 -0.853230  205.197  1.443930 -0.568098  92.3698  1.162370    -13
# 17  4.581550  0.903136  205.197  4.324480  0.757565  85.0584  0.798925    -13
# 18  5.308310  2.756700  205.197  4.764330 -1.291040  91.1077 -0.797687    -13
# 19 -1.397330 -3.956010  205.197 -0.286951  0.929673  72.6924  1.637340    -13
#
#     EventID  TrackID  ...  ProperTime  PathLength  PolX  PolY  PolZ  InitX  \
# 0         7        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 1         9        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 2        25        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 3        35        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 4        44        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 5        59        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 6        68        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 7        76        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 8       118        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 9       144        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 10      161        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 11      223        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 12      351        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 13      374        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 14      401        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 15      411        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 16      413        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 17      432        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 18      445        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 19      460        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
#
#     InitY  InitZ  InitT  InitKE
# 0     NaN    NaN    NaN     NaN
# 1     NaN    NaN    NaN     NaN
# 2     NaN    NaN    NaN     NaN
# 3     NaN    NaN    NaN     NaN
# 4     NaN    NaN    NaN     NaN
# 5     NaN    NaN    NaN     NaN
# 6     NaN    NaN    NaN     NaN
# 7     NaN    NaN    NaN     NaN
# 8     NaN    NaN    NaN     NaN
# 9     NaN    NaN    NaN     NaN
# 10    NaN    NaN    NaN     NaN
# 11    NaN    NaN    NaN     NaN
# 12    NaN    NaN    NaN     NaN
# 13    NaN    NaN    NaN     NaN
# 14    NaN    NaN    NaN     NaN
# 15    NaN    NaN    NaN     NaN
# 16    NaN    NaN    NaN     NaN
# 17    NaN    NaN    NaN     NaN
# 18    NaN    NaN    NaN     NaN
# 19    NaN    NaN    NaN     NaN
#
# [20 rows x 28 columns]
# Dx, Dy = 0.006341240796552948 0.005840317373372472

# %%
b_dict = {"Beta_x" : x_params[1], "Beta_y" : y_params[1]}
print(b_dict, x_params[4])
# Out:
# {'Beta_x': np.float64(1.5184525896846939), 'Beta_y': np.float64(0.38508275236723966)} 0.006341240796552948

# %%
with open("particles_after_q2upt.txt") as f:
    N_out = sum(1 for line in f if not line.startswith("#") and line.strip())
    print(N_out)
N_PARTICLES = 500
# Compute transmission (%)
trans_percent = 100.0 * N_out / int(N_PARTICLES)
print(trans_percent)
# Out:
# 12
# 2.4

# %%
def check_dipole_clearance(df, B_val, dipole_length_mm, dipole_halfwidth_mm):
    """
    Check which particles clear the dipole aperture based on their Larmor radius
    and deflection geometry.

    Parameters:
      df : pandas.DataFrame with columns ['Px','Py','Pz'] in MeV/c
      B_val : magnetic field (Tesla)
      dipole_length_mm : dipole magnet effective length (mm)
      dipole_halfwidth_mm : half-width of dipole aperture (mm)

    Returns:
      surviving_mask : boolean array, True if particle clears aperture
      r_L_mm : array of Larmor radii (mm)
      delta_r_mm : array of deflections (mm)
    """

    # constants
    e = 1.602176634e-19  # C
    c = 2.99792458e8     # m/s

    # convert MeV/c to SI (kg·m/s)
    mom_perp = np.sqrt(df["Px"]**2 + df["Pz"]**2) * 1e6 * e / c  # B assumed along y

    # Larmor radius [m]
    r_L = mom_perp / (e * np.abs(B_val))

    # convert to mm
    r_L_mm = r_L * 1e3
    s_mm = dipole_length_mm

    # deflection Δr = r * (1 - cos(φ)), φ = s / r
    phi = s_mm / r_L_mm
    delta_r_mm = r_L_mm * (1 - np.cos(phi))

    # check if deflection < half-width
    surviving_mask = delta_r_mm < dipole_halfwidth_mm


    return surviving_mask, r_L_mm, delta_r_mm

# %%
def run_dipole(df, B_field, B_length, Drift2_length, B_width=100, B_height=100, Drift2_z=0):
    """Run dipole simulation with given parameters."""
    params = {
        "Drift2_length": Drift2_length, 
        "Drift2_width": B_width,
        "Drift2_height": B_height,
        "Drift2_z": Drift2_z + Drift2_length/2,
        "B1_field": B_field,
        "B1_z": Drift2_z + Drift2_length + B_length/2,
        "B1_end": Drift2_z + Drift2_length + B_length,
        "B1_length": B_length,
        "B1_width": B_width,
        "B1_height": B_height
    }
    write_input_from_template("G4_FinalCooling_dispsup_B.g4bl", params, "G4_FinalCooling_dispsup_B_run.g4bl")
    outfile = "G4_FinalCooling_dispsup_B_run.g4bl"
    return run_g4beam(df, "G4_FinalCooling_dispsup_B_run.g4bl")

# %%
history_d =[]
def optimize_dipole_safe(x, df, beta_x_ref, beta_y_ref,
                         w_disp=1000.0, w_beta=10.0, w_surv=100.0):
    """
    Dipole optimizer with smooth survival penalty
    x = [B_field, B_length, Drift2_length]
    """

    B_field, B_length, Drift2_length = x
    print("\nTRYING dipole x =", x)

    try:
        result = run_dipole(df, B_field, B_length, Drift2_length)
    except Exception as e:
        print("EXCEPTION in run_dipole:", e)
        return 1e6

    if result is None or len(result) == 0:
        print("No particles survived")
        return 1e6

    # --- Survival (ground truth from G4BL)
    N0 = len(df)
    Ns = len(result)
    survival = Ns / N0
    survival_penalty = w_surv * (1.0 - survival)**2

    print(f"Survival: {Ns}/{N0} → penalty {survival_penalty:.3f}")

    # --- Optics
    try:
        x_params, y_params, _ = calc_all_params(result)
    except Exception as e:
        print("EXCEPTION in calc_all_params:", e)
        return 1e5

    Dx = x_params[4]
    beta_x = x_params[1]
    beta_y = y_params[1]

    beta_penalty = ((beta_x - beta_x_ref)/beta_x_ref)**2 \
                 + ((beta_y - beta_y_ref)/beta_y_ref)**2

    eps = 1e-6
    optics_loss = np.log(Dx**2 + eps) + np.log(beta_penalty**2 + eps)

    val = optics_loss + survival_penalty

    print(f"OBJECTIVE = {val:.6f}, Dx={Dx:.6f}, beta_penalty={beta_penalty:.6f}")
    history_d.append({
        "B_F": B_field,
        "B_L": B_length,
        "D2_L": Drift2_length,
        "Dx": Dx,
        "beta_x": beta_x,
        "beta_y": beta_y,
        "survival": survival,
        "objective": val})
    return val

# %%
# initial guess: B_field (T), B_length (mm), Drift2_length (mm)
x0_dip = [1.5, 200.0, 100.0]

# bounds
bounds_dip = [(0.1, 3.0),  # B_field
              (50, 400),   # B_length
              (20, 1000)]  # Drift2_length

res_dip = minimize(optimize_dipole_safe, x0_dip, args=(df_opt, b_dict['Beta_x'], b_dict['Beta_y']),
                method="Nelder-Mead", bounds=bounds_dip)

print("Optimal dipole parameters:", res_dip.x)
# Out:
# iter value
#
# TRYING dipole x = [  1.5 200.  100. ]
# Survival: 6/20 → penalty 49.000
# OBJECTIVE = 59.811778, Dx=-0.111660, beta_penalty=1994.493140
#
# TRYING dipole x = [  1.575 200.    100.   ]
# Survival: 6/20 → penalty 49.000
# OBJECTIVE = 59.811778, Dx=-0.111660, beta_penalty=1994.493140
#
# TRYING dipole x = [  1.5 210.  100. ]
# Survival: 6/20 → penalty 49.000
# OBJECTIVE = 60.075859, Dx=-0.114710, beta_penalty=2215.517490
#
# TRYING dipole x = [  1.5 200.  105. ]
# Survival: 7/20 → penalty 42.250
# OBJECTIVE = 45.079989, Dx=0.005497, beta_penalty=736.762714
#
# TRYING dipole x = [  1.55       190.         103.33333333]
# Survival: 6/20 → penalty 49.000
# OBJECTIVE = 59.631187, Dx=-0.109627, beta_penalty=1856.078393
#    1 4.50800e+01
# TRYING dipole x = [  1.45833333 193.33333333 105.55555556]
# Survival: 7/20 → penalty 42.250
# OBJECTIVE = 44.964564, Dx=0.005535, beta_penalty=690.778578
#
# TRYING dipole x = [  1.4        190.         108.33333333]
# Survival: 7/20 → penalty 42.250
# OBJECTIVE = 44.954468, Dx=0.005539, beta_penalty=686.874275
#    2 4.49545e+01
# TRYING dipole x = [  1.46666667 186.66666667 111.11111111]
# Survival: 7/20 → penalty 42.250
# OBJECTIVE = 44.943610, Dx=0.005543, beta_penalty=682.709571
#
# TRYING dipole x = [  1.45       180.         116.66666667]
# Survival: 7/20 → penalty 42.250
# OBJECTIVE = 44.922683, Dx=0.005550, beta_penalty=674.779343
#    3 4.49227e+01
# TRYING dipole x = [  1.35       190.         116.66666667]
# Survival: 7/20 → penalty 42.250
# OBJECTIVE = 45.110960, Dx=0.005486, beta_penalty=749.704844
#
# TRYING dipole x = [  1.4        190.         113.33333333]
# Survival: 7/20 → penalty 42.250
# OBJECTIVE = 45.049255, Dx=0.005507, beta_penalty=724.192643
#    4 4.49227e+01
# TRYING dipole x = [  1.33333333 173.33333333 120.55555556]
# Survival: 7/20 → penalty 42.250
# OBJECTIVE = 44.869072, Dx=0.005567, beta_penalty=654.926634
#
# TRYING dipole x = [  1.25       160.         128.33333333]
# Survival: 7/20 → penalty 42.250
# OBJECTIVE = 44.760861, Dx=0.005602, beta_penalty=616.649247
#    5 4.47609e+01
# TRYING dipole x = [  1.33333333 163.33333333 122.22222222]
# Survival: 7/20 → penalty 42.250
# OBJECTIVE = 44.705747, Dx=0.005620, beta_penalty=598.057700
#
# TRYING dipole x = [  1.3        150.         126.66666667]
# Survival: 7/20 → penalty 42.250
# OBJECTIVE = 44.526629, Dx=0.005676, beta_penalty=541.599706
#    6 4.45266e+01
# TRYING dipole x = [  1.26666667 136.66666667 139.44444444]
# Survival: 8/20 → penalty 36.000
# OBJECTIVE = 38.762764, Dx=0.008977, beta_penalty=440.687279
#
# TRYING dipole x = [  1.2 110.  155. ]
# Survival: 10/20 → penalty 25.000
# OBJECTIVE = 29.468411, Dx=-0.021823, beta_penalty=427.502898
#    7 2.94684e+01
# TRYING dipole x = [  1.05       100.         156.66666667]
# Survival: 10/20 → penalty 25.000
# OBJECTIVE = 29.205714, Dx=-0.021115, beta_penalty=387.422156
#
# TRYING dipole x = [  0.85        60.         176.66666667]
# Survival: 11/20 → penalty 20.250
# OBJECTIVE = 23.587388, Dx=-0.017804, beta_penalty=297.505708
#    8 2.35874e+01
# TRYING dipole x = [  0.98333333  53.33333333 177.22222222]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = 6.400340, Dx=-0.011801, beta_penalty=0.694975
#
# TRYING dipole x = [  0.85        50.         201.66666667]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 3.672519, Dx=-0.020038, beta_penalty=0.683968
#    9 3.67252e+00
# TRYING dipole x = [  0.63333333  50.         228.88888889]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 3.459199, Dx=-0.022090, beta_penalty=0.557768
#
# TRYING dipole x = [  0.3  50.  280. ]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -1.516140, Dx=-0.030086, beta_penalty=0.034035
#   10 -1.51614e+00
# TRYING dipole x = [1.33333333e-01 5.00000000e+01 2.83888889e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 5.072849, Dx=-0.029935, beta_penalty=0.922737
#   11 -1.51614e+00
# TRYING dipole x = [1.00000000e-01 5.00000000e+01 3.33703704e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 8.065161, Dx=-0.034261, beta_penalty=3.599852
#
# TRYING dipole x = [2.16666667e-01 5.00000000e+01 2.94444444e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 0.468048, Dx=-0.031121, beta_penalty=0.088772
#   12 -1.51614e+00
# TRYING dipole x = [  0.77777778  50.         233.51851852]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 3.724990, Dx=-0.022563, beta_penalty=0.623717
#
# TRYING dipole x = [  0.61666667  50.         246.11111111]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = 6.863949, Dx=-0.028585, beta_penalty=0.362854
#
# TRYING dipole x = [2.58333333e-01 5.00000000e+01 2.87222222e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -2.134753, Dx=-0.030604, beta_penalty=0.024548
#
# TRYING dipole x = [  0.575       50.         240.83333333]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 3.348318, Dx=-0.023016, beta_penalty=0.506500
#
# TRYING dipole x = [2.16666667e-01 5.00000000e+01 2.81944444e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -0.354359, Dx=-0.030011, beta_penalty=0.061013
#   13 -2.13475e+00
# TRYING dipole x = [1.00000000e-01 5.00000000e+01 3.25277778e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 7.906308, Dx=-0.033513, beta_penalty=3.399187
#
# TRYING dipole x = [  0.41666667  50.         261.94444444]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 1.522194, Dx=-0.028831, beta_penalty=0.162317
#   14 -2.13475e+00
# TRYING dipole x = [1.00000000e-01 5.00000000e+01 3.04166667e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 7.493630, Dx=-0.031637, beta_penalty=2.929241
#
# TRYING dipole x = [  0.3375  50.     272.5   ]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -0.162195, Dx=-0.029532, beta_penalty=0.068256
#   15 -2.13475e+00
# TRYING dipole x = [1.79166667e-01 5.00000000e+01 2.93611111e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 2.692305, Dx=-0.030935, beta_penalty=0.271574
#
# TRYING dipole x = [  0.29791667  50.         277.77777778]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -1.664670, Dx=-0.029883, beta_penalty=0.031812
#   16 -2.13475e+00
# TRYING dipole x = [  0.35416667  50.         281.38888889]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 0.341776, Dx=-0.030371, beta_penalty=0.085395
#
# TRYING dipole x = [2.51041667e-01 5.00000000e+01 2.81805556e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -2.519769, Dx=-0.030101, beta_penalty=0.020581
#   17 -2.51977e+00
# TRYING dipole x = [2.38194444e-01 5.00000000e+01 2.84537037e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -1.617992, Dx=-0.030305, beta_penalty=0.032110
#
# TRYING dipole x = [2.53645833e-01 5.00000000e+01 2.83402778e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -2.425064, Dx=-0.030250, beta_penalty=0.021474
#   18 -2.51977e+00
# TRYING dipole x = [2.10763889e-01 5.00000000e+01 2.90509259e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 0.599408, Dx=-0.030754, beta_penalty=0.095930
#
# TRYING dipole x = [2.76128472e-01 5.00000000e+01 2.80960648e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -2.487069, Dx=-0.030101, beta_penalty=0.020921
#   19 -2.51977e+00
# TRYING dipole x = [2.62210648e-01 5.00000000e+01 2.76890432e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -3.180331, Dx=-0.029697, beta_penalty=0.014977
#
# TRYING dipole x = [2.64149306e-01 5.00000000e+01 2.71724537e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -3.622134, Dx=-0.029244, beta_penalty=0.012180
#   20 -3.62213e+00
# TRYING dipole x = [  0.27390046  50.         272.92438272]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -3.081384, Dx=-0.029380, beta_penalty=0.015910
#   21 -3.62213e+00
# TRYING dipole x = [2.49932485e-01 5.00000000e+01 2.70009002e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -3.924963, Dx=-0.029050, beta_penalty=0.010527
#
# TRYING dipole x = [2.36834491e-01 5.00000000e+01 2.64533179e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -3.883143, Dx=-0.028524, beta_penalty=0.010951
#   22 -3.92496e+00
# TRYING dipole x = [  0.27427984  50.         261.29972565]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -3.486046, Dx=-0.028348, beta_penalty=0.013458
#   23 -3.92496e+00
# TRYING dipole x = [2.51673954e-01 5.00000000e+01 2.62431127e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -5.014259, Dx=-0.028381, beta_penalty=0.006198
#
# TRYING dipole x = [2.40560700e-01 5.00000000e+01 2.57184499e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -5.530362, Dx=-0.027882, beta_penalty=0.004834
#   24 -5.53036e+00
# TRYING dipole x = [2.28815158e-01 5.00000000e+01 2.71312300e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -2.260294, Dx=-0.029102, beta_penalty=0.024242
#
# TRYING dipole x = [2.62913666e-01 5.00000000e+01 2.63802869e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -4.329628, Dx=-0.028537, beta_penalty=0.008735
#   25 -5.53036e+00
# TRYING dipole x = [2.38121928e-01 5.00000000e+01 2.55606377e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -5.593843, Dx=-0.027735, beta_penalty=0.004703
#
# TRYING dipole x = [2.25108239e-01 5.00000000e+01 2.47547297e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -4.969704, Dx=-0.026980, beta_penalty=0.006678
#   26 -5.59384e+00
# TRYING dipole x = [2.44465044e-01 5.00000000e+01 2.47720161e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.539426, Dx=-0.027053, beta_penalty=0.001572
#
# TRYING dipole x = [  0.24173132  50.         236.57574112]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = 0.261802, Dx=-0.022445, beta_penalty=0.110977
#   27 -7.53943e+00
# TRYING dipole x = [2.19184782e-01 5.00000000e+01 2.43204489e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -0.461581, Dx=-0.027080, beta_penalty=0.009777
#
# TRYING dipole x = [2.51981445e-01 5.00000000e+01 2.58653274e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -5.522938, Dx=-0.028047, beta_penalty=0.004823
#   28 -7.53943e+00
# TRYING dipole x = [2.30117003e-01 5.00000000e+01 2.48354084e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -5.838130, Dx=-0.027066, beta_penalty=0.004244
#   29 -7.53943e+00
# TRYING dipole x = [2.34575284e-01 5.00000000e+01 2.43935916e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -3.999383, Dx=-0.027193, beta_penalty=0.001336
#
# TRYING dipole x = [2.39064346e-01 5.00000000e+01 2.53872353e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -6.075508, Dx=-0.027583, beta_penalty=0.003666
#   30 -7.53943e+00
# TRYING dipole x = [2.37642334e-01 5.00000000e+01 2.44358023e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.449413, Dx=-0.027241, beta_penalty=0.000877
#
# TRYING dipole x = [2.38002029e-01 5.00000000e+01 2.52794288e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -6.191172, Dx=-0.027485, beta_penalty=0.003457
#   31 -7.53943e+00
# TRYING dipole x = [2.50903943e-01 5.00000000e+01 2.54570451e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -6.103511, Dx=-0.027681, beta_penalty=0.003597
#   32 -7.53943e+00
# TRYING dipole x = [  0.24984967  50.         249.5175805 ]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -6.720364, Dx=-0.027229, beta_penalty=0.002603
#   33 -7.53943e+00
# TRYING dipole x = [2.37307216e-01 5.00000000e+01 2.45450902e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.161037, Dx=-0.027338, beta_penalty=0.001160
#
# TRYING dipole x = [2.47504762e-01 5.00000000e+01 2.52290564e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -6.651879, Dx=-0.027468, beta_penalty=0.002680
#   34 -7.53943e+00
# TRYING dipole x = [  0.25654429  50.         246.89124909]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -5.641106, Dx=-0.027016, beta_penalty=0.004716
#
# TRYING dipole x = [2.42637593e-01 5.00000000e+01 2.51318528e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -6.919070, Dx=-0.027367, beta_penalty=0.002304
#   35 -7.53943e+00
# TRYING dipole x = [2.43796774e-01 5.00000000e+01 2.46746950e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.727949, Dx=-0.026965, beta_penalty=0.001376
#
# TRYING dipole x = [2.41942780e-01 5.00000000e+01 2.43975142e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.702444, Dx=-0.027220, beta_penalty=0.000613
#   36 -7.72795e+00
# TRYING dipole x = [2.37416609e-01 5.00000000e+01 2.47672846e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.363866, Dx=-0.027028, beta_penalty=0.001774
#   37 -7.72795e+00
# TRYING dipole x = [2.41148025e-01 5.00000000e+01 2.43441443e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.767822, Dx=-0.027169, beta_penalty=0.000542
#
# TRYING dipole x = [2.42265201e-01 5.00000000e+01 2.49349257e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.322906, Dx=-0.027191, beta_penalty=0.001808
#   38 -7.72795e+00
# TRYING dipole x = [2.41520417e-01 5.00000000e+01 2.45410714e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.531214, Dx=-0.027348, beta_penalty=0.000786
#
# TRYING dipole x = [2.42079005e-01 5.00000000e+01 2.48364621e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.520159, Dx=-0.027103, beta_penalty=0.001589
#   39 -7.72795e+00
# TRYING dipole x = [  0.24947727  50.         247.54830911]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -6.897896, Dx=-0.027053, beta_penalty=0.002365
#
# TRYING dipole x = [2.40431775e-01 5.00000000e+01 2.47641712e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.634076, Dx=-0.027034, beta_penalty=0.001471
#   40 -7.72795e+00
# TRYING dipole x = [2.43716724e-01 5.00000000e+01 2.46374594e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.367037, Dx=-0.027442, beta_penalty=0.000945
#
# TRYING dipole x = [2.42488435e-01 5.00000000e+01 2.47867114e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.611811, Dx=-0.027060, beta_penalty=0.001492
#   41 -7.72795e+00
# TRYING dipole x = [2.40012945e-01 5.00000000e+01 2.47117022e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.729069, Dx=-0.026986, beta_penalty=0.001373
#
# TRYING dipole x = [2.37786895e-01 5.00000000e+01 2.46815453e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.622303, Dx=-0.026953, beta_penalty=0.001490
#   42 -7.72907e+00
# TRYING dipole x = [2.40339228e-01 5.00000000e+01 2.46470008e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.874819, Dx=-0.026930, beta_penalty=0.001227
#
# TRYING dipole x = [2.39264624e-01 5.00000000e+01 2.45771455e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.344489, Dx=-0.027373, beta_penalty=0.000973
#   43 -7.87482e+00
# TRYING dipole x = [2.42334189e-01 5.00000000e+01 2.45914275e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.461305, Dx=-0.027396, beta_penalty=0.000854
#
# TRYING dipole x = [2.40907379e-01 5.00000000e+01 2.47209852e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.738648, Dx=-0.026997, beta_penalty=0.001362
#   44 -7.87482e+00
# TRYING dipole x = [2.37042927e-01 5.00000000e+01 2.47117639e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.454494, Dx=-0.026977, beta_penalty=0.001673
#
# TRYING dipole x = [2.42108312e-01 5.00000000e+01 2.46839622e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.803347, Dx=-0.026968, beta_penalty=0.001297
#   45 -7.87482e+00
# TRYING dipole x = [2.42223668e-01 5.00000000e+01 2.46562633e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.846371, Dx=-0.026944, beta_penalty=0.001255
#   46 -7.87482e+00
# TRYING dipole x = [2.42206760e-01 5.00000000e+01 2.46038322e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.443056, Dx=-0.027407, beta_penalty=0.000872
#
# TRYING dipole x = [2.41232224e-01 5.00000000e+01 2.46916970e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.799643, Dx=-0.026972, beta_penalty=0.001301
#   47 -7.87482e+00
# TRYING dipole x = [2.41881914e-01 5.00000000e+01 2.46331205e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.393203, Dx=-0.027432, beta_penalty=0.000920
#
# TRYING dipole x = [2.41394647e-01 5.00000000e+01 2.46770529e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.826928, Dx=-0.026960, beta_penalty=0.001274
#   48 -7.87482e+00
# TRYING dipole x = [2.40530049e-01 5.00000000e+01 2.46362491e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.330542, Dx=-0.027431, beta_penalty=0.000983
#
# TRYING dipole x = [2.41713746e-01 5.00000000e+01 2.46720339e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.832576, Dx=-0.026956, beta_penalty=0.001268
#   49 -7.87482e+00
# TRYING dipole x = [2.41456448e-01 5.00000000e+01 2.46398124e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.370411, Dx=-0.027437, beta_penalty=0.000942
#
# TRYING dipole x = [2.41410097e-01 5.00000000e+01 2.46677428e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.843937, Dx=-0.026951, beta_penalty=0.001257
#   50 -7.87482e+00
# TRYING dipole x = [2.40934915e-01 5.00000000e+01 2.46419706e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.892495, Dx=-0.026927, beta_penalty=0.001209
#
# TRYING dipole x = [2.40545499e-01 5.00000000e+01 2.46269390e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.349375, Dx=-0.027422, beta_penalty=0.000964
#   51 -7.89249e+00
# TRYING dipole x = [2.40921777e-01 5.00000000e+01 2.46290804e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.366852, Dx=-0.027425, beta_penalty=0.000947
#
# TRYING dipole x = [2.41288017e-01 5.00000000e+01 2.46580772e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.862360, Dx=-0.026942, beta_penalty=0.001239
#   52 -7.89249e+00
# TRYING dipole x = [2.39484439e-01 5.00000000e+01 2.46417691e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.853495, Dx=-0.026922, beta_penalty=0.001249
#
# TRYING dipole x = [2.40169246e-01 5.00000000e+01 2.46453927e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.873466, Dx=-0.026928, beta_penalty=0.001228
#   53 -7.89249e+00
# TRYING dipole x = [2.39674242e-01 5.00000000e+01 2.46314989e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.271487, Dx=-0.027424, beta_penalty=0.001042
#
# TRYING dipole x = [2.40884573e-01 5.00000000e+01 2.46514326e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.874480, Dx=-0.026935, beta_penalty=0.001227
#   54 -7.89249e+00
# TRYING dipole x = [2.41269898e-01 5.00000000e+01 2.46482100e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.880448, Dx=-0.026933, beta_penalty=0.001221
#   55 -7.89249e+00
# TRYING dipole x = [2.40811454e-01 5.00000000e+01 2.46400217e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.340562, Dx=-0.027435, beta_penalty=0.000972
#
# TRYING dipole x = [2.40866293e-01 5.00000000e+01 2.46485799e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.879734, Dx=-0.026933, beta_penalty=0.001222
#   56 -7.89249e+00
# TRYING dipole x = [2.41708177e-01 5.00000000e+01 2.46455062e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.879179, Dx=-0.026932, beta_penalty=0.001222
#
# TRYING dipole x = [2.41365939e-01 5.00000000e+01 2.46458799e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.883885, Dx=-0.026932, beta_penalty=0.001217
#   57 -7.89249e+00
# TRYING dipole x = [2.41514208e-01 5.00000000e+01 2.46421271e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.888575, Dx=-0.026929, beta_penalty=0.001213
#   58 -7.89249e+00
# TRYING dipole x = [2.41273477e-01 5.00000000e+01 2.46384417e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.365932, Dx=-0.027435, beta_penalty=0.000947
#
# TRYING dipole x = [2.41270793e-01 5.00000000e+01 2.46457679e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.884900, Dx=-0.026931, beta_penalty=0.001216
#   59 -7.89249e+00
# TRYING dipole x = [2.41114005e-01 5.00000000e+01 2.46406973e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.354902, Dx=-0.027437, beta_penalty=0.000958
#
# TRYING dipole x = [2.41302956e-01 5.00000000e+01 2.46445842e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.886787, Dx=-0.026930, beta_penalty=0.001215
#   60 -7.89249e+00
# TRYING dipole x = [2.41230593e-01 5.00000000e+01 2.46400200e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.361359, Dx=-0.027436, beta_penalty=0.000951
#
# TRYING dipole x = [2.41260743e-01 5.00000000e+01 2.46443310e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.887571, Dx=-0.026930, beta_penalty=0.001214
#   61 -7.89249e+00
# TRYING dipole x = [2.41170288e-01 5.00000000e+01 2.46410349e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.893980, Dx=-0.026927, beta_penalty=0.001208
#
# TRYING dipole x = [2.41103955e-01 5.00000000e+01 2.46392603e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.357024, Dx=-0.027435, beta_penalty=0.000956
#   62 -7.89398e+00
# TRYING dipole x = [2.41152198e-01 5.00000000e+01 2.46390908e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.359529, Dx=-0.027435, beta_penalty=0.000953
#
# TRYING dipole x = [2.41233607e-01 5.00000000e+01 2.46430209e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.890120, Dx=-0.026929, beta_penalty=0.001211
#   63 -7.89398e+00
# TRYING dipole x = [2.40711665e-01 5.00000000e+01 2.46418905e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.891120, Dx=-0.026926, beta_penalty=0.001210
#   64 -7.89398e+00
# TRYING dipole x = [2.40644306e-01 5.00000000e+01 2.46402431e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.330078, Dx=-0.027435, beta_penalty=0.000983
#
# TRYING dipole x = [2.41086281e-01 5.00000000e+01 2.46423265e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.891952, Dx=-0.026928, beta_penalty=0.001210
#   65 -7.89398e+00
# TRYING dipole x = [2.41415991e-01 5.00000000e+01 2.46416642e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.890815, Dx=-0.026928, beta_penalty=0.001211
#
# TRYING dipole x = [2.40887747e-01 5.00000000e+01 2.46418339e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.892609, Dx=-0.026927, beta_penalty=0.001209
#   66 -7.89398e+00
# TRYING dipole x = [2.40909019e-01 5.00000000e+01 2.46408999e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.344230, Dx=-0.027436, beta_penalty=0.000969
#
# TRYING dipole x = [2.41041966e-01 5.00000000e+01 2.46419698e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.892630, Dx=-0.026927, beta_penalty=0.001209
#   67 -7.89398e+00
# TRYING dipole x = [2.41131752e-01 5.00000000e+01 2.46412552e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.893793, Dx=-0.026927, beta_penalty=0.001208
#   68 -7.89398e+00
# TRYING dipole x = [2.41341591e-01 5.00000000e+01 2.46410060e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.892846, Dx=-0.026927, beta_penalty=0.001209
#   69 -7.89398e+00
# TRYING dipole x = [2.41387122e-01 5.00000000e+01 2.46402276e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.367158, Dx=-0.027437, beta_penalty=0.000946
#
# TRYING dipole x = [2.41128255e-01 5.00000000e+01 2.46415343e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.893329, Dx=-0.026927, beta_penalty=0.001208
#   70 -7.89398e+00
# TRYING dipole x = [2.40945273e-01 5.00000000e+01 2.46415436e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.893368, Dx=-0.026926, beta_penalty=0.001208
#   71 -7.89398e+00
# TRYING dipole x = [2.41036621e-01 5.00000000e+01 2.46410215e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894369, Dx=-0.026926, beta_penalty=0.001207
#
# TRYING dipole x = [2.40990804e-01 5.00000000e+01 2.46407651e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.348773, Dx=-0.027436, beta_penalty=0.000964
#   72 -7.89437e+00
# TRYING dipole x = [2.41280502e-01 5.00000000e+01 2.46406642e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.362251, Dx=-0.027437, beta_penalty=0.000951
#
# TRYING dipole x = [2.41029080e-01 5.00000000e+01 2.46413237e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.893826, Dx=-0.026927, beta_penalty=0.001208
#   73 -7.89437e+00
# TRYING dipole x = [2.41025574e-01 5.00000000e+01 2.46409983e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894475, Dx=-0.026926, beta_penalty=0.001207
#
# TRYING dipole x = [2.40972485e-01 5.00000000e+01 2.46408698e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.347648, Dx=-0.027436, beta_penalty=0.000965
#   74 -7.89447e+00
# TRYING dipole x = [2.41125909e-01 5.00000000e+01 2.46407128e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.355454, Dx=-0.027437, beta_penalty=0.000957
#
# TRYING dipole x = [2.41053287e-01 5.00000000e+01 2.46411710e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894093, Dx=-0.026927, beta_penalty=0.001207
#   75 -7.89447e+00
# TRYING dipole x = [2.40906700e-01 5.00000000e+01 2.46410922e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894035, Dx=-0.026926, beta_penalty=0.001208
#
# TRYING dipole x = [2.40972597e-01 5.00000000e+01 2.46410779e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894255, Dx=-0.026926, beta_penalty=0.001207
#   76 -7.89447e+00
# TRYING dipole x = [2.40969907e-01 5.00000000e+01 2.46408942e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.347458, Dx=-0.027436, beta_penalty=0.000965
#
# TRYING dipole x = [2.41032442e-01 5.00000000e+01 2.46411018e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894246, Dx=-0.026927, beta_penalty=0.001207
#   77 -7.89447e+00
# TRYING dipole x = [2.40990752e-01 5.00000000e+01 2.46409634e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.348410, Dx=-0.027436, beta_penalty=0.000964
#
# TRYING dipole x = [2.41022020e-01 5.00000000e+01 2.46410672e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894293, Dx=-0.026927, beta_penalty=0.001207
#   78 -7.89447e+00
# TRYING dipole x = [2.41083546e-01 5.00000000e+01 2.46409801e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.353006, Dx=-0.027437, beta_penalty=0.000960
#
# TRYING dipole x = [2.41000334e-01 5.00000000e+01 2.46410535e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894311, Dx=-0.026926, beta_penalty=0.001207
#   79 -7.89447e+00
# TRYING dipole x = [2.41019666e-01 5.00000000e+01 2.46409817e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894466, Dx=-0.026926, beta_penalty=0.001207
#   80 -7.89447e+00
# TRYING dipole x = [2.41054240e-01 5.00000000e+01 2.46409475e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.351626, Dx=-0.027436, beta_penalty=0.000961
#
# TRYING dipole x = [2.41013811e-01 5.00000000e+01 2.46410270e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894357, Dx=-0.026926, beta_penalty=0.001207
#   81 -7.89447e+00
# TRYING dipole x = [2.41040763e-01 5.00000000e+01 2.46409740e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.350873, Dx=-0.027436, beta_penalty=0.000962
#
# TRYING dipole x = [2.41020549e-01 5.00000000e+01 2.46410137e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894421, Dx=-0.026926, beta_penalty=0.001207
#   82 -7.89447e+00
# TRYING dipole x = [2.41007238e-01 5.00000000e+01 2.46409743e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.349242, Dx=-0.027436, beta_penalty=0.000964
#
# TRYING dipole x = [2.41029275e-01 5.00000000e+01 2.46410097e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894420, Dx=-0.026926, beta_penalty=0.001207
#   83 -7.89447e+00
# TRYING dipole x = [2.41014584e-01 5.00000000e+01 2.46409861e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894464, Dx=-0.026926, beta_penalty=0.001207
#   84 -7.89447e+00
# TRYING dipole x = [2.41019334e-01 5.00000000e+01 2.46409636e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.349822, Dx=-0.027436, beta_penalty=0.000963
#
# TRYING dipole x = [2.41020245e-01 5.00000000e+01 2.46410012e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894443, Dx=-0.026926, beta_penalty=0.001207
#   85 -7.89447e+00
# TRYING dipole x = [2.41019638e-01 5.00000000e+01 2.46409761e+02]
# Survival: 12/20 → penalty 16.000
# OBJECTIVE = -4.349859, Dx=-0.027436, beta_penalty=0.000963
#
# TRYING dipole x = [2.41020093e-01 5.00000000e+01 2.46409949e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894466, Dx=-0.026926, beta_penalty=0.001207
#   86 -7.89447e+00
# TRYING dipole x = [2.41028972e-01 5.00000000e+01 2.46409972e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894474, Dx=-0.026926, beta_penalty=0.001207
#   87 -7.89447e+00
# TRYING dipole x = [2.41029381e-01 5.00000000e+01 2.46409898e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894465, Dx=-0.026926, beta_penalty=0.001207
#
# TRYING dipole x = [2.41022415e-01 5.00000000e+01 2.46409937e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894466, Dx=-0.026926, beta_penalty=0.001207
#   88 -7.89447e+00
# TRYING dipole x = [2.41027059e-01 5.00000000e+01 2.46409911e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894465, Dx=-0.026926, beta_penalty=0.001207
#
# TRYING dipole x = [2.41023576e-01 5.00000000e+01 2.46409930e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894466, Dx=-0.026926, beta_penalty=0.001207
#
# TRYING dipole x = [2.41027273e-01 5.00000000e+01 2.46409977e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894474, Dx=-0.026926, beta_penalty=0.001207
#
# TRYING dipole x = [2.4102262e-01 5.0000000e+01 2.4640990e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894465, Dx=-0.026926, beta_penalty=0.001207
#
# TRYING dipole x = [2.41023995e-01 5.00000000e+01 2.46409960e+02]
# Survival: 13/20 → penalty 12.250
# OBJECTIVE = -7.894466, Dx=-0.026926, beta_penalty=0.001207
#   90 -7.89447e+00
# Optimal dipole parameters: [2.41025574e-01 5.00000000e+01 2.46409983e+02]

# %%
df_opt_d = run_dipole(df_opt, B_field=res_dip.x[0], B_length=res_dip.x[1], Drift2_length=res_dip.x[2])
x_params_d, y_params_d, z_emit_d = calc_all_params(df_opt_d)
print("Dx Dy: ", x_params_d[4], y_params_d[4])
print("Betax Betay: ", x_params_d[1], y_params_d[1])
# Out:
# Dx Dy:  -0.026926337360847923 -0.0003816609062427824
# Betax Betay:  1.5184974942993732 0.3984617002766998

# %%
df_hist_b = pd.DataFrame(history_d)
plt.figure(figsize=(6,5))

sc = plt.scatter(
    df_hist_b["B_F"],
    df_hist_b["B_L"],
    c=df_hist_b["objective"].values,
    cmap="viridis",
    s=40
)

best = df_hist_b.loc[df_hist_b["objective"].idxmin()]
plt.scatter(
    best["B_F"],
    best["B_L"],
    color="red",
    s=120,
    label="Best"
)

plt.colorbar(sc, label="Objective")
plt.xlabel("B field strength (T)")
plt.ylabel("B length (mm)")
plt.title("Dipole optimization search space")
plt.legend()
plt.show()

plt.scatter(
    df_hist_b["B_F"],
    df_hist_b["B_L"],
    c=df_hist_b["survival"],
    cmap="plasma",
    s=40
)
plt.colorbar(label="Survival fraction")
plt.xlabel("B field strength (T)")
plt.ylabel("B length (mm)")
plt.title("Survival across quad parameter space")
plt.show()
plt.figure()
sc= plt.scatter(df_hist_b["Dx"], df_hist_b["objective"], c=df_hist_b["beta_x"].values, cmap="plasma", alpha=0.6)
plt.colorbar(sc, label="beta_x")
plt.xlabel("Dx")
plt.ylabel("Objective")
plt.title("Dispersion vs objective")
plt.show()

plt.figure(figsize=(6,5))
sc = plt.scatter(
    df_hist_b["B_F"],
    df_hist_b["B_L"],
    c=df_hist_b["Dx"].values,
    cmap="viridis",
    s=40
)

best = df_hist_b.loc[df_hist_b["Dx"].abs().idxmin()]
plt.scatter(
    best["B_F"],
    best["B_L"],
    color="red",
    s=120,
    label="Best"
)


plt.colorbar(sc, label="Dx")
plt.xlabel("B field strength (T)")
plt.ylabel("B length (mm)")
plt.title("Dipole optimization search space")
plt.legend()
plt.show()

plt.figure(figsize=(6,5))
sc = plt.scatter(
    df_hist_b["B_F"],
    df_hist_b["B_L"],
    c=df_hist_b["beta_x"].values,
    cmap="viridis",
    s=40
)

best = df_hist_b.loc[df_hist_b["beta_x"].idxmin()]
plt.scatter(
    best["B_F"],
    best["B_L"],
    color="red",
    s=120,
    label="Best min"
)
best_max = df_hist_b.loc[df_hist_b["beta_x"].idxmax()]
plt.scatter(
    best_max["B_F"],
    best_max["B_L"],
    color="blue",
    s=120,
    label="Best max"
)

plt.colorbar(sc, label="beta_x")
plt.xlabel("B field strength (T)")
plt.ylabel("B length (mm)")
plt.title("Dipole optimization search space")
plt.legend()
plt.show()

# %%
def parse_g4bl_file(filename):
    with open(filename) as f:
        text = f.read()

    pattern = r"\s*([A-Za-z0-9_]+):\s*([-\d\.]+)"
    entries = dict(re.findall(pattern, text))

    return {k: float(v) for k, v in entries.items()}

def build_magnet_regions(params):
    magnet_colors = {
        "wedge":  "#FF66CC",
        "Q1":     "#6699FF",
        "Drift1": "#BBBBBB",
        "Q2":     "#3366CC",
        "Drift2": "#999999",
        "B1":     "#FFAA33",
    }

    magnet_order = ["wedge", "Q1", "Drift1", "Q2", "Drift2", "B1"]
    regions = []

    for name in magnet_order:
        z_key = f"{name}_z"
        L_key = f"{name}_length"

        if name == "wedge":
            if "wedge_end" in params:
                z1 = 0.0
                z2 = params["wedge_end"]
                regions.append((z1, z2, magnet_colors[name], name))

        elif z_key in params and L_key in params:
            center = params[z_key]
            length = params[L_key]
            z1 = center - length / 2
            z2 = center + length / 2
            regions.append((z1, z2, magnet_colors[name], name))

    return regions

# %%
def twissPlot(z_positions, emit_x, emit_y, emit_z, beta_x, beta_y, alpha_x, alpha_y, D_x, Dp_x, D_y, Dp_y, output_folder="./dispsup_plots"):
    
    # -------------------------------------------------------------------
    # CONVERT TO ARRAYS FOR PLOTTING
    # -------------------------------------------------------------------
    z_positions = np.array(z_positions)
    order = np.argsort(z_positions)

    z_positions = z_positions[order]
    emit_x = np.array(emit_x)[order]
    emit_y = np.array(emit_y)[order]
    beta_x = np.array(beta_x)[order]
    beta_y = np.array(beta_y)[order]
    alpha_x = np.array(alpha_x)[order]
    alpha_y = np.array(alpha_y)[order]
    D_x = np.array(D_x)[order]
    Dp_x = np.array(Dp_x)[order]
    D_y = np.array(D_y)[order]
    Dp_y = np.array(Dp_y)[order]
    emit_z = np.array(emit_z)[order]

    # -------------------------------------------------------------------
    # PLOTTING
    # -------------------------------------------------------------------
    def make_plot(yvals, ylabel, title, filename, labels=("x", "y")):
        plt.figure(figsize=(7,5))

        # ---- draw magnet shading (already parsed) ----
        for z1, z2, color, label in regions:
            plt.axvspan(z1, z2, color=color, alpha=0.3, label=label)

        # ---- twiss curves ----
        plt.plot(z_positions, yvals[0], 'o-', color="#541352FF", label=f"{labels[0]}-plane")
        plt.plot(z_positions, yvals[1], 's--', color="#3A5E8CFF", label=f"{labels[1]}-plane")

        plt.xlabel("z [mm]")
        plt.ylabel(ylabel)
        plt.title(title)
        plt.grid(True)

        # ---- remove duplicate legend entries ----
        handles, labels = plt.gca().get_legend_handles_labels()
        by_label = dict(zip(labels, handles))
        plt.legend(by_label.values(), by_label.keys())

        plt.tight_layout()
        plt.savefig(os.path.join(output_folder, filename))
        plt.close()


    make_plot((emit_x, emit_y), "Emittance [mm·mrad]",
            "Emittance Evolution", "emittance_evolution.png")

    make_plot((beta_x, beta_y), "β-function [m]",
            "Beta Function Evolution", "beta_evolution.png")

    make_plot((alpha_x, alpha_y), "α-function [–]",
            "Alpha Function Evolution", "alpha_evolution.png")

    make_plot((D_x, D_y), "Dispersion D [m]",
            "Dispersion Function", "dispersion_D.png")

    make_plot((Dp_x, Dp_y), "Dispersion Derivative D' [-]",
            "Dispersion Derivative", "dispersion_Dprime.png")

    print(f"All plots saved in '{output_folder}'")


files = ["vd_start_dispsup.txt", "vd_Q1_dispsup.txt", "vd_D1_dispsup.txt", "particles_after_q2uptc.txt", "particles_after_b.txt"]
z_positions = []
emit_x = []
emit_y = []
emit_z = []
beta_x = []
beta_y= []
alpha_x=[]
alpha_y=[]
D_x=[]
Dp_x=[]
D_y=[]
Dp_y=[]

for i in files:
        df1 = read_trackfile(i)
        z_positions.append(np.mean(df1["z"]))
        x_params1, y_params1, z_emit1 = calc_all_params(df1)
        ex, bx, gx, ax, Dx, Dxp = x_params1
        ey, by, gy, ay, Dy, Dyp = y_params1
        emit_x.append(ex)
        emit_y.append(ey)
        beta_x.append(bx)
        beta_y.append(by)
        alpha_x.append(ax)
        alpha_y.append(ay)
        D_x.append(Dx), Dp_x.append(Dxp), D_y.append(Dy), Dp_y.append(Dyp)
        emit_z.append(z_emit1)

g4bl_files = [
    "G4_FinalCooling_dispsup_Q2_run.g4bl",
    "G4_FinalCooling_dispsup_B_run.g4bl",
]

params = {}
for f in g4bl_files:
    params.update(parse_g4bl_file(f))

regions = build_magnet_regions(params)


twissPlot(z_positions, emit_x, emit_y, emit_z, beta_x, beta_y, alpha_x, alpha_y, D_x, Dp_x, D_y, Dp_y)
# Out:
# All plots saved in './dispsup_plots'

# %% [markdown]
# ## Let's now try to max beta in quads and min it in dipoles

# %%
history_beta = []
def optimize_qq_drift_beta(x, df, beta_min=1.0, beta_max=2.0,w_surv=200.0, w_beta=50.0, w_disp=1.0):
    """
    Quad optimizer:
    - Strongly maximize survival
    - Maximize beta within [beta_min, beta_max]
    - Weakly minimize dispersion
    """

    bounds = np.array([
        [50, 2000],   # Q1_length
        [1, 30],      # Q1_gradient
        [50, 2000],   # Q2_length
        [-30, -1],    # Q2_gradient
        [10, 500],    # Q_radius
        [20, 1000]    # Drift1_length
    ])

    q1L, q1G, q2L, q2G, qR, dL = x
    print("\nTRYING QUAD x =", x)

    try:
        res = run_two_quadrupoles(
            df,
            Q1_length=q1L,
            Q1_gradient=q1G,
            Q2_length=q2L,
            Q2_gradient=q2G,
            Q_radius=qR,
            Drift1_length=dL
        )
    except Exception as e:
        print("RUN FAILURE:", e)
        return 1e6

    if res is None or len(res) < 100:
        return 1e6

    survival = len(res) / len(df)
    surv_penalty = w_surv * (1 - survival)**2

    try:
        xp, yp, _ = calc_all_params(res)
    except:
        return 1e5

    Dx = abs(xp[4])
    beta_x, beta_y = xp[1], yp[1]
    beta = 0.5 * (beta_x + beta_y)

    # ---- Beta window reward ----
    if beta < beta_min:
        beta_penalty = (beta_min - beta)**2
    elif beta > beta_max:
        beta_penalty = (beta - beta_max)**2
    else:
        beta_penalty = 0.0   # perfect region

    # ---- Dispersion penalty (weak) ----
    disp_penalty = Dx**2

    val = (
        w_surv * surv_penalty +
        w_beta * beta_penalty +
        w_disp * disp_penalty
    )

    print(
        f"OBJ={val:.4e} | surv={survival:.3f} "
        f"| beta={beta:.3f} m | Dx={Dx:.4f}"
    )
    history_beta.append({
    "Q1_L": q1L,
    "Q1_G": q1G,
    "Q2_L": q2L,
    "Q2_G": q2G,
    "Q_radius": qR,
    "Drift1_L": dL,
    "Dx": Dx,
    "beta_x": beta_x,
    "beta_y": beta_y,
    "survival": survival,
    "objective": val})
    return val

history_beta_d =[]
def optimize_dipole_beta(x, df_in, w_disp=100.0, w_beta=10.0, survival_threshold=0.95):
    """
    Dipole optimizer:
    - Strongly minimize dispersion
    - Weakly minimize beta
    - Enforce survival >= survival_threshold
    """

    B_field, B_length, Drift2_length = x
    print("\nTRYING DIPOLE x =", x)

    try:
        res = run_dipole(df_in, B_field, B_length, Drift2_length)
    except Exception as e:
        print("RUN FAILURE:", e)
        return 1e6

    if res is None or len(res) < 100:
        return 1e6

    survival = len(res) / len(df_in)
    if survival < survival_threshold:
        return 1e6 + 1e4 * (survival_threshold - survival)

    try:
        xp, yp, _ = calc_all_params(res)
    except:
        return 1e5

    Dx = abs(xp[4])
    beta_x, beta_y = xp[1], yp[1]
    beta = 0.5 * (beta_x + beta_y)

    val = (
        w_disp * Dx**2 +
        w_beta * beta**2
    )

    print(
        f"OBJ={val:.4e} | surv={survival:.3f} "
        f"| beta={beta:.3f} m | Dx={Dx:.4f}"
    )
    history_beta_d.append({
        "B_F": B_field,
        "B_L": B_length,
        "D2_L": Drift2_length,
        "Dx": Dx,
        "beta_x": beta_x,
        "beta_y": beta_y,
        "survival": survival,
        "objective": val})
    return val

# %%
x0_quad = [
    300,   # Q1 L
    10,    # Q1 G
    300,   # Q2 L
    -10,   # Q2 G
    50,    # radius
    200    # drift
]
x0_dip = [
    1.5,   # Tesla
    200,   # mm
    200    # mm
]

# %%
if os.path.exists("field_cellQ2.dat"):
    os.remove("field_cellQ2.dat")
    
res_q_beta = scipy.optimize.minimize(
    optimize_qq_drift_beta, x0_quad,
    args=(post_w1, beta_x_ref, beta_y_ref),
    method="Nelder-Mead",
    options={"xatol":1e-4, "fatol":1e-6, "maxiter":500}
)
print("Optimal parameters:", res_q_beta.x)
# Out:
# TRYING QUAD x = [300.  10. 300. -10.  50. 200.]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 157.894545453137
# Q1_length = 300.000000000000
# Q1_gradient = 10.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 307.894545453137
# Q2_length = 300.000000000000
# Q2_gradient = -10.000000000000
# Drift1_length = 200.000000000000
# Drift1_z = 407.894545453137
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 507.894545453137
# Q2_z = 657.894545453137
# Q2_end = 807.894545453137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:45 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.000000000000 \
#     fieldLength=300.000000000000 \
#     ironLength=300.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9106e+04 | surv=0.011 | beta=0.537 m | Dx=0.1099
#
# TRYING QUAD x = [315.  10. 300. -10.  50. 200.]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 165.394545453137
# Q1_length = 315.000000000000
# Q1_gradient = 10.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 322.894545453137
# Q2_length = 300.000000000000
# Q2_gradient = -10.000000000000
# Drift1_length = 200.000000000000
# Drift1_z = 422.894545453137
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 522.894545453137
# Q2_z = 672.894545453137
# Q2_end = 822.894545453137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:46 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.000000000000 \
#     fieldLength=315.000000000000 \
#     ironLength=315.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9140e+04 | surv=0.011 | beta=0.507 m | Dx=0.1316
#
# TRYING QUAD x = [300.   10.5 300.  -10.   50.  200. ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 157.894545453137
# Q1_length = 300.000000000000
# Q1_gradient = 10.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 307.894545453137
# Q2_length = 300.000000000000
# Q2_gradient = -10.000000000000
# Drift1_length = 200.000000000000
# Drift1_z = 407.894545453137
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 507.894545453137
# Q2_z = 657.894545453137
# Q2_end = 807.894545453137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:47 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.500000000000 \
#     fieldLength=300.000000000000 \
#     ironLength=300.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9104e+04 | surv=0.011 | beta=0.490 m | Dx=0.1228
#
# TRYING QUAD x = [300.  10. 315. -10.  50. 200.]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 157.894545453137
# Q1_length = 300.000000000000
# Q1_gradient = 10.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 307.894545453137
# Q2_length = 315.000000000000
# Q2_gradient = -10.000000000000
# Drift1_length = 200.000000000000
# Drift1_z = 407.894545453137
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 507.894545453137
# Q2_z = 665.394545453137
# Q2_end = 822.894545453137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:49 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.000000000000 \
#     fieldLength=300.000000000000 \
#     ironLength=300.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9127e+04 | surv=0.011 | beta=0.552 m | Dx=0.1125
#
# TRYING QUAD x = [300.   10.  300.  -10.5  50.  200. ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 157.894545453137
# Q1_length = 300.000000000000
# Q1_gradient = 10.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 307.894545453137
# Q2_length = 300.000000000000
# Q2_gradient = -10.500000000000
# Drift1_length = 200.000000000000
# Drift1_z = 407.894545453137
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 507.894545453137
# Q2_z = 657.894545453137
# Q2_end = 807.894545453137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:50 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.000000000000 \
#     fieldLength=300.000000000000 \
#     ironLength=300.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9110e+04 | surv=0.011 | beta=0.536 m | Dx=0.1091
#
# TRYING QUAD x = [300.   10.  300.  -10.   52.5 200. ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 157.894545453137
# Q1_length = 300.000000000000
# Q1_gradient = 10.000000000000
# radius_q = 52.500000000000
# thickness = 5.000000000000
# Q1_end = 307.894545453137
# Q2_length = 300.000000000000
# Q2_gradient = -10.000000000000
# Drift1_length = 200.000000000000
# Drift1_z = 407.894545453137
# Drift1_width = 105.000000000000
# Drift1_height = 105.000000000000
# D1_end = 507.894545453137
# Q2_z = 657.894545453137
# Q2_end = 807.894545453137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:51 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.000000000000 \
#     fieldLength=300.000000000000 \
#     ironLength=300.000000000000 \
#     ironRadius=52.500000000000+5.000000000000 \
#     apertureRadius=52.500000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9094e+04 | surv=0.012 | beta=0.536 m | Dx=0.1134
#
# TRYING QUAD x = [300.  10. 300. -10.  50. 210.]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 157.894545453137
# Q1_length = 300.000000000000
# Q1_gradient = 10.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 307.894545453137
# Q2_length = 300.000000000000
# Q2_gradient = -10.000000000000
# Drift1_length = 210.000000000000
# Drift1_z = 412.894545453137
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 517.894545453137
# Q2_z = 667.894545453137
# Q2_end = 817.894545453137
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:52 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.000000000000 \
#     fieldLength=300.000000000000 \
#     ironLength=300.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9086e+04 | surv=0.012 | beta=0.530 m | Dx=0.1107
#
# TRYING QUAD x = [285.          10.16666667 305.         -10.16666667  50.83333333
#  203.33333333]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 150.394545453137
# Q1_length = 285.000000000000
# Q1_gradient = 10.166666666667
# radius_q = 50.833333333333
# thickness = 5.000000000000
# Q1_end = 292.894545453137
# Q2_length = 305.000000000000
# Q2_gradient = -10.166666666667
# Drift1_length = 203.333333333333
# Drift1_z = 394.561212119803
# Drift1_width = 101.666666666667
# Drift1_height = 101.666666666667
# D1_end = 496.227878786470
# Q2_z = 648.727878786470
# Q2_end = 801.227878786470
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:54 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.166666666667 \
#     fieldLength=285.000000000000 \
#     ironLength=285.000000000000 \
#     ironRadius=50.833333333333+5.000000000000 \
#     apertureRadius=50.833333333333 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9110e+04 | surv=0.011 | beta=0.538 m | Dx=0.0995
#
# TRYING QUAD x = [295.          10.22222222 286.66666667 -10.22222222  51.11111111
#  204.44444444]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 155.394545453137
# Q1_length = 295.000000000000
# Q1_gradient = 10.222222222222
# radius_q = 51.111111111111
# thickness = 5.000000000000
# Q1_end = 302.894545453137
# Q2_length = 286.666666666667
# Q2_gradient = -10.222222222222
# Drift1_length = 204.444444444444
# Drift1_z = 405.116767675359
# Drift1_width = 102.222222222222
# Drift1_height = 102.222222222222
# D1_end = 507.338989897581
# Q2_z = 650.672323230914
# Q2_end = 794.005656564248
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:55 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.222222222222 \
#     fieldLength=295.000000000000 \
#     ironLength=295.000000000000 \
#     ironRadius=51.111111111111+5.000000000000 \
#     apertureRadius=51.111111111111 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9074e+04 | surv=0.012 | beta=0.525 m | Dx=0.1070
#
# TRYING QUAD x = [292.5         10.33333333 272.5        -10.33333333  51.66666667
#  206.66666667]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 154.144545453137
# Q1_length = 292.500000000000
# Q1_gradient = 10.333333333333
# radius_q = 51.666666666667
# thickness = 5.000000000000
# Q1_end = 300.394545453137
# Q2_length = 272.500000000000
# Q2_gradient = -10.333333333333
# Drift1_length = 206.666666666667
# Drift1_z = 403.727878786470
# Drift1_width = 103.333333333333
# Drift1_height = 103.333333333333
# D1_end = 507.061212119803
# Q2_z = 643.311212119803
# Q2_end = 779.561212119803
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:56 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.333333333333 \
#     fieldLength=292.500000000000 \
#     ironLength=292.500000000000 \
#     ironRadius=51.666666666667+5.000000000000 \
#     apertureRadius=51.666666666667 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9057e+04 | surv=0.012 | beta=0.509 m | Dx=0.1115
#
# TRYING QUAD x = [312.5         10.11111111 285.83333333 -10.11111111  50.55555556
#  202.22222222]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 164.144545453137
# Q1_length = 312.500000000000
# Q1_gradient = 10.111111111111
# radius_q = 50.555555555556
# thickness = 5.000000000000
# Q1_end = 320.394545453137
# Q2_length = 285.833333333333
# Q2_gradient = -10.111111111111
# Drift1_length = 202.222222222222
# Drift1_z = 421.505656564248
# Drift1_width = 101.111111111111
# Drift1_height = 101.111111111111
# D1_end = 522.616767675359
# Q2_z = 665.533434342026
# Q2_end = 808.450101008692
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:57 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.111111111111 \
#     fieldLength=312.500000000000 \
#     ironLength=312.500000000000 \
#     ironRadius=50.555555555556+5.000000000000 \
#     apertureRadius=50.555555555556 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9107e+04 | surv=0.011 | beta=0.477 m | Dx=0.1235
#
# TRYING QUAD x = [301.66666667  10.31481481 286.11111111  -9.64814815  51.57407407
#  206.2962963 ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 158.727878786470
# Q1_length = 301.666666666667
# Q1_gradient = 10.314814814815
# radius_q = 51.574074074074
# thickness = 5.000000000000
# Q1_end = 309.561212119803
# Q2_length = 286.111111111111
# Q2_gradient = -9.648148148148
# Drift1_length = 206.296296296296
# Drift1_z = 412.709360267952
# Drift1_width = 103.148148148148
# Drift1_height = 103.148148148148
# D1_end = 515.857508416100
# Q2_z = 658.913063971655
# Q2_end = 801.968619527211
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:33:58 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.314814814815 \
#     fieldLength=301.666666666667 \
#     ironLength=301.666666666667 \
#     ironRadius=51.574074074074+5.000000000000 \
#     apertureRadius=51.574074074074 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9069e+04 | surv=0.012 | beta=0.494 m | Dx=0.1153
#
# TRYING QUAD x = [285.55555556  10.27160494 300.37037037  -9.88271605  51.35802469
#  205.43209877]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 150.672323230915
# Q1_length = 285.555555555556
# Q1_gradient = 10.271604938272
# radius_q = 51.358024691358
# thickness = 5.000000000000
# Q1_end = 293.450101008692
# Q2_length = 300.370370370370
# Q2_gradient = -9.882716049383
# Drift1_length = 205.432098765432
# Drift1_z = 396.166150391408
# Drift1_width = 102.716049382716
# Drift1_height = 102.716049382716
# D1_end = 498.882199774124
# Q2_z = 649.067384959310
# Q2_end = 799.252570144495
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:00 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.271604938272 \
#     fieldLength=285.555555555556 \
#     ironLength=285.555555555556 \
#     ironRadius=51.358024691358+5.000000000000 \
#     apertureRadius=51.358024691358 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9106e+04 | surv=0.011 | beta=0.535 m | Dx=0.1064
#
# TRYING QUAD x = [293.24074074  10.47325103 286.32716049  -9.95473251  52.36625514
#  209.46502058]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 154.514915823507
# Q1_length = 293.240740740741
# Q1_gradient = 10.473251028807
# radius_q = 52.366255144033
# thickness = 5.000000000000
# Q1_end = 301.135286193878
# Q2_length = 286.327160493827
# Q2_gradient = -9.954732510288
# Drift1_length = 209.465020576132
# Drift1_z = 405.867796481943
# Drift1_width = 104.732510288066
# Drift1_height = 104.732510288066
# D1_end = 510.600306770009
# Q2_z = 653.763887016923
# Q2_end = 796.927467263836
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:01 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.473251028807 \
#     fieldLength=293.240740740741 \
#     ironLength=293.240740740741 \
#     ironRadius=52.366255144033+5.000000000000 \
#     apertureRadius=52.366255144033 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9070e+04 | surv=0.012 | beta=0.516 m | Dx=0.1178
#
# TRYING QUAD x = [310.24691358  10.26886145 281.27572016 -10.09602195  51.34430727
#  205.37722908]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 163.018002243260
# Q1_length = 310.246913580247
# Q1_gradient = 10.268861454047
# radius_q = 51.344307270233
# thickness = 5.000000000000
# Q1_end = 318.141459033384
# Q2_length = 281.275720164609
# Q2_gradient = -10.096021947874
# Drift1_length = 205.377229080933
# Drift1_z = 420.830073573850
# Drift1_width = 102.688614540466
# Drift1_height = 102.688614540466
# D1_end = 523.518688114316
# Q2_z = 664.156548196621
# Q2_end = 804.794408278925
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:02 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.268861454047 \
#     fieldLength=310.246913580247 \
#     ironLength=310.246913580247 \
#     ironRadius=51.344307270233+5.000000000000 \
#     apertureRadius=51.344307270233 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9102e+04 | surv=0.011 | beta=0.456 m | Dx=0.1225
#
# TRYING QUAD x = [299.218107     9.96342021 275.40466392 -10.01074531  53.15043439
#  212.60173754]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 157.503598951079
# Q1_length = 299.218106995885
# Q1_gradient = 9.963420210334
# radius_q = 53.150434385002
# thickness = 5.000000000000
# Q1_end = 307.112652449022
# Q2_length = 275.404663923183
# Q2_gradient = -10.010745313214
# Drift1_length = 212.601737540009
# Drift1_z = 413.413521219026
# Drift1_width = 106.300868770005
# Drift1_height = 106.300868770005
# D1_end = 519.714389989031
# Q2_z = 657.416721950622
# Q2_end = 795.119053912213
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:03 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=9.963420210334 \
#     fieldLength=299.218106995885 \
#     ironLength=299.218106995885 \
#     ironRadius=53.150434385002+5.000000000000 \
#     apertureRadius=53.150434385002 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9061e+04 | surv=0.012 | beta=0.507 m | Dx=0.1114
#
# TRYING QUAD x = [285.29492455  10.09274501 292.17192501  -9.88629782  52.40816949
#  209.63267795]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 150.542007730229
# Q1_length = 285.294924554184
# Q1_gradient = 10.092745008383
# radius_q = 52.408169486359
# thickness = 5.000000000000
# Q1_end = 293.189470007321
# Q2_length = 292.171925011431
# Q2_gradient = -9.886297820454
# Drift1_length = 209.632677945435
# Drift1_z = 398.005808980038
# Drift1_width = 104.816338972718
# Drift1_height = 104.816338972718
# D1_end = 502.822147952756
# Q2_z = 648.908110458471
# Q2_end = 794.994072964187
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:05 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.092745008383 \
#     fieldLength=285.294924554184 \
#     ironLength=285.294924554184 \
#     ironRadius=52.408169486359+5.000000000000 \
#     apertureRadius=52.408169486359 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9082e+04 | surv=0.012 | beta=0.526 m | Dx=0.0997
#
# TRYING QUAD x = [290.64014632  10.39252147 270.83828685  -9.94441904  51.22186659
#  218.22079967]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 153.214618612716
# Q1_length = 290.640146319159
# Q1_gradient = 10.392521465224
# radius_q = 51.221866585378
# thickness = 5.000000000000
# Q1_end = 298.534691772295
# Q2_length = 270.838286846517
# Q2_gradient = -9.944419041813
# Drift1_length = 218.220799674846
# Drift1_z = 407.645091609718
# Drift1_width = 102.443733170756
# Drift1_height = 102.443733170756
# D1_end = 516.755491447141
# Q2_z = 652.174634870400
# Q2_end = 787.593778293659
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:06 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.392521465224 \
#     fieldLength=290.640146319159 \
#     ironLength=290.640146319159 \
#     ironRadius=51.221866585378+5.000000000000 \
#     apertureRadius=51.221866585378 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9053e+04 | surv=0.012 | beta=0.508 m | Dx=0.1104
#
# TRYING QUAD x = [285.96021948  10.5887822  256.25743027  -9.91662856  50.58279988
#  227.33119951]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 150.874655192506
# Q1_length = 285.960219478738
# Q1_gradient = 10.588782197836
# radius_q = 50.582799878067
# thickness = 5.000000000000
# Q1_end = 293.854764931875
# Q2_length = 256.257430269776
# Q2_gradient = -9.916628562719
# Drift1_length = 227.331199512269
# Drift1_z = 407.520364688009
# Drift1_width = 101.165599756135
# Drift1_height = 101.165599756135
# D1_end = 521.185964444144
# Q2_z = 649.314679579032
# Q2_end = 777.443394713920
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:07 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.588782197836 \
#     fieldLength=285.960219478738 \
#     ironLength=285.960219478738 \
#     ironRadius=50.582799878067+5.000000000000 \
#     apertureRadius=50.582799878067 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9021e+04 | surv=0.012 | beta=0.500 m | Dx=0.0997
#
# TRYING QUAD x = [285.96021948  10.5887822  256.25743027  -9.91662856  53.91613321
#  213.99786618]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 150.874655192506
# Q1_length = 285.960219478738
# Q1_gradient = 10.588782197836
# radius_q = 53.916133211401
# thickness = 5.000000000000
# Q1_end = 293.854764931875
# Q2_length = 256.257430269776
# Q2_gradient = -9.916628562719
# Drift1_length = 213.997866178936
# Drift1_z = 400.853698021343
# Drift1_width = 107.832266422801
# Drift1_height = 107.832266422801
# D1_end = 507.852631110811
# Q2_z = 635.981346245699
# Q2_end = 764.110061380587
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:08 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.588782197836 \
#     fieldLength=285.960219478738 \
#     ironLength=285.960219478738 \
#     ironRadius=53.916133211401+5.000000000000 \
#     apertureRadius=53.916133211401 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9013e+04 | surv=0.013 | beta=0.498 m | Dx=0.1072
#
# TRYING QUAD x = [278.94032922  10.8831733  234.3861454   -9.87494284  55.87419982
#  215.99679927]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 147.364710062190
# Q1_length = 278.940329218107
# Q1_gradient = 10.883173296754
# radius_q = 55.874199817101
# thickness = 5.000000000000
# Q1_end = 286.834874671244
# Q2_length = 234.386145404664
# Q2_gradient = -9.874942844079
# Drift1_length = 215.996799268404
# Drift1_z = 394.833274305446
# Drift1_width = 111.748399634202
# Drift1_height = 111.748399634202
# D1_end = 502.831673939647
# Q2_z = 620.024746641980
# Q2_end = 737.217819344312
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:10 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.883173296754 \
#     fieldLength=278.940329218107 \
#     ironLength=278.940329218107 \
#     ironRadius=55.874199817101+5.000000000000 \
#     apertureRadius=55.874199817101 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8950e+04 | surv=0.013 | beta=0.497 m | Dx=0.1010
#
# TRYING QUAD x = [298.54709648  10.75951329 244.82357872 -10.02654575  52.66330717
#  216.48656201]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 157.168093692734
# Q1_length = 298.547096479195
# Q1_gradient = 10.759513285576
# radius_q = 52.663307168623
# thickness = 5.000000000000
# Q1_end = 306.441641932332
# Q2_length = 244.823578722756
# Q2_gradient = -10.026545750140
# Drift1_length = 216.486562007824
# Drift1_z = 414.684922936244
# Drift1_width = 105.326614337245
# Drift1_height = 105.326614337245
# D1_end = 522.928203940156
# Q2_z = 645.339993301534
# Q2_end = 767.751782662912
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:11 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.759513285576 \
#     fieldLength=298.547096479195 \
#     ironLength=298.547096479195 \
#     ironRadius=52.663307168623+5.000000000000 \
#     apertureRadius=52.663307168623 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9019e+04 | surv=0.012 | beta=0.445 m | Dx=0.0983
#
# TRYING QUAD x = [292.37006554  10.47442802 236.83381598  -9.98204881  52.80423885
#  218.99473319]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 154.079578222532
# Q1_length = 292.370065538790
# Q1_gradient = 10.474428017409
# radius_q = 52.804238852478
# thickness = 5.000000000000
# Q1_end = 300.264610991926
# Q2_length = 236.833815983336
# Q2_gradient = -9.982048806923
# Drift1_length = 218.994733187691
# Drift1_z = 409.761977585772
# Drift1_width = 105.608477704957
# Drift1_height = 105.608477704957
# D1_end = 519.259344179618
# Q2_z = 637.676252171286
# Q2_end = 756.093160162954
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:12 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.474428017409 \
#     fieldLength=292.370065538790 \
#     ironLength=292.370065538790 \
#     ironRadius=52.804238852478+5.000000000000 \
#     apertureRadius=52.804238852478 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.9025e+04 | surv=0.012 | beta=0.484 m | Dx=0.1019
#
# TRYING QUAD x = [280.84527257  10.68606863 220.62410032 -10.39993339  54.00647485
#  226.39626976]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 148.317181738256
# Q1_length = 280.845272570238
# Q1_gradient = 10.686068632266
# radius_q = 54.006474848572
# thickness = 5.000000000000
# Q1_end = 288.739818023375
# Q2_length = 220.624100323460
# Q2_gradient = -10.399933388655
# Drift1_length = 226.396269764658
# Drift1_z = 401.937952905704
# Drift1_width = 108.012949697144
# Drift1_height = 108.012949697144
# D1_end = 515.136087788033
# Q2_z = 625.448137949763
# Q2_end = 735.760188111494
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:13 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.686068632266 \
#     fieldLength=280.845272570238 \
#     ironLength=280.845272570238 \
#     ironRadius=54.006474848572+5.000000000000 \
#     apertureRadius=54.006474848572 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8946e+04 | surv=0.013 | beta=0.500 m | Dx=0.0927
#
# TRYING QUAD x = [270.43457552  10.87169554 187.88059493 -10.77582601  55.22267524
#  236.4462565 ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 143.111833214149
# Q1_length = 270.434575522024
# Q1_gradient = 10.871695540991
# radius_q = 55.222675235821
# thickness = 5.000000000000
# Q1_end = 278.329120975161
# Q2_length = 187.880594929635
# Q2_gradient = -10.775826008908
# Drift1_length = 236.446256498839
# Drift1_z = 396.552249224580
# Drift1_width = 110.445350471642
# Drift1_height = 110.445350471642
# D1_end = 514.775377474000
# Q2_z = 608.715674938817
# Q2_end = 702.655972403635
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:14 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=10.871695540991 \
#     fieldLength=270.434575522024 \
#     ironLength=270.434575522024 \
#     ironRadius=55.222675235821+5.000000000000 \
#     apertureRadius=55.222675235821 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8873e+04 | surv=0.014 | beta=0.525 m | Dx=0.0820
#
# TRYING QUAD x = [273.69932175  11.34022168 202.15585785 -10.29236312  53.12086149
#  228.03900151]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 144.744206328003
# Q1_length = 273.699321749733
# Q1_gradient = 11.340221680299
# radius_q = 53.120861487917
# thickness = 5.000000000000
# Q1_end = 281.593867202870
# Q2_length = 202.155857846873
# Q2_gradient = -10.292363122153
# Drift1_length = 228.039001507222
# Drift1_z = 395.613367956481
# Drift1_width = 106.241722975833
# Drift1_height = 106.241722975833
# D1_end = 509.632868710092
# Q2_z = 610.710797633529
# Q2_end = 711.788726556965
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:16 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=11.340221680299 \
#     fieldLength=273.699321749733 \
#     ironLength=273.699321749733 \
#     ironRadius=53.120861487917+5.000000000000 \
#     apertureRadius=53.120861487917 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8939e+04 | surv=0.013 | beta=0.504 m | Dx=0.0888
#
# TRYING QUAD x = [274.150536    11.30593801 181.61247439  -9.95611836  55.08936081
#  241.09818399]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 144.969813450901
# Q1_length = 274.150535995529
# Q1_gradient = 11.305938006289
# radius_q = 55.089360813336
# thickness = 5.000000000000
# Q1_end = 282.045081448665
# Q2_length = 181.612474385680
# Q2_gradient = -9.956118364974
# Drift1_length = 241.098183994083
# Drift1_z = 402.594173445707
# Drift1_width = 110.178721626671
# Drift1_height = 110.178721626671
# D1_end = 523.143265442749
# Q2_z = 613.949502635589
# Q2_end = 704.755739828429
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:17 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=11.305938006289 \
#     fieldLength=274.150535995529 \
#     ironLength=274.150535995529 \
#     ironRadius=55.089360813336+5.000000000000 \
#     apertureRadius=55.089360813336 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8928e+04 | surv=0.014 | beta=0.524 m | Dx=0.0817
#
# TRYING QUAD x = [268.20729394  11.44201332 198.87154454 -10.29875941  54.71349595
#  236.13793441]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 141.998192424296
# Q1_length = 268.207293942319
# Q1_gradient = 11.442013318506
# radius_q = 54.713495947810
# thickness = 5.000000000000
# Q1_end = 276.101839395456
# Q2_length = 198.871544536459
# Q2_gradient = -10.298759410734
# Drift1_length = 236.137934408523
# Drift1_z = 394.170806599717
# Drift1_width = 109.426991895619
# Drift1_height = 109.426991895619
# D1_end = 512.239773803978
# Q2_z = 611.675546072208
# Q2_end = 711.111318340437
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:18 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=11.442013318506 \
#     fieldLength=268.207293942319 \
#     ironLength=268.207293942319 \
#     ironRadius=54.713495947810+5.000000000000 \
#     apertureRadius=54.713495947810 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8919e+04 | surv=0.014 | beta=0.509 m | Dx=0.0897
#
# TRYING QUAD x = [268.69949816  11.61206951 160.31930167 -10.4915566   58.31183361
#  230.73704638]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 142.244294531586
# Q1_length = 268.699498156898
# Q1_gradient = 11.612069511636
# radius_q = 58.311833612135
# thickness = 5.000000000000
# Q1_end = 276.594043610034
# Q2_length = 160.319301672246
# Q2_gradient = -10.491556604277
# Drift1_length = 230.737046382696
# Drift1_z = 391.962566801382
# Drift1_width = 116.623667224270
# Drift1_height = 116.623667224270
# D1_end = 507.331089992730
# Q2_z = 587.490740828853
# Q2_end = 667.650391664976
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:19 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=11.612069511636 \
#     fieldLength=268.699498156898 \
#     ironLength=268.699498156898 \
#     ironRadius=58.311833612135+5.000000000000 \
#     apertureRadius=58.311833612135 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8848e+04 | surv=0.015 | beta=0.513 m | Dx=0.0748
#
# TRYING QUAD x = [260.0691375   12.12371317 112.35023737 -10.77902063  62.17635048
#  232.43996982]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 137.929114201125
# Q1_length = 260.069137495977
# Q1_gradient = 12.123713168536
# radius_q = 62.176350479169
# thickness = 5.000000000000
# Q1_end = 267.963682949114
# Q2_length = 112.350237373481
# Q2_gradient = -10.779020625055
# Drift1_length = 232.439969817909
# Drift1_z = 384.183667858069
# Drift1_width = 124.352700958337
# Drift1_height = 124.352700958337
# D1_end = 500.403652767023
# Q2_z = 556.578771453764
# Q2_end = 612.753890140505
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:21 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=12.123713168536 \
#     fieldLength=260.069137495977 \
#     ironLength=260.069137495977 \
#     ironRadius=62.176350479169+5.000000000000 \
#     apertureRadius=62.176350479169 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8708e+04 | surv=0.017 | beta=0.669 m | Dx=0.0605
#
# TRYING QUAD x = [243.28663483  11.89607172 127.59537277 -10.63246438  59.40234076
#  246.89948649]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 129.537862867487
# Q1_length = 243.286634828701
# Q1_gradient = 11.896071718215
# radius_q = 59.402340758428
# thickness = 5.000000000000
# Q1_end = 251.181180281838
# Q2_length = 127.595372769508
# Q2_gradient = -10.632464375161
# Drift1_length = 246.899486490503
# Drift1_z = 374.630923527089
# Drift1_width = 118.804681516856
# Drift1_height = 118.804681516856
# D1_end = 498.080666772341
# Q2_z = 561.878353157095
# Q2_end = 625.676039541849
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:22 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=11.896071718215 \
#     fieldLength=243.286634828701 \
#     ironLength=243.286634828701 \
#     ironRadius=59.402340758428+5.000000000000 \
#     apertureRadius=59.402340758428 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8669e+04 | surv=0.017 | beta=0.683 m | Dx=0.0664
#
# TRYING QUAD x = [215.656404    12.46435093  68.98126979 -10.93542369  62.77185755
#  262.10594873]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 115.722747454864
# Q1_length = 215.656404003454
# Q1_gradient = 12.464350934535
# radius_q = 62.771857553331
# thickness = 5.000000000000
# Q1_end = 223.550949456591
# Q2_length = 68.981269792885
# Q2_gradient = -10.935423687672
# Drift1_length = 262.105948731843
# Drift1_z = 354.603923822512
# Drift1_width = 125.543715106662
# Drift1_height = 125.543715106662
# D1_end = 485.656898188434
# Q2_z = 520.147533084876
# Q2_end = 554.638167981318
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:23 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=12.464350934535 \
#     fieldLength=215.656404003454 \
#     ironLength=215.656404003454 \
#     ironRadius=62.771857553331+5.000000000000 \
#     apertureRadius=62.771857553331 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8511e+04 | surv=0.020 | beta=1.120 m | Dx=0.0535
#
# TRYING QUAD x = [241.79876035  12.29947092  82.89784755 -11.1375609   58.49066736
#  262.75896572]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 128.793925628923
# Q1_length = 241.798760351572
# Q1_gradient = 12.299470919632
# radius_q = 58.490667355360
# thickness = 5.000000000000
# Q1_end = 249.693305804708
# Q2_length = 82.897847550340
# Q2_gradient = -11.137560895753
# Drift1_length = 262.758965717736
# Drift1_z = 381.072788663576
# Drift1_width = 116.981334710720
# Drift1_height = 116.981334710720
# D1_end = 512.452271522444
# Q2_z = 553.901195297615
# Q2_end = 595.350119072785
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:24 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=12.299470919632 \
#     fieldLength=241.798760351572 \
#     ironLength=241.798760351572 \
#     ironRadius=58.490667355360+5.000000000000 \
#     apertureRadius=58.490667355360 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8660e+04 | surv=0.017 | beta=0.921 m | Dx=0.0590
#
# TRYING QUAD x = [236.40624735  12.16217228  75.37546501 -11.00187321  63.03394097
#  262.29008488]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 126.097669130083
# Q1_length = 236.406247353892
# Q1_gradient = 12.162172282530
# radius_q = 63.033940973692
# thickness = 5.000000000000
# Q1_end = 244.300792807029
# Q2_length = 75.375465009287
# Q2_gradient = -11.001873208879
# Drift1_length = 262.290084882422
# Drift1_z = 375.445835248240
# Drift1_width = 126.067881947384
# Drift1_height = 126.067881947384
# D1_end = 506.590877689451
# Q2_z = 544.278610194094
# Q2_end = 581.966342698737
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:25 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=12.162172282530 \
#     fieldLength=236.406247353892 \
#     ironLength=236.406247353892 \
#     ironRadius=63.033940973692+5.000000000000 \
#     apertureRadius=63.033940973692 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8579e+04 | surv=0.018 | beta=0.977 m | Dx=0.0575
#
# TRYING QUAD x = [223.37360356  12.48186738  60.50651201 -11.68670291  63.71363504
#  256.29486936]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 119.581347233579
# Q1_length = 223.373603560884
# Q1_gradient = 12.481867381955
# radius_q = 63.713635035058
# thickness = 5.000000000000
# Q1_end = 231.268149014021
# Q2_length = 60.506512011682
# Q2_gradient = -11.686702914027
# Drift1_length = 256.294869358341
# Drift1_z = 359.415583693191
# Drift1_width = 127.427270070117
# Drift1_height = 127.427270070117
# D1_end = 487.563018372361
# Q2_z = 517.816274378202
# Q2_end = 548.069530384043
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:27 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=12.481867381955 \
#     fieldLength=223.373603560884 \
#     ironLength=223.373603560884 \
#     ironRadius=63.713635035058+5.000000000000 \
#     apertureRadius=63.713635035058 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8517e+04 | surv=0.019 | beta=1.139 m | Dx=0.0536
#
# TRYING QUAD x = [214.37228215  12.69241009  -2.87423565 -11.8067097   67.08954626
#  267.97409726]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 115.080686529944
# Q1_length = 214.372282153615
# Q1_gradient = 12.692410090887
# radius_q = 67.089546263001
# thickness = 5.000000000000
# Q1_end = 222.266827606752
# Q2_length = -2.874235647355
# Q2_gradient = -11.806709702697
# Drift1_length = 267.974097260507
# Drift1_z = 356.253876237006
# Drift1_width = 134.179092526001
# Drift1_height = 134.179092526001
# D1_end = 490.240924867260
# Q2_z = 488.803807043582
# Q2_end = 487.366689219904
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:28 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=12.692410090887 \
#     fieldLength=214.372282153615 \
#     ironLength=214.372282153615 \
#     ironRadius=67.089546263001+5.000000000000 \
#     apertureRadius=67.089546263001 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=4.4343e+04 | surv=0.023 | beta=11.099 m | Dx=0.0472
#
# TRYING QUAD x = [254.748541    11.75461251 148.43509949 -10.67574698  57.80750853
#  244.09697512]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 135.268815950708
# Q1_length = 254.748540995143
# Q1_gradient = 11.754612511601
# radius_q = 57.807508526607
# thickness = 5.000000000000
# Q1_end = 262.643086448280
# Q2_length = 148.435099490505
# Q2_gradient = -10.675746983725
# Drift1_length = 244.096975121519
# Drift1_z = 384.691574009039
# Drift1_width = 115.615017053215
# Drift1_height = 115.615017053215
# D1_end = 506.740061569799
# Q2_z = 580.957611315051
# Q2_end = 655.175161060304
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:29 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=11.754612511601 \
#     fieldLength=254.748540995143 \
#     ironLength=254.748540995143 \
#     ironRadius=57.807508526607+5.000000000000 \
#     apertureRadius=57.807508526607 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8774e+04 | surv=0.016 | beta=0.588 m | Dx=0.0697
#
# TRYING QUAD x = [206.9163224   13.55703353  -5.03178452 -11.29628343  67.44197807
#  270.21601471]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 111.352706652278
# Q1_length = 206.916322398283
# Q1_gradient = 13.557033525271
# radius_q = 67.441978071918
# thickness = 5.000000000000
# Q1_end = 214.810867851420
# Q2_length = -5.031784520242
# Q2_gradient = -11.296283429463
# Drift1_length = 270.216014711084
# Drift1_z = 349.918875206962
# Drift1_width = 134.883956143836
# Drift1_height = 134.883956143836
# D1_end = 485.026882562504
# Q2_z = 482.510990302383
# Q2_end = 479.995098042262
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:30 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.557033525271 \
#     fieldLength=206.916322398283 \
#     ironLength=206.916322398283 \
#     ironRadius=67.441978071918+5.000000000000 \
#     apertureRadius=67.441978071918 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=4.4163e+04 | surv=0.023 | beta=10.938 m | Dx=0.0486
#
# TRYING QUAD x = [254.55501224  11.54303004 139.65250007 -10.90594036  58.27750094
#  244.88869605]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 135.172051573681
# Q1_length = 254.555012241089
# Q1_gradient = 11.543030037061
# radius_q = 58.277500944845
# thickness = 5.000000000000
# Q1_end = 262.449557694225
# Q2_length = 139.652500067166
# Q2_gradient = -10.905940364047
# Drift1_length = 244.888696051900
# Drift1_z = 384.893905720176
# Drift1_width = 116.555001889690
# Drift1_height = 116.555001889690
# D1_end = 507.338253746126
# Q2_z = 577.164503779709
# Q2_end = 646.990753813292
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:31 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=11.543030037061 \
#     fieldLength=254.555012241089 \
#     ironLength=254.555012241089 \
#     ironRadius=58.277500944845+5.000000000000 \
#     apertureRadius=58.277500944845 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8720e+04 | surv=0.016 | beta=0.614 m | Dx=0.0688
#
# TRYING QUAD x = [222.53784734  12.60358906  31.48617778 -11.47309358  65.01380892
#  262.82920307]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 119.163469123377
# Q1_length = 222.537847340479
# Q1_gradient = 12.603589063148
# radius_q = 65.013808920544
# thickness = 5.000000000000
# Q1_end = 230.432392793616
# Q2_length = 31.486177777775
# Q2_gradient = -11.473093581419
# Drift1_length = 262.829203065198
# Drift1_z = 361.846994326215
# Drift1_width = 130.027617841089
# Drift1_height = 130.027617841089
# D1_end = 493.261595858815
# Q2_z = 509.004684747702
# Q2_end = 524.747773636590
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:33 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=12.603589063148 \
#     fieldLength=222.537847340479 \
#     ironLength=222.537847340479 \
#     ironRadius=65.013808920544+5.000000000000 \
#     apertureRadius=65.013808920544 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8598e+04 | surv=0.020 | beta=2.110 m | Dx=0.0487
#
# TRYING QUAD x = [212.05898779  13.16869121   4.21333644 -11.43195127  66.78925249
#  268.01765114]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 113.924039350302
# Q1_length = 212.058987794331
# Q1_gradient = 13.168691213050
# radius_q = 66.789252494206
# thickness = 5.000000000000
# Q1_end = 219.953533247467
# Q2_length = 4.213336437984
# Q2_gradient = -11.431951273555
# Drift1_length = 268.017651139249
# Drift1_z = 353.962358817092
# Drift1_width = 133.578504988412
# Drift1_height = 133.578504988412
# D1_end = 487.971184386717
# Q2_z = 490.077852605709
# Q2_end = 492.184520824701
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:34 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.168691213050 \
#     fieldLength=212.058987794331 \
#     ironLength=212.058987794331 \
#     ironRadius=66.789252494206+5.000000000000 \
#     apertureRadius=66.789252494206 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=4.4133e+04 | surv=0.021 | beta=10.817 m | Dx=0.0472
#
# TRYING QUAD x = [243.93100613  11.94944533 105.79270916 -11.03744309  60.40543883
#  250.67093482]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 129.860048517836
# Q1_length = 243.931006129399
# Q1_gradient = 11.949445331059
# radius_q = 60.405438832185
# thickness = 5.000000000000
# Q1_end = 251.825551582536
# Q2_length = 105.792709159870
# Q2_gradient = -11.037443091424
# Drift1_length = 250.670934823738
# Drift1_z = 377.161018994405
# Drift1_width = 120.810877664371
# Drift1_height = 120.810877664371
# D1_end = 502.496486406274
# Q2_z = 555.392840986209
# Q2_end = 608.289195566144
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:34:35 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=11.949445331059 \
#     fieldLength=243.931006129399 \
#     ironLength=243.931006129399 \
#     ironRadius=60.405438832185+5.000000000000 \
#     apertureRadius=60.405438832185 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
# ...
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401025
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:11 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401025
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:12 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401024
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:13 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401024
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:14 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401024
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:15 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401025
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:16 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401025
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:17 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401024
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:18 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401024
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:20 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401024
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:21 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401024
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:22 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401024
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:23 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
#
# TRYING QUAD x = [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401024
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:24 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# OBJ=3.8166e+04 | surv=0.024 | beta=1.071 m | Dx=0.0362
# Optimal parameters: [154.92757032  13.15531643  93.83668942 -12.85320328  90.65867974
#  114.48399591]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401024
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:25 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# FINAL:
# Survival: 0.0239
# Beta: 1.0712324978477992
# Dx: -0.036171074974890895

# %%
df_opt_q_beta = run_two_quadrupoles(post_w1, Q1_length=res_q_beta.x[0], Q1_gradient=res_q_beta.x[1],
                             Q2_length=res_q_beta.x[2], Q2_gradient=res_q_beta.x[3],
                             Q_radius=res_q_beta.x[4], Drift1_length=res_q_beta.x[5])

xp, yp, zp = calc_all_params(df_opt_q_beta)
print("FINAL:")
print("Survival:", len(df_opt_q_beta)/len(post_w1))
print("Beta:", 0.5*(xp[1] + yp[1]))
print("Dx:", xp[4])
# Out:
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 85.358330613908
# Q1_length = 154.927570321542
# Q1_gradient = 13.155316434444
# radius_q = 90.658679740930
# thickness = 5.000000000000
# Q1_end = 162.822115774679
# Q2_length = 93.836689423884
# Q2_gradient = -12.853203283144
# Drift1_length = 114.483995914404
# Drift1_z = 220.064113731881
# Drift1_width = 181.317359481859
# Drift1_height = 181.317359481859
# D1_end = 277.306111689083
# Q2_z = 324.224456401024
# Q2_end = 371.142801112966
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Tue Jan 20 10:48:26 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=13.155316434444 \
#     fieldLength=154.927570321542 \
#     ironLength=154.927570321542 \
#     ironRadius=90.658679740930+5.000000000000 \
#     apertureRadius=90.658679740930 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# FINAL:
# Survival: 0.0239
# Beta: 1.0712324978477992
# Dx: -0.036171074974890895

# %%
df_hist_beta = pd.DataFrame(history_beta)
plt.figure(figsize=(6,5))

sc = plt.scatter(
    df_hist_beta["Q1_G"],
    df_hist_beta["Q2_G"],
    c=df_hist_beta["objective"].values,
    cmap="viridis",
    s=40
)

best = df_hist_beta.loc[df_hist_beta["objective"].idxmin()]
plt.scatter(
    best["Q1_G"],
    best["Q2_G"],
    color="red",
    s=120,
    label="Best"
)

plt.colorbar(sc, label="Objective")
plt.xlabel("Q1 gradient")
plt.ylabel("Q2 gradient")
plt.title("Quad optimization search space")
plt.legend()
plt.show()

plt.scatter(
    df_hist_beta["Q1_G"],
    df_hist_beta["Q2_G"],
    c=df_hist_beta["survival"],
    cmap="plasma",
    s=40
)
plt.colorbar(label="Survival fraction")
plt.xlabel("Q1 gradient")
plt.ylabel("Q2 gradient")
plt.title("Survival across quad parameter space")
plt.show()
plt.figure()
sc= plt.scatter(df_hist_beta["Dx"], df_hist_beta["objective"], c=df_hist_beta["beta_x"].values, cmap="plasma", alpha=0.6)
plt.colorbar(sc, label="beta_x")
plt.xlabel("Dx")
plt.ylabel("Objective")
plt.title("Dispersion vs objective")
plt.show()

plt.figure(figsize=(6,5))
sc = plt.scatter(
    df_hist_beta["Q1_G"],
    df_hist_beta["Q2_G"],
    c=df_hist_beta["Dx"].values,
    cmap="viridis",
    s=40
)

best = df_hist_beta.loc[df_hist_beta["Dx"].idxmin()]
plt.scatter(
    best["Q1_G"],
    best["Q2_G"],
    color="red",
    s=120,
    label="Best"
)


plt.colorbar(sc, label="Dx")
plt.xlabel("Q1 gradient")
plt.ylabel("Q2 gradient")
plt.title("Quad optimization search space")
plt.legend()
plt.show()

plt.figure(figsize=(6,5))
sc = plt.scatter(
    df_hist_beta["Q1_G"],
    df_hist_beta["Q2_G"],
    c=df_hist_beta["beta_x"].values,
    cmap="viridis",
    s=40
)

best = df_hist_beta.loc[df_hist_beta["beta_x"].idxmin()]
plt.scatter(
    best["Q1_G"],
    best["Q2_G"],
    color="red",
    s=120,
    label="Best min"
)
best_max = df_hist_beta.loc[df_hist_beta["beta_x"].idxmax()]
plt.scatter(
    best_max["Q1_G"],
    best_max["Q2_G"],
    color="blue",
    s=120,
    label="Best max"
)

plt.colorbar(sc, label="beta_x")
plt.xlabel("Q1 gradient")
plt.ylabel("Q2 gradient")
plt.title("Quad optimization search space")
plt.legend()
plt.show()

# %%
if os.path.exists("field_cellB.dat"):
    os.remove("field_cellB.dat")

res_b_beta = minimize(optimize_dipole_safe, x0_dip, args=(df_opt_q_beta, xp[1], yp[1]), method="Nelder-Mead")

print("Optimal dipole parameters:", res_b_beta.x)
# Out:
# iter value
#
# TRYING dipole x = [  1.5 200.  200. ]
# Survival: 376/478 → penalty 4.553
# OBJECTIVE = 13.026405, Dx=-0.064988, beta_penalty=1064.102413
#
# TRYING dipole x = [  1.575 200.    200.   ]
# Survival: 376/478 → penalty 4.553
# OBJECTIVE = 13.026405, Dx=-0.064988, beta_penalty=1064.102413
#
# TRYING dipole x = [  1.5 210.  200. ]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.009903, Dx=-0.052217, beta_penalty=1146.502249
#
# TRYING dipole x = [  1.5 200.  210. ]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.009903, Dx=-0.052217, beta_penalty=1146.502249
#
# TRYING dipole x = [  1.55       206.66666667 206.66666667]
# Survival: 372/478 → penalty 4.918
# OBJECTIVE = 13.422583, Dx=-0.058432, beta_penalty=1202.581929
#
# TRYING dipole x = [  1.5125     201.66666667 201.66666667]
# Survival: 376/478 → penalty 4.553
# OBJECTIVE = 13.083158, Dx=-0.065447, beta_penalty=1087.058169
#
# TRYING dipole x = [  1.5 205.  205. ]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.009903, Dx=-0.052217, beta_penalty=1146.502249
#
# TRYING dipole x = [  1.5375 200.     205.    ]
# Survival: 376/478 → penalty 4.553
# OBJECTIVE = 13.111371, Dx=-0.065676, beta_penalty=1098.651673
#
# TRYING dipole x = [  1.5 200.  205. ]
# Survival: 376/478 → penalty 4.553
# OBJECTIVE = 13.111371, Dx=-0.065676, beta_penalty=1098.651673
#    1 1.30099e+01
# TRYING dipole x = [  1.525      203.33333333 208.33333333]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.038032, Dx=-0.052408, beta_penalty=1158.516038
#    2 1.30099e+01
# TRYING dipole x = [  1.47916667 205.55555556 210.55555556]
# Survival: 372/478 → penalty 4.918
# OBJECTIVE = 13.469036, Dx=-0.058775, beta_penalty=1223.654704
#
# TRYING dipole x = [  1.52291667 201.38888889 206.38888889]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.017227, Dx=-0.056519, beta_penalty=1112.900913
#    3 1.30099e+01
# TRYING dipole x = [  1.49027778 200.92592593 205.92592593]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.001675, Dx=-0.056406, beta_penalty=1106.487889
#
# TRYING dipole x = [  1.47291667 199.72222222 204.72222222]
# Survival: 376/478 → penalty 4.553
# OBJECTIVE = 13.101893, Dx=-0.065600, beta_penalty=1094.733414
#    4 1.30017e+01
# TRYING dipole x = [  1.47060185 202.5617284  207.5617284 ]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.011930, Dx=-0.052231, beta_penalty=1147.354371
#
# TRYING dipole x = [  1.48368056 202.26851852 207.26851852]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.001967, Dx=-0.052164, beta_penalty=1143.121555
#    5 1.30017e+01
# TRYING dipole x = [  1.48263889 197.12962963 210.46296296]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.014151, Dx=-0.056497, beta_penalty=1111.634372
#
# TRYING dipole x = [  1.49565972 203.03240741 206.36574074]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.999591, Dx=-0.052148, beta_penalty=1142.111189
#    6 1.29996e+01
# TRYING dipole x = [  1.47974537 204.15123457 203.04012346]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.007380, Dx=-0.056448, beta_penalty=1108.834231
#
# TRYING dipole x = [  1.48480903 203.11342593 204.78009259]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.019185, Dx=-0.056533, beta_penalty=1113.713305
#
# TRYING dipole x = [  1.49296875 201.97916667 206.14583333]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.023118, Dx=-0.056561, beta_penalty=1115.350760
#
# TRYING dipole x = [  1.48967014 202.65046296 206.81712963]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.000728, Dx=-0.052156, beta_penalty=1142.587038
#
# TRYING dipole x = [  1.49782986 201.5162037  208.18287037]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.004801, Dx=-0.052183, beta_penalty=1144.334386
#    7 1.29996e+01
# TRYING dipole x = [  1.4958044  202.82021605 208.09799383]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.025322, Dx=-0.052322, beta_penalty=1153.058531
#
# TRYING dipole x = [  1.49367766 202.18942901 206.63387346]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.034879, Dx=-0.056646, beta_penalty=1120.247488
#
# TRYING dipole x = [  1.49266493 202.84143519 206.59143519]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.000168, Dx=-0.052152, beta_penalty=1142.353197
#
# TRYING dipole x = [  1.49674479 202.27430556 207.27430556]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.002164, Dx=-0.052166, beta_penalty=1143.204475
#
# TRYING dipole x = [  1.49431424 202.50578704 206.25578704]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.033779, Dx=-0.056639, beta_penalty=1119.779982
#    8 1.29996e+01
# TRYING dipole x = [  1.49573206 202.92631173 207.23186728]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.012522, Dx=-0.052235, beta_penalty=1147.609292
#
# TRYING dipole x = [  1.4953776  202.82118056 206.98784722]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 13.006598, Dx=-0.052195, beta_penalty=1145.086330
#    9 1.29996e+01
# TRYING dipole x = [  1.49466869 202.61091821 206.4998071 ]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.994706, Dx=-0.052116, beta_penalty=1140.041479
#
# TRYING dipole x = [  1.49431424 202.50578704 206.25578704]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.033779, Dx=-0.056639, beta_penalty=1119.779982
#   10 1.29947e+01
# TRYING dipole x = [  1.49191744 203.38220165 205.69701646]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.994309, Dx=-0.052112, beta_penalty=1139.895846
#
# TRYING dipole x = [  1.48950376 203.93614969 204.90837191]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.035223, Dx=-0.056649, beta_penalty=1120.389614
#   11 1.29943e+01
# TRYING dipole x = [  1.49549897 203.17558299 205.78360768]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037087, Dx=-0.056663, beta_penalty=1121.156129
#
# TRYING dipole x = [  1.49337344 202.92497214 206.38947831]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.998301, Dx=-0.052139, beta_penalty=1141.584728
#   12 1.29943e+01
# TRYING dipole x = [  1.49097999 202.91298725 206.02512717]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.036779, Dx=-0.056660, beta_penalty=1121.035711
#
# TRYING dipole x = [  1.49448979 203.00255237 206.28058735]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.997683, Dx=-0.052135, beta_penalty=1141.309543
#   13 1.29943e+01
# TRYING dipole x = [  1.49401051 203.07214268 205.92879563]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992936, Dx=-0.052103, beta_penalty=1139.310791
#
# TRYING dipole x = [  1.49432904 203.14572795 205.69845429]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.035239, Dx=-0.056649, beta_penalty=1120.397261
#   14 1.29929e+01
# TRYING dipole x = [  1.49257463 203.04095599 205.80315878]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.035230, Dx=-0.056649, beta_penalty=1120.392360
#
# TRYING dipole x = [  1.494011   203.01215327 206.16123021]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.995828, Dx=-0.052123, beta_penalty=1140.527132
#   15 1.29929e+01
# TRYING dipole x = [  1.49305342 203.03135508 205.92251592]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.036965, Dx=-0.056662, beta_penalty=1121.100998
#
# TRYING dipole x = [  1.49377161 203.01695373 206.10155163]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.994884, Dx=-0.052116, beta_penalty=1140.125291
#   16 1.29929e+01
# TRYING dipole x = [  1.49329282 203.02655463 205.98219449]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.993069, Dx=-0.052104, beta_penalty=1139.364171
#   17 1.29929e+01
# TRYING dipole x = [  1.49147848 203.7096811  205.23886396]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.036880, Dx=-0.056662, beta_penalty=1121.067501
#
# TRYING dipole x = [  1.49387114 202.88560893 206.18457131]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.994025, Dx=-0.052111, beta_penalty=1139.757576
#   18 1.29929e+01
# TRYING dipole x = [  1.4955322  202.60733585 206.36669116]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037466, Dx=-0.056665, beta_penalty=1121.332918
#
# TRYING dipole x = [  1.49282113 203.1884852  205.86443514]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.993791, Dx=-0.052109, beta_penalty=1139.666560
#   19 1.29929e+01
# TRYING dipole x = [  1.4928785  203.30584607 205.66571219]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037263, Dx=-0.056664, beta_penalty=1121.226069
#
# TRYING dipole x = [  1.49362298 202.99066822 206.05485653]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.993651, Dx=-0.052108, beta_penalty=1139.602940
#   20 1.29929e+01
# TRYING dipole x = [  1.49446307 202.87109182 206.11279597]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037506, Dx=-0.056666, beta_penalty=1121.333538
#
# TRYING dipole x = [  1.49323162 203.10913685 205.92652534]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.993485, Dx=-0.052107, beta_penalty=1139.537459
#   21 1.29929e+01
# TRYING dipole x = [  1.49340031 203.14788789 205.83682044]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037530, Dx=-0.056666, beta_penalty=1121.343965
#
# TRYING dipole x = [  1.49356731 203.02997314 206.00034751]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.993425, Dx=-0.052106, beta_penalty=1139.516672
#   22 1.29929e+01
# TRYING dipole x = [  1.49401548 202.97664345 206.01436641]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992717, Dx=-0.052102, beta_penalty=1139.210350
#
# TRYING dipole x = [  1.49440741 202.91039674 206.05828694]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037331, Dx=-0.056664, beta_penalty=1121.269664
#   23 1.29927e+01
# TRYING dipole x = [  1.49397855 203.02025404 205.94989018]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037341, Dx=-0.056664, beta_penalty=1121.272038
#
# TRYING dipole x = [  1.49367012 203.02754336 205.98773318]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.993150, Dx=-0.052105, beta_penalty=1139.393979
#   24 1.29927e+01
# TRYING dipole x = [  1.49387574 203.02268381 205.96250451]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992631, Dx=-0.052101, beta_penalty=1139.174175
#
# TRYING dipole x = [  1.49397855 203.02025404 205.94989018]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037341, Dx=-0.056664, beta_penalty=1121.272038
#   25 1.29926e+01
# TRYING dipole x = [  1.49464167 203.02109199 205.95491654]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037444, Dx=-0.056665, beta_penalty=1121.315722
#
# TRYING dipole x = [  1.49363003 203.02518897 205.975375  ]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992903, Dx=-0.052103, beta_penalty=1139.293043
#   26 1.29926e+01
# TRYING dipole x = [  1.49367033 202.94420147 206.03936832]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037497, Dx=-0.056666, beta_penalty=1121.328927
#
# TRYING dipole x = [  1.49392546 203.04015738 205.9564388 ]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992821, Dx=-0.052102, beta_penalty=1139.253766
#   27 1.29926e+01
# TRYING dipole x = [  1.49424776 203.00113412 205.98016481]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037487, Dx=-0.056666, beta_penalty=1121.326403
#
# TRYING dipole x = [  1.49378446 203.01917526 205.97657246]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992766, Dx=-0.052102, beta_penalty=1139.225317
#   28 1.29926e+01
# TRYING dipole x = [  1.49385833 202.97217763 206.01252345]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037526, Dx=-0.056666, beta_penalty=1121.342214
#
# TRYING dipole x = [  1.49390868 203.02316244 205.97045996]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992836, Dx=-0.052102, beta_penalty=1139.269810
#
# TRYING dipole x = [  1.49394561 202.99966363 205.98843546]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992772, Dx=-0.052101, beta_penalty=1139.247116
#
# TRYING dipole x = [  1.4938301  203.02092953 205.96953848]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992712, Dx=-0.052102, beta_penalty=1139.206538
#
# TRYING dipole x = [  1.4939006  203.03142059 205.95947166]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992706, Dx=-0.052102, beta_penalty=1139.204140
#   29 1.29926e+01
# TRYING dipole x = [  1.49379202 203.050359   205.93924097]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992685, Dx=-0.052102, beta_penalty=1139.194915
#   30 1.29926e+01
# TRYING dipole x = [  1.49388214 203.04871273 205.93793961]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992692, Dx=-0.052101, beta_penalty=1139.202859
#   31 1.29926e+01
# TRYING dipole x = [  1.49379934 203.04974977 205.93365174]
# Survival: 374/478 → penalty 4.734
# OBJECTIVE = 13.037502, Dx=-0.056666, beta_penalty=1121.331244
#
# TRYING dipole x = [  1.49387529 203.03600289 205.95301668]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992626, Dx=-0.052102, beta_penalty=1139.162421
#   32 1.29926e+01
# TRYING dipole x = [  1.49381322 203.0239844  205.96523516]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992640, Dx=-0.052101, beta_penalty=1139.170837
#   33 1.29926e+01
# TRYING dipole x = [  1.49391748 203.00475506 205.98126326]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992698, Dx=-0.052101, beta_penalty=1139.211039
#
# TRYING dipole x = [  1.49382339 203.03895801 205.94974655]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992728, Dx=-0.052101, beta_penalty=1139.221730
#
# TRYING dipole x = [  1.49387551 203.02934335 205.95776059]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992713, Dx=-0.052101, beta_penalty=1139.215338
#
# TRYING dipole x = [  1.49384426 203.02999364 205.95912592]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992637, Dx=-0.052101, beta_penalty=1139.168961
#
# TRYING dipole x = [  1.49383365 203.04318094 205.94612883]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992646, Dx=-0.052102, beta_penalty=1139.173737
#   34 1.29926e+01
# TRYING dipole x = [  1.49382662 203.04344163 205.94775369]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992755, Dx=-0.052102, beta_penalty=1139.230215
#
# TRYING dipole x = [  1.49386329 203.03286792 205.95525887]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992769, Dx=-0.052101, beta_penalty=1139.245411
#
# TRYING dipole x = [  1.49385977 203.03299826 205.9560713 ]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992631, Dx=-0.052101, beta_penalty=1139.165841
#
# TRYING dipole x = [  1.49385447 203.03959192 205.94957275]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992640, Dx=-0.052101, beta_penalty=1139.171151
#
# TRYING dipole x = [  1.4938754  203.03267312 205.95538864]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992765, Dx=-0.052101, beta_penalty=1139.244392
#   35 1.29926e+01
# TRYING dipole x = [  1.49385095 203.03972226 205.95038518]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992670, Dx=-0.052102, beta_penalty=1139.184638
#
# TRYING dipole x = [  1.49385706 203.03795997 205.95163605]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992689, Dx=-0.052102, beta_penalty=1139.197291
#
# TRYING dipole x = [  1.49386753 203.03450058 205.95454399]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992634, Dx=-0.052101, beta_penalty=1139.167142
#
# TRYING dipole x = [  1.49386488 203.0377974  205.95129471]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992635, Dx=-0.052102, beta_penalty=1139.167933
#
# TRYING dipole x = [  1.49387534 203.034338   205.95420266]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992698, Dx=-0.052101, beta_penalty=1139.205142
#   36 1.29926e+01
# TRYING dipole x = [  1.49386312 203.03786257 205.95170093]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992687, Dx=-0.052102, beta_penalty=1139.196284
#
# TRYING dipole x = [  1.49386617 203.03698143 205.95232636]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992651, Dx=-0.052102, beta_penalty=1139.176241
#   37 1.29926e+01
# TRYING dipole x = [  1.49387229 203.03521915 205.95357722]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992742, Dx=-0.052101, beta_penalty=1139.229408
#
# TRYING dipole x = [  1.4938677  203.03654086 205.95263908]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992639, Dx=-0.052101, beta_penalty=1139.170076
#   38 1.29926e+01
# TRYING dipole x = [  1.49387076 203.03565972 205.95326451]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992690, Dx=-0.052102, beta_penalty=1139.198644
#
# TRYING dipole x = [  1.49386847 203.03632057 205.95279544]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992637, Dx=-0.052101, beta_penalty=1139.168962
#   39 1.29926e+01
# TRYING dipole x = [  1.49386999 203.03588    205.95310815]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992627, Dx=-0.052102, beta_penalty=1139.163159
#   40 1.29926e+01
# TRYING dipole x = [  1.49387699 203.03312491 205.95581783]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992686, Dx=-0.052102, beta_penalty=1139.196099
#
# TRYING dipole x = [  1.49386791 203.03662928 205.95242549]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992632, Dx=-0.052101, beta_penalty=1139.165993
#   41 1.29926e+01
# TRYING dipole x = [  1.4938746  203.03784087 205.95115623]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992627, Dx=-0.052102, beta_penalty=1139.163159
#   42 1.29926e+01
# TRYING dipole x = [  1.49387868 203.03651989 205.95242854]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992668, Dx=-0.052101, beta_penalty=1139.186645
#
# TRYING dipole x = [  1.4938706  203.03660193 205.95242626]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992633, Dx=-0.052102, beta_penalty=1139.166370
#
# TRYING dipole x = [  1.49387494 203.03692188 205.95208645]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.161714
#
# TRYING dipole x = [  1.49387264 203.03594145 205.95306241]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992626, Dx=-0.052102, beta_penalty=1139.162566
#
# TRYING dipole x = [  1.4938716  203.03631608 205.95272109]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992634, Dx=-0.052101, beta_penalty=1139.167142
#   43 1.29926e+01
# TRYING dipole x = [  1.49387698 203.03626139 205.95272261]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992661, Dx=-0.052101, beta_penalty=1139.182852
#
# TRYING dipole x = [  1.49387294 203.03630241 205.95272147]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992628, Dx=-0.052102, beta_penalty=1139.163688
#   44 1.29926e+01
# TRYING dipole x = [  1.49387564 203.03627506 205.95272223]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992627, Dx=-0.052102, beta_penalty=1139.163159
#
# TRYING dipole x = [  1.49387496 203.0362819  205.95272204]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992626, Dx=-0.052102, beta_penalty=1139.162566
#   45 1.29926e+01
# TRYING dipole x = [  1.49387362 203.03629557 205.95272166]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992626, Dx=-0.052102, beta_penalty=1139.162421
#   46 1.29926e+01
# TRYING dipole x = [  1.49387659 203.03687211 205.95215411]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992628, Dx=-0.052102, beta_penalty=1139.163688
#
# TRYING dipole x = [  1.49387363 203.03617411 205.95283534]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.161714
#   47 1.29926e+01
# TRYING dipole x = [  1.49387562 203.03643701 205.95257065]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.162044
#   48 1.29926e+01
# TRYING dipole x = [  1.49387417 203.03701911 205.95197829]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992627, Dx=-0.052102, beta_penalty=1139.163159
#
# TRYING dipole x = [  1.49387501 203.03625694 205.95275708]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992626, Dx=-0.052102, beta_penalty=1139.162421
#
# TRYING dipole x = [  1.49387428 203.036548   205.95246089]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.161714
#
# TRYING dipole x = [  1.49387462 203.03630556 205.952703  ]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.161714
#
# TRYING dipole x = [  1.49387446 203.0360885  205.95292601]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992626, Dx=-0.052102, beta_penalty=1139.162421
#   49 1.29926e+01
# TRYING dipole x = [  1.4938739  203.03659661 205.95240681]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992627, Dx=-0.052102, beta_penalty=1139.163159
#
# TRYING dipole x = [  1.49387432 203.03621553 205.95279621]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992627, Dx=-0.052102, beta_penalty=1139.162763
#
# TRYING dipole x = [  1.49387396 203.03636105 205.95264812]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.161714
#
# TRYING dipole x = [  1.49387413 203.03623984 205.95276917]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.161714
#
# TRYING dipole x = [  1.49387404 203.03613131 205.95288067]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992627, Dx=-0.052102, beta_penalty=1139.162763
#   50 1.29926e+01
# TRYING dipole x = [  1.49387376 203.03638536 205.95262107]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.162044
#
# TRYING dipole x = [  1.49387383 203.03632185 205.95268597]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.162044
#   51 1.29926e+01
# TRYING dipole x = [  1.49387397 203.03619482 205.95281577]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992627, Dx=-0.052102, beta_penalty=1139.162629
#
# TRYING dipole x = [  1.49387387 203.03629009 205.95271842]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.161714
#   52 1.29926e+01
# TRYING dipole x = [  1.49387394 203.03622658 205.95278332]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992627, Dx=-0.052102, beta_penalty=1139.162629
#
# TRYING dipole x = [  1.49387389 203.03627421 205.95273465]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.161714
#
# TRYING dipole x = [  1.49387379 203.03626758 205.95274173]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.161714
#
# TRYING dipole x = [  1.49387388 203.03620697 205.95280225]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.161714
#
# TRYING dipole x = [  1.49387375 203.0362321  205.95277688]
# Survival: 373/478 → penalty 4.825
# OBJECTIVE = 12.992625, Dx=-0.052102, beta_penalty=1139.161714
#   54 1.29926e+01
# Optimal dipole parameters: [  1.49387363 203.03617411 205.95283534]

# %%
df_opt_b_beta = run_dipole(df_opt_q_beta, B_field=res_b_beta.x[0], B_length=res_b_beta.x[1], Drift2_length=res_b_beta.x[2])
xp_d, yp_d, zp_d = calc_all_params(df_opt_b_beta)
print("FINAL:")
print("Survival:", len(df_opt_b_beta)/len(df_opt_q_beta))
print("Beta:", 0.5*(xp_d[1] + yp_d[1]))
print("Dx:", xp_d[4])
# Out:
# FINAL:
# Survival: 0.7803347280334728
# Beta: 27.53557071129021
# Dx: -0.05210151515543115

# %%
df_hist_b_beta = pd.DataFrame(history_d)
plt.figure(figsize=(6,5))

sc = plt.scatter(
    df_hist_b_beta["B_F"],
    df_hist_b_beta["B_L"],
    c=df_hist_b_beta["objective"].values,
    cmap="viridis",
    s=40
)

best = df_hist_b_beta.loc[df_hist_b_beta["objective"].idxmin()]
plt.scatter(
    best["B_F"],
    best["B_L"],
    color="red",
    s=120,
    label="Best"
)

plt.colorbar(sc, label="Objective")
plt.xlabel("B field strength (T)")
plt.ylabel("B length (mm)")
plt.title("Dipole optimization search space")
plt.legend()
plt.show()

plt.scatter(
    df_hist_b_beta["B_F"],
    df_hist_b_beta["B_L"],
    c=df_hist_b_beta["survival"],
    cmap="plasma",
    s=40
)
plt.colorbar(label="Survival fraction")
plt.xlabel("B field strength (T)")
plt.ylabel("B length (mm)")
plt.title("Survival across quad parameter space")
plt.show()
plt.figure()
sc= plt.scatter(df_hist_b_beta["Dx"], df_hist_b_beta["objective"], c=df_hist_b_beta["beta_x"].values, cmap="plasma", alpha=0.6)
plt.colorbar(sc, label="beta_x")
plt.xlabel("Dx")
plt.ylabel("Objective")
plt.title("Dispersion vs objective")
plt.show()

plt.figure(figsize=(6,5))
sc = plt.scatter(
    df_hist_b_beta["B_F"],
    df_hist_b_beta["B_L"],
    c=df_hist_b_beta["Dx"].values,
    cmap="viridis",
    s=40
)

best = df_hist_b_beta.loc[df_hist_b_beta["Dx"].idxmin()]
plt.scatter(
    best["B_F"],
    best["B_L"],
    color="red",
    s=120,
    label="Best"
)


plt.colorbar(sc, label="Dx")
plt.xlabel("B field strength (T)")
plt.ylabel("B length (mm)")
plt.title("Dipole optimization search space")
plt.legend()
plt.show()

plt.figure(figsize=(6,5))
sc = plt.scatter(
    df_hist_b_beta["B_F"],
    df_hist_b_beta["B_L"],
    c=df_hist_b_beta["beta_x"].values,
    cmap="viridis",
    s=40
)

best = df_hist_b_beta.loc[df_hist_b_beta["beta_x"].idxmin()]
plt.scatter(
    best["B_F"],
    best["B_L"],
    color="red",
    s=120,
    label="Best min"
)
best_max = df_hist_b_beta.loc[df_hist_b_beta["beta_x"].idxmax()]
plt.scatter(
    best_max["B_F"],
    best_max["B_L"],
    color="blue",
    s=120,
    label="Best max"
)

plt.colorbar(sc, label="beta_x")
plt.xlabel("B field strength (T)")
plt.ylabel("B length (mm)")
plt.title("Dipole optimization search space")
plt.legend()
plt.show()

# %% [markdown]
# ## Ignore for a bit

# %%
fig, ax = plt.subplots()
sc =ax.scatter(df_scan["B"], df_scan["L"], c=df_scan["Dx"], cmap='plasma', s=50, vmin=-0.09, vmax=0)
fig.colorbar(sc, ax=ax, label='D_x')
ax.set_xlabel("Magnetic Field (T)")
ax.set_ylabel("Magnetic Field Length (L)")
plt.show()
fig, ax = plt.subplots()
sc =ax.scatter(df_scan["B"], df_scan["L"], c=df_scan["beta_x"], cmap='plasma', s=50, vmin=0, vmax=1.5)
fig.colorbar(sc, ax=ax, label='D_x')
ax.set_xlabel("Magnetic Field (T)")
ax.set_ylabel("Magnetic Field Length (L)")
# Out:
# Text(0, 0.5, 'Magnetic Field Length (L)')

# %%
import imageio

# Create folders to save frames
os.makedirs("frames_dx", exist_ok=True)
os.makedirs("frames_betax", exist_ok=True)

# Get all unique DL values
DL_values = sorted(df_scan["DL"].unique())

# --- Dx GIF ---
dx_files = []
for DL0 in DL_values:
    df_DL = df_scan[df_scan["DL"] == DL0]
    pivot_Dx = df_DL.pivot(index="L", columns="B", values="Dx")

    plt.figure()
    plt.imshow(pivot_Dx, aspect="auto", origin="lower")
    plt.colorbar(label="Dx [m]")
    plt.xlabel("B")
    plt.ylabel("L")
    plt.title(f"Dx map at DL={DL0}")
    
    fname = f"frames_dx/Dx_DL{DL0}.png"
    plt.savefig(fname)
    plt.close()
    dx_files.append(fname)

images_dx = [imageio.imread(f) for f in dx_files]
with imageio.get_writer("Dx_maps.gif", mode="I", duration=1.5) as writer:
    for f in dx_files:
        img = imageio.imread(f)
        writer.append_data(img)
print("Dx GIF saved as Dx_maps.gif")

# --- beta_x GIF ---
betax_files = []
for DL0 in DL_values:
    df_DL = df_scan[df_scan["DL"] == DL0]
    pivot_betax = df_DL.pivot(index="L", columns="B", values="beta_x")

    plt.figure()
    plt.imshow(pivot_betax, aspect="auto", origin="lower")
    plt.colorbar(label=r"$\beta_x$ [m]")
    plt.xlabel("B")
    plt.ylabel("L")
    plt.title(f"beta_x map at DL={DL0}")
    
    fname = f"frames_betax/betax_DL{DL0}.png"
    plt.savefig(fname)
    plt.close()
    betax_files.append(fname)

images_betax = [imageio.imread(f) for f in betax_files]
with imageio.get_writer("betax_maps.gif", mode="I", duration=1.5) as writer:
    for f in betax_files:
        img = imageio.imread(f)
        writer.append_data(img)
print("beta_x GIF saved as betax_maps.gif")
# Out:
# Dx GIF saved as Dx_maps.gif
# beta_x GIF saved as betax_maps.gif
# /tmp/ipykernel_21641/251435781.py:28: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images_dx = [imageio.imread(f) for f in dx_files]
# /tmp/ipykernel_21641/251435781.py:31: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(f)
# /tmp/ipykernel_21641/251435781.py:53: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images_betax = [imageio.imread(f) for f in betax_files]
# /tmp/ipykernel_21641/251435781.py:56: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(f)

# %%
import matplotlib.colors as mcolors
DL0 = 100
df_DL = df_scan[df_scan["DL"] == DL0]
pivot_Dx = (df_DL.pivot(index="L", columns="B", values="Dx"))
# Decide min and max values for the whole dataset
dx_min = df_scan["Dx"].min()
dx_max = df_scan["Dx"].max()

# Define a high-resolution colormap
# For example, 1000 colors → can show differences ~ (dx_max-dx_min)/1000
num_colors = int((dx_max - dx_min)/0.001)  # 0.001 resolution
num_colors = min(num_colors, 10000)  # cap at 10k colors to avoid memory issues

plt.figure()
plt.imshow(
    pivot_Dx,
    aspect="auto",
    origin="lower",
    vmin=dx_min,
    vmax=dx_max
)
"""extent=[
        pivot_Dx.columns.min(),
        pivot_Dx.columns.max(),
        pivot_Dx.index.min(),
        pivot_Dx.index.max()
    ]"""
plt.colorbar(label="Dx [m]")
plt.xlabel("B")
plt.ylabel("L")
plt.title(f"Dx map at DL={DL0}")
plt.show()
# Decide min and max values for the whole dataset
betax_min = df_scan["beta_x"].min()
betax_max = df_scan["beta_x"].max()

pivot_betax = df_DL.pivot(index="L", columns="B", values="beta_x")

plt.figure()
plt.imshow(
    pivot_betax,
    aspect="auto",
    origin="lower",
    vmin=betax_min,
    vmax=betax_max
)
"""extent=[
        pivot_betax.columns.min(),
        pivot_betax.columns.max(),
        pivot_betax.index.min(),
        pivot_betax.index.max()
    ]"""
plt.colorbar(label=r"$\beta_x$ [m]")
plt.xlabel("B")
plt.ylabel("L")
plt.title(f"beta_x map at DL={DL0}")
plt.show()

# %%
df_scan["B"].values

# %%
B00 = -2.5
df_B = df_scan[df_scan["B"] == B00]

# Magnetic Field Strength Somehow Constant?
plt.plot(df_B["L"], df_B["Dx"], color="green")
plt.xlabel("Dipole Length")
plt.ylabel(r"$D_x$")
plt.show()
plt.plot(df_B["L"], df_B["beta_x"], color="orange")
plt.xlabel("Dipole Length")
plt.ylabel(r"$\beta_x$")
plt.show()

# %%
DL0 = 40
df_DL = df_scan[df_scan["DL"] == DL0]

# Magnetic Field Strength Somehow Constant?
plt.plot(df_DL["B"], df_DL["Dx"], color="green")
plt.xlabel("Magnetic Field")
plt.ylabel(r"$D_x$")
plt.show()
plt.plot(df_DL["B"], df_DL["beta_x"], color="orange")
plt.xlabel("Magnetic Field")
plt.ylabel(r"$\beta_x$")
plt.show()


# Dipole Length Matters!
plt.plot(df_DL["L"], df_DL["Dx"], color="green")
plt.xlabel("Dipole Length")
plt.ylabel(r"$D_x$")
closest_idx = np.argmin(np.abs(df_DL["Dx"]))
Dx = df_DL["Dx"].values
L =df_DL["L"].values
B =df_DL["B"].values
closest_b_idx = np.argmin(np.abs(df_DL["beta_x"]))
betax = df_DL["beta_x"].values
plt.title(f"Closest to 0: Dx = {Dx[closest_idx]:.2e} at L = {L[closest_idx]:.6f}")
plt.show()
plt.plot(df_DL["L"], df_DL["beta_x"], color="orange")
plt.xlabel("Dipole Length")
plt.ylabel(r"$\beta_x$")
plt.title(f"Closest to 0: beta_x = {betax[closest_idx]:.2e} at L = {L[closest_idx]:.6f}")
plt.show()

# %%
def parse_g4bl_file(filename):
    with open(filename) as f:
        text = f.read()

    pattern = r"\s*([A-Za-z0-9_]+):\s*([-\d\.]+)"
    entries = dict(re.findall(pattern, text))

    return {k: float(v) for k, v in entries.items()}

def build_magnet_regions(params):
    magnet_colors = {
        "wedge":  "#FF66CC",
        "Q1":     "#6699FF",
        "Drift1": "#BBBBBB",
        "Q2":     "#3366CC",
        "Drift2": "#999999",
        "B1":     "#FFAA33",
    }

    magnet_order = ["wedge", "Q1", "Drift1", "Q2", "Drift2", "B1"]
    regions = []

    for name in magnet_order:
        z_key = f"{name}_z"
        L_key = f"{name}_length"

        if name == "wedge":
            if "wedge_end" in params:
                z1 = 0.0
                z2 = params["wedge_end"]
                regions.append((z1, z2, magnet_colors[name], name))

        elif z_key in params and L_key in params:
            center = params[z_key]
            length = params[L_key]
            z1 = center - length / 2
            z2 = center + length / 2
            regions.append((z1, z2, magnet_colors[name], name))

    return regions

# %%
def twissPlot(z_positions, emit_x, emit_y, emit_z, beta_x, beta_y, alpha_x, alpha_y, D_x, Dp_x, D_y, Dp_y, output_folder="./dispsup_plots"):
    
    # -------------------------------------------------------------------
    # CONVERT TO ARRAYS FOR PLOTTING
    # -------------------------------------------------------------------
    z_positions = np.array(z_positions)
    order = np.argsort(z_positions)

    z_positions = z_positions[order]
    emit_x = np.array(emit_x)[order]
    emit_y = np.array(emit_y)[order]
    beta_x = np.array(beta_x)[order]
    beta_y = np.array(beta_y)[order]
    alpha_x = np.array(alpha_x)[order]
    alpha_y = np.array(alpha_y)[order]
    D_x = np.array(D_x)[order]
    Dp_x = np.array(Dp_x)[order]
    D_y = np.array(D_y)[order]
    Dp_y = np.array(Dp_y)[order]
    emit_z = np.array(emit_z)[order]

    # -------------------------------------------------------------------
    # PLOTTING
    # -------------------------------------------------------------------
    def make_plot(yvals, ylabel, title, filename, labels=("x", "y")):
        plt.figure(figsize=(7,5))

        # ---- draw magnet shading (already parsed) ----
        for z1, z2, color, label in regions:
            plt.axvspan(z1, z2, color=color, alpha=0.3, label=label)

        # ---- twiss curves ----
        plt.plot(z_positions, yvals[0], 'o-', color="#541352FF", label=f"{labels[0]}-plane")
        plt.plot(z_positions, yvals[1], 's--', color="#3A5E8CFF", label=f"{labels[1]}-plane")

        plt.xlabel("z [mm]")
        plt.ylabel(ylabel)
        plt.title(title)
        plt.grid(True)

        # ---- remove duplicate legend entries ----
        handles, labels = plt.gca().get_legend_handles_labels()
        by_label = dict(zip(labels, handles))
        plt.legend(by_label.values(), by_label.keys())

        plt.tight_layout()
        plt.savefig(os.path.join(output_folder, filename))
        plt.close()


    make_plot((emit_x, emit_y), "Emittance [mm·mrad]",
            "Emittance Evolution", "emittance_evolution.png")

    make_plot((beta_x, beta_y), "β-function [m]",
            "Beta Function Evolution", "beta_evolution.png")

    make_plot((alpha_x, alpha_y), "α-function [–]",
            "Alpha Function Evolution", "alpha_evolution.png")

    make_plot((D_x, D_y), "Dispersion D [m]",
            "Dispersion Function", "dispersion_D.png")

    make_plot((Dp_x, Dp_y), "Dispersion Derivative D' [-]",
            "Dispersion Derivative", "dispersion_Dprime.png")

    print(f"All plots saved in '{output_folder}'")


files = ["vd_start_dispsup.txt", "vd_Q1_dispsup.txt", "vd_D1_dispsup.txt", "particles_after_q2uptc.txt", "particles_after_b.txt"]
z_positions = []
emit_x = []
emit_y = []
emit_z = []
beta_x = []
beta_y= []
alpha_x=[]
alpha_y=[]
D_x=[]
Dp_x=[]
D_y=[]
Dp_y=[]

for i in files:
        df1 = read_trackfile(i)
        z_positions.append(np.mean(df1["z"]))
        x_params1, y_params1, z_emit1 = calc_all_params(df1)
        ex, bx, gx, ax, Dx, Dxp = x_params1
        ey, by, gy, ay, Dy, Dyp = y_params1
        emit_x.append(ex)
        emit_y.append(ey)
        beta_x.append(bx)
        beta_y.append(by)
        alpha_x.append(ax)
        alpha_y.append(ay)
        D_x.append(Dx), Dp_x.append(Dxp), D_y.append(Dy), Dp_y.append(Dyp)
        emit_z.append(z_emit1)

g4bl_files = [
    "G4_FinalCooling_dispsup_Q2_run.g4bl",
    "G4_FinalCooling_dispsup_B_run.g4bl",
]

params = {}
for f in g4bl_files:
    params.update(parse_g4bl_file(f))

regions = build_magnet_regions(params)


twissPlot(z_positions, emit_x, emit_y, emit_z, beta_x, beta_y, alpha_x, alpha_y, D_x, Dp_x, D_y, Dp_y)

# %%
def B_from_theta(theta, L_mm, p_GeV=0.879):
    L_m = L_mm * 1e-3
    return theta * p_GeV / (0.3 * L_m)

# %%
def optimize_dipole_aa(x, df_in, beta_x_ref, beta_y_ref,
                    w_disp=10.0, w_beta=100.0, w_len=5.0,
                    survival_threshold=0.95):

    theta, L_mm, Drift2_length = x

    # compute B from theta
    B_field = B_from_theta(theta, L_mm)

    # hard physical bounds
    if B_field < 0.1 or B_field > 3.0:
        return 1e6 + abs(B_field)

    result = run_dipole(df_in, B_field, L_mm, Drift2_length)
    if result is None or len(result) < 100:
        return 1e6

    mask, *_ = check_dipole_clearance(df_in, B_field, L_mm, 50)
    survival_frac = np.mean(mask)

    if survival_frac < survival_threshold:
        return 1e6 + 1e4*(survival_threshold - survival_frac)

    df_survived = result[mask]
    x_params_d, y_params_d, _ = calc_all_params(df_survived)

    Dx = x_params_d[4]
    beta_x = x_params_d[1]
    beta_y = y_params_d[1]

    # dispersion target
    disp_target = abs(theta * L_mm / 2)
    disp_penalty = ((Dx - disp_target) / disp_target)**2

    # beta mismatch
    beta_penalty = ((beta_x - beta_x_ref)/beta_x_ref)**2 \
                 + ((beta_y - beta_y_ref)/beta_y_ref)**2

    # discourage tiny magnets
    length_penalty = (50.0 / L_mm)**2

    if disp_penalty > 5.0:
        return w_disp * disp_penalty

    val = (
        w_disp * disp_penalty +
        w_beta * beta_penalty +
        w_len  * length_penalty
    )

    print(f"θ={theta:.3f}, L={L_mm:.1f}, B={B_field:.2f}, Obj={val:.3e}")
    return val
x0_dip = [0.15, 200.0, 100.0]  # theta [rad], L [mm], drift [mm]

bounds_dip = [
    (0.05, 0.30),   # bend angle
    (80, 400),      # dipole length
    (20, 1000)      # drift
]

res_dip = minimize(
    optimize_dipole_aa,
    x0_dip,
    args=(df_opt, b_dict['Beta_x'], b_dict['Beta_y']),
    method="Nelder-Mead", bounds=bounds_dip
)

# %%
def beam_size(beta, eps, n_sigma=1):
    """
    Compute full beam width/height in mm for given beta (m) and emittance (mm·mrad)
    """
    sigma = np.sqrt(beta * eps * 1e3)  # convert sigma (mm) = sqrt(m * 1e3 * mm)
    return 2 * n_sigma * sigma
B_width = beam_size(x_params[1], x_params[0])
B_height = beam_size(y_params[1], y_params[0])
print(B_height, B_width)

# %%
def optimize_dipole(x, df_in, beta_x_ref, beta_y_ref, w_disp=10.0, w_beta=1000.0, w_clear=100.0, D_tol=1e-3, survival_threshold=0.95):
    """
    Optimize dipole parameters but only for distributions that survive >= survival_threshold.
    x = [B_field, B_length, Drift2_length]
    """
    B_field, B_length, Drift2_length = x
    total_cost = 0
    # Run G4BL with these parameters
    result = run_dipole(df_in, B_field, B_length, Drift2_length)
    if result is None or len(result) < 100:
        return 1e6 + 10*(
            abs(B_field) + B_length + Drift2_length)

    # Check which particles survive
    mask, r_L_mm, delta_r_mm = check_dipole_clearance(df_in, B_field, B_length, 100/2)
    
    survival_frac = np.mean(mask)
    if survival_frac < survival_threshold:
        # Penalize strongly: configuration not feasible
        return 1e6 + 1e3*(survival_threshold - survival_frac)

    # Compute dispersion & beta from survived particles
    df_survived = result[mask] if isinstance(result, np.ndarray) else result[mask.values]
    x_params_d, y_params_d, _ = calc_all_params(df_survived)
    Dx, beta_x = x_params_d[4], x_params_d[1]
    Dy, beta_y = y_params_d[4], y_params_d[1]

    disp_penalty = Dx**2
    beta_penalty = ((beta_x - beta_x_ref)/beta_x_ref)**2 + ((beta_y - beta_y_ref)/beta_y_ref)**2

    val = w_disp*disp_penalty + w_beta * beta_penalty
    print("OBJECTIVE =", val)
    return val


# initial guess: B_field (T), B_length (mm), Drift2_length (mm)
x0_dip = [1.5, 200.0, 100.0]

# bounds
bounds_dip = [(0.1, 3.0),  # B_field
              (50, 400),   # B_length
              (20, 1000)]  # Drift2_length

res_dip = minimize(optimize_dipole, x0_dip, args=(df_opt, b_dict['Beta_x'], b_dict['Beta_y']),
                method="Nelder-Mead", bounds=bounds_dip)

print("Optimal dipole parameters:", res_dip.x)

# %%
# Run a single case of optimal values
opt_params = {
    "Drift2_length": res_dip.x[2], 
    "Drift2_width": 100,
    "Drift2_height": 100,
    "Drift2_z": (L_centerline + res.x[0] + res.x[5] + res.x[2]) + res_dip.x[2]/2,
    "B1_field": res_dip.x[0],
    "B1_z": (L_centerline + res.x[0] + res.x[5] + res.x[2]) + res_dip.x[2] + res_dip.x[1]/2,
    "B1_end": (L_centerline + res.x[0] + res.x[5] + res.x[2]) + res_dip.x[2] + res_dip.x[1],
    "B1_length": res_dip.x[1],
    "B1_width": 100,
    "B1_height": 100
    }
print(opt_params)
write_input_from_template("G4_FinalCooling_dispsup_B.g4bl", opt_params, "G4_FinalCooling_dispsup_B_opt.g4bl")
if os.path.exists("field_cellB.dat"):
    os.remove("field_cellB.dat")
result = subprocess.run(["g4bl", "G4_FinalCooling_dispsup_B_opt.g4bl"], capture_output=True, text=True, check=True)
df_dip = read_trackfile("particles_after_b.txt")
x_params_dip, y_params_dip, z_emit_dip = calc_all_params(df_dip)
D_dict_dip = {"D_x": x_params_dip[4], "D'_x": x_params_dip[5], "D_y": y_params_dip[4], "D'_y": y_params_dip[5]}
b_dict_dip = {"Beta_x": x_params_dip[1], "Beta_y": y_params_dip[1]}
print(D_dict_dip, r"Epsilon_z: "+str(z_emit_dip), b_dict_dip)

# %% [markdown]
# ## Scrap

# %%
def run_dipole_quad(df, Q1_length, Q1_gradient, B_field, B_length, Drift2_length, Drift3_length, Drift2_z=0, Q_radius=res.x[4], thickness=5):
    """Run dipole simulation with given parameters."""
    params = {
        "Q1_length": Q1_length,
        "Q1_gradient": Q1_gradient,
        "Q1_z": Drift2_z + Drift2_length + B_length + Drift3_length + Q1_length/2,
        "Q1_end": Drift2_z + Drift2_length + B_length + Drift3_length + Q1_length,
        "radius_q": Q_radius,
        "thickness": thickness,
        "Drift2_length": Drift2_length, 
        "Drift2_width": B_width,
        "Drift2_height": B_height,
        "Drift2_z": Drift2_z + Drift2_length/2,
        "B1_field": B_field,
        "B1_z": Drift2_z + Drift2_length + B_length/2,
        "B1_end": Drift2_z + Drift2_length + B_length,
        "B1_length": B_length,
        "B1_width": B_width,
        "B1_height": B_height,
        "Drift3_length": Drift2_length, 
        "Drift3_width": B_width,
        "Drift3_height": B_height,
        "Drift3_z": Drift2_z + Drift2_length + B_length + Drift3_length/2,
    }
    write_input_from_template("G4_FinalCooling_dispsup_BQ.g4bl", params, "G4_FinalCooling_dispsup_BQ_run.g4bl")
    outfile = "G4_FinalCooling_dispsup_BQ_run.g4bl"
    print("=== DEBUG FILE CHECK ===")
    print("Absolute path:", os.path.abspath(outfile))
    print("Last modified:", time.ctime(os.path.getmtime(outfile)))
    print("========================")

    # Print Q1 block robustly (NOT by line number)
    print("---- B BLOCK ----")
    with open(outfile, "r") as f:
        printing = False
        for line in f:
            if line.startswith("genericbend B"):
                printing = True
            if printing:
                print(line.rstrip())
            if printing and line.strip() == "":
                break
    print("-------------------")
    return run_g4beam(df, "G4_FinalCooling_dispsup_BQ_run.g4bl")

# %%
def optimize_dipole_quad(x, df_in, beta_x_ref, beta_y_ref, w_disp=10.0, w_beta=1000.0, w_clear=100.0, D_tol=1e-3, survival_threshold=0.95):
    """
    Optimize dipole parameters but only for distributions that survive >= survival_threshold.
    x = [B_field, B_length, Drift2_length]
    """
    Q_length, Q_gradient, B_field, B_length, Drift2_length, Drift3_length = x
    total_cost = 0
    # Run G4BL with these parameters
    result = run_dipole_quad(df_in, Q_length, Q_gradient, B_field, B_length, Drift2_length, Drift3_length)
    if result is None or len(result) < 100:
        return 1e6

    # Check which particles survive
    mask, r_L_mm, delta_r_mm = check_dipole_clearance(df_in, B_field, B_length, 100/2)
    
    survival_frac = np.mean(mask)
    if survival_frac < survival_threshold:
        # Penalize strongly: configuration not feasible
        return 1e6 + 1e3*(survival_threshold - survival_frac)

    # Compute dispersion & beta from survived particles
    df_survived = result[mask] if isinstance(result, np.ndarray) else result[mask.values]
    x_params_d, y_params_d, _ = calc_all_params(df_survived)
    Dx, beta_x = x_params_d[4], x_params_d[1]
    Dy, beta_y = y_params_d[4], y_params_d[1]

    disp_penalty = Dx**2
    beta_penalty = ((beta_x - beta_x_ref)/beta_x_ref)**2 + ((beta_y - beta_y_ref)/beta_y_ref)**2

    val = w_disp*disp_penalty + w_beta * beta_penalty
    print("OBJECTIVE =", val)
    return val


# initial guess: Q_length (mm), Q_gradient (T/m), B_field (T), B_length (mm), Drift2_length (mm), Drift3_length (mm)
x0_dipq = [200.0, 10, 1.5, 200.0, 100.0, 100.0]

# bounds
bounds_dipq = [(20, 1000),(1, 30), (0.1, 3.0),
            (50, 400),(20, 1000),(20, 1000)]

res_dipq = minimize(optimize_dipole_quad, x0_dipq, args=(df_opt, b_dict['Beta_x'], b_dict['Beta_y']),
                method="Nelder-Mead", bounds=bounds_dipq)

print("Optimal dipole parameters:", res_dipq.x)

# %% [markdown]
# # Phase rotation
#
# The following are taken as constants, as they are primarily constrained by technical limitations. The optimal RF gradient is heavily dependent on both of these.
# - **Drift length**: Longer drift length will give better results
# - **RF frequency**: Lower frequency will usually give better results. There's an optimal point, but I believe it's lower than practical
#
# We then optimize the RF phase, cavity length, and gradient

# %%
drift_length = 16000
rf_freq = 0.025

# Function to optimize
def func(x):
    rf_phase, rf_length, rf_grad = x
    drift_to_start = drift_length-rf_length/2
    post_drift = recenter_t(z_prop(no_transverse, drift_to_start))
    post_cavity = run_g4beam(post_drift, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad, nparticles=len(no_transverse))
    pre_w2 = recombine_transverse(post_cavity, reverse_transverse)
    return np.std(p_total(cut_pz(pre_w2)))

# Run optimization
optim_result = minimize(func, [0, 4700, 7], method="Nelder-Mead", bounds=((-90, 90), (2000, 6000), (1, 10)), options=dict(fatol=1e-6))

# Get results
rf_phase, rf_length, rf_grad = optim_result.x
print(f"Phase = {rf_phase:.2f} deg\nLength = {rf_length:.0f} mm\nGradient = {rf_grad:.2f} MV/m\nFrequency = {rf_freq*1000:.1f} MHz")

# Runs a single case with the optimal parameters and add the transverse back in
drift_to_start = drift_length-rf_length/2
post_drift = recenter_t(z_prop(no_transverse, drift_to_start))
post_cavity = cut_pz(recenter_t(run_g4beam(post_drift, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad)))
pre_w2 = recombine_transverse(post_cavity, reverse_transverse)
print_all_params(pre_w2)

# %% [markdown]
# # Second wedge
#
# Optimize the second wedge in the same way as the first

# %%
# Function to optimize
def func(x):
    length, angle = x
    return emittances(cut_outliers(run_distribution(pre_w2, length, angle, vd_dist, axis=1)))[1]

# Run optimization
optim_result = minimize(func, [5.5, 45], method="Nelder-Mead", bounds=((1, 10), (30, 70)), options=dict(fatol=1e-6))

# Get results
w2_length, w2_angle = optim_result.x
print(f"Length = {w2_length:.2f} mm\nAngle = {w2_angle:.1f} deg")

# Runs a single case with the optimal parameters
post_w2 = run_distribution(pre_w2, w2_length, w2_angle, vd_dist, axis=1)
print_all_params(post_w2)

# Do cuts at this point
post_w2_cut = cut_outliers(post_w2)
print_all_params(post_w2_cut)

# %% [markdown]
# # Save/load result

# %%
# Parameter list
PARAMS = [
    "t_emit",
    "momentum",
    "beta",
    "alpha",
    "l_emit",
    "pz_std",
    "vd_dist",
    "w1_length",
    "w1_angle",
    "w2_length",
    "w2_angle",
    "drift_length",
    "rf_freq",
    "rf_phase",
    "rf_length",
    "rf_grad"
]

# %%
# Show parameters
{k:globals()[k] for k in PARAMS}

# %%
# Input parameters
parameters = {'t_emit': 0.145,
 'momentum': 100,
 'beta': 0.03,
 'alpha': 1,
 'l_emit': 1,
 'pz_std': 1,
 'vd_dist': 24,
 'w1_length': 9.20751061747799,
 'w1_angle': 49.78231333988419,
 'w2_length': 6.724887901827298,
 'w2_angle': 42.245718529695516,
 'drift_length': 16000,
 'rf_freq': 0.025,
 'rf_phase': 0.001987066319906211,
 'rf_length': 5153.756925848655,
 'rf_grad': 4.046563465382562}
globals().update(parameters)

# %%
# Save parameter set
parameters = {k:globals()[k] for k in PARAMS}
filename = "results/parameters/"+input("Enter run name to save: ")+".pkl"
with open(filename, "wb+") as file:
    pickle.dump(parameters, file)
    print("Saved to", filename)

# %%
# Load parameter set
filename = "results/parameters/"+input("Enter run name to load: ")+".pkl"
with open(filename, "rb+") as file:
    parameters = pickle.load(file)
    globals().update(parameters)
    print("Loaded from", filename)

# %%
# View parameter set
filename = "results/parameters/"+input("Enter run name to view: ")+".pkl"
with open(filename, "rb+") as file:
    parameters = pickle.load(file)
    print("Viewing", filename)
    print(parameters)

# %%
vd_dist=36

# %% [markdown]
# # Analyze single case

# %%
# Tweak parameters
rf_phase += 180
rf_phase

# %%
# Run best case
pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=100000)
pre_w1["PDGid"] = -13
print("Running first wedge")
post_w1 = run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0)
post_correct = remove_dispersion(post_w1)
reverse_transverse = post_correct.copy(deep=True)
reverse_transverse["Px"] *= -1
reverse_transverse["Py"] *= -1
drift_to_start = drift_length-rf_length/2
post_drift = recenter_t(z_prop(post_correct, drift_to_start))
no_transverse = remove_transverse(post_drift)
print("Running RF cavity")
post_cavity = cut_pz(recenter_t(run_g4beam(no_transverse, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad, nparticles=len(no_transverse))), tails=0.15)
pre_w2 = recombine_transverse(post_cavity, reverse_transverse)
print("Running second wedge")
post_w2 = run_distribution(pre_w2, w2_length, w2_angle, vd_dist, axis=1)
post_w2_cut = recenter_t(cut_outliers(post_w2))
print_all_params(post_w2_cut)
beep()

# %%
# Make some phase space plots
PLOT_TARGETS = [pre_w1, post_correct, post_drift, pre_w2, remove_dispersion(post_w2_cut)]
PLOT_TITLES = ["Initial distribution", "After first wedge", "After drift", "After RF cavity and refocusing", "After second wedge"]
PLOT_AXES = [("x", "Px"), ("y", "Py"), ("t", "Pz")]
PLOT_LABELS = [("x (mm)", "Px (MeV/c)"), ("y (mm)", "Py (MeV/c)"), ("t (ns)", "Pz (MeV/c)")]
T_RANGES = [[-7.5, 7.5], [-30, 30]]
L_RANGES = [[-10, 10], [40, 110]]

fig, axes = plt.subplots(nrows = len(PLOT_AXES), ncols = len(PLOT_TARGETS), layout="constrained")
fig.set_size_inches(16, 8)
for i, df in enumerate(PLOT_TARGETS):
    axes[0][i].set_title(PLOT_TITLES[i])
    for j, ((xaxis, yaxis), (xlabel, ylabel)) in enumerate(zip(PLOT_AXES, PLOT_LABELS)):
        ax = axes[j][i]
        ax.hist2d(df[xaxis], df[yaxis], bins=50, range=L_RANGES if j == 2 else T_RANGES)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(ylabel)
# fig.suptitle(f"temit={t_emit*1000:.0f} μm, σP={pz_std:.2f} MeV/c")

# %%
SAMPLE_DISTS = [pre_w1, post_correct, pre_w2, remove_dispersion(post_w2_cut)]
SAMPLE_TITLES = ["Initial distribution", "After first wedge", "After RF cavity + 10% cut", "After second wedge + 4 sigma cut"]
VARIABLE_NAMES = ["x emit (μm)", "y emit (μm)", "z-emit (mm)", "sigma-p (MeV/c)", "sigma-t (ns)", "Beam remaining"]
VARIABLE_FUNCS = [
    lambda df: emittances(df)[0]*1000,
    lambda df: emittances(df)[1]*1000,
    lambda df: emittances(df)[2],
    lambda df: np.std(p_total(df)),
    lambda df: np.std(df["t"]),
    lambda df: len(df) / len(pre_w1)
]
table = [[n] + [y(x) for y in VARIABLE_FUNCS] for n, x in zip(SAMPLE_TITLES, SAMPLE_DISTS)]
print(tabulate(
    table,
    headers=["Stage"] + VARIABLE_NAMES,
    # tablefmt="latex_raw",
    floatfmt=(None, ".1f", ".1f", ".3f", ".3f", ".3f", ".1%")
))

# %% [markdown]
# ## Anomaly investigation
#
# This is going insane

# %%
momentum = 100
pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
pre_w1["PDGid"] = -13
run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0, debug=True)

# %%
momentums = list(range(50, 101, 10))
results = list() #  Yeah we're back to the old days now
for momentum in tqdm(momentums):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
    pre_w1["PDGid"] = -13
    results.append(run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0))
beep()

# %%
fig, axs = plt.subplots(nrows = 3, ncols = 2)
axs = axs.flatten()
fig.set_size_inches(10, 12)
for momentum, x, ax in zip(momentums, results, axs):
    ax.hist(p_total(x), bins=200, range=(40, 110))
    ax.axvline(momentum, color="red", linestyle="--")
pass

# %%
results[0]["PDGid"]

# %%
angles = [30, 40, 50, 60]
momentum = 70
results1 = list() #  Yeah we're back to the old days now
for angle in tqdm(angles):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
    results1.append(run_distribution(pre_w1, w1_length, angle, vd_dist, axis=0))
beep()

# %%
fig, axs = plt.subplots(nrows = 2, ncols = 2)
axs = axs.flatten()
fig.set_size_inches(10, 8)
for angle, x, ax in zip(angles, results1, axs):
    ax.hist(p_total(x), bins=200, range=(40, 110))
    ax.axvline(momentum, color="red", linestyle="--")
    ax.set_title(f"{angle} deg")
pass

# %%
lengths = [3, 6, 9, 12]
momentum = 70
results2 = list() #  Yeah we're back to the old days now
for length in tqdm(lengths):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
    results2.append(run_distribution(pre_w1, length, w1_angle, 40, axis=0))
beep()

# %%
fig, axs = plt.subplots(nrows = 2, ncols = 2)
axs = axs.flatten()
fig.set_size_inches(10, 8)
for length, x, ax in zip(lengths, results2, axs):
    ax.hist(p_total(x), bins=200, range=(40, 110))
    ax.axvline(momentum, color="red", linestyle="--")
    ax.set_title(f"{length} mm")
pass

# %%
fig, ax = plt.subplots()
ax.hist(p_total(post_w2_cut), bins=200)
select_bottom, select_top = 60.5, 62.5
ax.axvline(select_bottom, color="r", linestyle="--")
ax.axvline(select_top, color="r", linestyle="--")
anomaly = post_w2_cut[(p_total(post_w2_cut) < select_top) & (p_total(post_w2_cut) > select_bottom)]
pre_anomaly = pre_w2.loc[anomaly["EventID"]]
post_anomaly = run_distribution(pre_anomaly, w2_length, w2_angle, vd_dist, axis=1)

# %%
# Show the anomaly
PLOT_TARGETS = [pre_w2, pre_anomaly, post_w2_cut, post_anomaly]
PLOT_TITLES = ["Before (full)", "Before (anomalous)", "After (full)", "After (anomalous)"]
PLOT_AXES = [("x", "Px"), ("y", "Py"), ("t", "Pz")]
PLOT_LABELS = [("x (mm)", "Px (MeV/c)"), ("y (mm)", "Py (MeV/c)"), ("t (ns)", "Pz (MeV/c)")]
T_RANGES = [[-7.5, 7.5], [-30, 30]]
L_RANGES = [[-10, 10], [40, 110]]

fig, axes = plt.subplots(nrows = len(PLOT_AXES), ncols = len(PLOT_TARGETS), layout="constrained")
fig.set_size_inches(10, 8)
for i, df in enumerate(PLOT_TARGETS):
    axes[0][i].set_title(PLOT_TITLES[i])
    for j, ((xaxis, yaxis), (xlabel, ylabel)) in enumerate(zip(PLOT_AXES, PLOT_LABELS)):
        ax = axes[j][i]
        ax.hist2d(df[xaxis], df[yaxis], bins=50, range=L_RANGES if j == 2 else T_RANGES)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(ylabel)
# fig.suptitle(f"temit={t_emit*1000:.0f} μm, σP={pz_std:.2f} MeV/c")

# %%
run_distribution(pre_w1, w2_length, w2_angle, vd_dist, axis=1, debug=True)

# %%
fig, ax = plt.subplots()
ax.hist(post_w2_cut["y"], bins=200)
pass

# %%
p_ranges = [(58.5+2*i, 60.5+2*i) for i in range(7)]

fig, axes = plt.subplots(ncols = 2, nrows = len(p_ranges), layout="constrained")
fig.set_size_inches(6, 3*len(p_ranges))
for i, r in enumerate(p_ranges):
    ax = axes[i][0]
    ax.hist(p_total(post_w2_cut), bins=200, range=(55, 90))
    select_bottom, select_top = r
    ax.axvline(select_bottom, color="r", linestyle="--")
    ax.axvline(select_top, color="r", linestyle="--")

    selected = post_w2_cut[(p_total(post_w2_cut) < select_top) & (p_total(post_w2_cut) > select_bottom)]
    pre_selected = pre_w2.loc[selected["EventID"]]

    ax = axes[i][1]
    ax.hist2d(pre_selected["y"], pre_selected["Py"], bins=50, range=T_RANGES)
    ax.set_xlabel("y")
    ax.set_ylabel("Py")

# %% [markdown]
# ## Two optimal wedges (regenerated)

# %%
# Range to scan
angles = np.linspace(30, 60, 20)
lengths = np.linspace(5, 11, 20)

# %%
def fun(length, angle):
    return run_distribution(pre_w2, length, angle, 24, axis=1)

results = run_scan(fun, (lengths, angles), filename="results/second_wedge_length_angle.pkl")
beep()

# %%
def fun(length, angle):
    return run_distribution(pre_w1, length, angle, 24, axis=0)

results = run_scan(fun, (lengths, angles), filename="results/first_wedge_length_angle.pkl")
beep()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, layout="constrained")
fig.set_size_inches(10, 4)

# First wedge

with open("results/first_wedge_length_angle.pkl", "rb") as file:
    results = pickle.load(file)

mesh = np.meshgrid(lengths, angles)
meshz = qmap_to_meshgrid(mesh, calc_quantity(lambda df: emittances(cut_outliers(df))[0], results))
meshx, meshy = mesh

cax = ax1.contourf(meshx, meshy, meshz, levels=50)
ax1.set_xlabel("First wedge length (mm)")
ax1.set_ylabel("First wedge half-angle (deg)")
ax1.set_title("First wedge")
plt.colorbar(cax, ax=ax1).set_label("x-emittance (mm)")

ax1.plot(w1_length, w1_angle, 'rx')
ax1.annotate(f"{w1_length:.2f} mm, {w1_angle:.2f} deg", (w1_length, w1_angle), c="red", xytext = (-30, 10), textcoords="offset points")

# Second wedge

with open("results/second_wedge_length_angle.pkl", "rb") as file:
    results = pickle.load(file)

mesh = np.meshgrid(lengths, angles)
meshz = qmap_to_meshgrid(mesh, calc_quantity(lambda df: emittances(cut_outliers(df))[1], results))
meshx, meshy = mesh

cax = ax2.contourf(meshx, meshy, meshz, levels=50)
ax2.set_xlabel("Second wedge length (mm)")
ax2.set_ylabel("Second wedge half-angle (deg)")
ax2.set_title("Second wedge")
plt.colorbar(cax, ax=ax2).set_label("y-emittance (mm)")

ax2.plot(w2_length, w2_angle, 'rx')
ax2.annotate(f"{w2_length:.2f} mm, {w2_angle:.2f} deg", (w2_length, w2_angle), c="red", xytext = (-30, 10), textcoords="offset points")

# %% [markdown]
# ## Frequency and gradient (regenerated)

# %%
rf_freqs = np.linspace(0.01, 0.06, 20)
rf_grads = np.linspace(1,10,20)

# %%
# get no_transverse from above

def fun(rf_grad, rf_freq):
    return recenter_t(run_g4beam(no_transverse, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad))

results = run_scan(fun, (rf_grads, rf_freqs), "results/rf_grad_freq_16m.pkl")

# %%
with open("results/rf_grad_freq_16m.pkl", "rb") as file:
    results = pickle.load(file)
mesh = np.meshgrid(rf_grads, rf_freqs)
meshz = qmap_to_meshgrid(mesh, calc_quantity(lambda df: np.std(cut_pz(df)["Pz"]), results))
meshx, meshy = mesh

meshy = 1000 * meshy # Scale to MHz

fig, ax = plt.subplots()
cax = ax.contourf(meshx, meshy, meshz, levels=50)
ax.set_xlabel("RF gradient (MV/m)")
ax.set_ylabel("RF frequency (MHz)")
plt.colorbar(cax).set_label("sigma-Pz (MeV/c)")

minpoint = np.unravel_index(np.argmin(meshz), meshz.shape)
ax.plot(rf_grad, rf_freq*1000, 'rx')
ax.annotate(f"{rf_grad:.2f} MV/m, {rf_freq*1000:.1f} MHz", (rf_grad, rf_freq*1000), c="red", xytext = (-30, 10), textcoords="offset points")

# %% [markdown]
# # Scan of optimal over pz_std

# %%
t_emit = 0.110  # mm
momentum = 100  # MeV/c
beta = 0.03    # m
alpha = 1     # dimensionless
l_emit = 1      # mm
pz_stds = np.linspace(0.8, 1.1, 6)
vd_dist = 24    # mm

# %%
# Meta-function (containing optimization)
def metafun(pz_std):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit)
    
    def func(x):
        length, angle = x
        return emittances(cut_outliers(run_distribution(pre_w1, length, angle, vd_dist, axis=0)))[0]

    return scipy.optimize.minimize(func, [7.5, 45], method="Nelder-Mead", bounds=((1, 10), (30, 70)), options=dict(fatol=2e-4))

run_scan(metafun, (pz_stds,), filename="results/optimal_scan.pkl", trials=5)

# %%
with open("results/optimal_scan.pkl", "rb") as file:
    results = pickle.load(file)

def optim_fun(optim_result):
    return optim_result.fun

def optim_x1(optim_result):
    return optim_result.x[0]

def optim_x2(optim_result):
    return optim_result.x[1]


fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, layout="constrained")
fig.set_size_inches(10, 4)
ax1.errorbar(*qmap_to_arrays(pz_stds, calc_quantity(optim_fun, results)), capsize=2)
ax1.set_xlabel(r"$\sigma p$ (MeV/c)")
ax1.set_ylabel("minimum x emit (mm)")

ax2.errorbar(*qmap_to_arrays(pz_stds, calc_quantity(optim_x1, results)), capsize=2)
ax2.set_xlabel(r"$\sigma p$ (MeV/c)")
ax2.set_ylabel("optimal length (mm)")

ax3.errorbar(*qmap_to_arrays(pz_stds, calc_quantity(optim_x2, results)), capsize=2)
ax3.set_xlabel(r"$\sigma p$ (MeV/c)")
ax3.set_ylabel("optimal half-angle (deg)")

# %%
calc_quantity(optim_fun, results)

# %%
1e-5

# %%
calc_quantity(optim_fun, results)[(0.8,)][1] / 1e-4
