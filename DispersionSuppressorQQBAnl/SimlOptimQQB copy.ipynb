# %% [markdown]
# This notebook demonstrates the full optimization process for the first wedge and the dispersion suppressor.
#
# Updated: 1/10/2026

# %% [markdown]
# # Setup

# %%
from scan import *
from g4beam import *
import math
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import cm
import numpy as np
import pandas as pd
from tqdm import *
import pickle
import itertools
from tabulate import tabulate
from scipy.optimize import differential_evolution
import re
import uuid

# %%
# Make Sure g4bl is here
import os
os.environ["PATH"] += os.pathsep + "/home/incik/G4beamline-3.08/bin"
import shutil
print(shutil.which("g4bl"))
# Out:
# /home/incik/G4beamline-3.08/bin/g4bl

# %%
import scan, sys
print("scan imported from:", scan.__file__)
print("cwd:", os.getcwd())
print("sys.path[0]:", sys.path[0])
# Out:
# scan imported from: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/scan.py
# cwd: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl
# sys.path[0]: /home/incik/miniconda3/lib/python312.zip

# %% [markdown]
# # Initial distribution
#
# The parameters of the initial beam are treated as constants, but some things are known about their effects:
# - **Transverse emittance**: Should be as low as possible. For this test we use an "optimistic" value of 110 microns.
# - **Momentum**: Decreasing this appears to slightly decreases x-emittance.
# - **Beta**: Decreasing this decreases the y-emittance growth. There may also be an optimal value for x-emittance.
# - **Alpha**: Increasing this decreases the y-emittance growth, but past a certain point increases the x-emittance. I believe 0.7 focuses the beam onto the wedge center with a VD distance of 24 mm.
# - **Longitudinal emittance**: Effects not yet tested.
# - **Standard deviation of momentum**: Decreasing this decreases the x-emittance.
# - **Virtual detector distance**: Almost irrelevant. Should be more than 3x the length of the wedge to ensure accurate measurements.

# %%
t_emit = 0.145  # mm
momentum = 100  # MeV/c
beta = 0.03    # m
alpha = 0.7     # dimensionless
l_emit = 1      # mm
pz_std = 1    # MeV/c
vd_dist = 24    # mm

pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=20000)
pre_w1["PDGid"] = -13
print_all_params(pre_w1)
# Out:
# -----------------------------
# Twiss parameters for X
# emit  = 0.14652137353180544 mm
# beta  = 0.02976340643176925 m
# gamma = 49.60487300695458 1/m
# alpha = 0.6902245984477
# D     = -0.0014764132821804615 m
# D'    = 0.06494126437235362
#
# Twiss parameters for Y
# emit  = 0.1445921214133504 mm
# beta  = 0.029956681701927088 m
# gamma = 50.03939404662737 1/m
# alpha = 0.7064093714073459
# D     = -0.001397019940754504 m
# D'    = -0.04720493961037511
#
# Z-emittance:  1.2592026976853512 mm
# Z std: 153.36051593516797 mm
# p std: 1.00434958099274 MeV/c
# Mean momentum: 99.99365529962014 MeV/c
# -----------------------------

# %%
write_trackfile(pre_w1, "particles_before.txt")

# %% [markdown]
# # First wedge
#
# Determines the optimal length and angle for the first wedge

# %%
# Function to optimize
def func(x):
    length, angle = x
    return emittances(cut_outliers(run_distribution(pre_w1, length, angle, vd_dist, axis=0)))[0]

start = time.time()
# Run optimization
optim_result = minimize(func, [7.5, 45], method="Nelder-Mead", bounds=((1, 10), (30, 70)), options=dict(fatol=1e-6))

# Get results
w1_length, w1_angle = optim_result.x
print(f"Length = {w1_length:.2f} mm\nAngle = {w1_angle:.1f} deg")
print("Time spent:", time.time()-start)

# Runs a single case with the optimal parameters
post_w1 = run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0)
print_all_params(post_w1)
print_all_params(cut_outliers(post_w1))
# Out:
# iter value
#    5 4.27242e-02

# %%
post_w1 = run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0)
print_all_params(post_w1)
print_all_params(cut_outliers(post_w1))
# Out:
# -----------------------------
# Twiss parameters for X
# emit  = 0.0454003340973011 mm
# beta  = 0.035092065586904315 m
# gamma = 194.40246723686 1/m
# alpha = -2.412878805603777
# D     = 0.019887870874984555 m
# D'    = -0.023893064858575425
#
# Twiss parameters for Y
# emit  = 0.15015529230517022 mm
# beta  = 0.025129804111852703 m
# gamma = 58.106154180713226 1/m
# alpha = -0.6783776767070352
# D     = -5.9007614380756955e-05 m
# D'    = 0.004528368142907044
#
# Z-emittance:  6.411554398917607 mm
# Z std: 141.44512986672666 mm
# p std: 7.30349351501906 MeV/c
# Mean momentum: 87.35776817200221 MeV/c
# -----------------------------
# -----------------------------
# Twiss parameters for X
# emit  = 0.041812654606354235 mm
# beta  = 0.03627923558891792 m
# gamma = 202.84008127664887 1/m
# alpha = -2.5216825921417634
# D     = 0.020052341828052093 m
# D'    = -0.042267033447090596
#
# Twiss parameters for Y
# emit  = 0.1487208662514312 mm
# beta  = 0.02511513054510641 m
# gamma = 57.6554039491146 1/m
# alpha = -0.669345200037213
# D     = -7.761500469850267e-06 m
# D'    = 0.0004177015950484878
#
# Z-emittance:  6.2089873360107255 mm
# Z std: 141.57670165995327 mm
# p std: 7.127300509085975 MeV/c
# Mean momentum: 87.43863028128533 MeV/c
# -----------------------------

# %%
# Optimized G4_FinalCooling_auto.g4bl parameters
offset = w1_length / (math.tan(w1_angle * math.pi / 180) * 2)
base_length = 2*offset
abswidth = 100
parameters = dict(
        abshalfangle3=str(w1_angle),
        absoffset3=str(offset),
        abshgt=str(offset * base_length / w1_length + 0.1),
        absLEN3=str(base_length)
    )
L_centerline = float(parameters['absLEN3']) + 1
print("Where to put the next element: " + str(L_centerline) + "mm")
# Out:
# Where to put the next element: 7.927699296606463mm

# %%
L_centerline_orig = (abswidth/2)/np.abs(math.tan(w1_angle)) + base_length
print("Where to not put the next element: " + str(L_centerline_orig) + "mm")
# Out:
# Where to not put the next element: 379.74316188281864mm

# %%
# Write the wedge output into a file
write_trackfile(post_w1, "particles_after.txt")

# %%
# If particles_after isn't updated with Z = 0.
def convertZ(input_file, output_file, set_to=0):
    event_id_counter = 1
    with open(input_file, "r") as infile, open(output_file, "w") as outfile:
        for line in infile:
            # Skip header lines (those starting with #)
            if line.strip().startswith("#"):
                outfile.write(line)
                continue

            # Split the line into columns
            parts = line.strip().split()
            if len(parts) >= 12:
                parts[2] = str(set_to)  # Set the 3rd column (z) to 0
                # Replace event ID (assuming it's the 9th column, zero-based index 8)
                # Adjust if your event ID is in a different column
                parts[8] = str(event_id_counter)
                event_id_counter += 1
                new_line = " ".join(parts)
                outfile.write(new_line + "\n")
            else:
                # Handle lines that don't match expected format
                outfile.write(line)
    print(f"Updated file saved as '{output_file}'")
    os.remove(input_file)
    return None

# %%
os.remove("particles_afterupt.txt")
convertZ("particles_after.txt", "particles_afterupt.txt", set_to=L_centerline)
# Out:
# Updated file saved as 'particles_afterupt.txt'

# %% [markdown]
# # Dispersion correction optimization
#
# The main goal is to have $D_x \approx 0$ up to 1e-5 m while keeping $\beta_x$ relatively periodic and about at the same value.

# %%
# Write values to the prepared G4BL template
def write_input_from_template(template_path, replacements, out_path):
    with open(template_path, 'r') as f:
        txt = f.read()
    try:
        txt = txt.format(**replacements)
    except KeyError as e:
        raise RuntimeError(f"Template substitution failed; missing placeholder: {e}")
    with open(out_path, 'w') as f:
        f.write(txt)

# %%
def clean_field_files():
    for f in ["field_cellQ1.dat", "field_cellQ2.dat"]:
        if os.path.exists(f):
            os.remove(f)

# %%
x0_params, y0_params, _ = calc_all_params(post_w1)
beta_x_ref= x0_params[1]; beta_y_ref= y0_params[1]
print(r"$\beta_x$: " + str(beta_x_ref), r"$\beta_y$: " + str(beta_y_ref))
print("D_x: " + str(x0_params[4]), "D_y: " + str(y0_params[4]))
# Out:
# $\beta_x$: 0.035092065586904315 $\beta_y$: 0.025129804111852703
# D_x: 0.019887870874984555 D_y: -5.9007614380756955e-05

# %%
def run_two_quadrupoles(df, Q1_length, Q1_gradient, Q2_length, Q2_gradient, Q_radius, Drift1_length, Q1_z=L_centerline, thickness=5):
    """
    Runs G4BL with two sequential quadrupoles.
    """
    Drift1_width=2*Q_radius
    Drift1_height=2*Q_radius
    # Q1_z : f"{L_centerline + (Q1_length / 2):.12f}",
    params = {
    "Q1_z": f"{Q1_z + (Q1_length / 2):.12f}",
    "Q1_length": f"{Q1_length:.12f}",
    "Q1_gradient": f"{Q1_gradient:.12f}",
    "radius_q": f"{Q_radius:.12f}",
    "thickness": f"{thickness:.12f}",
    "Q1_end": f"{Q1_z + Q1_length:.12f}",
    "Q2_length":f"{Q2_length:.12f}",
    "Q2_gradient": f"{Q2_gradient:.12f}",
    "Drift1_length": f"{Drift1_length:.12f}",
    "Drift1_z": f"{Q1_z + Q1_length + (Drift1_length / 2):.12f}",
    "Drift1_width": f"{Drift1_width:.12f}", 
    "Drift1_height":f"{Drift1_height:.12f}", 
    "D1_end": f"{Q1_z + Q1_length + Drift1_length:.12f}",
    "Q2_z": f"{Q1_z + Q1_length + Drift1_length + Q2_length/2:.12f}",
    "Q2_end": f"{Q1_z + Q1_length + Drift1_length + Q2_length:.12f}"
    }

    print("PARAMS PASSED TO TEMPLATE:")
    for k, v in params.items():
        print(k, "=", v)
    write_input_from_template("G4_FinalCooling_dispsup_Q2.g4bl", params, "G4_FinalCooling_dispsup_Q2_run.g4bl")
    
    # Print first few lines to confirm
    outfile = "G4_FinalCooling_dispsup_Q2_run.g4bl"
    print("=== DEBUG FILE CHECK ===")
    print("Absolute path:", os.path.abspath(outfile))
    print("Last modified:", time.ctime(os.path.getmtime(outfile)))
    print("========================")

    # Print Q1 block robustly (NOT by line number)
    print("---- Q1 BLOCK ----")
    with open(outfile, "r") as f:
        printing = False
        for line in f:
            if line.startswith("genericquad Q1"):
                printing = True
            if printing:
                print(line.rstrip())
            if printing and line.strip() == "":
                break
    print("-------------------")
    
    # Run this file
    clean_field_files()
    res = run_g4beam(df, "G4_FinalCooling_dispsup_Q2_run.g4bl")

    if res is None or len(res) < 10:
        print("G4BL run failed or empty. Check template and parameters.")
        return None
    return res

# %%
def optimize_qq_drift_safe(x, df, beta_x_ref, beta_y_ref,
                           w_disp=1.0, w_beta=10.0, w_surv=100.0):
    """
    Optimizer wrapper with:
    - Survival-aware penalty
    - Full diagnostics
    """
    # Physical bounds
    bounds = np.array([
        [50, 2000],   # Q1_length
        [1, 30],      # Q1_gradient
        [50, 2000],   # Q2_length
        [-30, -1],    # Q2_gradient
        [10, 500],    # Q_radius
        [20, 1000]    # Drift1_length
    ])

    """# Clip x to bounds (Nelder-Mead ignores bounds)
    x_clipped = np.clip(x, bounds[:, 0], bounds[:, 1])
    if not np.allclose(x, x_clipped):
        print("Clipping input:", x, "→", x_clipped)
    x = x_clipped"""

    q1_length, q1_gradient, q2_length, q2_gradient, q_radius, d_length = x
    print("\nTRYING x =", x)

    try:
        result = run_two_quadrupoles(
            df,
            Q1_length=q1_length,
            Q1_gradient=q1_gradient,
            Q2_length=q2_length,
            Q2_gradient=q2_gradient,
            Q_radius=q_radius,
            Drift1_length=d_length
        )
    except Exception as e:
        print("EXCEPTION in run_two_quadrupoles:", e)
        return 1e6

    if result is None or len(result) == 0:
        print("No particles survived")
        return 1e6

    # Compute survival fraction
    N0 = len(df)
    Ns = len(result)
    survival = Ns / N0
    survival_penalty = w_surv * (1.0 - survival)**2
    print(f"Particles survived: {Ns}/{N0} → penalty {survival_penalty:.3f}")

    # Compute optics parameters
    try:
        x_params, y_params, _ = calc_all_params(result)
    except Exception as e:
        print("EXCEPTION in calc_all_params:", e)
        return 1e5

    Dx = x_params[4]
    Dy = y_params[4]
    beta_x = x_params[1]
    beta_y = y_params[1]

    beta_penalty = ((beta_x - beta_x_ref)/beta_x_ref)**2 + ((beta_y - beta_y_ref)/beta_y_ref)**2
    eps = 1e-4

    # Log-scaled optics loss
    optics_loss = np.log(Dx**2 + eps) + np.log(beta_penalty**2 + eps)

    # Total objective
    val = optics_loss + survival_penalty

    print(f"OBJECTIVE = {val:.6f}, Dx={Dx:.6f}, beta_penalty={beta_penalty:.6f}")
    return val

# %%
def optimize_qq_drift(x, df, beta_x_ref, beta_y_ref, w_disp=1.0, w_beta=10.0, D_tol=1e-3):
    q1_length, q1_gradient, q2_length, q2_gradient, q_radius, d_length = x 

    print("TRYING x =", x)
    result = run_two_quadrupoles(df, Q1_length=q1_length, Q1_gradient=q1_gradient, Q2_length=q2_length, Q2_gradient=q2_gradient, Q_radius=q_radius, Drift1_length=d_length)
    if result is None or len(result) < 100:
        return 1e3 + 10*(
            abs(q1_gradient) +
            abs(q2_gradient) +
            q1_length +
            q2_length +
            d_length
        )

    x_params, y_params, _ = calc_all_params(result)
    Dx = x_params[4]
    Dy = y_params[4]  
    disp_penalty = Dx

    
    beta_x = x_params[1]
    beta_y = y_params[1]
    beta_penalty = ((beta_x - beta_x_ref)/beta_x_ref)**2 + ((beta_y - beta_y_ref)/beta_y_ref)**2
    eps = 1e-4
    val = np.log(Dx**2 + eps) + np.log(beta_penalty**2 + eps)

    print("OBJECTIVE =", val)
    return val

# x = [Q1_len, Q1_grad, Q2_len, Q2_grad, Q_radius, Drift_length]
x0 = [121.21526189, 1, 139.77335625, -17.64495411, 10, 20]  # initial guess: length=100mm, gradient=10 T/m, radius=50mm, Drift_length=200mm
bounds = ((50, 2000), (1, 30), (50, 2000), (-30, -1), (10, 500), (20, 1000))  # physical limits

res = scipy.optimize.minimize(optimize_qq_drift, x0, args=(post_w1, beta_x_ref, beta_y_ref), method="Nelder-Mead", bounds=bounds)
print("Optimal parameters:", res.x)
# Out:
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:46 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [127.27602498   1.         139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 71.565711788856
# Q1_length = 127.276024984500
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 135.203724281106
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 145.203724281106
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 155.203724281106
# Q2_z = 225.090402406106
# Q2_end = 294.977080531106
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:47 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=127.276024984500 \
#     ironLength=127.276024984500 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [121.21526189   1.05       139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.050000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:48 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.050000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [121.21526189   1.         146.76202406 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 146.762024062500
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 222.523973217856
# Q2_end = 295.904985249107
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:49 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [121.21526189   1.         139.77335625 -18.52720182  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -18.527201815500
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:49 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.5
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.500000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 21.000000000000
# Drift1_height = 21.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:50 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.500000000000+5.000000000000 \
#     apertureRadius=10.500000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   21.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 21.000000000000
# Drift1_z = 139.642961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 150.142961186606
# Q2_z = 220.029639311606
# Q2_end = 289.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:51 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [123.23551625   1.01666667 132.78468844 -17.93903668  10.16666667
#   20.33333333]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.545457424023
# Q1_length = 123.235516254833
# Q1_gradient = 1.016666666667
# radius_q = 10.166666666667
# thickness = 5.000000000000
# Q1_end = 131.163215551440
# Q2_length = 132.784688437500
# Q2_gradient = -17.939036678500
# Drift1_length = 20.333333333333
# Drift1_z = 141.329882218106
# Drift1_width = 20.333333333333
# Drift1_height = 20.333333333333
# D1_end = 151.496548884773
# Q2_z = 217.888893103523
# Q2_end = 284.281237322273
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:52 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.016666666667 \
#     fieldLength=123.235516254833 \
#     ironLength=123.235516254833 \
#     ironRadius=10.166666666667+5.000000000000 \
#     apertureRadius=10.166666666667 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [124.24564344   1.025      125.79602062 -18.08607796  10.25
#   20.5       ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 70.050521015231
# Q1_length = 124.245643437250
# Q1_gradient = 1.025000000000
# radius_q = 10.250000000000
# thickness = 5.000000000000
# Q1_end = 132.173342733856
# Q2_length = 125.796020625000
# Q2_gradient = -18.086077962750
# Drift1_length = 20.500000000000
# Drift1_z = 142.423342733856
# Drift1_width = 20.500000000000
# Drift1_height = 20.500000000000
# D1_end = 152.673342733856
# Q2_z = 215.571353046356
# Q2_end = 278.469363358856
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:53 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.025000000000 \
#     fieldLength=124.245643437250 \
#     ironLength=124.245643437250 \
#     ironRadius=10.250000000000+5.000000000000 \
#     apertureRadius=10.250000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [116.16462598   1.025      135.11424437 -18.08607796  10.25
#   20.5       ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 66.010012285565
# Q1_length = 116.164625977917
# Q1_gradient = 1.025000000000
# radius_q = 10.250000000000
# thickness = 5.000000000000
# Q1_end = 124.092325274523
# Q2_length = 135.114244375000
# Q2_gradient = -18.086077962750
# Drift1_length = 20.500000000000
# Drift1_z = 134.342325274523
# Drift1_width = 20.500000000000
# Drift1_height = 20.500000000000
# D1_end = 144.592325274523
# Q2_z = 212.149447462023
# Q2_end = 279.706569649523
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:53 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.025000000000 \
#     fieldLength=116.164625977917 \
#     ironLength=116.164625977917 \
#     ironRadius=10.250000000000+5.000000000000 \
#     apertureRadius=10.250000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [120.54184377   1.03333333 133.56120708 -18.23311925  10.33333333
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.198621180801
# Q1_length = 120.541843768389
# Q1_gradient = 1.033333333333
# radius_q = 10.333333333333
# thickness = 5.000000000000
# Q1_end = 128.469543064995
# Q2_length = 133.561207083333
# Q2_gradient = -18.233119247000
# Drift1_length = 20.000000000000
# Drift1_z = 138.469543064995
# Drift1_width = 20.666666666667
# Drift1_height = 20.666666666667
# D1_end = 148.469543064995
# Q2_z = 215.250146606662
# Q2_end = 282.030750148329
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:54 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.033333333333 \
#     fieldLength=120.541843768389 \
#     ironLength=120.541843768389 \
#     ironRadius=10.333333333333+5.000000000000 \
#     apertureRadius=10.333333333333 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [120.31737106   1.04444444 131.49049069 -17.25284402  10.44444444
#   20.33333333]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.086384827199
# Q1_length = 120.317371061185
# Q1_gradient = 1.044444444444
# radius_q = 10.444444444444
# thickness = 5.000000000000
# Q1_end = 128.245070357792
# Q2_length = 131.490490694444
# Q2_gradient = -17.252844018667
# Drift1_length = 20.333333333333
# Drift1_z = 138.411737024458
# Drift1_width = 20.888888888889
# Drift1_height = 20.888888888889
# D1_end = 148.578403691125
# Q2_z = 214.323649038347
# Q2_end = 280.068894385569
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:55 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.044444444444 \
#     fieldLength=120.317371061185 \
#     ironLength=120.317371061185 \
#     ironRadius=10.444444444444+5.000000000000 \
#     apertureRadius=10.444444444444 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [120.01807412   1.         128.72953551 -18.00438836  10.59259259
#   20.44444444]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.936736355730
# Q1_length = 120.018074118247
# Q1_gradient = 1.000000000000
# radius_q = 10.592592592593
# thickness = 5.000000000000
# Q1_end = 127.945773414853
# Q2_length = 128.729535509259
# Q2_gradient = -18.004388360389
# Drift1_length = 20.444444444444
# Drift1_z = 138.167995637076
# Drift1_width = 21.185185185185
# Drift1_height = 21.185185185185
# D1_end = 148.390217859298
# Q2_z = 212.754985613927
# Q2_end = 277.119753368557
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:56 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=120.018074118247 \
#     ironLength=120.018074118247 \
#     ironRadius=10.592592592593+5.000000000000 \
#     apertureRadius=10.592592592593 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [119.41948023   1.         123.20762514 -18.18410549  10.88888889
#   20.66666667]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.637439412792
# Q1_length = 119.419480232370
# Q1_gradient = 1.000000000000
# radius_q = 10.888888888889
# thickness = 5.000000000000
# Q1_end = 127.347179528977
# Q2_length = 123.207625138889
# Q2_gradient = -18.184105485583
# Drift1_length = 20.666666666667
# Drift1_z = 137.680512862310
# Drift1_width = 21.777777777778
# Drift1_height = 21.777777777778
# D1_end = 148.013846195643
# Q2_z = 209.617658765088
# Q2_end = 271.221471334532
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:57 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=119.419480232370 \
#     ironLength=119.419480232370 \
#     ironRadius=10.888888888889+5.000000000000 \
#     apertureRadius=10.888888888889 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [119.41948023   1.04259259 123.20762514 -18.18410549  10.88888889
#   20.66666667]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.637439412792
# Q1_length = 119.419480232370
# Q1_gradient = 1.042592592593
# radius_q = 10.888888888889
# thickness = 5.000000000000
# Q1_end = 127.347179528977
# Q2_length = 123.207625138889
# Q2_gradient = -18.184105485583
# Drift1_length = 20.666666666667
# Drift1_z = 137.680512862310
# Drift1_width = 21.777777777778
# Drift1_height = 21.777777777778
# D1_end = 148.013846195643
# Q2_z = 209.617658765088
# Q2_end = 271.221471334532
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:58 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.042592592593 \
#     fieldLength=119.419480232370 \
#     ironLength=119.419480232370 \
#     ironRadius=10.888888888889+5.000000000000 \
#     apertureRadius=10.888888888889 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [118.82088635   1.05679012 117.68571477 -18.36382261  10.51851852
#   20.88888889]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.338142469853
# Q1_length = 118.820886346494
# Q1_gradient = 1.056790123457
# radius_q = 10.518518518519
# thickness = 5.000000000000
# Q1_end = 126.748585643100
# Q2_length = 117.685714768518
# Q2_gradient = -18.363822610778
# Drift1_length = 20.888888888889
# Drift1_z = 137.193030087545
# Drift1_width = 21.037037037037
# Drift1_height = 21.037037037037
# D1_end = 147.637474531989
# Q2_z = 206.480331916248
# Q2_end = 265.323189300508
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:59 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.056790123457 \
#     fieldLength=118.820886346494 \
#     ironLength=118.820886346494 \
#     ironRadius=10.518518518519+5.000000000000 \
#     apertureRadius=10.518518518519 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [117.62369857   1.08518519 106.64189403 -18.72325686  10.52777778
#   21.33333333]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 66.739548583977
# Q1_length = 117.623698574741
# Q1_gradient = 1.085185185185
# radius_q = 10.527777777778
# thickness = 5.000000000000
# Q1_end = 125.551397871347
# Q2_length = 106.641894027778
# Q2_gradient = -18.723256861167
# Drift1_length = 21.333333333333
# Drift1_z = 136.218064538014
# Drift1_width = 21.055555555556
# Drift1_height = 21.055555555556
# D1_end = 146.884731204680
# Q2_z = 200.205678218569
# Q2_end = 253.526625232458
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:39:59 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.085185185185 \
#     fieldLength=117.623698574741 \
#     ironLength=117.623698574741 \
#     ironRadius=10.527777777778+5.000000000000 \
#     apertureRadius=10.527777777778 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [118.5215894    1.04074074 114.92475958 -17.93903668  10.75
#   21.33333333]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 67.188493998384
# Q1_length = 118.521589403555
# Q1_gradient = 1.040740740741
# radius_q = 10.750000000000
# thickness = 5.000000000000
# Q1_end = 126.449288700162
# Q2_length = 114.924759583333
# Q2_gradient = -17.939036678500
# Drift1_length = 21.333333333333
# Drift1_z = 137.115955366829
# Drift1_width = 21.500000000000
# Drift1_height = 21.500000000000
# D1_end = 147.782622033495
# Q2_z = 205.245001825162
# Q2_end = 262.707381616828
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:40:00 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.040740740741 \
#     fieldLength=118.521589403555 \
#     ironLength=118.521589403555 \
#     ironRadius=10.750000000000+5.000000000000 \
#     apertureRadius=10.750000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [123.68446167   1.05432099 106.64189403 -18.0370642   11.
#   21.11111111]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.769930131227
# Q1_length = 123.684461669241
# Q1_gradient = 1.054320987654
# radius_q = 11.000000000000
# thickness = 5.000000000000
# Q1_end = 131.612160965847
# Q2_length = 106.641894027778
# Q2_gradient = -18.037064201333
# Drift1_length = 21.111111111111
# Drift1_z = 142.167716521403
# Drift1_width = 22.000000000000
# Drift1_height = 22.000000000000
# D1_end = 152.723272076958
# Q2_z = 206.044219090847
# Q2_end = 259.365166104736
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:40:01 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.054320987654 \
#     fieldLength=123.684461669241 \
#     ironLength=123.684461669241 \
#     ironRadius=11.000000000000+5.000000000000 \
#     apertureRadius=11.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [120.65408012   1.03816872 101.98278215 -19.13170487  10.99074074
#   21.53703704]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.254739357602
# Q1_length = 120.654080121991
# Q1_gradient = 1.038168724280
# radius_q = 10.990740740741
# thickness = 5.000000000000
# Q1_end = 128.581779418597
# Q2_length = 101.982782152778
# Q2_gradient = -19.131704872972
# Drift1_length = 21.537037037037
# Drift1_z = 139.350297937116
# Drift1_width = 21.981481481481
# Drift1_height = 21.981481481481
# D1_end = 150.118816455634
# Q2_z = 201.110207532023
# Q2_end = 252.101598608412
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:40:02 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.038168724280 \
#     fieldLength=120.654080121991 \
#     ironLength=120.654080121991 \
#     ironRadius=10.990740740741+5.000000000000 \
#     apertureRadius=10.990740740741 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# TRYING x = [120.82243465   1.03503086  87.22892788 -20.0711353   11.26388889
#   22.13888889]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.338916622803
# Q1_length = 120.822434652393
# Q1_gradient = 1.035030864198
# radius_q = 11.263888888889
# thickness = 5.000000000000
# Q1_end = 128.750133949000
# Q2_length = 87.228927881944
# Q2_gradient = -20.071135300125
# Drift1_length = 22.138888888889
# Drift1_z = 139.819578393444
# Drift1_width = 22.527777777778
# Drift1_height = 22.527777777778
# D1_end = 150.889022837889
# Q2_z = 194.503486778861
# Q2_end = 238.117950719833
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:40:03 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.035030864198 \
#     fieldLength=120.822434652393 \
#     ironLength=120.822434652393 \
#     ironRadius=11.263888888889+5.000000000000 \
#     apertureRadius=11.263888888889 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 34
#      31 x0 = [121.21526189, 1, 139.77335625, -17.64495411, 10, 20]  # initial guess: length=100mm, gradient=10 T/m, radius=50mm, Drift_length=200mm
#      32 bounds = ((50, 2000), (1, 30), (50, 2000), (-30, -1), (10, 500), (20, 1000))  # physical limits
# ---> 34 res = scipy.optimize.minimize(optimize_qq_drift, x0, args=(post_w1, beta_x_ref, beta_y_ref), method="Nelder-Mead", bounds=bounds)
#      35 print("Optimal parameters:", res.x)
#
# File ~/miniconda3/lib/python3.12/site-packages/scipy/optimize/_minimize.py:726, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     723 callback = _wrap_callback(callback, meth)
#     725 if meth == 'nelder-mead':
# --> 726     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     727                                **options)
#     728 elif meth == 'powell':
#     729     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~/miniconda3/lib/python3.12/site-packages/scipy/optimize/_optimize.py:865, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     863 if bounds is not None:
#     864     xe = np.clip(xe, lower_bound, upper_bound)
# --> 865 fxe = func(xe)
#     867 if fxe < fxr:
#     868     sim[-1] = xe
#
# File ~/miniconda3/lib/python3.12/site-packages/scipy/optimize/_optimize.py:542, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     540 ncalls[0] += 1
#     541 # A copy of x is sent to the user function (gh13740)
# --> 542 fx = function(np.copy(x), *(wrapper_args + args))
#     543 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     544 # backwards-compatibility, also allow np.array([1.3]),
#     545 # np.array([[1.3]]) etc.
#     546 if not np.isscalar(fx):
#
# Cell In[67], line 5, in optimize_qq_drift(x, df, beta_x_ref, beta_y_ref, w_disp, w_beta, D_tol)
#       2 q1_length, q1_gradient, q2_length, q2_gradient, q_radius, d_length = x
#       4 print("TRYING x =", x)
# ----> 5 result = run_two_quadrupoles(df, Q1_length=q1_length, Q1_gradient=q1_gradient, Q2_length=q2_length, Q2_gradient=q2_gradient, Q_radius=q_radius, Drift1_length=d_length)
#       6 if result is None or len(result) < 100:
#       7     return 1e3 + 10*(
#       8         abs(q1_gradient) +
#       9         abs(q2_gradient) +
#    (...)     12         d_length
#      13     )
#
# Cell In[65], line 53, in run_two_quadrupoles(df, Q1_length, Q1_gradient, Q2_length, Q2_gradient, Q_radius, Drift1_length, Q1_z, thickness)
#      51 # Run this file
#      52 clean_field_files()
# ---> 53 res = run_g4beam(df, "G4_FinalCooling_dispsup_Q2_run.g4bl")
#      55 if res is None or len(res) < 10:
#      56     print("G4BL run failed or empty. Check template and parameters.")
#
# File ~/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:387, in run_g4beam(df, filename, **kwargs)
#     384 command = ["g4bl", filename, f"beamfile={in_filename}", f"outname={out_base}"] + [x + "=" + str(y) for x, y in kwargs.items()]
#     386 try:
# --> 387     subprocess.run(command, stdout=subprocess.DEVNULL)
#     388 except Exception:
#     389     os.remove(in_filename)
#
# File ~/miniconda3/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/miniconda3/lib/python3.12/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File ~/miniconda3/lib/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File ~/miniconda3/lib/python3.12/subprocess.py:2051, in Popen._wait(self, timeout)
#    2049 if self.returncode is not None:
#    2050     break  # Another thread waited.
# -> 2051 (pid, sts) = self._try_wait(0)
#    2052 # Check the pid and loop as waitpid has been known to
#    2053 # return 0 even without WNOHANG in odd situations.
#    2054 # http://bugs.python.org/issue14396.
#    2055 if pid == self.pid:
#
# File ~/miniconda3/lib/python3.12/subprocess.py:2009, in Popen._try_wait(self, wait_flags)
#    2007 """All callers to this function MUST hold self._waitpid_lock."""
#    2008 try:
# -> 2009     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2010 except ChildProcessError:
#    2011     # This happens if SIGCLD is set to be ignored or waiting
#    2012     # for child processes has otherwise been disabled for our
#    2013     # process.  This child is dead, we can't get the status.
#    2014     pid = self.pid
#
# KeyboardInterrupt:

# %%
x0 = [121.21526189, 1, 139.77335625, -17.64495411, 10, 20]
res = scipy.optimize.minimize(
    optimize_qq_drift_safe, x0,
    args=(post_w1, beta_x_ref, beta_y_ref),
    method="Nelder-Mead",
    options={"xatol":1e-4, "fatol":1e-6, "maxiter":500}
)
print("Optimal parameters:", res.x)
# Out:
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:39 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [127.27602498   1.         139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 71.565711788856
# Q1_length = 127.276024984500
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 135.203724281106
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 145.203724281106
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 155.203724281106
# Q2_z = 225.090402406106
# Q2_end = 294.977080531106
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:39 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=127.276024984500 \
#     ironLength=127.276024984500 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.05       139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.050000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:40 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.050000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         146.76202406 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 146.762024062500
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 222.523973217856
# Q2_end = 295.904985249107
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:41 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -18.52720182  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -18.527201815500
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:42 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.5
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.500000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 21.000000000000
# Drift1_height = 21.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:43 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.500000000000+5.000000000000 \
#     apertureRadius=10.500000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   21.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 21.000000000000
# Drift1_z = 139.642961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 150.142961186606
# Q2_z = 220.029639311606
# Q2_end = 289.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:43 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
# Clipping input: [123.23551625   1.01666667 142.10291219 -17.93903668  10.16666667
#   19.        ] → [123.23551625   1.01666667 142.10291219 -17.93903668  10.16666667
#   20.        ]
#
# TRYING x = [123.23551625   1.01666667 142.10291219 -17.93903668  10.16666667
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.545457424023
# Q1_length = 123.235516254833
# Q1_gradient = 1.016666666667
# radius_q = 10.166666666667
# thickness = 5.000000000000
# Q1_end = 131.163215551440
# Q2_length = 142.102912187500
# Q2_gradient = -17.939036678500
# Drift1_length = 20.000000000000
# Drift1_z = 141.163215551440
# Drift1_width = 20.333333333333
# Drift1_height = 20.333333333333
# D1_end = 151.163215551440
# Q2_z = 222.214671645190
# Q2_end = 293.266127738940
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:44 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.016666666667 \
#     fieldLength=123.235516254833 \
#     ironLength=123.235516254833 \
#     ironRadius=10.166666666667+5.000000000000 \
#     apertureRadius=10.166666666667 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.72032548   1.00416667 140.35574523 -17.71847475  10.04166667
#   20.5       ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.787862037211
# Q1_length = 121.720325481208
# Q1_gradient = 1.004166666667
# radius_q = 10.041666666667
# thickness = 5.000000000000
# Q1_end = 129.648024777815
# Q2_length = 140.355745234375
# Q2_gradient = -17.718474752125
# Drift1_length = 20.500000000000
# Drift1_z = 139.898024777815
# Drift1_width = 20.083333333333
# Drift1_height = 20.083333333333
# D1_end = 150.148024777815
# Q2_z = 220.325897395002
# Q2_end = 290.503770012190
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:45 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.004166666667 \
#     fieldLength=121.720325481208 \
#     ironLength=121.720325481208 \
#     ironRadius=10.041666666667+5.000000000000 \
#     apertureRadius=10.041666666667 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [124.24564344   1.         139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 70.050521015231
# Q1_length = 124.245643437250
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 132.173342733856
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 142.173342733856
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 152.173342733856
# Q2_z = 222.060020858856
# Q2_end = 291.946698983856
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:46 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=124.245643437250 \
#     ironLength=124.245643437250 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.025      139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.025000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:47 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.025000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         143.26769016 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 143.267690156250
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 220.776806264731
# Q2_end = 292.410651342856
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:47 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -18.08607796  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -18.086077962750
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:48 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.25
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.250000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.500000000000
# Drift1_height = 20.500000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:49 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.250000000000+5.000000000000 \
#     apertureRadius=10.250000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   20.5       ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.500000000000
# Drift1_z = 139.392961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.642961186606
# Q2_z = 219.529639311606
# Q2_end = 289.416317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:50 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
# Clipping input: [122.22538907   1.00833333 140.93813422 -17.79199539  10.08333333
#   19.5       ] → [122.22538907   1.00833333 140.93813422 -17.79199539  10.08333333
#   20.        ]
#
# TRYING x = [122.22538907   1.00833333 140.93813422 -17.79199539  10.08333333
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.040393832815
# Q1_length = 122.225389072417
# Q1_gradient = 1.008333333333
# radius_q = 10.083333333333
# thickness = 5.000000000000
# Q1_end = 130.153088369023
# Q2_length = 140.938134218750
# Q2_gradient = -17.791995394250
# Drift1_length = 20.000000000000
# Drift1_z = 140.153088369023
# Drift1_width = 20.166666666667
# Drift1_height = 20.166666666667
# D1_end = 150.153088369023
# Q2_z = 220.622155478398
# Q2_end = 291.091222587773
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:51 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.008333333333 \
#     fieldLength=122.225389072417 \
#     ironLength=122.225389072417 \
#     ironRadius=10.083333333333+5.000000000000 \
#     apertureRadius=10.083333333333 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.46779369   1.00208333 140.06455074 -17.68171443  10.02083333
#   20.25      ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.661596139409
# Q1_length = 121.467793685604
# Q1_gradient = 1.002083333333
# radius_q = 10.020833333333
# thickness = 5.000000000000
# Q1_end = 129.395492982211
# Q2_length = 140.064550742188
# Q2_gradient = -17.681714431063
# Drift1_length = 20.250000000000
# Drift1_z = 139.520492982211
# Drift1_width = 20.041666666667
# Drift1_height = 20.041666666667
# D1_end = 149.645492982211
# Q2_z = 219.677768353304
# Q2_end = 289.710043724398
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:52 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.002083333333 \
#     fieldLength=121.467793685604 \
#     ironLength=121.467793685604 \
#     ironRadius=10.020833333333+5.000000000000 \
#     apertureRadius=10.020833333333 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [122.73045266   1.         139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 69.292925628419
# Q1_length = 122.730452663625
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 130.658151960231
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 140.658151960231
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 150.658151960231
# Q2_z = 220.544830085231
# Q2_end = 290.431508210231
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:52 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=122.730452663625 \
#     ironLength=122.730452663625 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.0125     139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.012500000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:53 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.012500000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         141.5205232  -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 141.520523203125
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.903222788169
# Q2_end = 290.663484389731
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:54 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.86551604  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.865516036375
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:55 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.125
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.125000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.250000000000
# Drift1_height = 20.250000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:56 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.125000000000+5.000000000000 \
#     apertureRadius=10.125000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   20.25      ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.250000000000
# Drift1_z = 139.267961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.392961186606
# Q2_z = 219.279639311606
# Q2_end = 289.166317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:56 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
# Clipping input: [121.72032548   1.00416667 140.35574523 -17.71847475  10.04166667
#   19.75      ] → [121.72032548   1.00416667 140.35574523 -17.71847475  10.04166667
#   20.        ]
#
# TRYING x = [121.72032548   1.00416667 140.35574523 -17.71847475  10.04166667
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.787862037211
# Q1_length = 121.720325481208
# Q1_gradient = 1.004166666667
# radius_q = 10.041666666667
# thickness = 5.000000000000
# Q1_end = 129.648024777815
# Q2_length = 140.355745234375
# Q2_gradient = -17.718474752125
# Drift1_length = 20.000000000000
# Drift1_z = 139.648024777815
# Drift1_width = 20.083333333333
# Drift1_height = 20.083333333333
# D1_end = 149.648024777815
# Q2_z = 219.825897395002
# Q2_end = 290.003770012190
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:57 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.004166666667 \
#     fieldLength=121.720325481208 \
#     ironLength=121.720325481208 \
#     ironRadius=10.041666666667+5.000000000000 \
#     apertureRadius=10.041666666667 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.34152779   1.00104167 139.9189535  -17.66333427  10.01041667
#   20.125     ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.598463190508
# Q1_length = 121.341527787802
# Q1_gradient = 1.001041666667
# radius_q = 10.010416666667
# thickness = 5.000000000000
# Q1_end = 129.269227084409
# Q2_length = 139.918953496094
# Q2_gradient = -17.663334270531
# Drift1_length = 20.125000000000
# Drift1_z = 139.331727084409
# Drift1_width = 20.020833333333
# Drift1_height = 20.020833333333
# D1_end = 149.394227084409
# Q2_z = 219.353703832455
# Q2_end = 289.313180580502
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:58 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.001041666667 \
#     fieldLength=121.341527787802 \
#     ironLength=121.341527787802 \
#     ironRadius=10.010416666667+5.000000000000 \
#     apertureRadius=10.010416666667 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.97285728   1.         139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.914127935013
# Q1_length = 121.972857276812
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.900556573419
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.900556573419
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.900556573419
# Q2_z = 219.787234698419
# Q2_end = 289.673912823419
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:59 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.972857276812 \
#     ironLength=121.972857276812 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.00625    139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.006250000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:44:59 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.006250000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         140.64693973 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 140.646939726562
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.466431049888
# Q2_end = 289.789900913169
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:00 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.75523507  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.755235073187
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:01 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.0625
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.062500000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.125000000000
# Drift1_height = 20.125000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:02 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.062500000000+5.000000000000 \
#     apertureRadius=10.062500000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   20.125     ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.125000000000
# Drift1_z = 139.205461186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.267961186606
# Q2_z = 219.154639311606
# Q2_end = 289.041317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:03 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
# Clipping input: [121.46779369   1.00208333 140.06455074 -17.68171443  10.02083333
#   19.875     ] → [121.46779369   1.00208333 140.06455074 -17.68171443  10.02083333
#   20.        ]
#
# TRYING x = [121.46779369   1.00208333 140.06455074 -17.68171443  10.02083333
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.661596139409
# Q1_length = 121.467793685604
# Q1_gradient = 1.002083333333
# radius_q = 10.020833333333
# thickness = 5.000000000000
# Q1_end = 129.395492982211
# Q2_length = 140.064550742188
# Q2_gradient = -17.681714431062
# Drift1_length = 20.000000000000
# Drift1_z = 139.395492982211
# Drift1_width = 20.041666666667
# Drift1_height = 20.041666666667
# D1_end = 149.395492982211
# Q2_z = 219.427768353304
# Q2_end = 289.460043724398
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:04 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.002083333333 \
#     fieldLength=121.467793685604 \
#     ironLength=121.467793685604 \
#     ironRadius=10.020833333333+5.000000000000 \
#     apertureRadius=10.020833333333 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.27839484   1.00052083 139.84615487 -17.65414419  10.00520833
#   20.0625    ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.566896716057
# Q1_length = 121.278394838901
# Q1_gradient = 1.000520833333
# radius_q = 10.005208333333
# thickness = 5.000000000000
# Q1_end = 129.206094135507
# Q2_length = 139.846154873047
# Q2_gradient = -17.654144190266
# Drift1_length = 20.062500000000
# Drift1_z = 139.237344135507
# Drift1_width = 20.010416666667
# Drift1_height = 20.010416666667
# D1_end = 149.268594135507
# Q2_z = 219.191671572031
# Q2_end = 289.114749008554
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:04 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000520833333 \
#     fieldLength=121.278394838901 \
#     ironLength=121.278394838901 \
#     ironRadius=10.005208333333+5.000000000000 \
#     apertureRadius=10.005208333333 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.59405958   1.         139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.724729088310
# Q1_length = 121.594059583406
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.521758880013
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.521758880013
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.521758880013
# Q2_z = 219.408437005013
# Q2_end = 289.295115130013
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:05 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.594059583406 \
#     ironLength=121.594059583406 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.003125   139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.003125000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:06 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.003125000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         140.21014799 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 140.210147988281
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.248035180747
# Q2_end = 289.353109174888
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:07 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.70009459  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.700094591594
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:08 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.03125
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.031250000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.062500000000
# Drift1_height = 20.062500000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:08 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.031250000000+5.000000000000 \
#     apertureRadius=10.031250000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   20.0625    ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.062500000000
# Drift1_z = 139.174211186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.205461186606
# Q2_z = 219.092139311606
# Q2_end = 288.978817436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:09 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
# Clipping input: [121.34152779   1.00104167 139.9189535  -17.66333427  10.01041667
#   19.9375    ] → [121.34152779   1.00104167 139.9189535  -17.66333427  10.01041667
#   20.        ]
#
# TRYING x = [121.34152779   1.00104167 139.9189535  -17.66333427  10.01041667
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.598463190507
# Q1_length = 121.341527787802
# Q1_gradient = 1.001041666667
# radius_q = 10.010416666667
# thickness = 5.000000000000
# Q1_end = 129.269227084409
# Q2_length = 139.918953496094
# Q2_gradient = -17.663334270531
# Drift1_length = 20.000000000000
# Drift1_z = 139.269227084409
# Drift1_width = 20.020833333333
# Drift1_height = 20.020833333333
# D1_end = 149.269227084409
# Q2_z = 219.228703832455
# Q2_end = 289.188180580502
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:45:10 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.001041666667 \
#     fieldLength=121.341527787802 \
#     ironLength=121.341527787802 \
#     ironRadius=10.010416666667+5.000000000000 \
#     apertureRadius=10.010416666667 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.24682836   1.00026042 139.80975556 -17.64954915  10.00260417
#   20.03125   ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.551113478832
# Q1_length = 121.246828364451
# Q1_gradient = 1.000260416667
# radius_q = 10.002604166667
# thickness = 5.000000000000
# Q1_end = 129.174527661057
# Q2_length = 139.809755561523
# Q2_gradient = -17.649549150133
# Drift1_length = 20.031250000000
# Drift1_z = 139.190152661057
# Drift1_width = 20.005208333333
# Drift1_height = 20.005208333333
# D1_end = 149.205777661057
# Q2_z = 219.110655441819
# Q2_end = 289.015533222580
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# ...
# Drift1_z = 139.143053666512
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.143053666512
# Q2_z = 219.029731791512
# Q2_end = 288.916409916512
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:20 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215354369906 \
#     ironLength=121.215354369906 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.00000076 139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000762939
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:23 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000762939 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77346289 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773462888608
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029692630910
# Q2_end = 288.916424075214
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:24 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64496757  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644967572032
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:25 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.00000763
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000007629395
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000015258789
# Drift1_height = 20.000015258789
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:26 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000007629395+5.000000000000 \
#     apertureRadius=10.000007629395 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   20.00001526]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000015258789
# Drift1_z = 139.142968816001
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142976445396
# Q2_z = 219.029654570396
# Q2_end = 288.916332695396
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:29 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21529272   1.00000025 139.7733918  -17.6449586   10.00000254
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535345654924
# Q1_length = 121.215292716635
# Q1_gradient = 1.000000254313
# radius_q = 10.000002543132
# thickness = 5.000000000000
# Q1_end = 129.142992013242
# Q2_length = 139.773391796203
# Q2_gradient = -17.644958597344
# Drift1_length = 20.000000000000
# Drift1_z = 139.142992013242
# Drift1_width = 20.000005086263
# Drift1_height = 20.000005086263
# D1_end = 149.142992013242
# Q2_z = 219.029687911343
# Q2_end = 288.916383809444
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:30 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000254313 \
#     fieldLength=121.215292716635 \
#     ironLength=121.215292716635 \
#     ironRadius=10.000002543132+5.000000000000 \
#     apertureRadius=10.000002543132 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.2152696    1.00000006 139.77336514 -17.64495523  10.00000064
#   20.00000763]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535334094936
# Q1_length = 121.215269596659
# Q1_gradient = 1.000000063578
# radius_q = 10.000000635783
# thickness = 5.000000000000
# Q1_end = 129.142968893265
# Q2_length = 139.773365136551
# Q2_gradient = -17.644955231836
# Drift1_length = 20.000007629395
# Drift1_z = 139.142972707963
# Drift1_width = 20.000001271566
# Drift1_height = 20.000001271566
# D1_end = 149.142976522660
# Q2_z = 219.029659090935
# Q2_end = 288.916341659211
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:31 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000063578 \
#     fieldLength=121.215269596659 \
#     ironLength=121.215269596659 \
#     ironRadius=10.000000635783+5.000000000000 \
#     apertureRadius=10.000000635783 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21530813   1.         139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535353361583
# Q1_length = 121.215308129953
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.143007426559
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.143007426559
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.143007426559
# Q2_z = 219.029685551559
# Q2_end = 288.916363676559
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:31 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215308129953 \
#     ironLength=121.215308129953 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.00000038 139.77335625 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000381470
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:32 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000381470 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77340957 -17.64495411  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773409569304
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029665971258
# Q2_end = 288.916370755910
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:33 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64496084  10.
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644960841016
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:34 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.00000381
#   20.        ]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000003814697
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000000000000
# Drift1_z = 139.142961186606
# Drift1_width = 20.000007629395
# Drift1_height = 20.000007629395
# D1_end = 149.142961186606
# Q2_z = 219.029639311606
# Q2_end = 288.916317436607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:35 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000003814697+5.000000000000 \
#     apertureRadius=10.000003814697 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
#
# TRYING x = [121.21526189   1.         139.77335625 -17.64495411  10.
#   20.00000763]
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 68.535330241606
# Q1_length = 121.215261890000
# Q1_gradient = 1.000000000000
# radius_q = 10.000000000000
# thickness = 5.000000000000
# Q1_end = 129.142961186606
# Q2_length = 139.773356250000
# Q2_gradient = -17.644954110000
# Drift1_length = 20.000007629395
# Drift1_z = 139.142965001304
# Drift1_width = 20.000000000000
# Drift1_height = 20.000000000000
# D1_end = 149.142968816001
# Q2_z = 219.029646941001
# Q2_end = 288.916325066001
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:46:36 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=121.215261890000 \
#     ironLength=121.215261890000 \
#     ironRadius=10.000000000000+5.000000000000 \
#     apertureRadius=10.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# No particles survived
# Optimal parameters: [121.21526189   1.         139.77335625 -17.64495411  10.
#   20.        ]

# %%
def survival_fraction_asym(df_out, Q_radius):
    """Fraction of particles surviving both transverse planes"""
    survived = ((df_out['x'].abs() < Q_radius) & (df_out['y'].abs() < Q_radius))
    return survived.sum() / len(df_out)

results = []

Q1_lengths = np.linspace(50, 2000, 5)
Q1_gradients = np.linspace(1, 30, 5)
Q2_lengths = np.linspace(50, 2000, 5)
Q2_gradients = np.linspace(-30, -1, 5)

for L1, G1, L2, G2 in itertools.product(Q1_lengths, Q1_gradients, Q2_lengths, Q2_gradients):
    res = run_two_quadrupoles(post_w1,
                              Q1_length=L1, Q1_gradient=G1,
                              Q2_length=L2, Q2_gradient=G2,
                              Q_radius=50.0, Drift1_length=100)
    if res is None:
        continue
    surv_frac = survival_fraction_asym(res, 50.0)
    results.append({'Q1_L': L1, 'Q1_G': G1, 'Q2_L': L2, 'Q2_G': G2, 'survival': surv_frac})

df_results = pd.DataFrame(results)
df_safe = df_results[df_results['survival'] >= 0.95]

# Bounds for optimizer
Q1_L_bounds = (df_safe['Q1_L'].min(), df_safe['Q1_L'].max())
Q1_G_bounds = (df_safe['Q1_G'].min(), df_safe['Q1_G'].max())
Q2_L_bounds = (df_safe['Q2_L'].min(), df_safe['Q2_L'].max())
Q2_G_bounds = (df_safe['Q2_G'].min(), df_safe['Q2_G'].max())
# Out:
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:02:51 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:02:52 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:02:53 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:02:54 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:02:55 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:02:56 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:02:57 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:02:58 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:02:59 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:00 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:02 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:03 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:04 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:05 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:06 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:07 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:08 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:09 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:10 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:11 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 2000.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 1157.927699296607
# Q2_end = 2157.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:12 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 2000.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 1157.927699296607
# Q2_end = 2157.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:13 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 2000.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 1157.927699296607
# Q2_end = 2157.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:15 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 2000.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 1157.927699296607
# Q2_end = 2157.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:16 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 2000.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 1157.927699296607
# Q2_end = 2157.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:17 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:18 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:19 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:20 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:21 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:22 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:23 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:24 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:25 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:26 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:27 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:28 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:29 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:31 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:32 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:33 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:34 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:35 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:36 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:38 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:39 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 2000.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 1157.927699296607
# Q2_end = 2157.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:40 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 2000.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 1157.927699296607
# Q2_end = 2157.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:03:41 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
# ...
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 1025.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 2620.427699296607
# Q2_end = 3132.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:38 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 1025.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 2620.427699296607
# Q2_end = 3132.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:39 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 1025.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 2620.427699296607
# Q2_end = 3132.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:40 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 1025.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 2620.427699296607
# Q2_end = 3132.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:41 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 1025.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 2620.427699296607
# Q2_end = 3132.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:42 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 1512.500000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 2864.177699296607
# Q2_end = 3620.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:42 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 1512.500000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 2864.177699296607
# Q2_end = 3620.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:43 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 1512.500000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 2864.177699296607
# Q2_end = 3620.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:44 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 1512.500000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 2864.177699296607
# Q2_end = 3620.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:45 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 1512.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 2864.177699296607
# Q2_end = 3620.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:46 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 2000.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 3107.927699296607
# Q2_end = 4107.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:47 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 2000.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 3107.927699296607
# Q2_end = 4107.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:48 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 2000.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 3107.927699296607
# Q2_end = 4107.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:49 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 2000.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 3107.927699296607
# Q2_end = 4107.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:50 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 1007.927699296606
# Q1_length = 2000.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 2007.927699296607
# Q2_length = 2000.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 2057.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 2107.927699296607
# Q2_z = 3107.927699296607
# Q2_end = 4107.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:13:51 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=2000.000000000000 \
#     ironLength=2000.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# G4BL run failed or empty. Check template and parameters.

# %%
print(len(df_safe))
df_safe.to_csv('safebounds.csv')
# Out:
# 72

# %%
df_scan = pd.read_csv("safebounds.csv")

results = []

for idx, row in df_scan.iterrows():
    L1, G1, L2, G2 = row['Q1_L'], row['Q1_G'], row['Q2_L'], row['Q2_G']
    
    res = run_two_quadrupoles(post_w1,
                              Q1_length=L1, Q1_gradient=G1,
                              Q2_length=L2, Q2_gradient=G2,
                              Q_radius=50.0, Drift1_length=100)
    
    if res is None:
        print(f"Skipping run {idx} → failed")
        continue
    
    x_params, y_params, z_emit = calc_all_params(res)
    dx = x_params[4]
    beta_x = x_params[1]
    beta_y = y_params[1]
    
    results.append({'Q1_L': L1, 'Q1_G': G1,
                    'Q2_L': L2, 'Q2_G': G2,
                    'dx': dx, 'beta_x': beta_x, 'beta_y': beta_y})
# Out:
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:13 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:14 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:15 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:16 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:17 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:18 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:19 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:20 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:21 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:22 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:24 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:25 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:26 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:27 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:28 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:29 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:30 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:31 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:32 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:33 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:34 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:35 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 15.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:37 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=15.500000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 15.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:38 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=15.500000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 15.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:39 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=15.500000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 15.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:40 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=15.500000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 15.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:41 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=15.500000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 15.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:42 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=15.500000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 15.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:43 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=15.500000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 15.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:44 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=15.500000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 15.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:45 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=15.500000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 15.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:46 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=15.500000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 15.500000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:47 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=15.500000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:48 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:49 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:50 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:51 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:52 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:53 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:54 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:55 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 537.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 426.677699296606
# Q2_end = 695.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:57 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1025.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 670.427699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:58 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 1512.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 914.177699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:51:59 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:00 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:01 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:02 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 157.927699296606
# Q2_z = 182.927699296606
# Q2_end = 207.927699296606
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:04 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=30.000000000000 \
#     fieldLength=50.000000000000 \
#     ironLength=50.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 32.927699296606
# Q1_length = 50.000000000000
# Q1_gradient = 30.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 57.927699296606
# Q2_length = 50.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 107.927699296606
# ...
# Q1_gradient = 8.250000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 545.427699296606
# Q2_length = 537.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 595.427699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 645.427699296606
# Q2_z = 914.177699296606
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:14 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=8.250000000000 \
#     fieldLength=537.500000000000 \
#     ironLength=537.500000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 276.677699296606
# Q1_length = 537.500000000000
# Q1_gradient = 22.750000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 545.427699296606
# Q2_length = 537.500000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 595.427699296606
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 645.427699296606
# Q2_z = 914.177699296606
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:15 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=22.750000000000 \
#     fieldLength=537.500000000000 \
#     ironLength=537.500000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 520.427699296606
# Q1_length = 1025.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1032.927699296607
# Q2_length = 50.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1082.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1132.927699296607
# Q2_z = 1157.927699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:16 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1025.000000000000 \
#     ironLength=1025.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 520.427699296606
# Q1_length = 1025.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1032.927699296607
# Q2_length = 50.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1082.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1132.927699296607
# Q2_z = 1157.927699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:18 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1025.000000000000 \
#     ironLength=1025.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 520.427699296606
# Q1_length = 1025.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1032.927699296607
# Q2_length = 50.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1082.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1132.927699296607
# Q2_z = 1157.927699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:19 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1025.000000000000 \
#     ironLength=1025.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 520.427699296606
# Q1_length = 1025.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1032.927699296607
# Q2_length = 50.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1082.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1132.927699296607
# Q2_z = 1157.927699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:20 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1025.000000000000 \
#     ironLength=1025.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 520.427699296606
# Q1_length = 1025.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1032.927699296607
# Q2_length = 50.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1082.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1132.927699296607
# Q2_z = 1157.927699296607
# Q2_end = 1182.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:22 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1025.000000000000 \
#     ironLength=1025.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 520.427699296606
# Q1_length = 1025.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1032.927699296607
# Q2_length = 537.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1082.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1132.927699296607
# Q2_z = 1401.677699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:23 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1025.000000000000 \
#     ironLength=1025.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 520.427699296606
# Q1_length = 1025.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1032.927699296607
# Q2_length = 1025.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1082.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1132.927699296607
# Q2_z = 1645.427699296607
# Q2_end = 2157.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:24 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1025.000000000000 \
#     ironLength=1025.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 520.427699296606
# Q1_length = 1025.000000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1032.927699296607
# Q2_length = 1512.500000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1082.927699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1132.927699296607
# Q2_z = 1889.177699296607
# Q2_end = 2645.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:25 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1025.000000000000 \
#     ironLength=1025.000000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 764.177699296606
# Q1_length = 1512.500000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1520.427699296607
# Q2_length = 50.000000000000
# Q2_gradient = -30.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1570.427699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1620.427699296607
# Q2_z = 1645.427699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:27 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1512.500000000000 \
#     ironLength=1512.500000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 764.177699296606
# Q1_length = 1512.500000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1520.427699296607
# Q2_length = 50.000000000000
# Q2_gradient = -22.750000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1570.427699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1620.427699296607
# Q2_z = 1645.427699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:28 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1512.500000000000 \
#     ironLength=1512.500000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 764.177699296606
# Q1_length = 1512.500000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1520.427699296607
# Q2_length = 50.000000000000
# Q2_gradient = -15.500000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1570.427699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1620.427699296607
# Q2_z = 1645.427699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:29 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1512.500000000000 \
#     ironLength=1512.500000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 764.177699296606
# Q1_length = 1512.500000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1520.427699296607
# Q2_length = 50.000000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1570.427699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1620.427699296607
# Q2_z = 1645.427699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:30 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1512.500000000000 \
#     ironLength=1512.500000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 764.177699296606
# Q1_length = 1512.500000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1520.427699296607
# Q2_length = 50.000000000000
# Q2_gradient = -1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1570.427699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1620.427699296607
# Q2_z = 1645.427699296607
# Q2_end = 1670.427699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:32 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1512.500000000000 \
#     ironLength=1512.500000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 764.177699296606
# Q1_length = 1512.500000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1520.427699296607
# Q2_length = 537.500000000000
# Q2_gradient = -8.250000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1570.427699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1620.427699296607
# Q2_z = 1889.177699296607
# Q2_end = 2157.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:52:33 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1512.500000000000 \
#     ironLength=1512.500000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------

# %%
df_results = pd.DataFrame(results)

# Option 1: minimize dx only
best_dx_row = df_results.loc[df_results['dx'].idxmin()]

# Option 2: combine dx + beta_x as a metric
df_results['score'] = df_results['dx'] + 0.1*df_results['beta_x']
best_row = df_results.loc[df_results['score'].idxmin()]

print("Best quad set (min dx + beta):")
print(best_row)
# Out:
# Best quad set (min dx + beta):
# Q1_L      1512.500000
# Q1_G         1.000000
# Q2_L       537.500000
# Q2_G        -8.250000
# dx          -0.130531
# beta_x       0.842484
# beta_y       0.746318
# score       -0.046283
# Name: 71, dtype: float64

# %%
res = run_two_quadrupoles(post_w1,
                              Q1_length=best_row["Q1_L"], Q1_gradient=best_row["Q1_G"],
                              Q2_length=best_row["Q2_L"], Q2_gradient=best_row["Q1_G"],
                              Q_radius=50.0, Drift1_length=100)
write_trackfile(res, "particles_after_q2.txt")
convertZ("particles_after_q2.txt", "particles_after_q2upt.txt")
# Out:
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 764.177699296606
# Q1_length = 1512.500000000000
# Q1_gradient = 1.000000000000
# radius_q = 50.000000000000
# thickness = 5.000000000000
# Q1_end = 1520.427699296607
# Q2_length = 537.500000000000
# Q2_gradient = 1.000000000000
# Drift1_length = 100.000000000000
# Drift1_z = 1570.427699296607
# Drift1_width = 100.000000000000
# Drift1_height = 100.000000000000
# D1_end = 1620.427699296607
# Q2_z = 1889.177699296607
# Q2_end = 2157.927699296607
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 18:55:06 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000000000000 \
#     fieldLength=1512.500000000000 \
#     ironLength=1512.500000000000 \
#     ironRadius=50.000000000000+5.000000000000 \
#     apertureRadius=50.000000000000 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
# Updated file saved as 'particles_after_q2upt.txt'

# %%
res_0 = read_trackfile("particles_after_q2upt.txt")

# %%
def run_dipole(df, B_field, B_length, Drift2_length, B_width = 100, B_height = 100, Drift2_z=0):
    """Run dipole simulation with given parameters."""
    params = {
        "Drift2_length": Drift2_length, 
        "Drift2_width": B_width,
        "Drift2_height": B_height,
        "Drift2_z": Drift2_z + Drift2_length/2,
        "B1_field": B_field,
        "B1_z": Drift2_z + Drift2_length + B_length/2,
        "B1_end": Drift2_z + Drift2_length + B_length,
        "B1_length": B_length,
        "B1_width": B_width,
        "B1_height": B_height
    }
    write_input_from_template("G4_FinalCooling_dispsup_B.g4bl", params, "G4_FinalCooling_dispsup_B_run.g4bl")
    outfile = "G4_FinalCooling_dispsup_B_run.g4bl"
    return run_g4beam(df, "G4_FinalCooling_dispsup_B_run.g4bl")

# %%
Drift2_lengths = np.linspace(5, 300, 20)   # drift before dipole
B1_lengths = np.linspace(50, 500, 50)       # dipole length
B1_fields = np.linspace(-3.0, 3.0, 12)          # dipole field strength (T)

resultsd = []

for drift_len, b_len, b_field in itertools.product(Drift2_lengths, B1_lengths, B1_fields):
    
    res = run_dipole(res_0,
                     B_field=b_field,
                     B_length=b_len,
                     Drift2_length=drift_len,
                     Drift2_z=0)
    
    if res is None:
        continue
    
    surv_frac = survival_fraction_asym(res, 50.0)
    
    resultsd.append({'Drift2_length': drift_len,
                    'B1_length': b_len,
                    'B1_field': b_field,
                    'survival': surv_frac})

df_resultsd = pd.DataFrame(resultsd)
df_safed = df_resultsd[df_resultsd['survival'] >= 0.95]

# Bounds for optimizer
Drift2_length_bounds = (df_safed['Drift2_length'].min(), df_safed['Drift2_length'].max())
B1_length_bounds = (df_safed['B1_length'].min(), df_safed['B1_length'].max())
B1_field_bounds = (df_safed['B1_field'].min(), df_safed['B1_field'].max())
# Out:
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)
# /tmp/ipykernel_21641/1396384763.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   return survived.sum() / len(df_out)

# %%
print(len(df_safed))
df_safed.to_csv('safeboundsd.csv')
# Out:
# 55

# %%
df_scan = pd.read_csv("safeboundsd.csv")

results = []

for idx, row in df_scan.iterrows():
    D1, B1, L1 = row['Drift2_length'], row['B1_length'], row['B1_field']
    
    res_d = run_dipole(res_0, B_field=B1, B_length=L1, Drift2_length=D1, B_width = 100, B_height = 100, Drift2_z=0)
    
    if res_d is None:
        print(f"Skipping run {idx} → failed")
        continue
    
    x_params, y_params, z_emit = calc_all_params(res_d)
    dx = x_params[4]
    beta_x = x_params[1]
    beta_y = y_params[1]
    
    results.append({'Drift2_length': D1, 'Q1_G': B1,
                    'B1_length': L1,
                    'dx': dx, 'beta_x': beta_x, 'beta_y': beta_y})
# Out:
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless

# %%
df_d_results = pd.DataFrame(results)

# Option 1: minimize dx only
best_dx_row_d = df_d_results.loc[df_d_results['dx'].idxmin()]

# Option 2: combine dx + beta_x as a metric
df_d_results['score'] = df_d_results['dx'] + 0.1*df_d_results['beta_x']
best_row_d = df_d_results.loc[df_d_results['score'].idxmin()]

print("Best dipole set (min dx + beta):")
print(best_row_d)
# Out:
# Best dipole set (min dx + beta):
# Drift2_length    109.736842
# Q1_G             408.163265
# B1_length          0.272727
# dx                -0.136825
# beta_x             0.810813
# beta_y             0.174981
# score             -0.055743
# Name: 13, dtype: float64

# %%
x_test = [121.21526189, 1, 139.77335625, -17.64495411, 10, 20]
res = run_two_quadrupoles(
    post_w1,
    Q1_length=x_test[0],
    Q1_gradient=x_test[1],
    Q2_length=x_test[2],
    Q2_gradient=x_test[3],
    Q_radius=x_test[4],
    Drift1_length=x_test[5]
)
print(res)

# %%
# [165.44850696   1.         117.80564137 -16.64715284  10. 20.        ]
# [203.10586964   1.         242.37880814  -7.24549651  10. 20.        ]
print(res.x)
# Out:
# [121.27689123   1.00062591 146.55791301 -17.6125612    9.99916928
#   20.00454974]

# %%
if os.path.exists("field_cellQ2.dat"):
    os.remove("field_cellQ2.dat")
df_opt = run_two_quadrupoles(post_w1, Q1_length=res.x[0], Q1_gradient=res.x[1],
                             Q2_length=res.x[2], Q2_gradient=res.x[3],
                             Q_radius=res.x[4], Drift1_length=res.x[5])
print(df_opt)
x_params, y_params, z_emit = calc_all_params(df_opt)
print("Dx, Dy =", x_params[4], y_params[4])
# Out:
# PARAMS PASSED TO TEMPLATE:
# Q1_z = 440.381607497347
# Q1_length = 121.276891229056
# Q1_gradient = 1.000625911067
# radius_q = 9.999169278458
# thickness = 5.000000000000
# Q1_end = 501.020053111875
# Q2_length = 146.557913013408
# Q2_gradient = -17.612561197470
# Drift1_length = 20.004549738408
# Drift1_z = 511.022327981079
# Drift1_width = 19.998338556917
# Drift1_height = 19.998338556917
# D1_end = 521.024602850283
# Q2_z = 594.303559356987
# Q2_end = 667.582515863691
# === DEBUG FILE CHECK ===
# Absolute path: /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/G4_FinalCooling_dispsup_Q2_run.g4bl
# Last modified: Mon Jan 19 16:18:38 2026
# ========================
# ---- Q1 BLOCK ----
# genericquad Q1 \
#     gradient=1.000625911067 \
#     fieldLength=121.276891229056 \
#     ironLength=121.276891229056 \
#     ironRadius=9.999169278458+5.000000000000 \
#     apertureRadius=9.999169278458 \
#     maxStep=0.5 \
#     ironMaterial=Fe fieldMaterial=Vacuum \
#     ironColor=0.4,0.8,0.4 \
#     kill=1 \
#     fringe=0
#
# -------------------
#            x          y        z        Px        Py       Pz        t  PDGid  \
# 0    67.3126  -5.576900  667.583   8.49745 -0.855538  86.2508  3.85681    -13
# 1   -23.4730 -57.436200  667.583  -3.10644 -7.850440  89.7057  3.83869    -13
# 2    14.9056  70.998900  667.583   1.76190  9.351490  90.8491  4.48182    -13
# 3    86.4769  68.690200  667.583  10.83610  8.493850  84.8895  3.80142    -13
# 4   -30.4990  35.853600  667.583  -3.02890  3.978020  74.6773  2.65999    -13
# ..       ...        ...      ...       ...       ...      ...      ...    ...
# 376  11.7605 -76.425800  667.583   1.56206 -9.483450  85.1077  3.89084    -13
# 377 -68.8698 -55.342200  667.583  -8.73577 -6.910150  86.3919  4.59256    -13
# 378 -91.9265  72.798400  667.583 -12.06880  9.177830  88.7955  2.96035    -13
# 379  27.9524  -0.175951  667.583   3.69279  0.511977  88.8610  3.44467    -13
# 380 -11.7364  44.891100  667.583  -1.62709  6.044190  91.4212  4.22574    -13
#
#      EventID  TrackID  ...  ProperTime  PathLength  PolX  PolY  PolZ  InitX  \
# 0          1        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 1          2        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 2          3        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 3          4        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 4          5        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# ..       ...      ...  ...         ...         ...   ...   ...   ...    ...
# 376      494        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 377      496        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 378      497        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 379      498        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
# 380      499        1  ...         NaN         NaN   NaN   NaN   NaN    NaN
#
#      InitY  InitZ  InitT  InitKE
# 0      NaN    NaN    NaN     NaN
# 1      NaN    NaN    NaN     NaN
# 2      NaN    NaN    NaN     NaN
# 3      NaN    NaN    NaN     NaN
# 4      NaN    NaN    NaN     NaN
# ..     ...    ...    ...     ...
# 376    NaN    NaN    NaN     NaN
# 377    NaN    NaN    NaN     NaN
# 378    NaN    NaN    NaN     NaN
# 379    NaN    NaN    NaN     NaN
# 380    NaN    NaN    NaN     NaN
#
# [381 rows x 28 columns]
# Dx, Dy = -0.020951742603884035 0.0005910393495034264

# %%
b_dict = {"Beta_x" : x_params[1], "Beta_y" : y_params[1]}
print(b_dict)
# Out:
# {'Beta_x': np.float64(72.39807786889581), 'Beta_y': np.float64(22.560635616029888)}

# %%
# Runs a single case with the optimal parameters
opt_params = {
    "Q1_z": L_centerline_orig + (res.x[0] / 2),
    "Q1_length": res.x[0],
    "Q1_gradient": res.x[1],
    "radius_q": res.x[4],
    "thickness": 5,
    "Q1_end": L_centerline_orig + res.x[0],
    "Q2_length": res.x[2],
    "Q2_gradient": res.x[3],
    "Drift1_length": res.x[5],
    "Drift1_z": L_centerline_orig + res.x[0] + (res.x[5] / 2),
    "Drift1_width": 100, 
    "Drift1_height": 100, 
    "D1_end": L_centerline_orig + res.x[0] + res.x[5],
    "Q2_z": L_centerline_orig + res.x[0] + res.x[5] + res.x[2]/2,
    "Q2_end": L_centerline_orig + res.x[0] + res.x[5] + res.x[2],
    }
write_input_from_template("G4_FinalCooling_dispsup_Q2.g4bl", opt_params, "G4_FinalCooling_dispsup_Q2_opt.g4bl")
if os.path.exists("field_cellQ2.dat"):
    os.remove("field_cellQ2.dat")
result = subprocess.run(["g4bl", "G4_FinalCooling_dispsup_Q2_opt.g4bl"], capture_output=True, text=True, check=True)
df_opt = read_trackfile("particles_after_q2.txt")
x_params, y_params, z_emit = calc_all_params(df_opt)
D_dict = {"D_x": x_params[4], "D'_x": x_params[5], "D_y": y_params[4], "D'_y": y_params[5]}
b_dict= {"Beta_x": x_params[1], "Beta_y": y_params[1]}
print(D_dict, r"Epsilon_z: "+str(z_emit), b_dict)
print(x_params[0], y_params[0])
# Out:
# {'D_x': np.float64(-0.08783904878145891), "D'_x": np.float64(-0.15344373297819064), 'D_y': np.float64(0.057650843125764496), "D'_y": np.float64(0.08332458125322721)} Epsilon_z: 6.297898761918679 {'Beta_x': np.float64(76.53867829697991), 'Beta_y': np.float64(30.924397970261392)}
# 0.06704296864188604 0.17294800716731085

# %%
"""if os.path.exists("particles_after_q2upt.txt"):
    os.remove("particles_after_q2upt.txt")"""
convertZ("particles_after_q2upt.txt", "particles_after_q2uptc.txt", set_to=(L_centerline_orig + res.x[0] + res.x[5] + res.x[2]))

# %%
with open("particles_after_q2upt.txt") as f:
    N_out = sum(1 for line in f if not line.startswith("#") and line.strip())
    print(N_out)
N_PARTICLES = 500
# Compute transmission (%)
trans_percent = 100.0 * N_out / int(N_PARTICLES)
print(trans_percent)
# Out:
# 25
# 5.0

# %%
def check_dipole_clearance(df, B_val, dipole_length_mm, dipole_halfwidth_mm):
    """
    Check which particles clear the dipole aperture based on their Larmor radius
    and deflection geometry.

    Parameters:
      df : pandas.DataFrame with columns ['Px','Py','Pz'] in MeV/c
      B_val : magnetic field (Tesla)
      dipole_length_mm : dipole magnet effective length (mm)
      dipole_halfwidth_mm : half-width of dipole aperture (mm)

    Returns:
      surviving_mask : boolean array, True if particle clears aperture
      r_L_mm : array of Larmor radii (mm)
      delta_r_mm : array of deflections (mm)
    """

    # constants
    e = 1.602176634e-19  # C
    c = 2.99792458e8     # m/s

    # convert MeV/c to SI (kg·m/s)
    mom_perp = np.sqrt(df["Px"]**2 + df["Pz"]**2) * 1e6 * e / c  # B assumed along y

    # Larmor radius [m]
    r_L = mom_perp / (e * np.abs(B_val))

    # convert to mm
    r_L_mm = r_L * 1e3
    s_mm = dipole_length_mm

    # deflection Δr = r * (1 - cos(φ)), φ = s / r
    phi = s_mm / r_L_mm
    delta_r_mm = r_L_mm * (1 - np.cos(phi))

    # check if deflection < half-width
    surviving_mask = delta_r_mm < dipole_halfwidth_mm


    return surviving_mask, r_L_mm, delta_r_mm

# %%
def beam_size(beta, eps, n_sigma=1):
    """
    Compute full beam width/height in mm for given beta (m) and emittance (mm·mrad)
    """
    sigma = np.sqrt(beta * eps * 1e3)  # convert sigma (mm) = sqrt(m * 1e3 * mm)
    return 2 * n_sigma * sigma
B_width = beam_size(x_params[1], x_params[0])
B_height = beam_size(y_params[1], y_params[0])
print(B_height, B_width)
# Out:
# 146.26432240031113 143.26730553696927

# %%
def run_dipole(df, B_field, B_length, Drift2_length, Drift2_z=0):
    """Run dipole simulation with given parameters."""
    params = {
        "Drift2_length": Drift2_length, 
        "Drift2_width": B_width,
        "Drift2_height": B_height,
        "Drift2_z": Drift2_z + Drift2_length/2,
        "B1_field": B_field,
        "B1_z": Drift2_z + Drift2_length + B_length/2,
        "B1_end": Drift2_z + Drift2_length + B_length,
        "B1_length": B_length,
        "B1_width": B_width,
        "B1_height": B_height
    }
    write_input_from_template("G4_FinalCooling_dispsup_B.g4bl", params, "G4_FinalCooling_dispsup_B_run.g4bl")
    outfile = "G4_FinalCooling_dispsup_B_run.g4bl"
    return run_g4beam(df, "G4_FinalCooling_dispsup_B_run.g4bl")

# %%
results = []
"""for DL in tqdm(np.linspace(10, 300, 30)): 
    # print("Trying Drift Length: " + str(DL))"""
DL=100
for B in tqdm(np.linspace(-2.5, 2.5, 25)):
    # print("Trying B Strength: " + str(B))
    for L in tqdm(np.linspace(100, 1000, 10)):
        # print("Trying B Length: " + str(L))
        if os.path.exists("field_cellB.dat"):
            os.remove("field_cellB.dat")
        df_dipp = run_dipole(df_opt, B, L, DL)
        x_params_D, y_params_D, _ = calc_all_params(df_dipp)
        # print(f"B={B:.2f} Dx={x_params_D[4]:.4f} beta_x={x_params_D[1]:.2f}")
        Dx = x_params_D[4]
        beta_x = x_params_D[1]

        results.append([DL, B, L, Dx, beta_x])
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# 100%|██████████| 10/10 [00:07<00:00,  1.41it/s]
#   4%|▍         | 1/25 [00:07<02:49,  7.08s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:128: RuntimeWarning: divide by zero encountered in scalar divide
#   eb / e / 1000,  # mm --> m
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ey / e * 1000,  # 1/mm --> 1/m
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:130: RuntimeWarning: invalid value encountered in scalar divide
#   ea / e,  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# 100%|██████████| 10/10 [00:06<00:00,  1.53it/s]
#   8%|▊         | 2/25 [00:13<02:35,  6.75s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:128: RuntimeWarning: invalid value encountered in scalar divide
#   eb / e / 1000,  # mm --> m
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ey / e * 1000,  # 1/mm --> 1/m
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:130: RuntimeWarning: invalid value encountered in scalar divide
#   ea / e,  # dimensionless
# 100%|██████████| 10/10 [00:06<00:00,  1.50it/s]
#  12%|█▏        | 3/25 [00:20<02:27,  6.72s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# 100%|██████████| 10/10 [00:06<00:00,  1.48it/s]
#  16%|█▌        | 4/25 [00:27<02:21,  6.73s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   eb = mean_x2 - np.square(mean_xd) / mean_d2  # mm^2
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:119: RuntimeWarning: invalid value encountered in scalar divide
#   ey = mean_xp2 - np.square(mean_xpd) / mean_d2  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:120: RuntimeWarning: invalid value encountered in scalar divide
#   ea = -mean_xxp + mean_xpd * mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:123: RuntimeWarning: invalid value encountered in scalar divide
#   d = mean_xd / mean_d2  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   dp = mean_xpd / mean_d2  # dimensionless
# 100%|██████████| 10/10 [00:06<00:00,  1.46it/s]
#  20%|██        | 5/25 [00:33<02:15,  6.77s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:128: RuntimeWarning: invalid value encountered in scalar divide
#   eb / e / 1000,  # mm --> m
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ey / e * 1000,  # 1/mm --> 1/m
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:130: RuntimeWarning: invalid value encountered in scalar divide
#   ea / e,  # dimensionless
# 100%|██████████| 10/10 [00:06<00:00,  1.50it/s]
#  24%|██▍       | 6/25 [00:40<02:08,  6.74s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# 100%|██████████| 10/10 [00:07<00:00,  1.41it/s]
# 100%|██████████| 10/10 [00:06<00:00,  1.43it/s]
# 100%|██████████| 10/10 [00:06<00:00,  1.52it/s]
# 100%|██████████| 10/10 [00:06<00:00,  1.56it/s]
# 100%|██████████| 10/10 [00:06<00:00,  1.53it/s]
# 100%|██████████| 10/10 [00:06<00:00,  1.53it/s]
# 100%|██████████| 10/10 [00:06<00:00,  1.52it/s]
# 100%|██████████| 10/10 [00:06<00:00,  1.56it/s]
# 100%|██████████| 10/10 [00:06<00:00,  1.54it/s]
#  60%|██████    | 15/25 [01:40<01:05,  6.53s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# 100%|██████████| 10/10 [00:06<00:00,  1.53it/s]
#  64%|██████▍   | 16/25 [01:46<00:58,  6.53s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# 100%|██████████| 10/10 [00:06<00:00,  1.56it/s]
# 100%|██████████| 10/10 [00:06<00:00,  1.54it/s]
#  72%|███████▏  | 18/25 [01:59<00:45,  6.49s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# 100%|██████████| 10/10 [00:06<00:00,  1.52it/s]
#  76%|███████▌  | 19/25 [02:06<00:39,  6.52s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# 100%|██████████| 10/10 [00:06<00:00,  1.54it/s]
#  80%|████████  | 20/25 [02:12<00:32,  6.51s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:128: RuntimeWarning: invalid value encountered in scalar divide
#   eb / e / 1000,  # mm --> m
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:129: RuntimeWarning: divide by zero encountered in scalar divide
#   ey / e * 1000,  # 1/mm --> 1/m
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:130: RuntimeWarning: invalid value encountered in scalar divide
#   ea / e,  # dimensionless
# 100%|██████████| 10/10 [00:06<00:00,  1.54it/s]
# 100%|██████████| 10/10 [00:06<00:00,  1.53it/s]
#  88%|████████▊ | 22/25 [02:25<00:19,  6.51s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# 100%|██████████| 10/10 [00:06<00:00,  1.54it/s]
#  92%|█████████▏| 23/25 [02:32<00:13,  6.50s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# 100%|██████████| 10/10 [00:06<00:00,  1.53it/s]
#  96%|█████████▌| 24/25 [02:38<00:06,  6.51s/it]/home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:128: RuntimeWarning: divide by zero encountered in scalar divide
#   eb / e / 1000,  # mm --> m
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ey / e * 1000,  # 1/mm --> 1/m
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:130: RuntimeWarning: invalid value encountered in scalar divide
#   ea / e,  # dimensionless
# /home/incik/Cooling_4D/DispersionSuppressorQQBAnl/g4beam.py:121: RuntimeWarning: invalid value encountered in sqrt
#   e = np.sqrt(eb * ey - np.square(ea))  # mm
# 100%|██████████| 10/10 [00:06<00:00,  1.52it/s]
# 100%|██████████| 25/25 [02:45<00:00,  6.61s/it]

# %%
df_scan = pd.DataFrame(
    results,
    columns=["DL", "B", "L", "Dx", "beta_x"]
)
results
# Out:
# [[100,
#   np.float64(-2.5),
#   np.float64(100.0),
#   np.float64(-0.10029544838031253),
#   np.float64(1.7639585825062005)],
#  [100,
#   np.float64(-2.5),
#   np.float64(200.0),
#   np.float64(-0.12015825430504865),
#   np.float64(8.656442559125688)],
#  [100,
#   np.float64(-2.5),
#   np.float64(300.0),
#   np.float64(-0.14567969765894095),
#   np.float64(9.79230305700987)],
#  [100,
#   np.float64(-2.5),
#   np.float64(400.0),
#   np.float64(-0.037318140525189676),
#   np.float64(10.615564214385925)],
#  [100,
#   np.float64(-2.5),
#   np.float64(500.0),
#   np.float64(-0.23947942406192832),
#   np.float64(10.654704961462182)],
#  [100,
#   np.float64(-2.5),
#   np.float64(600.0),
#   np.float64(-0.34576023318080334),
#   np.float64(10.745809965347588)],
#  [100,
#   np.float64(-2.5),
#   np.float64(700.0),
#   np.float64(-0.3508484840795659),
#   np.float64(11.603536909920754)],
#  [100,
#   np.float64(-2.5),
#   np.float64(800.0),
#   np.float64(-0.5895048884964234),
#   np.float64(11.406577352806574)],
#  [100,
#   np.float64(-2.5),
#   np.float64(900.0),
#   np.float64(-1.1214048004961346),
#   np.float64(10.085435641534819)],
#  [100,
#   np.float64(-2.5),
#   np.float64(1000.0),
#   np.float64(-2.232546702389336),
#   np.float64(-1.4481546878700493)],
#  [100,
#   np.float64(-2.2916666666666665),
#   np.float64(100.0),
#   np.float64(-0.10146061894854927),
#   np.float64(2.7604165610359748)],
#  [100,
#   np.float64(-2.2916666666666665),
#   np.float64(200.0),
#   np.float64(-0.12014127676689017),
#   np.float64(9.37351425823403)],
#  [100,
#   np.float64(-2.2916666666666665),
#   np.float64(300.0),
#   np.float64(-0.14566803392670788),
#   np.float64(10.599668930548711)],
#  [100,
#   np.float64(-2.2916666666666665),
#   np.float64(400.0),
#   np.float64(-0.03729514226834074),
#   np.float64(11.486899664300408)],
#  [100,
#   np.float64(-2.2916666666666665),
#   np.float64(500.0),
#   np.float64(-0.23807834352109195),
#   np.float64(11.521778914641121)],
#  [100,
#   np.float64(-2.2916666666666665),
#   np.float64(600.0),
#   np.float64(-0.38416372844937363),
#   np.float64(11.472783286635972)],
#  [100,
#   np.float64(-2.2916666666666665),
#   np.float64(700.0),
#   np.float64(-0.3432984062269204),
#   np.float64(12.653404817127072)],
#  [100,
#   np.float64(-2.2916666666666665),
#   np.float64(800.0),
#   np.float64(-0.5804634302736593),
#   np.float64(12.399436649862501)],
#  [100,
#   np.float64(-2.2916666666666665),
#   np.float64(900.0),
#   np.float64(-1.097416817456719),
#   np.float64(10.994250723157869)],
#  [100,
#   np.float64(-2.2916666666666665),
#   np.float64(1000.0),
#   np.float64(-2.174502796552413),
#   np.float64(inf)],
#  [100,
#   np.float64(-2.0833333333333335),
#   np.float64(100.0),
#   np.float64(-0.10165120518590588),
#   np.float64(3.031680030150365)],
#  [100,
#   np.float64(-2.0833333333333335),
#   np.float64(200.0),
#   np.float64(-0.1201229571197857),
#   np.float64(10.229061263356098)],
#  [100,
#   np.float64(-2.0833333333333335),
#   np.float64(300.0),
#   np.float64(-0.1456546617481212),
#   np.float64(11.563000715581584)],
#  [100,
#   np.float64(-2.0833333333333335),
#   np.float64(400.0),
#   np.float64(-0.037269390883050715),
#   np.float64(12.527181348865554)],
#  [100,
#   np.float64(-2.0833333333333335),
#   np.float64(500.0),
#   np.float64(-0.23666236704633967),
#   np.float64(12.557885225972862)],
#  [100,
#   np.float64(-2.0833333333333335),
#   np.float64(600.0),
#   np.float64(-0.3805524831067722),
#   np.float64(12.495635116643507)],
#  [100,
#   np.float64(-2.0833333333333335),
#   np.float64(700.0),
#   np.float64(-0.3356845972051794),
#   np.float64(13.916500935728813)],
#  [100,
#   np.float64(-2.0833333333333335),
#   np.float64(800.0),
#   np.float64(-0.5713304148429622),
#   np.float64(13.596226186401148)],
#  [100,
#   np.float64(-2.0833333333333335),
#   np.float64(900.0),
#   np.float64(-1.0731132974184525),
#   np.float64(12.095323548696111)],
#  [100,
#   np.float64(-2.0833333333333335),
#   np.float64(1000.0),
#   np.float64(-2.1144117201472556),
#   np.float64(nan)],
#  [100,
#   np.float64(-1.875),
#   np.float64(100.0),
#   np.float64(-0.10119604957538803),
#   np.float64(3.3814599346704712)],
#  [100,
#   np.float64(-1.875),
#   np.float64(200.0),
#   np.float64(-0.11788702353196928),
#   np.float64(1.8261603397185815)],
#  [100,
#   np.float64(-1.875),
#   np.float64(300.0),
#   np.float64(-0.14480186565053219),
#   np.float64(13.538519216330759)],
#  [100,
#   np.float64(-1.875),
#   np.float64(400.0),
#   np.float64(-0.03611268964297229),
#   np.float64(14.671549218972086)],
#  [100,
#   np.float64(-1.875),
#   np.float64(500.0),
#   np.float64(-0.2344012919829513),
#   np.float64(14.725174250365278)],
#  [100,
#   np.float64(-1.875),
#   np.float64(600.0),
#   np.float64(-0.37589386842247074),
#   np.float64(14.670098480986399)],
#  [100,
#   np.float64(-1.875),
#   np.float64(700.0),
#   np.float64(-0.30339329384666275),
#   np.float64(16.642251429461023)],
#  [100,
#   np.float64(-1.875),
#   np.float64(800.0),
#   np.float64(-0.5615408078931052),
#   np.float64(16.67416827132166)],
#  [100,
#   np.float64(-1.875),
#   np.float64(900.0),
#   np.float64(-1.047758221505583),
#   np.float64(16.182458060942036)],
#  [100,
#   np.float64(-1.875),
#   np.float64(1000.0),
#   np.float64(nan),
#   np.float64(nan)],
#  [100,
#   np.float64(-1.6666666666666665),
#   np.float64(100.0),
#   np.float64(-0.09915883245653513),
#   np.float64(12.123875679671265)],
#  [100,
#   np.float64(-1.6666666666666665),
#   np.float64(200.0),
#   np.float64(-0.1193772779852492),
#   np.float64(13.3346083193083)],
#  [100,
#   np.float64(-1.6666666666666665),
#   np.float64(300.0),
#   np.float64(-0.14473017036571426),
#   np.float64(15.062125946354028)],
#  [100,
#   np.float64(-1.6666666666666665),
#   np.float64(400.0),
#   np.float64(-0.03599825823421061),
#   np.float64(16.31998035454409)],
#  [100,
#   np.float64(-1.6666666666666665),
#   np.float64(500.0),
#   np.float64(-0.23288547059206144),
#   np.float64(16.372583988356766)],
#  [100,
#   np.float64(-1.6666666666666665),
#   np.float64(600.0),
#   np.float64(-0.3721303771799015),
#   np.float64(16.301922881013123)],
#  [100,
#   np.float64(-1.6666666666666665),
#   np.float64(700.0),
#   np.float64(-0.2833707013840429),
#   np.float64(18.04615538022639)],
#  [100,
#   np.float64(-1.6666666666666665),
#   np.float64(800.0),
#   np.float64(-0.5520920135306551),
#   np.float64(18.705820865899295)],
#  [100,
#   np.float64(-1.6666666666666665),
#   np.float64(900.0),
#   np.float64(-1.0220555814737382),
#   np.float64(18.260836698902953)],
#  [100,
#   np.float64(-1.6666666666666665),
#   np.float64(1000.0),
#   np.float64(nan),
#   np.float64(nan)],
#  [100,
#   np.float64(-1.4583333333333333),
#   np.float64(100.0),
#   np.float64(-0.09914840855127165),
#   np.float64(13.686467773053533)],
#  [100,
#   np.float64(-1.4583333333333333),
#   np.float64(200.0),
#   np.float64(-0.11932345494643092),
#   np.float64(15.0583666522577)],
#  [100,
#   np.float64(-1.4583333333333333),
#   np.float64(300.0),
#   np.float64(-0.14466091548946897),
#   np.float64(17.002635291305648)],
#  [100,
#   np.float64(-1.4583333333333333),
#   np.float64(400.0),
#   np.float64(-0.035888152944428764),
#   np.float64(18.421673366511794)],
#  [100,
#   np.float64(-1.4583333333333333),
#   np.float64(500.0),
#   np.float64(-0.23136543194006848),
#   np.float64(18.475963753298206)],
#  [100,
#   np.float64(-1.4583333333333333),
#   np.float64(600.0),
#   np.float64(-0.3683515623794862),
#   np.float64(18.388513977984946)],
#  [100,
#   np.float64(-1.4583333333333333),
#   np.float64(700.0),
#   np.float64(-0.24405489952733295),
#   np.float64(19.005210247507712)],
#  [100,
#   np.float64(-1.4583333333333333),
#   np.float64(800.0),
#   np.float64(-0.542607409677778),
#   np.float64(21.32394699554452)],
#  [100,
#   np.float64(-1.4583333333333333),
#   np.float64(900.0),
#   np.float64(-0.9711719924987288),
#   np.float64(22.024959066434235)],
#  [100,
#   np.float64(-1.4583333333333333),
#   np.float64(1000.0),
#   np.float64(-4.5540067583028465),
#   np.float64(nan)],
#  [100,
#   np.float64(-1.25),
#   np.float64(100.0),
#   np.float64(-0.09894576577556835),
#   np.float64(15.464406697185089)],
#  [100,
#   np.float64(-1.25),
#   np.float64(200.0),
#   np.float64(-0.11886649083169885),
#   np.float64(17.024885214923792)],
#  [100,
#   np.float64(-1.25),
#   np.float64(300.0),
#   np.float64(-0.14414802814638142),
#   np.float64(19.226780618362003)],
#  [100,
#   np.float64(-1.25),
#   np.float64(400.0),
#   np.float64(-0.03518911778593977),
#   np.float64(20.844656066862328)],
#  [100,
#   np.float64(-1.25),
#   np.float64(500.0),
#   np.float64(-0.22442296141452953),
#   np.float64(20.94751813201494)],
#  [100,
#   np.float64(-1.25),
#   np.float64(600.0),
#   np.float64(-0.3519898401512046),
#   np.float64(20.934577401809385)],
#  [100,
#   np.float64(-1.25),
#   np.float64(700.0),
#   np.float64(-0.26735666800578184),
#   np.float64(21.566500604139016)],
#  [100,
#   np.float64(-1.25),
#   np.float64(800.0),
#   np.float64(-0.5089143919724168),
#   np.float64(24.68706053041127)],
#  [100,
#   np.float64(-1.25),
#   np.float64(900.0),
#   np.float64(-0.7454957587934234),
#   np.float64(30.610049915772272)],
#  [100,
#   np.float64(-1.25),
#   np.float64(1000.0),
#   np.float64(-0.10305757685233323),
#   np.float64(nan)],
#  [100,
#   np.float64(-1.0416666666666665),
#   np.float64(100.0),
#   np.float64(-0.09679336161671122),
#   np.float64(17.916419270337816)],
#  [100,
#   np.float64(-1.0416666666666665),
#   np.float64(200.0),
#   np.float64(-0.11599375252277576),
#   np.float64(19.74786248378671)],
#  [100,
#   np.float64(-1.0416666666666665),
#   np.float64(300.0),
#   np.float64(-0.14054932307350407),
#   np.float64(22.309788783895655)],
#  [100,
#   np.float64(-1.0416666666666665),
#   np.float64(400.0),
#   np.float64(-0.030581519457844996),
#   np.float64(24.210704415592783)],
#  [100,
#   np.float64(-1.0416666666666665),
#   np.float64(500.0),
#   np.float64(-0.20921578358435572),
#   np.float64(24.424243141608887)],
#  [100,
#   np.float64(-1.0416666666666665),
#   np.float64(600.0),
#   np.float64(-0.3194524147995958),
#   np.float64(24.568735574720353)],
#  [100,
#   np.float64(-1.0416666666666665),
#   np.float64(700.0),
#   np.float64(-0.21233860440691202),
#   np.float64(25.565180128500465)],
#  [100,
#   np.float64(-1.0416666666666665),
#   np.float64(800.0),
#   np.float64(-0.3993436616426221),
#   np.float64(29.209471312795095)],
#  [100,
#   np.float64(-1.0416666666666665),
#   np.float64(900.0),
#   np.float64(-0.5630456565285663),
#   np.float64(39.511001774654886)],
#  [100,
#   np.float64(-1.0416666666666665),
#   np.float64(1000.0),
#   np.float64(0.2736696371524028),
#   np.float64(1438.129080726491)],
#  [100,
#   np.float64(-0.8333333333333333),
#   np.float64(100.0),
#   np.float64(-0.09191537249080753),
#   np.float64(21.585047297342527)],
#  [100,
#   np.float64(-0.8333333333333333),
#   np.float64(200.0),
#   np.float64(-0.1097181179469977),
#   np.float64(23.843228955792522)],
#  [100,
#   np.float64(-0.8333333333333333),
#   np.float64(300.0),
#   np.float64(-0.13257338704716454),
#   np.float64(26.947004847421745)],
#  [100,
#   np.float64(-0.8333333333333333),
#   np.float64(400.0),
#   np.float64(-0.020771490726808246),
#   np.float64(29.285169177340578)],
#  [100,
#   np.float64(-0.8333333333333333),
#   np.float64(500.0),
#   np.float64(-0.18251749380340876),
#   np.float64(29.73098610370436)],
#  [100,
#   np.float64(-0.8333333333333333),
#   np.float64(600.0),
#   np.float64(-0.264844698806626),
#   np.float64(30.18599886559894)],
#  [100,
#   np.float64(-0.8333333333333333),
#   np.float64(700.0),
#   np.float64(-0.12924469045113696),
#   np.float64(31.704488347502945)],
#  [100,
#   np.float64(-0.8333333333333333),
#   np.float64(800.0),
#   np.float64(-0.2102778086729937),
#   np.float64(34.001326881164076)],
#  [100,
#   np.float64(-0.8333333333333333),
#   np.float64(900.0),
#   np.float64(-0.29484739296692514),
#   np.float64(51.77002193959243)],
#  [100,
#   np.float64(-0.8333333333333333),
#   np.float64(1000.0),
#   np.float64(0.33197844027091755),
#   np.float64(431.2322527715003)],
#  [100,
#   np.float64(-0.625),
#   np.float64(100.0),
#   np.float64(-0.09262685095983796),
#   np.float64(26.888844229923123)],
#  [100,
#   np.float64(-0.625),
#   np.float64(200.0),
#   np.float64(-0.11044305667292253),
#   np.float64(29.789426451818024)],
#  [100,
#   np.float64(-0.625),
#   np.float64(300.0),
#   np.float64(-0.1335248281179081),
#   np.float64(33.66580385051588)],
#  [100,
#   np.float64(-0.625),
#   np.float64(400.0),
#   np.float64(-0.022074150241799425),
#   np.float64(36.64829259643084)],
#  [100,
#   np.float64(-0.625),
#   np.float64(500.0),
#   np.float64(-0.18165239539428876),
#   np.float64(37.229751990140365)],
#  [100,
#   np.float64(-0.625),
#   np.float64(600.0),
#   np.float64(-0.2615132035199531),
#   np.float64(37.83061730016476)],
#  [100,
#   np.float64(-0.625),
#   np.float64(700.0),
#   np.float64(-0.12144672682278446),
#   np.float64(39.69482437461588)],
#  [100,
#   np.float64(-0.625),
#   np.float64(800.0),
#   np.float64(-0.2818656658044407),
#   np.float64(42.36211048203376)],
#  [100,
#   np.float64(-0.625),
#   np.float64(900.0),
#   np.float64(-0.27566524346407545),
#   np.float64(58.08633314218981)],
#  [100,
#   np.float64(-0.625),
#   np.float64(1000.0),
#   np.float64(1.4836862717046828),
#   np.float64(34.81016433053769)],
#  [100,
#   np.float64(-0.4166666666666665),
#   np.float64(100.0),
#   np.float64(-0.09594993765335666),
#   np.float64(37.60125625479549)],
#  [100,
#   np.float64(-0.4166666666666665),
#   np.float64(200.0),
#   np.float64(-0.11433793256547728),
#   np.float64(42.011354981966065)],
#  [100,
#   np.float64(-0.4166666666666665),
#   np.float64(300.0),
#   np.float64(-0.13854351063810083),
#   np.float64(47.5083107430455)],
#  [100,
#   np.float64(-0.4166666666666665),
#   np.float64(400.0),
#   np.float64(-0.02908126931931162),
#   np.float64(51.987517233462185)],
#  [100,
#   np.float64(-0.4166666666666665),
#   np.float64(500.0),
#   np.float64(-0.18897596031247155),
#   np.float64(53.026496199354966)],
#  [100,
#   np.float64(-0.4166666666666665),
#   np.float64(600.0),
#   np.float64(-0.27195702831551644),
#   np.float64(54.16178891193401)],
#  [100,
#   np.float64(-0.4166666666666665),
#   np.float64(700.0),
#   np.float64(-0.13286626012834757),
#   np.float64(56.95791684081921)],
#  [100,
#   np.float64(-0.4166666666666665),
#   np.float64(800.0),
#   np.float64(-0.2976160172349343),
#   np.float64(60.576548032724794)],
#  [100,
#   np.float64(-0.4166666666666665),
#   np.float64(900.0),
#   np.float64(0.04349273722043019),
#   np.float64(75.3897330743307)],
#  [100,
#   np.float64(-0.4166666666666665),
#   np.float64(1000.0),
#   np.float64(0.938171821511321),
#   np.float64(79.62706572557478)],
#  [100,
#   np.float64(-0.20833333333333304),
#   np.float64(100.0),
#   np.float64(-0.10243704184107007),
#   np.float64(66.57888344679984)],
#  [100,
#   np.float64(-0.20833333333333304),
#   np.float64(200.0),
#   np.float64(-0.12222946302468947),
#   np.float64(77.19895448557352)],
#  [100,
#   np.float64(-0.20833333333333304),
#   np.float64(300.0),
#   np.float64(-0.14838330672960348),
#   np.float64(87.41963381659674)],
#  [100,
#   np.float64(-0.20833333333333304),
#   np.float64(400.0),
#   np.float64(-0.0407542286978836),
#   np.float64(97.69098838732837)],
#  [100,
#   np.float64(-0.20833333333333304),
#   np.float64(500.0),
#   np.float64(-0.20922690702751448),
#   np.float64(102.0035576890583)],
#  [100,
#   np.float64(-0.20833333333333304),
#   np.float64(600.0),
#   np.float64(-0.30837453794254616),
#   np.float64(106.7173283592097)],
#  [100,
#   np.float64(-0.20833333333333304),
#   np.float64(700.0),
#   np.float64(-0.16904397573287547),
#   np.float64(112.50050531881924)],
#  [100,
#   np.float64(-0.20833333333333304),
#   np.float64(800.0),
#   np.float64(-0.36866500279584125),
#   np.float64(118.63100093455132)],
#  [100,
#   np.float64(-0.20833333333333304),
#   np.float64(900.0),
#   np.float64(-0.15485428347501426),
#   np.float64(157.17724658527774)],
#  [100,
#   np.float64(-0.20833333333333304),
#   np.float64(1000.0),
#   np.float64(0.9279188884141599),
#   np.float64(150.53000208416842)],
#  [100,
#   np.float64(0.0),
#   np.float64(100.0),
#   np.float64(-0.10236557591154861),
#   np.float64(117.75738955808015)],
#  [100,
#   np.float64(0.0),
#   np.float64(200.0),
#   np.float64(-0.12206166780515272),
#   np.float64(158.05654364852484)],
#  [100,
#   np.float64(0.0),
#   np.float64(300.0),
#   np.float64(-0.14814735973354276),
#   np.float64(184.35214950349084)],
#  [100,
#   np.float64(0.0),
#   np.float64(400.0),
#   np.float64(-0.04039414032897614),
#   np.float64(227.8751329822611)],
#  [100,
#   np.float64(0.0),
#   np.float64(500.0),
#   np.float64(-0.20680491253431765),
#   np.float64(273.7823532041941)],
#  [100,
#   np.float64(0.0),
#   np.float64(600.0),
#   np.float64(-0.3027626176269836),
#   np.float64(313.8029272733542)],
#  [100,
#   np.float64(0.0),
#   np.float64(700.0),
#   np.float64(-0.15896390740034316),
#   np.float64(359.22537340011877)],
#  [100,
#   np.float64(0.0),
#   np.float64(800.0),
#   np.float64(-0.35741264282153556),
#   np.float64(479.32546785931095)],
#  [100,
#   np.float64(0.0),
#   np.float64(900.0),
#   np.float64(-0.13512587645150045),
#   np.float64(501.42143046660027)],
#  [100,
#   np.float64(0.0),
#   np.float64(1000.0),
#   np.float64(1.1298948994106142),
#   np.float64(569.6981018447165)],
#  [100,
#   np.float64(0.20833333333333348),
#   np.float64(100.0),
#   np.float64(-0.10508789472510997),
#   np.float64(71.92202610069488)],
#  [100,
#   np.float64(0.20833333333333348),
#   np.float64(200.0),
#   np.float64(-0.12519056461771377),
#   np.float64(84.42376121069039)],
#  [100,
#   np.float64(0.20833333333333348),
#   np.float64(300.0),
#   np.float64(-0.15199354386029268),
#   np.float64(97.26120141352278)],
#  [100,
#   np.float64(0.20833333333333348),
#   np.float64(400.0),
#   np.float64(-0.045171322149624514),
#   np.float64(108.26855575233313)],
#  [100,
#   np.float64(0.20833333333333348),
#   np.float64(500.0),
#   np.float64(-0.21150783939892528),
#   np.float64(112.30482593040551)],
#  [100,
#   np.float64(0.20833333333333348),
#   np.float64(600.0),
#   np.float64(-0.3091695038765911),
#   np.float64(112.60424260420311)],
#  [100,
#   np.float64(0.20833333333333348),
#   np.float64(700.0),
#   np.float64(-0.16086651770668214),
#   np.float64(126.36234422367168)],
#  [100,
#   np.float64(0.20833333333333348),
#   np.float64(800.0),
#   np.float64(-0.3712697885271483),
#   np.float64(130.9690714863386)],
#  [100,
#   np.float64(0.20833333333333348),
#   np.float64(900.0),
#   np.float64(0.05483243971047591),
#   np.float64(143.68414975518164)],
#  [100,
#   np.float64(0.20833333333333348),
#   np.float64(1000.0),
#   np.float64(-0.7531124825338259),
#   np.float64(309.1807406129371)],
#  [100,
#   np.float64(0.41666666666666696),
#   np.float64(100.0),
#   np.float64(-0.10046175952632569),
#   np.float64(45.35341332011802)],
#  [100,
#   np.float64(0.41666666666666696),
#   np.float64(200.0),
#   np.float64(-0.11924362259079932),
#   np.float64(51.17930067392546)],
#  [100,
#   np.float64(0.41666666666666696),
#   np.float64(300.0),
#   np.float64(-0.14502138280955998),
#   np.float64(58.4599717874607)],
#  [100,
#   np.float64(0.41666666666666696),
#   np.float64(400.0),
#   np.float64(-0.03480940178645985),
#   np.float64(63.89420815949936)],
#  [100,
#   np.float64(0.41666666666666696),
#   np.float64(500.0),
#   np.float64(-0.1860855728714927),
#   np.float64(64.83610877721385)],
#  [100,
#   np.float64(0.41666666666666696),
#   np.float64(600.0),
#   np.float64(-0.2602108011835568),
#   np.float64(64.56702832816704)],
#  [100,
#   np.float64(0.41666666666666696),
#   np.float64(700.0),
#   np.float64(-0.08028848473142339),
#   np.float64(70.93472149011765)],
#  [100,
#   np.float64(0.41666666666666696),
#   np.float64(800.0),
#   np.float64(-0.2657601492028132),
#   np.float64(70.39425469584418)],
#  [100,
#   np.float64(0.41666666666666696),
#   np.float64(900.0),
#   np.float64(0.5925894961251436),
#   np.float64(73.19846942276975)],
#  [100,
#   np.float64(0.41666666666666696),
#   np.float64(1000.0),
#   np.float64(6.75618460754448),
#   np.float64(41531416.314158425)],
#  [100,
#   np.float64(0.625),
#   np.float64(100.0),
#   np.float64(-0.10043353082950783),
#   np.float64(31.519433724916304)],
#  [100,
#   np.float64(0.625),
#   np.float64(200.0),
#   np.float64(-0.119158651525083),
#   np.float64(35.06245109340763)],
#  [100,
#   np.float64(0.625),
#   np.float64(300.0),
#   np.float64(-0.1449078470797021),
#   np.float64(39.937568289482186)],
#  [100,
#   np.float64(0.625),
#   np.float64(400.0),
#   np.float64(-0.034634595438770927),
#   np.float64(43.399069748530046)],
#  [100,
#   np.float64(0.625),
#   np.float64(500.0),
#   np.float64(-0.18432663497598314),
#   np.float64(43.77785824533714)],
#  [100,
#   np.float64(0.625),
#   np.float64(600.0),
#   np.float64(-0.2559112872304073),
#   np.float64(43.62587633549974)],
#  [100,
#   np.float64(0.625),
#   np.float64(700.0),
#   np.float64(-0.07211429456243858),
#   np.float64(47.58525451398865)],
#  [100,
#   np.float64(0.625),
#   np.float64(800.0),
#   np.float64(-0.25650754039326357),
#   np.float64(46.909813900576204)],
#  [100,
#   np.float64(0.625),
#   np.float64(900.0),
#   np.float64(0.1726317505872586),
#   np.float64(42.82962944005731)],
#  [100,
#   np.float64(0.625),
#   np.float64(1000.0),
#   np.float64(6.8099392117457604),
#   np.float64(59304207.70696456)],
#  [100,
#   np.float64(0.8333333333333335),
#   np.float64(100.0),
#   np.float64(-0.10409634824032105),
#   np.float64(24.76607548605138)],
#  [100,
#   np.float64(0.8333333333333335),
#   np.float64(200.0),
#   np.float64(-0.12343682308767105),
#   np.float64(27.42593928881589)],
#  [100,
#   np.float64(0.8333333333333335),
#   np.float64(300.0),
#   np.float64(-0.15015172964645337),
#   np.float64(31.208825777530215)],
#  [100,
#   np.float64(0.8333333333333335),
#   np.float64(400.0),
#   np.float64(-0.04105467548268465),
#   np.float64(33.857020588845614)],
#  [100,
#   np.float64(0.8333333333333335),
#   np.float64(500.0),
#   np.float64(-0.19298809478839052),
#   np.float64(34.16641035786079)],
#  [100,
#   np.float64(0.8333333333333335),
#   np.float64(600.0),
#   np.float64(-0.2702504728212934),
#   np.float64(34.16246504952641)],
#  [100,
#   np.float64(0.8333333333333335),
#   np.float64(700.0),
#   np.float64(-0.08369824785566247),
#   np.float64(37.44253467538518)],
#  [100,
#   np.float64(0.8333333333333335),
#   np.float64(800.0),
#   np.float64(-0.28714874791791367),
#   np.float64(36.288502248631914)],
#  [100,
#   np.float64(0.8333333333333335),
#   np.float64(900.0),
#   np.float64(0.03366285809261824),
#   np.float64(35.09977324395113)],
#  [100,
#   np.float64(0.8333333333333335),
#   np.float64(1000.0),
#   np.float64(-0.5412771287193017),
#   np.float64(nan)],
#  [100,
#   np.float64(1.041666666666667),
#   np.float64(100.0),
#   np.float64(-0.10402553180576118),
#   np.float64(20.07411167680934)],
#  [100,
#   np.float64(1.041666666666667),
#   np.float64(200.0),
#   np.float64(-0.12328097114368908),
#   np.float64(22.169056103519008)],
#  [100,
#   np.float64(1.041666666666667),
#   np.float64(300.0),
#   np.float64(-0.14992771926643617),
#   np.float64(25.21715339547928)],
#  [100,
#   np.float64(1.041666666666667),
#   np.float64(400.0),
#   np.float64(-0.04071151165100519),
#   np.float64(27.340126898640612)],
#  [100,
#   np.float64(1.041666666666667),
#   np.float64(500.0),
#   np.float64(-0.1909804079173772),
#   np.float64(27.585849644904545)],
#  [100,
#   np.float64(1.041666666666667),
#   np.float64(600.0),
#   np.float64(-0.26551042989388024),
#   np.float64(27.641147910297082)],
#  [100,
#   np.float64(1.041666666666667),
#   np.float64(700.0),
#   np.float64(-0.07501711280396992),
#   np.float64(30.285455962883418)],
#  [100,
#   np.float64(1.041666666666667),
#   np.float64(800.0),
#   np.float64(-0.24703334153616457),
#   np.float64(29.757365754438354)],
#  [100,
#   np.float64(1.041666666666667),
#   np.float64(900.0),
#   np.float64(0.06341573796377585),
#   np.float64(28.70374464511146)],
#  [100,
#   np.float64(1.041666666666667),
#   np.float64(1000.0),
#   np.float64(-0.5342679204603875),
#   np.float64(75965679.16285402)],
#  [100,
#   np.float64(1.25),
#   np.float64(100.0),
#   np.float64(-0.09905950813011447),
#   np.float64(5.326916351444796)],
#  [100,
#   np.float64(1.25),
#   np.float64(200.0),
#   np.float64(-0.1209821368804874),
#   np.float64(2.8029824193216344)],
#  [100,
#   np.float64(1.25),
#   np.float64(300.0),
#   np.float64(-0.14970397627060944),
#   np.float64(21.176046714246684)],
#  [100,
#   np.float64(1.25),
#   np.float64(400.0),
#   np.float64(-0.040368799896641806),
#   np.float64(22.956283430028055)],
#  [100,
#   np.float64(1.25),
#   np.float64(500.0),
#   np.float64(-0.18898320918045322),
#   np.float64(23.17190881268406)],
#  [100,
#   np.float64(1.25),
#   np.float64(600.0),
#   np.float64(-0.2607952012647679),
#   np.float64(23.265493399993343)],
#  [100,
#   np.float64(1.25),
#   np.float64(700.0),
#   np.float64(-0.06638564483683372),
#   np.float64(25.503142197803857)],
#  [100,
#   np.float64(1.25),
#   np.float64(800.0),
#   np.float64(-0.39229346075639493),
#   np.float64(23.946735432860503)],
#  [100,
#   np.float64(1.25),
#   np.float64(900.0),
#   np.float64(0.09317664323173104),
#   np.float64(24.408778966387057)],
#  [100,
#   np.float64(1.25),
#   np.float64(1000.0),
#   np.float64(-0.5271669439136686),
#   np.float64(nan)],
#  [100,
#   np.float64(1.4583333333333335),
#   np.float64(100.0),
#   np.float64(-0.09927605329807804),
#   np.float64(4.569509784072127)],
#  [100,
#   np.float64(1.4583333333333335),
#   np.float64(200.0),
#   np.float64(-0.12201034877545992),
#   np.float64(2.415187797649718)],
#  [100,
#   np.float64(1.4583333333333335),
#   np.float64(300.0),
#   np.float64(-0.1494797612954163),
#   np.float64(18.2697525860448)],
#  [100,
#   np.float64(1.4583333333333335),
#   np.float64(400.0),
#   np.float64(-0.04002517703252267),
#   np.float64(19.80896697899397)],
#  [100,
#   np.float64(1.4583333333333335),
#   np.float64(500.0),
#   np.float64(-0.18699255039374116),
#   np.float64(20.008541021522493)],
#  [100,
#   np.float64(1.4583333333333335),
#   np.float64(600.0),
#   np.float64(-0.2560986757280147),
#   np.float64(20.12896826909871)],
#  [100,
#   np.float64(1.4583333333333335),
#   np.float64(700.0),
#   np.float64(-0.057792432691061935),
#   np.float64(22.08572696605247)],
#  [100,
#   np.float64(1.4583333333333335),
#   np.float64(800.0),
#   np.float64(-0.4103167005172512),
#   np.float64(20.24588696785199)],
#  [100,
#   np.float64(1.4583333333333335),
#   np.float64(900.0),
#   np.float64(0.12292183125320154),
#   np.float64(21.331471880627443)],
#  [100,
#   np.float64(1.4583333333333335),
#   np.float64(1000.0),
#   np.float64(-0.5200103795901669),
#   np.float64(nan)],
#  [100,
#   np.float64(1.666666666666667),
#   np.float64(100.0),
#   np.float64(-0.09998113152276346),
#   np.float64(1.898724472270831)],
#  [100,
#   np.float64(1.666666666666667),
#   np.float64(200.0),
#   np.float64(-0.11907881106915005),
#   np.float64(0.9893883069255971)],
#  [100,
#   np.float64(1.666666666666667),
#   np.float64(300.0),
#   np.float64(-0.14925359761061938),
#   np.float64(16.077594841779323)],
#  [100,
#   np.float64(1.666666666666667),
#   np.float64(400.0),
#   np.float64(-0.03967837865440688),
#   np.float64(17.43743285284706)],
#  [100,
#   np.float64(1.666666666666667),
#   np.float64(500.0),
#   np.float64(-0.18500202490426787),
#   np.float64(17.62801864429236)],
#  [100,
#   np.float64(1.666666666666667),
#   np.float64(600.0),
#   np.float64(-0.2514055740042629),
#   np.float64(17.768382924237507)],
#  [100,
#   np.float64(1.666666666666667),
#   np.float64(700.0),
#   np.float64(-0.04921235407672565),
#   np.float64(19.519415540014492)],
#  [100,
#   np.float64(1.666666666666667),
#   np.float64(800.0),
#   np.float64(-0.3288410388048616),
#   np.float64(17.650865894451155)],
#  [100,
#   np.float64(1.666666666666667),
#   np.float64(900.0),
#   np.float64(0.1528243488094623),
#   np.float64(19.022687037046627)],
#  [100,
#   np.float64(1.666666666666667),
#   np.float64(1000.0),
#   np.float64(-0.2207434835800387),
#   np.float64(nan)],
#  [100,
#   np.float64(1.875),
#   np.float64(100.0),
#   np.float64(-0.10001365618537655),
#   np.float64(1.6880087706264912)],
#  [100,
#   np.float64(1.875),
#   np.float64(200.0),
#   np.float64(-0.1256393066288103),
#   np.float64(1.0674467329402826)],
#  [100,
#   np.float64(1.875),
#   np.float64(300.0),
#   np.float64(-0.14902883967364455),
#   np.float64(14.370189912789682)],
#  [100,
#   np.float64(1.875),
#   np.float64(400.0),
#   np.float64(-0.039334233422650196),
#   np.float64(15.591992953293815)],
#  [100,
#   np.float64(1.875),
#   np.float64(500.0),
#   np.float64(-0.18302622121920425),
#   np.float64(15.777365372723683)],
#  [100,
#   np.float64(1.875),
#   np.float64(600.0),
#   np.float64(-0.24674784698118946),
#   np.float64(15.933408587713007)],
#  [100,
#   np.float64(1.875),
#   np.float64(700.0),
#   np.float64(-0.014911502582018735),
#   np.float64(17.62797820932379)],
#  [100,
#   np.float64(1.875),
#   np.float64(800.0),
#   np.float64(-0.31857733912945285),
#   np.float64(15.789188353544267)],
#  [100,
#   np.float64(1.875),
#   np.float64(900.0),
#   np.float64(0.17884279716854523),
#   np.float64(15.9255856675253)],
#  [100,
#   np.float64(1.875),
#   np.float64(1000.0),
#   np.float64(0.350092529183247),
#   np.float64(107703735.20276578)],
#  [100,
#   np.float64(2.083333333333334),
#   np.float64(100.0),
#   np.float64(-0.0980769876246299),
#   np.float64(1.3825378341806407)],
#  [100,
#   np.float64(2.083333333333334),
#   np.float64(200.0),
#   np.float64(-0.12663577560843234),
#   np.float64(1.7608627147623583)],
#  [100,
#   np.float64(2.083333333333334),
#   np.float64(300.0),
#   np.float64(-0.14880574667274446),
#   np.float64(13.002049091495856)],
#  [100,
#   np.float64(2.083333333333334),
#   np.float64(400.0),
#   np.float64(-0.03899212100096731),
#   np.float64(14.114175107266286)],
#  [100,
#   np.float64(2.083333333333334),
#   np.float64(500.0),
#   np.float64(-0.1810619989109082),
#   np.float64(14.296727297285923)],
#  [100,
#   np.float64(2.083333333333334),
#   np.float64(600.0),
#   np.float64(-0.24211685569999056),
#   np.float64(14.465530984054118)],
#  [100,
#   np.float64(2.083333333333334),
#   np.float64(700.0),
#   np.float64(-0.006106338527197664),
#   np.float64(16.00282171283172)],
#  [100,
#   np.float64(2.083333333333334),
#   np.float64(800.0),
#   np.float64(-0.3083381481036384),
#   np.float64(14.309285429674434)],
#  [100,
#   np.float64(2.083333333333334),
#   np.float64(900.0),
#   np.float64(0.20845831871150897),
#   np.float64(14.624706452386254)],
#  [100,
#   np.float64(2.083333333333334),
#   np.float64(1000.0),
#   np.float64(0.3741602131872742),
#   np.float64(nan)],
#  [100,
#   np.float64(2.291666666666667),
#   np.float64(100.0),
#   np.float64(-0.09829393771842744),
#   np.float64(1.2574411371092042)],
#  [100,
#   np.float64(2.291666666666667),
#   np.float64(200.0),
#   np.float64(-0.12234654282460705),
#   np.float64(10.431386053200514)],
#  [100,
#   np.float64(2.291666666666667),
#   np.float64(300.0),
#   np.float64(-0.1485812924743735),
#   np.float64(11.88050918951274)],
#  [100,
#   np.float64(2.291666666666667),
#   np.float64(400.0),
#   np.float64(-0.038647932652144314),
#   np.float64(12.903428136702093)],
#  [100,
#   np.float64(2.291666666666667),
#   np.float64(500.0),
#   np.float64(-0.17910171337297262),
#   np.float64(13.084654997838383)],
#  [100,
#   np.float64(2.291666666666667),
#   np.float64(600.0),
#   np.float64(-0.23749794154881002),
#   np.float64(13.2644192150785)],
#  [100,
#   np.float64(2.291666666666667),
#   np.float64(700.0),
#   np.float64(-0.14029091400700008),
#   np.float64(14.183099752190245)],
#  [100,
#   np.float64(2.291666666666667),
#   np.float64(800.0),
#   np.float64(-0.29809984765991243),
#   np.float64(13.105391733892153)],
#  [100,
#   np.float64(2.291666666666667),
#   np.float64(900.0),
#   np.float64(0.23811779781038406),
#   np.float64(13.56698708562269)],
#  [100,
#   np.float64(2.291666666666667),
#   np.float64(1000.0),
#   np.float64(0.3983214726473162),
#   np.float64(nan)],
#  [100,
#   np.float64(2.5),
#   np.float64(100.0),
#   np.float64(-0.09851218549048063),
#   np.float64(1.1536400161149336)],
#  [100,
#   np.float64(2.5),
#   np.float64(200.0),
#   np.float64(-0.12219126191754764),
#   np.float64(9.605840763875323)],
#  [100,
#   np.float64(2.5),
#   np.float64(300.0),
#   np.float64(-0.1483575033055963),
#   np.float64(10.94494246561002)],
#  [100,
#   np.float64(2.5),
#   np.float64(400.0),
#   np.float64(-0.03830467167176715),
#   np.float64(11.894047476881276)],
#  [100,
#   np.float64(2.5),
#   np.float64(500.0),
#   np.float64(-0.17714996883082929),
#   np.float64(12.07495263739149)],
#  [100,
#   np.float64(2.5),
#   np.float64(600.0),
#   np.float64(-0.23289965764196685),
#   np.float64(12.26429958023688)],
#  [100,
#   np.float64(2.5),
#   np.float64(700.0),
#   np.float64(-0.16241963067276582),
#   np.float64(12.87464106852132)],
#  [100,
#   np.float64(2.5),
#   np.float64(800.0),
#   np.float64(-0.3027720942873539),
#   np.float64(11.97383181673648)],
#  [100,
#   np.float64(2.5),
#   np.float64(900.0),
#   np.float64(0.2677224246913765),
#   np.float64(12.692788215499442)],
#  [100,
#   np.float64(2.5),
#   np.float64(1000.0),
#   np.float64(-97.54279723806653),
#   np.float64(inf)]]

# %%
df_scan_clean = df_scan.dropna(subset=["Dx", "beta_x"])

# %%
print("Before:", len(df_scan))
print("After :", len(df_scan_clean))
np.savetxt("df.txt",df_scan_clean)
# Out:
# Before: 250
# After : 239

# %%
fig, ax = plt.subplots()
sc =ax.scatter(df_scan["B"], df_scan["L"], c=df_scan["Dx"], cmap='plasma', s=50, vmin=-0.09, vmax=0)
fig.colorbar(sc, ax=ax, label='D_x')
ax.set_xlabel("Magnetic Field (T)")
ax.set_ylabel("Magnetic Field Length (L)")
plt.show()
fig, ax = plt.subplots()
sc =ax.scatter(df_scan["B"], df_scan["L"], c=df_scan["beta_x"], cmap='plasma', s=50, vmin=0, vmax=1.5)
fig.colorbar(sc, ax=ax, label='D_x')
ax.set_xlabel("Magnetic Field (T)")
ax.set_ylabel("Magnetic Field Length (L)")
# Out:
# Text(0, 0.5, 'Magnetic Field Length (L)')

# %%
import imageio

# Create folders to save frames
os.makedirs("frames_dx", exist_ok=True)
os.makedirs("frames_betax", exist_ok=True)

# Get all unique DL values
DL_values = sorted(df_scan["DL"].unique())

# --- Dx GIF ---
dx_files = []
for DL0 in DL_values:
    df_DL = df_scan[df_scan["DL"] == DL0]
    pivot_Dx = df_DL.pivot(index="L", columns="B", values="Dx")

    plt.figure()
    plt.imshow(pivot_Dx, aspect="auto", origin="lower")
    plt.colorbar(label="Dx [m]")
    plt.xlabel("B")
    plt.ylabel("L")
    plt.title(f"Dx map at DL={DL0}")
    
    fname = f"frames_dx/Dx_DL{DL0}.png"
    plt.savefig(fname)
    plt.close()
    dx_files.append(fname)

images_dx = [imageio.imread(f) for f in dx_files]
with imageio.get_writer("Dx_maps.gif", mode="I", duration=1.5) as writer:
    for f in dx_files:
        img = imageio.imread(f)
        writer.append_data(img)
print("Dx GIF saved as Dx_maps.gif")

# --- beta_x GIF ---
betax_files = []
for DL0 in DL_values:
    df_DL = df_scan[df_scan["DL"] == DL0]
    pivot_betax = df_DL.pivot(index="L", columns="B", values="beta_x")

    plt.figure()
    plt.imshow(pivot_betax, aspect="auto", origin="lower")
    plt.colorbar(label=r"$\beta_x$ [m]")
    plt.xlabel("B")
    plt.ylabel("L")
    plt.title(f"beta_x map at DL={DL0}")
    
    fname = f"frames_betax/betax_DL{DL0}.png"
    plt.savefig(fname)
    plt.close()
    betax_files.append(fname)

images_betax = [imageio.imread(f) for f in betax_files]
with imageio.get_writer("betax_maps.gif", mode="I", duration=1.5) as writer:
    for f in betax_files:
        img = imageio.imread(f)
        writer.append_data(img)
print("beta_x GIF saved as betax_maps.gif")
# Out:
# Dx GIF saved as Dx_maps.gif
# beta_x GIF saved as betax_maps.gif
# /tmp/ipykernel_21641/251435781.py:28: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images_dx = [imageio.imread(f) for f in dx_files]
# /tmp/ipykernel_21641/251435781.py:31: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(f)
# /tmp/ipykernel_21641/251435781.py:53: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images_betax = [imageio.imread(f) for f in betax_files]
# /tmp/ipykernel_21641/251435781.py:56: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(f)

# %%
import matplotlib.colors as mcolors
DL0 = 100
df_DL = df_scan[df_scan["DL"] == DL0]
pivot_Dx = (df_DL.pivot(index="L", columns="B", values="Dx"))
# Decide min and max values for the whole dataset
dx_min = df_scan["Dx"].min()
dx_max = df_scan["Dx"].max()

# Define a high-resolution colormap
# For example, 1000 colors → can show differences ~ (dx_max-dx_min)/1000
num_colors = int((dx_max - dx_min)/0.001)  # 0.001 resolution
num_colors = min(num_colors, 10000)  # cap at 10k colors to avoid memory issues

plt.figure()
plt.imshow(
    pivot_Dx,
    aspect="auto",
    origin="lower",
    vmin=dx_min,
    vmax=dx_max
)
"""extent=[
        pivot_Dx.columns.min(),
        pivot_Dx.columns.max(),
        pivot_Dx.index.min(),
        pivot_Dx.index.max()
    ]"""
plt.colorbar(label="Dx [m]")
plt.xlabel("B")
plt.ylabel("L")
plt.title(f"Dx map at DL={DL0}")
plt.show()
# Decide min and max values for the whole dataset
betax_min = df_scan["beta_x"].min()
betax_max = df_scan["beta_x"].max()

pivot_betax = df_DL.pivot(index="L", columns="B", values="beta_x")

plt.figure()
plt.imshow(
    pivot_betax,
    aspect="auto",
    origin="lower",
    vmin=betax_min,
    vmax=betax_max
)
"""extent=[
        pivot_betax.columns.min(),
        pivot_betax.columns.max(),
        pivot_betax.index.min(),
        pivot_betax.index.max()
    ]"""
plt.colorbar(label=r"$\beta_x$ [m]")
plt.xlabel("B")
plt.ylabel("L")
plt.title(f"beta_x map at DL={DL0}")
plt.show()

# %%
df_scan["B"].values

# %%
B00 = -2.5
df_B = df_scan[df_scan["B"] == B00]

# Magnetic Field Strength Somehow Constant?
plt.plot(df_B["L"], df_B["Dx"], color="green")
plt.xlabel("Dipole Length")
plt.ylabel(r"$D_x$")
plt.show()
plt.plot(df_B["L"], df_B["beta_x"], color="orange")
plt.xlabel("Dipole Length")
plt.ylabel(r"$\beta_x$")
plt.show()

# %%
DL0 = 40
df_DL = df_scan[df_scan["DL"] == DL0]

# Magnetic Field Strength Somehow Constant?
plt.plot(df_DL["B"], df_DL["Dx"], color="green")
plt.xlabel("Magnetic Field")
plt.ylabel(r"$D_x$")
plt.show()
plt.plot(df_DL["B"], df_DL["beta_x"], color="orange")
plt.xlabel("Magnetic Field")
plt.ylabel(r"$\beta_x$")
plt.show()


# Dipole Length Matters!
plt.plot(df_DL["L"], df_DL["Dx"], color="green")
plt.xlabel("Dipole Length")
plt.ylabel(r"$D_x$")
closest_idx = np.argmin(np.abs(df_DL["Dx"]))
Dx = df_DL["Dx"].values
L =df_DL["L"].values
B =df_DL["B"].values
closest_b_idx = np.argmin(np.abs(df_DL["beta_x"]))
betax = df_DL["beta_x"].values
plt.title(f"Closest to 0: Dx = {Dx[closest_idx]:.2e} at L = {L[closest_idx]:.6f}")
plt.show()
plt.plot(df_DL["L"], df_DL["beta_x"], color="orange")
plt.xlabel("Dipole Length")
plt.ylabel(r"$\beta_x$")
plt.title(f"Closest to 0: beta_x = {betax[closest_idx]:.2e} at L = {L[closest_idx]:.6f}")
plt.show()

# %%
def parse_g4bl_file(filename):
    with open(filename) as f:
        text = f.read()

    pattern = r"\s*([A-Za-z0-9_]+):\s*([-\d\.]+)"
    entries = dict(re.findall(pattern, text))

    return {k: float(v) for k, v in entries.items()}

def build_magnet_regions(params):
    magnet_colors = {
        "wedge":  "#FF66CC",
        "Q1":     "#6699FF",
        "Drift1": "#BBBBBB",
        "Q2":     "#3366CC",
        "Drift2": "#999999",
        "B1":     "#FFAA33",
    }

    magnet_order = ["wedge", "Q1", "Drift1", "Q2", "Drift2", "B1"]
    regions = []

    for name in magnet_order:
        z_key = f"{name}_z"
        L_key = f"{name}_length"

        if name == "wedge":
            if "wedge_end" in params:
                z1 = 0.0
                z2 = params["wedge_end"]
                regions.append((z1, z2, magnet_colors[name], name))

        elif z_key in params and L_key in params:
            center = params[z_key]
            length = params[L_key]
            z1 = center - length / 2
            z2 = center + length / 2
            regions.append((z1, z2, magnet_colors[name], name))

    return regions

# %%
def twissPlot(z_positions, emit_x, emit_y, emit_z, beta_x, beta_y, alpha_x, alpha_y, D_x, Dp_x, D_y, Dp_y, output_folder="./dispsup_plots"):
    
    # -------------------------------------------------------------------
    # CONVERT TO ARRAYS FOR PLOTTING
    # -------------------------------------------------------------------
    z_positions = np.array(z_positions)
    order = np.argsort(z_positions)

    z_positions = z_positions[order]
    emit_x = np.array(emit_x)[order]
    emit_y = np.array(emit_y)[order]
    beta_x = np.array(beta_x)[order]
    beta_y = np.array(beta_y)[order]
    alpha_x = np.array(alpha_x)[order]
    alpha_y = np.array(alpha_y)[order]
    D_x = np.array(D_x)[order]
    Dp_x = np.array(Dp_x)[order]
    D_y = np.array(D_y)[order]
    Dp_y = np.array(Dp_y)[order]
    emit_z = np.array(emit_z)[order]

    # -------------------------------------------------------------------
    # PLOTTING
    # -------------------------------------------------------------------
    def make_plot(yvals, ylabel, title, filename, labels=("x", "y")):
        plt.figure(figsize=(7,5))

        # ---- draw magnet shading (already parsed) ----
        for z1, z2, color, label in regions:
            plt.axvspan(z1, z2, color=color, alpha=0.3, label=label)

        # ---- twiss curves ----
        plt.plot(z_positions, yvals[0], 'o-', color="#541352FF", label=f"{labels[0]}-plane")
        plt.plot(z_positions, yvals[1], 's--', color="#3A5E8CFF", label=f"{labels[1]}-plane")

        plt.xlabel("z [mm]")
        plt.ylabel(ylabel)
        plt.title(title)
        plt.grid(True)

        # ---- remove duplicate legend entries ----
        handles, labels = plt.gca().get_legend_handles_labels()
        by_label = dict(zip(labels, handles))
        plt.legend(by_label.values(), by_label.keys())

        plt.tight_layout()
        plt.savefig(os.path.join(output_folder, filename))
        plt.close()


    make_plot((emit_x, emit_y), "Emittance [mm·mrad]",
            "Emittance Evolution", "emittance_evolution.png")

    make_plot((beta_x, beta_y), "β-function [m]",
            "Beta Function Evolution", "beta_evolution.png")

    make_plot((alpha_x, alpha_y), "α-function [–]",
            "Alpha Function Evolution", "alpha_evolution.png")

    make_plot((D_x, D_y), "Dispersion D [m]",
            "Dispersion Function", "dispersion_D.png")

    make_plot((Dp_x, Dp_y), "Dispersion Derivative D' [-]",
            "Dispersion Derivative", "dispersion_Dprime.png")

    print(f"All plots saved in '{output_folder}'")


files = ["vd_start_dispsup.txt", "vd_Q1_dispsup.txt", "vd_D1_dispsup.txt", "particles_after_q2uptc.txt", "particles_after_b.txt"]
z_positions = []
emit_x = []
emit_y = []
emit_z = []
beta_x = []
beta_y= []
alpha_x=[]
alpha_y=[]
D_x=[]
Dp_x=[]
D_y=[]
Dp_y=[]

for i in files:
        df1 = read_trackfile(i)
        z_positions.append(np.mean(df1["z"]))
        x_params1, y_params1, z_emit1 = calc_all_params(df1)
        ex, bx, gx, ax, Dx, Dxp = x_params1
        ey, by, gy, ay, Dy, Dyp = y_params1
        emit_x.append(ex)
        emit_y.append(ey)
        beta_x.append(bx)
        beta_y.append(by)
        alpha_x.append(ax)
        alpha_y.append(ay)
        D_x.append(Dx), Dp_x.append(Dxp), D_y.append(Dy), Dp_y.append(Dyp)
        emit_z.append(z_emit1)

g4bl_files = [
    "G4_FinalCooling_dispsup_Q2_run.g4bl",
    "G4_FinalCooling_dispsup_B_run.g4bl",
]

params = {}
for f in g4bl_files:
    params.update(parse_g4bl_file(f))

regions = build_magnet_regions(params)


twissPlot(z_positions, emit_x, emit_y, emit_z, beta_x, beta_y, alpha_x, alpha_y, D_x, Dp_x, D_y, Dp_y)

# %%
def B_from_theta(theta, L_mm, p_GeV=0.879):
    L_m = L_mm * 1e-3
    return theta * p_GeV / (0.3 * L_m)

# %%
def optimize_dipole_aa(x, df_in, beta_x_ref, beta_y_ref,
                    w_disp=10.0, w_beta=100.0, w_len=5.0,
                    survival_threshold=0.95):

    theta, L_mm, Drift2_length = x

    # compute B from theta
    B_field = B_from_theta(theta, L_mm)

    # hard physical bounds
    if B_field < 0.1 or B_field > 3.0:
        return 1e6 + abs(B_field)

    result = run_dipole(df_in, B_field, L_mm, Drift2_length)
    if result is None or len(result) < 100:
        return 1e6

    mask, *_ = check_dipole_clearance(df_in, B_field, L_mm, 50)
    survival_frac = np.mean(mask)

    if survival_frac < survival_threshold:
        return 1e6 + 1e4*(survival_threshold - survival_frac)

    df_survived = result[mask]
    x_params_d, y_params_d, _ = calc_all_params(df_survived)

    Dx = x_params_d[4]
    beta_x = x_params_d[1]
    beta_y = y_params_d[1]

    # dispersion target
    disp_target = abs(theta * L_mm / 2)
    disp_penalty = ((Dx - disp_target) / disp_target)**2

    # beta mismatch
    beta_penalty = ((beta_x - beta_x_ref)/beta_x_ref)**2 \
                 + ((beta_y - beta_y_ref)/beta_y_ref)**2

    # discourage tiny magnets
    length_penalty = (50.0 / L_mm)**2

    if disp_penalty > 5.0:
        return w_disp * disp_penalty

    val = (
        w_disp * disp_penalty +
        w_beta * beta_penalty +
        w_len  * length_penalty
    )

    print(f"θ={theta:.3f}, L={L_mm:.1f}, B={B_field:.2f}, Obj={val:.3e}")
    return val
x0_dip = [0.15, 200.0, 100.0]  # theta [rad], L [mm], drift [mm]

bounds_dip = [
    (0.05, 0.30),   # bend angle
    (80, 400),      # dipole length
    (20, 1000)      # drift
]

res_dip = minimize(
    optimize_dipole_aa,
    x0_dip,
    args=(df_opt, b_dict['Beta_x'], b_dict['Beta_y']),
    method="Nelder-Mead", bounds=bounds_dip
)

# %%
def beam_size(beta, eps, n_sigma=1):
    """
    Compute full beam width/height in mm for given beta (m) and emittance (mm·mrad)
    """
    sigma = np.sqrt(beta * eps * 1e3)  # convert sigma (mm) = sqrt(m * 1e3 * mm)
    return 2 * n_sigma * sigma
B_width = beam_size(x_params[1], x_params[0])
B_height = beam_size(y_params[1], y_params[0])
print(B_height, B_width)

# %%
def optimize_dipole(x, df_in, beta_x_ref, beta_y_ref, w_disp=10.0, w_beta=1000.0, w_clear=100.0, D_tol=1e-3, survival_threshold=0.95):
    """
    Optimize dipole parameters but only for distributions that survive >= survival_threshold.
    x = [B_field, B_length, Drift2_length]
    """
    B_field, B_length, Drift2_length = x
    total_cost = 0
    # Run G4BL with these parameters
    result = run_dipole(df_in, B_field, B_length, Drift2_length)
    if result is None or len(result) < 100:
        return 1e6 + 10*(
            abs(B_field) + B_length + Drift2_length)

    # Check which particles survive
    mask, r_L_mm, delta_r_mm = check_dipole_clearance(df_in, B_field, B_length, 100/2)
    
    survival_frac = np.mean(mask)
    if survival_frac < survival_threshold:
        # Penalize strongly: configuration not feasible
        return 1e6 + 1e3*(survival_threshold - survival_frac)

    # Compute dispersion & beta from survived particles
    df_survived = result[mask] if isinstance(result, np.ndarray) else result[mask.values]
    x_params_d, y_params_d, _ = calc_all_params(df_survived)
    Dx, beta_x = x_params_d[4], x_params_d[1]
    Dy, beta_y = y_params_d[4], y_params_d[1]

    disp_penalty = Dx**2
    beta_penalty = ((beta_x - beta_x_ref)/beta_x_ref)**2 + ((beta_y - beta_y_ref)/beta_y_ref)**2

    val = w_disp*disp_penalty + w_beta * beta_penalty
    print("OBJECTIVE =", val)
    return val


# initial guess: B_field (T), B_length (mm), Drift2_length (mm)
x0_dip = [1.5, 200.0, 100.0]

# bounds
bounds_dip = [(0.1, 3.0),  # B_field
              (50, 400),   # B_length
              (20, 1000)]  # Drift2_length

res_dip = minimize(optimize_dipole, x0_dip, args=(df_opt, b_dict['Beta_x'], b_dict['Beta_y']),
                method="Nelder-Mead", bounds=bounds_dip)

print("Optimal dipole parameters:", res_dip.x)

# %%
# Run a single case of optimal values
opt_params = {
    "Drift2_length": res_dip.x[2], 
    "Drift2_width": 100,
    "Drift2_height": 100,
    "Drift2_z": (L_centerline + res.x[0] + res.x[5] + res.x[2]) + res_dip.x[2]/2,
    "B1_field": res_dip.x[0],
    "B1_z": (L_centerline + res.x[0] + res.x[5] + res.x[2]) + res_dip.x[2] + res_dip.x[1]/2,
    "B1_end": (L_centerline + res.x[0] + res.x[5] + res.x[2]) + res_dip.x[2] + res_dip.x[1],
    "B1_length": res_dip.x[1],
    "B1_width": 100,
    "B1_height": 100
    }
print(opt_params)
write_input_from_template("G4_FinalCooling_dispsup_B.g4bl", opt_params, "G4_FinalCooling_dispsup_B_opt.g4bl")
if os.path.exists("field_cellB.dat"):
    os.remove("field_cellB.dat")
result = subprocess.run(["g4bl", "G4_FinalCooling_dispsup_B_opt.g4bl"], capture_output=True, text=True, check=True)
df_dip = read_trackfile("particles_after_b.txt")
x_params_dip, y_params_dip, z_emit_dip = calc_all_params(df_dip)
D_dict_dip = {"D_x": x_params_dip[4], "D'_x": x_params_dip[5], "D_y": y_params_dip[4], "D'_y": y_params_dip[5]}
b_dict_dip = {"Beta_x": x_params_dip[1], "Beta_y": y_params_dip[1]}
print(D_dict_dip, r"Epsilon_z: "+str(z_emit_dip), b_dict_dip)

# %% [markdown]
# ## Scrap

# %%
def run_dipole_quad(df, Q1_length, Q1_gradient, B_field, B_length, Drift2_length, Drift3_length, Drift2_z=0, Q_radius=res.x[4], thickness=5):
    """Run dipole simulation with given parameters."""
    params = {
        "Q1_length": Q1_length,
        "Q1_gradient": Q1_gradient,
        "Q1_z": Drift2_z + Drift2_length + B_length + Drift3_length + Q1_length/2,
        "Q1_end": Drift2_z + Drift2_length + B_length + Drift3_length + Q1_length,
        "radius_q": Q_radius,
        "thickness": thickness,
        "Drift2_length": Drift2_length, 
        "Drift2_width": B_width,
        "Drift2_height": B_height,
        "Drift2_z": Drift2_z + Drift2_length/2,
        "B1_field": B_field,
        "B1_z": Drift2_z + Drift2_length + B_length/2,
        "B1_end": Drift2_z + Drift2_length + B_length,
        "B1_length": B_length,
        "B1_width": B_width,
        "B1_height": B_height,
        "Drift3_length": Drift2_length, 
        "Drift3_width": B_width,
        "Drift3_height": B_height,
        "Drift3_z": Drift2_z + Drift2_length + B_length + Drift3_length/2,
    }
    write_input_from_template("G4_FinalCooling_dispsup_BQ.g4bl", params, "G4_FinalCooling_dispsup_BQ_run.g4bl")
    outfile = "G4_FinalCooling_dispsup_BQ_run.g4bl"
    print("=== DEBUG FILE CHECK ===")
    print("Absolute path:", os.path.abspath(outfile))
    print("Last modified:", time.ctime(os.path.getmtime(outfile)))
    print("========================")

    # Print Q1 block robustly (NOT by line number)
    print("---- B BLOCK ----")
    with open(outfile, "r") as f:
        printing = False
        for line in f:
            if line.startswith("genericbend B"):
                printing = True
            if printing:
                print(line.rstrip())
            if printing and line.strip() == "":
                break
    print("-------------------")
    return run_g4beam(df, "G4_FinalCooling_dispsup_BQ_run.g4bl")

# %%
def optimize_dipole_quad(x, df_in, beta_x_ref, beta_y_ref, w_disp=10.0, w_beta=1000.0, w_clear=100.0, D_tol=1e-3, survival_threshold=0.95):
    """
    Optimize dipole parameters but only for distributions that survive >= survival_threshold.
    x = [B_field, B_length, Drift2_length]
    """
    Q_length, Q_gradient, B_field, B_length, Drift2_length, Drift3_length = x
    total_cost = 0
    # Run G4BL with these parameters
    result = run_dipole_quad(df_in, Q_length, Q_gradient, B_field, B_length, Drift2_length, Drift3_length)
    if result is None or len(result) < 100:
        return 1e6

    # Check which particles survive
    mask, r_L_mm, delta_r_mm = check_dipole_clearance(df_in, B_field, B_length, 100/2)
    
    survival_frac = np.mean(mask)
    if survival_frac < survival_threshold:
        # Penalize strongly: configuration not feasible
        return 1e6 + 1e3*(survival_threshold - survival_frac)

    # Compute dispersion & beta from survived particles
    df_survived = result[mask] if isinstance(result, np.ndarray) else result[mask.values]
    x_params_d, y_params_d, _ = calc_all_params(df_survived)
    Dx, beta_x = x_params_d[4], x_params_d[1]
    Dy, beta_y = y_params_d[4], y_params_d[1]

    disp_penalty = Dx**2
    beta_penalty = ((beta_x - beta_x_ref)/beta_x_ref)**2 + ((beta_y - beta_y_ref)/beta_y_ref)**2

    val = w_disp*disp_penalty + w_beta * beta_penalty
    print("OBJECTIVE =", val)
    return val


# initial guess: Q_length (mm), Q_gradient (T/m), B_field (T), B_length (mm), Drift2_length (mm), Drift3_length (mm)
x0_dipq = [200.0, 10, 1.5, 200.0, 100.0, 100.0]

# bounds
bounds_dipq = [(20, 1000),(1, 30), (0.1, 3.0),
            (50, 400),(20, 1000),(20, 1000)]

res_dipq = minimize(optimize_dipole_quad, x0_dipq, args=(df_opt, b_dict['Beta_x'], b_dict['Beta_y']),
                method="Nelder-Mead", bounds=bounds_dipq)

print("Optimal dipole parameters:", res_dipq.x)

# %% [markdown]
# # Phase rotation
#
# The following are taken as constants, as they are primarily constrained by technical limitations. The optimal RF gradient is heavily dependent on both of these.
# - **Drift length**: Longer drift length will give better results
# - **RF frequency**: Lower frequency will usually give better results. There's an optimal point, but I believe it's lower than practical
#
# We then optimize the RF phase, cavity length, and gradient

# %%
drift_length = 16000
rf_freq = 0.025

# Function to optimize
def func(x):
    rf_phase, rf_length, rf_grad = x
    drift_to_start = drift_length-rf_length/2
    post_drift = recenter_t(z_prop(no_transverse, drift_to_start))
    post_cavity = run_g4beam(post_drift, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad, nparticles=len(no_transverse))
    pre_w2 = recombine_transverse(post_cavity, reverse_transverse)
    return np.std(p_total(cut_pz(pre_w2)))

# Run optimization
optim_result = minimize(func, [0, 4700, 7], method="Nelder-Mead", bounds=((-90, 90), (2000, 6000), (1, 10)), options=dict(fatol=1e-6))

# Get results
rf_phase, rf_length, rf_grad = optim_result.x
print(f"Phase = {rf_phase:.2f} deg\nLength = {rf_length:.0f} mm\nGradient = {rf_grad:.2f} MV/m\nFrequency = {rf_freq*1000:.1f} MHz")

# Runs a single case with the optimal parameters and add the transverse back in
drift_to_start = drift_length-rf_length/2
post_drift = recenter_t(z_prop(no_transverse, drift_to_start))
post_cavity = cut_pz(recenter_t(run_g4beam(post_drift, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad)))
pre_w2 = recombine_transverse(post_cavity, reverse_transverse)
print_all_params(pre_w2)

# %% [markdown]
# # Second wedge
#
# Optimize the second wedge in the same way as the first

# %%
# Function to optimize
def func(x):
    length, angle = x
    return emittances(cut_outliers(run_distribution(pre_w2, length, angle, vd_dist, axis=1)))[1]

# Run optimization
optim_result = minimize(func, [5.5, 45], method="Nelder-Mead", bounds=((1, 10), (30, 70)), options=dict(fatol=1e-6))

# Get results
w2_length, w2_angle = optim_result.x
print(f"Length = {w2_length:.2f} mm\nAngle = {w2_angle:.1f} deg")

# Runs a single case with the optimal parameters
post_w2 = run_distribution(pre_w2, w2_length, w2_angle, vd_dist, axis=1)
print_all_params(post_w2)

# Do cuts at this point
post_w2_cut = cut_outliers(post_w2)
print_all_params(post_w2_cut)

# %% [markdown]
# # Save/load result

# %%
# Parameter list
PARAMS = [
    "t_emit",
    "momentum",
    "beta",
    "alpha",
    "l_emit",
    "pz_std",
    "vd_dist",
    "w1_length",
    "w1_angle",
    "w2_length",
    "w2_angle",
    "drift_length",
    "rf_freq",
    "rf_phase",
    "rf_length",
    "rf_grad"
]

# %%
# Show parameters
{k:globals()[k] for k in PARAMS}

# %%
# Input parameters
parameters = {'t_emit': 0.145,
 'momentum': 100,
 'beta': 0.03,
 'alpha': 1,
 'l_emit': 1,
 'pz_std': 1,
 'vd_dist': 24,
 'w1_length': 9.20751061747799,
 'w1_angle': 49.78231333988419,
 'w2_length': 6.724887901827298,
 'w2_angle': 42.245718529695516,
 'drift_length': 16000,
 'rf_freq': 0.025,
 'rf_phase': 0.001987066319906211,
 'rf_length': 5153.756925848655,
 'rf_grad': 4.046563465382562}
globals().update(parameters)

# %%
# Save parameter set
parameters = {k:globals()[k] for k in PARAMS}
filename = "results/parameters/"+input("Enter run name to save: ")+".pkl"
with open(filename, "wb+") as file:
    pickle.dump(parameters, file)
    print("Saved to", filename)

# %%
# Load parameter set
filename = "results/parameters/"+input("Enter run name to load: ")+".pkl"
with open(filename, "rb+") as file:
    parameters = pickle.load(file)
    globals().update(parameters)
    print("Loaded from", filename)

# %%
# View parameter set
filename = "results/parameters/"+input("Enter run name to view: ")+".pkl"
with open(filename, "rb+") as file:
    parameters = pickle.load(file)
    print("Viewing", filename)
    print(parameters)

# %%
vd_dist=36

# %% [markdown]
# # Analyze single case

# %%
# Tweak parameters
rf_phase += 180
rf_phase

# %%
# Run best case
pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=100000)
pre_w1["PDGid"] = -13
print("Running first wedge")
post_w1 = run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0)
post_correct = remove_dispersion(post_w1)
reverse_transverse = post_correct.copy(deep=True)
reverse_transverse["Px"] *= -1
reverse_transverse["Py"] *= -1
drift_to_start = drift_length-rf_length/2
post_drift = recenter_t(z_prop(post_correct, drift_to_start))
no_transverse = remove_transverse(post_drift)
print("Running RF cavity")
post_cavity = cut_pz(recenter_t(run_g4beam(no_transverse, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad, nparticles=len(no_transverse))), tails=0.15)
pre_w2 = recombine_transverse(post_cavity, reverse_transverse)
print("Running second wedge")
post_w2 = run_distribution(pre_w2, w2_length, w2_angle, vd_dist, axis=1)
post_w2_cut = recenter_t(cut_outliers(post_w2))
print_all_params(post_w2_cut)
beep()

# %%
# Make some phase space plots
PLOT_TARGETS = [pre_w1, post_correct, post_drift, pre_w2, remove_dispersion(post_w2_cut)]
PLOT_TITLES = ["Initial distribution", "After first wedge", "After drift", "After RF cavity and refocusing", "After second wedge"]
PLOT_AXES = [("x", "Px"), ("y", "Py"), ("t", "Pz")]
PLOT_LABELS = [("x (mm)", "Px (MeV/c)"), ("y (mm)", "Py (MeV/c)"), ("t (ns)", "Pz (MeV/c)")]
T_RANGES = [[-7.5, 7.5], [-30, 30]]
L_RANGES = [[-10, 10], [40, 110]]

fig, axes = plt.subplots(nrows = len(PLOT_AXES), ncols = len(PLOT_TARGETS), layout="constrained")
fig.set_size_inches(16, 8)
for i, df in enumerate(PLOT_TARGETS):
    axes[0][i].set_title(PLOT_TITLES[i])
    for j, ((xaxis, yaxis), (xlabel, ylabel)) in enumerate(zip(PLOT_AXES, PLOT_LABELS)):
        ax = axes[j][i]
        ax.hist2d(df[xaxis], df[yaxis], bins=50, range=L_RANGES if j == 2 else T_RANGES)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(ylabel)
# fig.suptitle(f"temit={t_emit*1000:.0f} μm, σP={pz_std:.2f} MeV/c")

# %%
SAMPLE_DISTS = [pre_w1, post_correct, pre_w2, remove_dispersion(post_w2_cut)]
SAMPLE_TITLES = ["Initial distribution", "After first wedge", "After RF cavity + 10% cut", "After second wedge + 4 sigma cut"]
VARIABLE_NAMES = ["x emit (μm)", "y emit (μm)", "z-emit (mm)", "sigma-p (MeV/c)", "sigma-t (ns)", "Beam remaining"]
VARIABLE_FUNCS = [
    lambda df: emittances(df)[0]*1000,
    lambda df: emittances(df)[1]*1000,
    lambda df: emittances(df)[2],
    lambda df: np.std(p_total(df)),
    lambda df: np.std(df["t"]),
    lambda df: len(df) / len(pre_w1)
]
table = [[n] + [y(x) for y in VARIABLE_FUNCS] for n, x in zip(SAMPLE_TITLES, SAMPLE_DISTS)]
print(tabulate(
    table,
    headers=["Stage"] + VARIABLE_NAMES,
    # tablefmt="latex_raw",
    floatfmt=(None, ".1f", ".1f", ".3f", ".3f", ".3f", ".1%")
))

# %% [markdown]
# ## Anomaly investigation
#
# This is going insane

# %%
momentum = 100
pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
pre_w1["PDGid"] = -13
run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0, debug=True)

# %%
momentums = list(range(50, 101, 10))
results = list() #  Yeah we're back to the old days now
for momentum in tqdm(momentums):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
    pre_w1["PDGid"] = -13
    results.append(run_distribution(pre_w1, w1_length, w1_angle, vd_dist, axis=0))
beep()

# %%
fig, axs = plt.subplots(nrows = 3, ncols = 2)
axs = axs.flatten()
fig.set_size_inches(10, 12)
for momentum, x, ax in zip(momentums, results, axs):
    ax.hist(p_total(x), bins=200, range=(40, 110))
    ax.axvline(momentum, color="red", linestyle="--")
pass

# %%
results[0]["PDGid"]

# %%
angles = [30, 40, 50, 60]
momentum = 70
results1 = list() #  Yeah we're back to the old days now
for angle in tqdm(angles):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
    results1.append(run_distribution(pre_w1, w1_length, angle, vd_dist, axis=0))
beep()

# %%
fig, axs = plt.subplots(nrows = 2, ncols = 2)
axs = axs.flatten()
fig.set_size_inches(10, 8)
for angle, x, ax in zip(angles, results1, axs):
    ax.hist(p_total(x), bins=200, range=(40, 110))
    ax.axvline(momentum, color="red", linestyle="--")
    ax.set_title(f"{angle} deg")
pass

# %%
lengths = [3, 6, 9, 12]
momentum = 70
results2 = list() #  Yeah we're back to the old days now
for length in tqdm(lengths):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit, N=12000)
    results2.append(run_distribution(pre_w1, length, w1_angle, 40, axis=0))
beep()

# %%
fig, axs = plt.subplots(nrows = 2, ncols = 2)
axs = axs.flatten()
fig.set_size_inches(10, 8)
for length, x, ax in zip(lengths, results2, axs):
    ax.hist(p_total(x), bins=200, range=(40, 110))
    ax.axvline(momentum, color="red", linestyle="--")
    ax.set_title(f"{length} mm")
pass

# %%
fig, ax = plt.subplots()
ax.hist(p_total(post_w2_cut), bins=200)
select_bottom, select_top = 60.5, 62.5
ax.axvline(select_bottom, color="r", linestyle="--")
ax.axvline(select_top, color="r", linestyle="--")
anomaly = post_w2_cut[(p_total(post_w2_cut) < select_top) & (p_total(post_w2_cut) > select_bottom)]
pre_anomaly = pre_w2.loc[anomaly["EventID"]]
post_anomaly = run_distribution(pre_anomaly, w2_length, w2_angle, vd_dist, axis=1)

# %%
# Show the anomaly
PLOT_TARGETS = [pre_w2, pre_anomaly, post_w2_cut, post_anomaly]
PLOT_TITLES = ["Before (full)", "Before (anomalous)", "After (full)", "After (anomalous)"]
PLOT_AXES = [("x", "Px"), ("y", "Py"), ("t", "Pz")]
PLOT_LABELS = [("x (mm)", "Px (MeV/c)"), ("y (mm)", "Py (MeV/c)"), ("t (ns)", "Pz (MeV/c)")]
T_RANGES = [[-7.5, 7.5], [-30, 30]]
L_RANGES = [[-10, 10], [40, 110]]

fig, axes = plt.subplots(nrows = len(PLOT_AXES), ncols = len(PLOT_TARGETS), layout="constrained")
fig.set_size_inches(10, 8)
for i, df in enumerate(PLOT_TARGETS):
    axes[0][i].set_title(PLOT_TITLES[i])
    for j, ((xaxis, yaxis), (xlabel, ylabel)) in enumerate(zip(PLOT_AXES, PLOT_LABELS)):
        ax = axes[j][i]
        ax.hist2d(df[xaxis], df[yaxis], bins=50, range=L_RANGES if j == 2 else T_RANGES)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(ylabel)
# fig.suptitle(f"temit={t_emit*1000:.0f} μm, σP={pz_std:.2f} MeV/c")

# %%
run_distribution(pre_w1, w2_length, w2_angle, vd_dist, axis=1, debug=True)

# %%
fig, ax = plt.subplots()
ax.hist(post_w2_cut["y"], bins=200)
pass

# %%
p_ranges = [(58.5+2*i, 60.5+2*i) for i in range(7)]

fig, axes = plt.subplots(ncols = 2, nrows = len(p_ranges), layout="constrained")
fig.set_size_inches(6, 3*len(p_ranges))
for i, r in enumerate(p_ranges):
    ax = axes[i][0]
    ax.hist(p_total(post_w2_cut), bins=200, range=(55, 90))
    select_bottom, select_top = r
    ax.axvline(select_bottom, color="r", linestyle="--")
    ax.axvline(select_top, color="r", linestyle="--")

    selected = post_w2_cut[(p_total(post_w2_cut) < select_top) & (p_total(post_w2_cut) > select_bottom)]
    pre_selected = pre_w2.loc[selected["EventID"]]

    ax = axes[i][1]
    ax.hist2d(pre_selected["y"], pre_selected["Py"], bins=50, range=T_RANGES)
    ax.set_xlabel("y")
    ax.set_ylabel("Py")

# %% [markdown]
# ## Two optimal wedges (regenerated)

# %%
# Range to scan
angles = np.linspace(30, 60, 20)
lengths = np.linspace(5, 11, 20)

# %%
def fun(length, angle):
    return run_distribution(pre_w2, length, angle, 24, axis=1)

results = run_scan(fun, (lengths, angles), filename="results/second_wedge_length_angle.pkl")
beep()

# %%
def fun(length, angle):
    return run_distribution(pre_w1, length, angle, 24, axis=0)

results = run_scan(fun, (lengths, angles), filename="results/first_wedge_length_angle.pkl")
beep()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, layout="constrained")
fig.set_size_inches(10, 4)

# First wedge

with open("results/first_wedge_length_angle.pkl", "rb") as file:
    results = pickle.load(file)

mesh = np.meshgrid(lengths, angles)
meshz = qmap_to_meshgrid(mesh, calc_quantity(lambda df: emittances(cut_outliers(df))[0], results))
meshx, meshy = mesh

cax = ax1.contourf(meshx, meshy, meshz, levels=50)
ax1.set_xlabel("First wedge length (mm)")
ax1.set_ylabel("First wedge half-angle (deg)")
ax1.set_title("First wedge")
plt.colorbar(cax, ax=ax1).set_label("x-emittance (mm)")

ax1.plot(w1_length, w1_angle, 'rx')
ax1.annotate(f"{w1_length:.2f} mm, {w1_angle:.2f} deg", (w1_length, w1_angle), c="red", xytext = (-30, 10), textcoords="offset points")

# Second wedge

with open("results/second_wedge_length_angle.pkl", "rb") as file:
    results = pickle.load(file)

mesh = np.meshgrid(lengths, angles)
meshz = qmap_to_meshgrid(mesh, calc_quantity(lambda df: emittances(cut_outliers(df))[1], results))
meshx, meshy = mesh

cax = ax2.contourf(meshx, meshy, meshz, levels=50)
ax2.set_xlabel("Second wedge length (mm)")
ax2.set_ylabel("Second wedge half-angle (deg)")
ax2.set_title("Second wedge")
plt.colorbar(cax, ax=ax2).set_label("y-emittance (mm)")

ax2.plot(w2_length, w2_angle, 'rx')
ax2.annotate(f"{w2_length:.2f} mm, {w2_angle:.2f} deg", (w2_length, w2_angle), c="red", xytext = (-30, 10), textcoords="offset points")

# %% [markdown]
# ## Frequency and gradient (regenerated)

# %%
rf_freqs = np.linspace(0.01, 0.06, 20)
rf_grads = np.linspace(1,10,20)

# %%
# get no_transverse from above

def fun(rf_grad, rf_freq):
    return recenter_t(run_g4beam(no_transverse, "G4_RFCavity.g4bl", RF_length=rf_length, frfcool=rf_freq, ficool=rf_phase, Vrfcool=rf_grad))

results = run_scan(fun, (rf_grads, rf_freqs), "results/rf_grad_freq_16m.pkl")

# %%
with open("results/rf_grad_freq_16m.pkl", "rb") as file:
    results = pickle.load(file)
mesh = np.meshgrid(rf_grads, rf_freqs)
meshz = qmap_to_meshgrid(mesh, calc_quantity(lambda df: np.std(cut_pz(df)["Pz"]), results))
meshx, meshy = mesh

meshy = 1000 * meshy # Scale to MHz

fig, ax = plt.subplots()
cax = ax.contourf(meshx, meshy, meshz, levels=50)
ax.set_xlabel("RF gradient (MV/m)")
ax.set_ylabel("RF frequency (MHz)")
plt.colorbar(cax).set_label("sigma-Pz (MeV/c)")

minpoint = np.unravel_index(np.argmin(meshz), meshz.shape)
ax.plot(rf_grad, rf_freq*1000, 'rx')
ax.annotate(f"{rf_grad:.2f} MV/m, {rf_freq*1000:.1f} MHz", (rf_grad, rf_freq*1000), c="red", xytext = (-30, 10), textcoords="offset points")

# %% [markdown]
# # Scan of optimal over pz_std

# %%
t_emit = 0.110  # mm
momentum = 100  # MeV/c
beta = 0.03    # m
alpha = 1     # dimensionless
l_emit = 1      # mm
pz_stds = np.linspace(0.8, 1.1, 6)
vd_dist = 24    # mm

# %%
# Meta-function (containing optimization)
def metafun(pz_std):
    pre_w1 = gen_distribution((beta, alpha, t_emit, 0, 0), (beta, alpha, t_emit, 0, 0), momentum, pz_std, z_emit=l_emit)
    
    def func(x):
        length, angle = x
        return emittances(cut_outliers(run_distribution(pre_w1, length, angle, vd_dist, axis=0)))[0]

    return scipy.optimize.minimize(func, [7.5, 45], method="Nelder-Mead", bounds=((1, 10), (30, 70)), options=dict(fatol=2e-4))

run_scan(metafun, (pz_stds,), filename="results/optimal_scan.pkl", trials=5)

# %%
with open("results/optimal_scan.pkl", "rb") as file:
    results = pickle.load(file)

def optim_fun(optim_result):
    return optim_result.fun

def optim_x1(optim_result):
    return optim_result.x[0]

def optim_x2(optim_result):
    return optim_result.x[1]


fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, layout="constrained")
fig.set_size_inches(10, 4)
ax1.errorbar(*qmap_to_arrays(pz_stds, calc_quantity(optim_fun, results)), capsize=2)
ax1.set_xlabel(r"$\sigma p$ (MeV/c)")
ax1.set_ylabel("minimum x emit (mm)")

ax2.errorbar(*qmap_to_arrays(pz_stds, calc_quantity(optim_x1, results)), capsize=2)
ax2.set_xlabel(r"$\sigma p$ (MeV/c)")
ax2.set_ylabel("optimal length (mm)")

ax3.errorbar(*qmap_to_arrays(pz_stds, calc_quantity(optim_x2, results)), capsize=2)
ax3.set_xlabel(r"$\sigma p$ (MeV/c)")
ax3.set_ylabel("optimal half-angle (deg)")

# %%
calc_quantity(optim_fun, results)

# %%
1e-5

# %%
calc_quantity(optim_fun, results)[(0.8,)][1] / 1e-4
